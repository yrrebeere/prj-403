# %%
import pandas as pd
import numpy as np
from darts import TimeSeries
from darts.models import XGBModel
from sklearn.metrics import mean_squared_error, mean_squared_log_error
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../Data/Kaggle/StoreSales/train_darts.csv", parse_dates=["date"])

# %%
df.head()
# Out:
#         date  store_nbr  family  sales  onpromotion  typeholiday  dcoilwtico  \
# 0 2013-01-01          1       0    0.0            0            3       93.14
# 1 2013-01-01          1       1    0.0            0            3       93.14
# 2 2013-01-01          1       2    0.0            0            3       93.14
# 3 2013-01-01          1       3    0.0            0            3       93.14
# 4 2013-01-01          1       4    0.0            0            3       93.14
#
#    city  state  typestores  cluster  day_of_week  day  month  year
# 0    18     12           3       13            2    1      1  2013
# 1    18     12           3       13            2    1      1  2013
# 2    18     12           3       13            2    1      1  2013
# 3    18     12           3       13            2    1      1  2013
# 4    18     12           3       13            2    1      1  2013

# %%
unique_combinations = df[['store_nbr', 'family']].drop_duplicates()

# %%
total_rmse = 0
total_rmsle = 0
num_models = 0

# %%
trained_models = {}

# %%
for index, row in unique_combinations.iterrows():
    store_nbr = row['store_nbr']
    family = row['family']
    
    print(f"\nTraining model for store {store_nbr} and family {family}...")
    
    df_subset = df[(df['store_nbr'] == store_nbr) & (df['family'] == family)]
    
    ts = TimeSeries.from_dataframe(df_subset, value_cols=["sales"])

    training_size = int(len(ts) - 30)
    
    train = ts[:training_size]
    val = ts[training_size:]

    model = XGBModel(lags=2)
    model.fit(train)

    trained_models[(store_nbr, family)] = model

    predictions = model.predict(n=len(val))

    val = val.pd_series().tolist()
    predictions = predictions.pd_series().tolist()

    predictions = np.maximum(predictions, 0)

    rmse = np.sqrt(mean_squared_error(val, predictions))
    rmsle = np.sqrt(mean_squared_error(np.log1p(val), np.log1p(predictions)))

    total_rmse += rmse
    total_rmsle += rmsle
    num_models += 1

    print(f"Root Mean Squared Error (RMSE): {rmse}")
    print(f"Root Mean Squared Logarithmic Error (RMSLE): {rmsle}")

    plt.figure(figsize=(12, 6))
    plt.plot(val, label='Actual')
    plt.plot(predictions, label='Predictions')
    plt.title(f"Model for store {store_nbr} and family {family}")
    plt.legend()
    plt.savefig(f"XGBoost/Monthly/Monthly_M06.6_store{store_nbr}_family{family}.png")
    plt.close()
# Out:
# Training model for store 1 and family 0...
# Root Mean Squared Error (RMSE): 3.448778888823363
# Root Mean Squared Logarithmic Error (RMSLE): 0.6814377810818175
#
# Training model for store 1 and family 1...
# Root Mean Squared Error (RMSE): 1.659708120585598e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6597081205855979e-16
#
# Training model for store 1 and family 2...
# Root Mean Squared Error (RMSE): 2.1418045416874447
# Root Mean Squared Logarithmic Error (RMSLE): 0.43380482276917554
#
# Training model for store 1 and family 3...
# Root Mean Squared Error (RMSE): 601.8636725094966
# Root Mean Squared Logarithmic Error (RMSLE): 0.35802145636339
#
# Training model for store 1 and family 4...
# Root Mean Squared Error (RMSE): 0.2512175420770836
# Root Mean Squared Logarithmic Error (RMSLE): 0.1731905907980404
#
# Training model for store 1 and family 5...
# Root Mean Squared Error (RMSE): 121.50545595989772
# Root Mean Squared Logarithmic Error (RMSLE): 0.4640437937474404
#
# Training model for store 1 and family 6...
# Root Mean Squared Error (RMSE): 9.051274604101584
# Root Mean Squared Logarithmic Error (RMSLE): 0.9413110837720889
#
# Training model for store 1 and family 7...
# Root Mean Squared Error (RMSE): 221.38151724604919
# Root Mean Squared Logarithmic Error (RMSLE): 0.467647946659452
#
# Training model for store 1 and family 8...
# Root Mean Squared Error (RMSE): 243.16901527588684
# Root Mean Squared Logarithmic Error (RMSLE): 0.4654732463689286
#
# Training model for store 1 and family 9...
# Root Mean Squared Error (RMSE): 42.34133171650723
# Root Mean Squared Logarithmic Error (RMSLE): 0.3968914557919337
#
# Training model for store 1 and family 10...
# Root Mean Squared Error (RMSE): 38.81054082728551
# Root Mean Squared Logarithmic Error (RMSLE): 0.35022303916109176
#
# Training model for store 1 and family 11...
# Root Mean Squared Error (RMSE): 48.65777584422798
# Root Mean Squared Logarithmic Error (RMSLE): 0.4857275338836214
#
# Training model for store 1 and family 12...
# Root Mean Squared Error (RMSE): 915.8695777753262
# Root Mean Squared Logarithmic Error (RMSLE): 0.4945334870929293
#
# Training model for store 1 and family 13...
# Root Mean Squared Error (RMSE): 12.438487953819534
# Root Mean Squared Logarithmic Error (RMSLE): 0.5557797304358713
#
# Training model for store 1 and family 14...
# Root Mean Squared Error (RMSE): 1.587023362751939
# Root Mean Squared Logarithmic Error (RMSLE): 0.6279640484800796
#
# Training model for store 1 and family 15...
# Root Mean Squared Error (RMSE): 15.489645556517173
# Root Mean Squared Logarithmic Error (RMSLE): 0.8151321270110368
#
# Training model for store 1 and family 16...
# Root Mean Squared Error (RMSE): 16.974098216608777
# Root Mean Squared Logarithmic Error (RMSLE): 1.0087979783451047
#
# Training model for store 1 and family 17...
# Root Mean Squared Error (RMSE): 1.0665285790035148
# Root Mean Squared Logarithmic Error (RMSLE): 0.49248554279866075
#
# Training model for store 1 and family 18...
# Root Mean Squared Error (RMSE): 68.66044689279136
# Root Mean Squared Logarithmic Error (RMSLE): 0.46574243826839357
#
# Training model for store 1 and family 19...
# Root Mean Squared Error (RMSE): 9.218892834143945
# Root Mean Squared Logarithmic Error (RMSLE): 0.6667438327561471
#
# Training model for store 1 and family 20...
# Root Mean Squared Error (RMSE): 13.203631148026098
# Root Mean Squared Logarithmic Error (RMSLE): 0.8603452203779092
#
# Training model for store 1 and family 21...
# Root Mean Squared Error (RMSE): 5.895026884870767
# Root Mean Squared Logarithmic Error (RMSLE): 0.9481772959746023
#
# Training model for store 1 and family 22...
# Root Mean Squared Error (RMSE): 51.18932318197713
# Root Mean Squared Logarithmic Error (RMSLE): 1.2405421265346126
#
# Training model for store 1 and family 23...
# Root Mean Squared Error (RMSE): 4.108135617835949
# Root Mean Squared Logarithmic Error (RMSLE): 0.545770280570657
#
# Training model for store 1 and family 24...
# Root Mean Squared Error (RMSE): 202.47494963261948
# Root Mean Squared Logarithmic Error (RMSLE): 0.6874801930330945
#
# Training model for store 1 and family 25...
# Root Mean Squared Error (RMSE): 70.6286123418843
# Root Mean Squared Logarithmic Error (RMSLE): 0.5268089548135182
#
# Training model for store 1 and family 26...
# Root Mean Squared Error (RMSE): 2.718203477878573
# Root Mean Squared Logarithmic Error (RMSLE): 0.5362033479717254
#
# Training model for store 1 and family 27...
# Root Mean Squared Error (RMSE): 4.922141596065693
# Root Mean Squared Logarithmic Error (RMSLE): 0.7538803451134203
#
# Training model for store 1 and family 28...
# Root Mean Squared Error (RMSE): 116.945761692461
# Root Mean Squared Logarithmic Error (RMSLE): 0.44136131251979865
#
# Training model for store 1 and family 29...
# Root Mean Squared Error (RMSE): 34.197583172001934
# Root Mean Squared Logarithmic Error (RMSLE): 0.551516941259133
#
# Training model for store 1 and family 30...
# Root Mean Squared Error (RMSE): 1056.6782993339218
# Root Mean Squared Logarithmic Error (RMSLE): 1.4970817583835645
#
# Training model for store 1 and family 31...
# Root Mean Squared Error (RMSE): 0.10400722175836563
# Root Mean Squared Logarithmic Error (RMSLE): 0.09894648928130334
#
# Training model for store 1 and family 32...
# Root Mean Squared Error (RMSE): 15.107726300738467
# Root Mean Squared Logarithmic Error (RMSLE): 0.5366329930351248
#
# Training model for store 10 and family 0...
# Root Mean Squared Error (RMSE): 1.995671729307558
# Root Mean Squared Logarithmic Error (RMSLE): 0.8877937086958041
#
# Training model for store 10 and family 1...
# Root Mean Squared Error (RMSE): 0.034870460629463196
# Root Mean Squared Logarithmic Error (RMSLE): 0.03427626007220183
#
# Training model for store 10 and family 2...
# Root Mean Squared Error (RMSE): 2.11089638144869
# Root Mean Squared Logarithmic Error (RMSLE): 0.6431482025142855
#
# Training model for store 10 and family 3...
# Root Mean Squared Error (RMSE): 457.987686035567
# Root Mean Squared Logarithmic Error (RMSLE): 0.3701388639245271
#
# Training model for store 10 and family 4...
# Root Mean Squared Error (RMSE): 1.659708120585598e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6597081205855979e-16
#
# Training model for store 10 and family 5...
# Root Mean Squared Error (RMSE): 30.319878898074215
# Root Mean Squared Logarithmic Error (RMSLE): 0.28838589011898863
#
# Training model for store 10 and family 6...
# Root Mean Squared Error (RMSE): 3.2608504030650285
# Root Mean Squared Logarithmic Error (RMSLE): 0.6501073054953351
#
# Training model for store 10 and family 7...
# Root Mean Squared Error (RMSE): 601.1400797045412
# Root Mean Squared Logarithmic Error (RMSLE): 0.5206390903183246
#
# Training model for store 10 and family 8...
# Root Mean Squared Error (RMSE): 94.30260946298253
# Root Mean Squared Logarithmic Error (RMSLE): 0.3249024157970693
#
# Training model for store 10 and family 9...
# Root Mean Squared Error (RMSE): 89.48594284383833
# Root Mean Squared Logarithmic Error (RMSLE): 0.3704632127077043
#
# Training model for store 10 and family 10...
# Root Mean Squared Error (RMSE): 34.2938636722359
# Root Mean Squared Logarithmic Error (RMSLE): 0.7764468143293496
#
# Training model for store 10 and family 11...
# Root Mean Squared Error (RMSE): 22.557914251104354
# Root Mean Squared Logarithmic Error (RMSLE): 0.4571073508536674
#
# Training model for store 10 and family 12...
# Root Mean Squared Error (RMSE): 771.7803433094859
# Root Mean Squared Logarithmic Error (RMSLE): 0.3142108293328367
#
# Training model for store 10 and family 13...
# Root Mean Squared Error (RMSE): 5.027910241415937
# Root Mean Squared Logarithmic Error (RMSLE): 0.7242010609196398
#
# Training model for store 10 and family 14...
# Root Mean Squared Error (RMSE): 0.7458906558063498
# Root Mean Squared Logarithmic Error (RMSLE): 0.5111404144800665
#
# Training model for store 10 and family 15...
# Root Mean Squared Error (RMSE): 6.886579954148578
# Root Mean Squared Logarithmic Error (RMSLE): 0.6687539143283295
#
# Training model for store 10 and family 16...
# Root Mean Squared Error (RMSE): 3.6516589402338147
# Root Mean Squared Logarithmic Error (RMSLE): 0.4878536151561338
#
# Training model for store 10 and family 17...
# Root Mean Squared Error (RMSE): 0.2713607089172205
# Root Mean Squared Logarithmic Error (RMSLE): 0.2069828659229269
#
# Training model for store 10 and family 18...
# Root Mean Squared Error (RMSE): 51.4834539787824
# Root Mean Squared Logarithmic Error (RMSLE): 0.28924709114127467
# Training model for store 10 and family 19...
# Root Mean Squared Error (RMSE): 4.124485130835482
# Root Mean Squared Logarithmic Error (RMSLE): 0.888670929877987
#
# Training model for store 10 and family 20...
# Root Mean Squared Error (RMSE): 0.0036758265923708677
# Root Mean Squared Logarithmic Error (RMSLE): 0.0036690872518513485
#
# Training model for store 10 and family 21...
# Root Mean Squared Error (RMSE): 2.299877446156977
# Root Mean Squared Logarithmic Error (RMSLE): 0.8783519562572769
#
# Training model for store 10 and family 22...
# Root Mean Squared Error (RMSE): 14.90663151106403
# Root Mean Squared Logarithmic Error (RMSLE): 0.9096937661876597
#
# Training model for store 10 and family 23...
# Root Mean Squared Error (RMSE): 0.5258804634168004
# Root Mean Squared Logarithmic Error (RMSLE): 0.3773259855981518
#
# Training model for store 10 and family 24...
# Root Mean Squared Error (RMSE): 48.07725165642044
# Root Mean Squared Logarithmic Error (RMSLE): 0.26008627764998754
#
# Training model for store 10 and family 25...
# Root Mean Squared Error (RMSE): 52.07943498304908
# Root Mean Squared Logarithmic Error (RMSLE): 0.30171937029907053
#
# Training model for store 10 and family 26...
# Root Mean Squared Error (RMSE): 1.061955321807637
# Root Mean Squared Logarithmic Error (RMSLE): 0.509638551332035
#
# Training model for store 10 and family 27...
# Root Mean Squared Error (RMSE): 2.806600717238604
# Root Mean Squared Logarithmic Error (RMSLE): 0.614392712342827
#
# Training model for store 10 and family 28...
# Root Mean Squared Error (RMSE): 49.87871355755963
# Root Mean Squared Logarithmic Error (RMSLE): 0.32439153892880646
#
# Training model for store 10 and family 29...
# Root Mean Squared Error (RMSE): 9.876882405251939
# Root Mean Squared Logarithmic Error (RMSLE): 0.3649693900525094
#
# Training model for store 10 and family 30...
# Root Mean Squared Error (RMSE): 75.87882735034982
# Root Mean Squared Logarithmic Error (RMSLE): 0.281836875291187
#
# Training model for store 10 and family 31...
# Root Mean Squared Error (RMSE): 3.8871880107147296
# Root Mean Squared Logarithmic Error (RMSLE): 0.842092821085329
#
# Training model for store 10 and family 32...
# Root Mean Squared Error (RMSE): 2.5252303933696423
# Root Mean Squared Logarithmic Error (RMSLE): 0.8208608934045268
#
# Training model for store 11 and family 0...
# Root Mean Squared Error (RMSE): 4.528691190351305
# Root Mean Squared Logarithmic Error (RMSLE): 0.5304793439836545
#
# Training model for store 11 and family 1...
# Root Mean Squared Error (RMSE): 0.4191466709989405
# Root Mean Squared Logarithmic Error (RMSLE): 0.28757583938945136
#
# Training model for store 11 and family 2...
# Root Mean Squared Error (RMSE): 2.3072575751926703
# Root Mean Squared Logarithmic Error (RMSLE): 0.3824969540467262
#
# Training model for store 11 and family 3...
# Root Mean Squared Error (RMSE): 955.596413566843
# Root Mean Squared Logarithmic Error (RMSLE): 0.20012654007797323
#
# Training model for store 11 and family 4...
# Root Mean Squared Error (RMSE): 1.659708120585598e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6597081205855979e-16
#
# Training model for store 11 and family 5...
# Root Mean Squared Error (RMSE): 291.6433502263284
# Root Mean Squared Logarithmic Error (RMSLE): 0.28292282597888957
#
# Training model for store 11 and family 6...
# Root Mean Squared Error (RMSE): 7.369701577415887
# Root Mean Squared Logarithmic Error (RMSLE): 0.4697468371847532
#
# Training model for store 11 and family 7...
# Root Mean Squared Error (RMSE): 457.25497111126685
# Root Mean Squared Logarithmic Error (RMSLE): 0.22737492233715198
#
# Training model for store 11 and family 8...
# Root Mean Squared Error (RMSE): 144.59009479018428
# Root Mean Squared Logarithmic Error (RMSLE): 0.2322914962115247
#
# Training model for store 11 and family 9...
# Root Mean Squared Error (RMSE): 118.9056186928821
# Root Mean Squared Logarithmic Error (RMSLE): 0.23639463671601268
#
# Training model for store 11 and family 10...
# Root Mean Squared Error (RMSE): 247.95521043206062
# Root Mean Squared Logarithmic Error (RMSLE): 0.7419452088852984
#
# Training model for store 11 and family 11...
# Root Mean Squared Error (RMSE): 43.1218531051043
# Root Mean Squared Logarithmic Error (RMSLE): 0.4944473566902088
#
# Training model for store 11 and family 12...
# Root Mean Squared Error (RMSE): 2269.076443106523
# Root Mean Squared Logarithmic Error (RMSLE): 0.3314200321196543
#
# Training model for store 11 and family 13...
# Root Mean Squared Error (RMSE): 26.32353555489785
# Root Mean Squared Logarithmic Error (RMSLE): 0.9006118011002053
#
# Training model for store 11 and family 14...
# Root Mean Squared Error (RMSE): 0.9819544452179919
# Root Mean Squared Logarithmic Error (RMSLE): 0.5122686740770442
#
# Training model for store 11 and family 15...
# Root Mean Squared Error (RMSE): 26.077324262261914
# Root Mean Squared Logarithmic Error (RMSLE): 0.8037669266219
#
# Training model for store 11 and family 16...
# Root Mean Squared Error (RMSE): 10.115477135075118
# Root Mean Squared Logarithmic Error (RMSLE): 0.4616359955507027
#
# Training model for store 11 and family 17...
# Root Mean Squared Error (RMSE): 0.5940401924902373
# Root Mean Squared Logarithmic Error (RMSLE): 0.4558647149305836
#
# Training model for store 11 and family 18...
# Root Mean Squared Error (RMSE): 171.15614822928686
# Root Mean Squared Logarithmic Error (RMSLE): 0.31017429261945606
#
# Training model for store 11 and family 19...
# Root Mean Squared Error (RMSE): 10.394369286455046
# Root Mean Squared Logarithmic Error (RMSLE): 0.7004048056263831
#
# Training model for store 11 and family 20...
# Root Mean Squared Error (RMSE): 2.0875903968733347
# Root Mean Squared Logarithmic Error (RMSLE): 0.6839186239991594
#
# Training model for store 11 and family 21...
# Root Mean Squared Error (RMSE): 5.762817578723385
# Root Mean Squared Logarithmic Error (RMSLE): 0.4828813940371685
#
# Training model for store 11 and family 22...
# Root Mean Squared Error (RMSE): 29.893925044371578
# Root Mean Squared Logarithmic Error (RMSLE): 0.7447940969417092
#
# Training model for store 11 and family 23...
# Root Mean Squared Error (RMSE): 2.5117084226654107
# Root Mean Squared Logarithmic Error (RMSLE): 0.7147788247552894
#
# Training model for store 11 and family 24...
# Root Mean Squared Error (RMSE): 172.40127504835425
# Root Mean Squared Logarithmic Error (RMSLE): 0.26233821677459046
#
# Training model for store 11 and family 25...
# Root Mean Squared Error (RMSE): 155.5918839951905
# Root Mean Squared Logarithmic Error (RMSLE): 0.3869793029458561
#
# Training model for store 11 and family 26...
# Root Mean Squared Error (RMSE): 2.7485606019114863
# Root Mean Squared Logarithmic Error (RMSLE): 0.5988374381132509
#
# Training model for store 11 and family 27...
# Root Mean Squared Error (RMSE): 6.341333443284176
# Root Mean Squared Logarithmic Error (RMSLE): 0.388436858215615
#
# Training model for store 11 and family 28...
# Root Mean Squared Error (RMSE): 189.12214949226257
# Root Mean Squared Logarithmic Error (RMSLE): 0.45042089081430614
#
# Training model for store 11 and family 29...
# Root Mean Squared Error (RMSE): 36.28333803657349
# Root Mean Squared Logarithmic Error (RMSLE): 0.3793246931746868
#
# Training model for store 11 and family 30...
# Root Mean Squared Error (RMSE): 595.9890027634962
# Root Mean Squared Logarithmic Error (RMSLE): 0.3983959913378858
#
# Training model for store 11 and family 31...
# Root Mean Squared Error (RMSE): 15.651898464796592
# Root Mean Squared Logarithmic Error (RMSLE): 1.318685689207303
#
# Training model for store 11 and family 32...
# Root Mean Squared Error (RMSE): 7.488000695760407
# Root Mean Squared Logarithmic Error (RMSLE): 0.6075988756839008
#
# Training model for store 12 and family 0...
# Root Mean Squared Error (RMSE): 3.3311744001557644
# Root Mean Squared Logarithmic Error (RMSLE): 0.5139345599706182
#
# Training model for store 12 and family 1...
# Root Mean Squared Error (RMSE): 0.07303179055452347
# Root Mean Squared Logarithmic Error (RMSLE): 0.07048809093988649
#
# Training model for store 12 and family 2...
# Root Mean Squared Error (RMSE): 0.9564731100852987
# Root Mean Squared Logarithmic Error (RMSLE): 0.510635613548686
#
# Training model for store 12 and family 3...
# Root Mean Squared Error (RMSE): 417.8807091292601
# Root Mean Squared Logarithmic Error (RMSLE): 0.25150756179791556
#
# Training model for store 12 and family 4...
# Root Mean Squared Error (RMSE): 1.659708120585598e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6597081205855979e-16
#
# Training model for store 12 and family 5...
# Root Mean Squared Error (RMSE): 44.171857625851786
# Root Mean Squared Logarithmic Error (RMSLE): 0.23700106879256022
#
# Training model for store 12 and family 6...
# Root Mean Squared Error (RMSE): 13.01831267279496
# Root Mean Squared Logarithmic Error (RMSLE): 0.7528244012375341
#
# Training model for store 12 and family 7...
# Root Mean Squared Error (RMSE): 888.5312367377138
# Root Mean Squared Logarithmic Error (RMSLE): 0.6185015422985392
#
# Training model for store 12 and family 8...
# Root Mean Squared Error (RMSE): 107.88939557304805
# Root Mean Squared Logarithmic Error (RMSLE): 0.26438348143378143
#
# Training model for store 12 and family 9...
# Root Mean Squared Error (RMSE): 36.84878221554678
# Root Mean Squared Logarithmic Error (RMSLE): 0.169644385293408
#
# Training model for store 12 and family 10...
# Root Mean Squared Error (RMSE): 56.7236406346848
# Root Mean Squared Logarithmic Error (RMSLE): 0.7487271143546183
#
# Training model for store 12 and family 11...
# Root Mean Squared Error (RMSE): 21.090919153344633
# Root Mean Squared Logarithmic Error (RMSLE): 0.4545031447651545
#
# Training model for store 12 and family 12...
# Root Mean Squared Error (RMSE): 570.3659210696447
# Root Mean Squared Logarithmic Error (RMSLE): 0.20518658896164643
#
# Training model for store 12 and family 13...
# Root Mean Squared Error (RMSE): 6.865411405913869
# Root Mean Squared Logarithmic Error (RMSLE): 0.6405369939401062
#
# Training model for store 12 and family 14...
# Root Mean Squared Error (RMSE): 0.8491742167726736
# Root Mean Squared Logarithmic Error (RMSLE): 0.5596443551982381
#
# Training model for store 12 and family 15...
# Root Mean Squared Error (RMSE): 7.793871284753882
# Root Mean Squared Logarithmic Error (RMSLE): 0.49202763355663326
#
# Training model for store 12 and family 16...
# Root Mean Squared Error (RMSE): 8.71681019010472
# Root Mean Squared Logarithmic Error (RMSLE): 0.4804891699889236
#
# Training model for store 12 and family 17...
# Root Mean Squared Error (RMSE): 0.47457142161941124
# Root Mean Squared Logarithmic Error (RMSLE): 0.3208514152649398
#
# Training model for store 12 and family 18...
# Root Mean Squared Error (RMSE): 29.343263528094173
# Root Mean Squared Logarithmic Error (RMSLE): 0.17452666198575956
#
# Training model for store 12 and family 19...
# Root Mean Squared Error (RMSE): 4.95170564477586
# Root Mean Squared Logarithmic Error (RMSLE): 0.60718400606535
#
# Training model for store 12 and family 20...
# Root Mean Squared Error (RMSE): 0.0024318359792232513
# Root Mean Squared Logarithmic Error (RMSLE): 0.0024288838512004363
#
# Training model for store 12 and family 21...
# Root Mean Squared Error (RMSE): 4.044256038233399
# Root Mean Squared Logarithmic Error (RMSLE): 0.7384502370362955
#
# Training model for store 12 and family 22...
# Root Mean Squared Error (RMSE): 30.512521355579587
# Root Mean Squared Logarithmic Error (RMSLE): 0.7558809637499476
#
# Training model for store 12 and family 23...
# Root Mean Squared Error (RMSE): 1.1767435239921973
# Root Mean Squared Logarithmic Error (RMSLE): 0.5432916351888972
#
# Training model for store 12 and family 24...
# Root Mean Squared Error (RMSE): 46.52465270432983
# Root Mean Squared Logarithmic Error (RMSLE): 0.2714772533159143
#
# Training model for store 12 and family 25...
# Root Mean Squared Error (RMSE): 59.993341047411874
# Root Mean Squared Logarithmic Error (RMSLE): 0.33103963986163876
#
# Training model for store 12 and family 26...
# Root Mean Squared Error (RMSE): 1.6485761430060792
# Root Mean Squared Logarithmic Error (RMSLE): 0.5802256184313851
#
# Training model for store 12 and family 27...
# Root Mean Squared Error (RMSE): 4.32486085452471
# Root Mean Squared Logarithmic Error (RMSLE): 0.5267450149417935
#
# Training model for store 12 and family 28...
# Root Mean Squared Error (RMSE): 40.849537085940604
# Root Mean Squared Logarithmic Error (RMSLE): 0.2357600607355754
#
# Training model for store 12 and family 29...
# Root Mean Squared Error (RMSE): 17.458749972345075
# Root Mean Squared Logarithmic Error (RMSLE): 0.5767726086773372
#
# Training model for store 12 and family 30...
# Root Mean Squared Error (RMSE): 62.029332050566246
# Root Mean Squared Logarithmic Error (RMSLE): 0.17414757079954352
#
# Training model for store 12 and family 31...
# Root Mean Squared Error (RMSE): 5.767082026572738
# Root Mean Squared Logarithmic Error (RMSLE): 1.150044318195828
#
# Training model for store 12 and family 32...
# Root Mean Squared Error (RMSE): 2.9666795166082593
# Root Mean Squared Logarithmic Error (RMSLE): 0.7623577571943844
#
# Training model for store 13 and family 0...
# Root Mean Squared Error (RMSE): 3.0845943413903063
# Root Mean Squared Logarithmic Error (RMSLE): 0.47679559731393134
#
# Training model for store 13 and family 1...
# Root Mean Squared Error (RMSE): 1.659708120585598e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6597081205855979e-16
#
# Training model for store 13 and family 2...
# Root Mean Squared Error (RMSE): 3.8072047186258064
# Root Mean Squared Logarithmic Error (RMSLE): 0.9821695323826547
#
# Training model for store 13 and family 3...
# Root Mean Squared Error (RMSE): 474.96959802010383
# Root Mean Squared Logarithmic Error (RMSLE): 0.30537526714860586
#
# Training model for store 13 and family 4...
# Root Mean Squared Error (RMSE): 1.659708120585598e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6597081205855979e-16
#
# Training model for store 13 and family 5...
# Root Mean Squared Error (RMSE): 129.91628402427958
# Root Mean Squared Logarithmic Error (RMSLE): 0.5900077083351987
#
# Training model for store 13 and family 6...
# Root Mean Squared Error (RMSE): 6.051560490025816
# Root Mean Squared Logarithmic Error (RMSLE): 0.7610338982605269
#
# Training model for store 13 and family 7...
# Root Mean Squared Error (RMSE): 505.67796976178846
# Root Mean Squared Logarithmic Error (RMSLE): 0.40496766019216723
#
# Training model for store 13 and family 8...
# Root Mean Squared Error (RMSE): 88.31636664274113
# Root Mean Squared Logarithmic Error (RMSLE): 0.30620676438960615
#
# Training model for store 13 and family 9...
# Root Mean Squared Error (RMSE): 51.130379667395474
# Root Mean Squared Logarithmic Error (RMSLE): 0.30990469990208075
#
# Training model for store 13 and family 10...
# Root Mean Squared Error (RMSE): 36.240692493600186
# Root Mean Squared Logarithmic Error (RMSLE): 0.6316754465444003
#
# Training model for store 13 and family 11...
# Root Mean Squared Error (RMSE): 12.098397978268258
# Root Mean Squared Logarithmic Error (RMSLE): 0.36416418483051644
#
# Training model for store 13 and family 12...
# Root Mean Squared Error (RMSE): 582.2770947178144
# Root Mean Squared Logarithmic Error (RMSLE): 0.19708528359999944
#
# Training model for store 13 and family 13...
# Root Mean Squared Error (RMSE): 13.528062437752267
# Root Mean Squared Logarithmic Error (RMSLE): 1.0475454424067971
#
# Training model for store 13 and family 14...
# Root Mean Squared Error (RMSE): 0.7325838382666308
# Root Mean Squared Logarithmic Error (RMSLE): 0.5437865682587474
#
# Training model for store 13 and family 15...
# Root Mean Squared Error (RMSE): 10.182279548904226
# Root Mean Squared Logarithmic Error (RMSLE): 0.6437537030877682
#
# Training model for store 13 and family 16...
# Root Mean Squared Error (RMSE): 11.059504803419317
# Root Mean Squared Logarithmic Error (RMSLE): 0.7791652480074426
#
# Training model for store 13 and family 17...
# Root Mean Squared Error (RMSE): 0.20760390135914789
# Root Mean Squared Logarithmic Error (RMSLE): 0.16335016479496378
#
# Training model for store 13 and family 18...
# Root Mean Squared Error (RMSE): 62.895876757130196
# Root Mean Squared Logarithmic Error (RMSLE): 0.3750139165507307
#
# Training model for store 13 and family 19...
# Root Mean Squared Error (RMSE): 3.436840786901019
# Root Mean Squared Logarithmic Error (RMSLE): 1.0756588589757647
#
# Training model for store 13 and family 20...
# Root Mean Squared Error (RMSE): 0.007325540762394667
# Root Mean Squared Logarithmic Error (RMSLE): 0.0072988393110815465
#
# Training model for store 13 and family 21...
# Root Mean Squared Error (RMSE): 2.8192124152308744
# Root Mean Squared Logarithmic Error (RMSLE): 0.7381333937673601
#
# Training model for store 13 and family 22...
# Root Mean Squared Error (RMSE): 34.113794974627744
# Root Mean Squared Logarithmic Error (RMSLE): 0.9150680980215397
#
# Training model for store 13 and family 23...
# Root Mean Squared Error (RMSE): 1.7065849090171559
# Root Mean Squared Logarithmic Error (RMSLE): 0.6355650012643217
#
# Training model for store 13 and family 24...
# Root Mean Squared Error (RMSE): 50.30722194912617
# Root Mean Squared Logarithmic Error (RMSLE): 0.3567685098402312
#
# Training model for store 13 and family 25...
# Root Mean Squared Error (RMSE): 57.81401876749495
# Root Mean Squared Logarithmic Error (RMSLE): 0.2998112337829172
#
# Training model for store 13 and family 26...
# Root Mean Squared Error (RMSE): 0.6803881513593778
# Root Mean Squared Logarithmic Error (RMSLE): 0.4365050211542143
#
# Training model for store 13 and family 27...
# Root Mean Squared Error (RMSE): 3.297023224281595
# Root Mean Squared Logarithmic Error (RMSLE): 0.5514286699194237
#
# Training model for store 13 and family 28...
# Root Mean Squared Error (RMSE): 54.546304182270426
# Root Mean Squared Logarithmic Error (RMSLE): 0.485090295682914
#
# Training model for store 13 and family 29...
# Root Mean Squared Error (RMSE): 7.7985541909569
# Root Mean Squared Logarithmic Error (RMSLE): 0.3134352638255931
#
# Training model for store 13 and family 30...
# Root Mean Squared Error (RMSE): 46.175736668339006
# Root Mean Squared Logarithmic Error (RMSLE): 0.2368152507557254
#
# Training model for store 13 and family 31...
# Root Mean Squared Error (RMSE): 6.2704397683229365
# Root Mean Squared Logarithmic Error (RMSLE): 1.1003343480301544
#
# Training model for store 13 and family 32...
# Root Mean Squared Error (RMSE): 1.8824993690193481
# Root Mean Squared Logarithmic Error (RMSLE): 0.6921724730662844
#
# Training model for store 14 and family 0...
# Root Mean Squared Error (RMSE): 3.187727359685487
# Root Mean Squared Logarithmic Error (RMSLE): 0.7099920238358075
#
# Training model for store 14 and family 1...
# Root Mean Squared Error (RMSE): 0.0030567175708711147
# Root Mean Squared Logarithmic Error (RMSLE): 0.0030520553081145665
#
# Training model for store 14 and family 2...
# Root Mean Squared Error (RMSE): 1.9944741597597775
# Root Mean Squared Logarithmic Error (RMSLE): 0.5448605420678652
#
# Training model for store 14 and family 3...
# Root Mean Squared Error (RMSE): 511.7262362129513
# Root Mean Squared Logarithmic Error (RMSLE): 0.31916446765088974
#
# Training model for store 14 and family 4...
# Root Mean Squared Error (RMSE): 1.659708120585598e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6597081205855979e-16
#
# Training model for store 14 and family 5...
# Root Mean Squared Error (RMSE): 47.30480641788944
# Root Mean Squared Logarithmic Error (RMSLE): 0.269926782093548
#
# Training model for store 14 and family 6...
# Root Mean Squared Error (RMSE): 8.468163442581817
# Root Mean Squared Logarithmic Error (RMSLE): 0.7237870347752897
#
# Training model for store 14 and family 7...
# Root Mean Squared Error (RMSE): 1192.1104090773565
# Root Mean Squared Logarithmic Error (RMSLE): 0.6131709723705816
#
# Training model for store 14 and family 8...
# Root Mean Squared Error (RMSE): 103.76349980911033
# Root Mean Squared Logarithmic Error (RMSLE): 0.2843907532279294
#
# Training model for store 14 and family 9...
# Root Mean Squared Error (RMSE): 73.57398667603589
# Root Mean Squared Logarithmic Error (RMSLE): 0.2785045197750657
#
# Training model for store 14 and family 10...
# Root Mean Squared Error (RMSE): 22.64687140922052
# Root Mean Squared Logarithmic Error (RMSLE): 0.5821196852809436
#
# Training model for store 14 and family 11...
# Root Mean Squared Error (RMSE): 22.820190970257013
# Root Mean Squared Logarithmic Error (RMSLE): 0.45437492762732723
#
# Training model for store 14 and family 12...
# Root Mean Squared Error (RMSE): 756.3916657606446
# Root Mean Squared Logarithmic Error (RMSLE): 0.24065153211111603
#
# Training model for store 14 and family 13...
# Root Mean Squared Error (RMSE): 12.526481779276944
# Root Mean Squared Logarithmic Error (RMSLE): 1.0221278483020302
#
# Training model for store 14 and family 14...
# Root Mean Squared Error (RMSE): 0.7950670265219965
# Root Mean Squared Logarithmic Error (RMSLE): 0.4166228168995155
#
# Training model for store 14 and family 15...
# Root Mean Squared Error (RMSE): 11.451311999990248
# Root Mean Squared Logarithmic Error (RMSLE): 0.730474310285067
#
# Training model for store 14 and family 16...
# Root Mean Squared Error (RMSE): 10.987413296263279
# Root Mean Squared Logarithmic Error (RMSLE): 0.45892080160874843
#
# Training model for store 14 and family 17...
# Root Mean Squared Error (RMSE): 0.4280986445357353
# Root Mean Squared Logarithmic Error (RMSLE): 0.26526868948720006
#
# Training model for store 14 and family 18...
# Root Mean Squared Error (RMSE): 92.30033124579879
# Root Mean Squared Logarithmic Error (RMSLE): 0.42498137276228126
#
# Training model for store 14 and family 19...
# Root Mean Squared Error (RMSE): 2.19724831964155
# Root Mean Squared Logarithmic Error (RMSLE): 0.8722490578061195
#
# Training model for store 14 and family 20...
# Root Mean Squared Error (RMSE): 1.659708120585598e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6597081205855979e-16
#
# Training model for store 14 and family 21...
# Root Mean Squared Error (RMSE): 2.9075036845759796
# Root Mean Squared Logarithmic Error (RMSLE): 0.8439216264900237
#
# Training model for store 14 and family 22...
# Root Mean Squared Error (RMSE): 19.196244704077632
# Root Mean Squared Logarithmic Error (RMSLE): 0.9765375172225353
#
# Training model for store 14 and family 23...
# Root Mean Squared Error (RMSE): 1.6645775147862634
# Root Mean Squared Logarithmic Error (RMSLE): 0.5774007262984997
#
# Training model for store 14 and family 24...
# Root Mean Squared Error (RMSE): 164.09982812140547
# Root Mean Squared Logarithmic Error (RMSLE): 0.623717086591291
#
# Training model for store 14 and family 25...
# Root Mean Squared Error (RMSE): 91.21244084504399
# Root Mean Squared Logarithmic Error (RMSLE): 0.34628638391954664
#
# Training model for store 14 and family 26...
# Root Mean Squared Error (RMSE): 1.3024460678318917
# Root Mean Squared Logarithmic Error (RMSLE): 0.5789944378691287
#
# Training model for store 14 and family 27...
# Root Mean Squared Error (RMSE): 2.7084521420064256
# Root Mean Squared Logarithmic Error (RMSLE): 0.47788061485500516
#
# Training model for store 14 and family 28...
# Root Mean Squared Error (RMSE): 62.74465926261125
# Root Mean Squared Logarithmic Error (RMSLE): 0.6078588196932699
#
# Training model for store 14 and family 29...
# Root Mean Squared Error (RMSE): 28.66660641656806
# Root Mean Squared Logarithmic Error (RMSLE): 0.35995334456157074
#
# Training model for store 14 and family 30...
# Root Mean Squared Error (RMSE): 96.34552443439213
# Root Mean Squared Logarithmic Error (RMSLE): 0.2246386856103854
#
# Training model for store 14 and family 31...
# Root Mean Squared Error (RMSE): 3.633767163695653
# Root Mean Squared Logarithmic Error (RMSLE): 0.9767270545171406
#
# Training model for store 14 and family 32...
# Root Mean Squared Error (RMSE): 3.4994581674190126
# Root Mean Squared Logarithmic Error (RMSLE): 0.711677613253117
#
# Training model for store 15 and family 0...
# Root Mean Squared Error (RMSE): 2.5217880846781506
# Root Mean Squared Logarithmic Error (RMSLE): 0.532746204367932
#
# Training model for store 15 and family 1...
# Root Mean Squared Error (RMSE): 1.3485460874898945
# Root Mean Squared Logarithmic Error (RMSLE): 0.6780942801117158
#
# Training model for store 15 and family 2...
# Root Mean Squared Error (RMSE): 2.891446966989591
# Root Mean Squared Logarithmic Error (RMSLE): 0.6337836920637169
#
# Training model for store 15 and family 3...
# Root Mean Squared Error (RMSE): 342.56947617403836
# Root Mean Squared Logarithmic Error (RMSLE): 0.22361195911725032
#
# Training model for store 15 and family 4...
# Root Mean Squared Error (RMSE): 1.659708120585598e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6597081205855979e-16
#
# Training model for store 15 and family 5...
# Root Mean Squared Error (RMSE): 29.323502479768724
# Root Mean Squared Logarithmic Error (RMSLE): 0.19850595351996878
#
# Training model for store 15 and family 6...
# Root Mean Squared Error (RMSE): 5.548989125664108
# Root Mean Squared Logarithmic Error (RMSLE): 1.2242030151610004
#
# Training model for store 15 and family 7...
# Root Mean Squared Error (RMSE): 253.07931556465655
# Root Mean Squared Logarithmic Error (RMSLE): 0.25863779587908997
#
# Training model for store 15 and family 8...
# Root Mean Squared Error (RMSE): 62.98030293036703
# Root Mean Squared Logarithmic Error (RMSLE): 0.19720961339614393
#
# Training model for store 15 and family 9...
# Root Mean Squared Error (RMSE): 55.962955711167545
# Root Mean Squared Logarithmic Error (RMSLE): 0.2211751706649408
#
# Training model for store 15 and family 10...
# Root Mean Squared Error (RMSE): 30.092360618810183
# Root Mean Squared Logarithmic Error (RMSLE): 0.3078007169009811
#
# Training model for store 15 and family 11...
# Root Mean Squared Error (RMSE): 22.150845316503588
# Root Mean Squared Logarithmic Error (RMSLE): 0.3426180124061384
#
# Training model for store 15 and family 12...
# Root Mean Squared Error (RMSE): 436.71071006225634
# Root Mean Squared Logarithmic Error (RMSLE): 0.16075164697532435
#
# Training model for store 15 and family 13...
# Root Mean Squared Error (RMSE): 6.845588499772918
# Root Mean Squared Logarithmic Error (RMSLE): 0.7049294112023798
#
# Training model for store 15 and family 14...
# Root Mean Squared Error (RMSE): 1.3903823628843301
# Root Mean Squared Logarithmic Error (RMSLE): 0.6248223545310869
#
# Training model for store 15 and family 15...
# Root Mean Squared Error (RMSE): 15.668004554988192
# Root Mean Squared Logarithmic Error (RMSLE): 0.7328601372937875
#
# Training model for store 15 and family 16...
# Root Mean Squared Error (RMSE): 7.431909502066152
# Root Mean Squared Logarithmic Error (RMSLE): 0.4915840375062002
#
# Training model for store 15 and family 17...
# Root Mean Squared Error (RMSE): 0.4587771156744167
# Root Mean Squared Logarithmic Error (RMSLE): 0.27792985619572746
#
# Training model for store 15 and family 18...
# Root Mean Squared Error (RMSE): 60.47359202852184
# Root Mean Squared Logarithmic Error (RMSLE): 0.28660894690037914
#
# Training model for store 15 and family 19...
# Root Mean Squared Error (RMSE): 5.228685629239833
# Root Mean Squared Logarithmic Error (RMSLE): 0.5465461263259126
#
# Training model for store 15 and family 20...
# Root Mean Squared Error (RMSE): 0.007892073132097721
# Root Mean Squared Logarithmic Error (RMSLE): 0.00786109361128392
#
# Training model for store 15 and family 21...
# Root Mean Squared Error (RMSE): 3.314891084240805
# Root Mean Squared Logarithmic Error (RMSLE): 0.8663020062912227
#
# Training model for store 15 and family 22...
# Root Mean Squared Error (RMSE): 16.67232791733156
# Root Mean Squared Logarithmic Error (RMSLE): 0.7461461937950833
#
# Training model for store 15 and family 23...
# Root Mean Squared Error (RMSE): 1.5923231264406332
# Root Mean Squared Logarithmic Error (RMSLE): 0.5302931577208488
#
# Training model for store 15 and family 24...
# Root Mean Squared Error (RMSE): 33.08214976227958
# Root Mean Squared Logarithmic Error (RMSLE): 0.26049099898006106
#
# Training model for store 15 and family 25...
# Root Mean Squared Error (RMSE): 60.22618258067532
# Root Mean Squared Logarithmic Error (RMSLE): 0.30495028363717047
#
# Training model for store 15 and family 26...
# Root Mean Squared Error (RMSE): 0.9585204022344068
# Root Mean Squared Logarithmic Error (RMSLE): 0.47716620500069123
#
# Training model for store 15 and family 27...
# Root Mean Squared Error (RMSE): 3.2826767397554093
# Root Mean Squared Logarithmic Error (RMSLE): 0.484095604991526
#
# Training model for store 15 and family 28...
# Root Mean Squared Error (RMSE): 36.42889008453739
# Root Mean Squared Logarithmic Error (RMSLE): 0.32424853666353043
#
# Training model for store 15 and family 29...
# Root Mean Squared Error (RMSE): 23.98067311886629
# Root Mean Squared Logarithmic Error (RMSLE): 0.671161763700384
#
# Training model for store 15 and family 30...
# Root Mean Squared Error (RMSE): 252.15610944256855
# Root Mean Squared Logarithmic Error (RMSLE): 0.4580501085465158
#
# Training model for store 15 and family 31...
# Root Mean Squared Error (RMSE): 6.136028398709594
# Root Mean Squared Logarithmic Error (RMSLE): 1.0743025637389965
#
# Training model for store 15 and family 32...
# Root Mean Squared Error (RMSE): 2.90630721090514
# Root Mean Squared Logarithmic Error (RMSLE): 0.5327590984867316
#
# Training model for store 16 and family 0...
# Root Mean Squared Error (RMSE): 3.043767365201265
# Root Mean Squared Logarithmic Error (RMSLE): 0.6141556098924779
#
# Training model for store 16 and family 1...
# Root Mean Squared Error (RMSE): 0.5010641813065609
# Root Mean Squared Logarithmic Error (RMSLE): 0.30832847686039533
#
# Training model for store 16 and family 2...
# Root Mean Squared Error (RMSE): 1.9985477827396958
# Root Mean Squared Logarithmic Error (RMSLE): 0.7294992285096012
#
# Training model for store 16 and family 3...
# Root Mean Squared Error (RMSE): 415.9741894788598
# Root Mean Squared Logarithmic Error (RMSLE): 0.3041269544067559
#
# Training model for store 16 and family 4...
# Root Mean Squared Error (RMSE): 1.659708120585598e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6597081205855979e-16
#
# Training model for store 16 and family 5...
# Root Mean Squared Error (RMSE): 56.4582044841987
# Root Mean Squared Logarithmic Error (RMSLE): 0.3670454769742482
#
# Training model for store 16 and family 6...
# Root Mean Squared Error (RMSE): 4.219543669773333
# Root Mean Squared Logarithmic Error (RMSLE): 0.7777147908764733
#
# Training model for store 16 and family 7...
# Root Mean Squared Error (RMSE): 584.7808738622896
# Root Mean Squared Logarithmic Error (RMSLE): 0.5391219139495663
#
# Training model for store 16 and family 8...
# Root Mean Squared Error (RMSE): 78.42901199866799
# Root Mean Squared Logarithmic Error (RMSLE): 0.28071801625870685
#
# Training model for store 16 and family 9...
# Root Mean Squared Error (RMSE): 60.67104517164013
# Root Mean Squared Logarithmic Error (RMSLE): 0.32981320631981
#
# Training model for store 16 and family 10...
# Root Mean Squared Error (RMSE): 124.21174350175136
# Root Mean Squared Logarithmic Error (RMSLE): 0.6790369138081885
#
# Training model for store 16 and family 11...
# Root Mean Squared Error (RMSE): 23.458870498219817
# Root Mean Squared Logarithmic Error (RMSLE): 0.564653216584659
#
# Training model for store 16 and family 12...
# Root Mean Squared Error (RMSE): 989.3424926449553
# Root Mean Squared Logarithmic Error (RMSLE): 0.40510098424816704
#
# Training model for store 16 and family 13...
# Root Mean Squared Error (RMSE): 4.105560442613007
# Root Mean Squared Logarithmic Error (RMSLE): 0.7427845881496757
#
# Training model for store 16 and family 14...
# Root Mean Squared Error (RMSE): 0.770416417324674
# Root Mean Squared Logarithmic Error (RMSLE): 0.4875157341240853
#
# Training model for store 16 and family 15...
# Root Mean Squared Error (RMSE): 10.337323930595664
# Root Mean Squared Logarithmic Error (RMSLE): 0.7994102711170954
#
# Training model for store 16 and family 16...
# Root Mean Squared Error (RMSE): 7.550322234952298
# Root Mean Squared Logarithmic Error (RMSLE): 0.5237422650668824
#
# Training model for store 16 and family 17...
# Root Mean Squared Error (RMSE): 0.5321325527879661
# Root Mean Squared Logarithmic Error (RMSLE): 0.3305019232615888
#
# Training model for store 16 and family 18...
# Root Mean Squared Error (RMSE): 58.020814486753295
# Root Mean Squared Logarithmic Error (RMSLE): 0.33492571111240677
#
# Training model for store 16 and family 19...
# Root Mean Squared Error (RMSE): 1.659708120585598e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6597081205855979e-16
#
# Training model for store 16 and family 20...
# Root Mean Squared Error (RMSE): 0.007948258891701698
# Root Mean Squared Logarithmic Error (RMSLE): 0.007916837867141844
#
# Training model for store 16 and family 21...
# Root Mean Squared Error (RMSE): 2.5193806293502843
# Root Mean Squared Logarithmic Error (RMSLE): 0.7590397085943559
#
# Training model for store 16 and family 22...
# Root Mean Squared Error (RMSE): 38.609215478725815
# Root Mean Squared Logarithmic Error (RMSLE): 1.1779860676176315
#
# Training model for store 16 and family 23...
# Root Mean Squared Error (RMSE): 1.4592047881821752
# Root Mean Squared Logarithmic Error (RMSLE): 0.5463986150321045
#
# Training model for store 16 and family 24...
# Root Mean Squared Error (RMSE): 32.448860365885736
# Root Mean Squared Logarithmic Error (RMSLE): 0.4891881659815843
#
# Training model for store 16 and family 25...
# Root Mean Squared Error (RMSE): 88.1606276956781
# Root Mean Squared Logarithmic Error (RMSLE): 0.5112212139187667
#
# Training model for store 16 and family 26...
# Root Mean Squared Error (RMSE): 1.102333838351895
# Root Mean Squared Logarithmic Error (RMSLE): 0.5671215854096204
#
# Training model for store 16 and family 27...
# Root Mean Squared Error (RMSE): 2.5246017546146144
# Root Mean Squared Logarithmic Error (RMSLE): 0.6821332395575185
#
# Training model for store 16 and family 28...
# Root Mean Squared Error (RMSE): 45.574241807181245
# Root Mean Squared Logarithmic Error (RMSLE): 0.5544935539827827
#
# Training model for store 16 and family 29...
# Root Mean Squared Error (RMSE): 12.73967203860795
# Root Mean Squared Logarithmic Error (RMSLE): 0.3626539975587803
#
# Training model for store 16 and family 30...
# Root Mean Squared Error (RMSE): 235.21703891080503
# Root Mean Squared Logarithmic Error (RMSLE): 0.3944463194099123
#
# Training model for store 16 and family 31...
# Root Mean Squared Error (RMSE): 0.023659540340304375
# Root Mean Squared Logarithmic Error (RMSLE): 0.023383991197119796
#
# Training model for store 16 and family 32...
# Root Mean Squared Error (RMSE): 2.581294857639768
# Root Mean Squared Logarithmic Error (RMSLE): 1.0361195580730993
#
# Training model for store 17 and family 0...
# Root Mean Squared Error (RMSE): 6.626293385239945
# Root Mean Squared Logarithmic Error (RMSLE): 0.5758838504498345
#
# Training model for store 17 and family 1...
# Root Mean Squared Error (RMSE): 1.0434874993949401
# Root Mean Squared Logarithmic Error (RMSLE): 0.5816782807534995
#
# Training model for store 17 and family 2...
# Root Mean Squared Error (RMSE): 2.9362484873987285
# Root Mean Squared Logarithmic Error (RMSLE): 0.6071120651758382
#
# Training model for store 17 and family 3...
# Root Mean Squared Error (RMSE): 767.7113632678644
# Root Mean Squared Logarithmic Error (RMSLE): 0.23408233060205494
#
# Training model for store 17 and family 4...
# Root Mean Squared Error (RMSE): 1.659708120585598e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6597081205855979e-16
#
# Training model for store 17 and family 5...
# Root Mean Squared Error (RMSE): 144.30417210613382
# Root Mean Squared Logarithmic Error (RMSLE): 0.5050388702836676
#
# Training model for store 17 and family 6...
# Root Mean Squared Error (RMSE): 8.368318037671479
# Root Mean Squared Logarithmic Error (RMSLE): 0.9946103222592418
#
# Training model for store 17 and family 7...
# Root Mean Squared Error (RMSE): 423.2408644793001
# Root Mean Squared Logarithmic Error (RMSLE): 0.3219309678004444
#
# Training model for store 17 and family 8...
# Root Mean Squared Error (RMSE): 239.5144371646933
# Root Mean Squared Logarithmic Error (RMSLE): 0.33400667130332257
#
# Training model for store 17 and family 9...
# Root Mean Squared Error (RMSE): 140.1647964386741
# Root Mean Squared Logarithmic Error (RMSLE): 0.2716552154219661
#
# Training model for store 17 and family 10...
# Root Mean Squared Error (RMSE): 103.89386536011885
# Root Mean Squared Logarithmic Error (RMSLE): 0.5007799284930855
#
# Training model for store 17 and family 11...
# Root Mean Squared Error (RMSE): 60.11128156117207
# Root Mean Squared Logarithmic Error (RMSLE): 0.553225616066071
#
# Training model for store 17 and family 12...
# Root Mean Squared Error (RMSE): 1722.9291904815661
# Root Mean Squared Logarithmic Error (RMSLE): 0.4327172968648279
#
# Training model for store 17 and family 13...
# Root Mean Squared Error (RMSE): 14.72302472883251
# Root Mean Squared Logarithmic Error (RMSLE): 1.0265761016013493
#
# Training model for store 17 and family 14...
# Root Mean Squared Error (RMSE): 1.454757982299016
# Root Mean Squared Logarithmic Error (RMSLE): 0.5966848881600203
#
# Training model for store 17 and family 15...
# Root Mean Squared Error (RMSE): 10.771051502448797
# Root Mean Squared Logarithmic Error (RMSLE): 0.4401336781681449
#
# Training model for store 17 and family 16...
# Root Mean Squared Error (RMSE): 8.058631701750853
# Root Mean Squared Logarithmic Error (RMSLE): 0.29225949995427064
#
# Training model for store 17 and family 17...
# Root Mean Squared Error (RMSE): 0.5628918139510112
# Root Mean Squared Logarithmic Error (RMSLE): 0.3517037929556764
#
# Training model for store 17 and family 18...
# Root Mean Squared Error (RMSE): 68.9929981947439
# Root Mean Squared Logarithmic Error (RMSLE): 0.2325389983929002
#
# Training model for store 17 and family 19...
# Root Mean Squared Error (RMSE): 0.979292023811105
# Root Mean Squared Logarithmic Error (RMSLE): 0.5118148834802777
#
# Training model for store 17 and family 20...
# Root Mean Squared Error (RMSE): 0.0317949503660202
# Root Mean Squared Logarithmic Error (RMSLE): 0.031299955811804316
#
# Training model for store 17 and family 21...
# Root Mean Squared Error (RMSE): 10.063693417091274
# Root Mean Squared Logarithmic Error (RMSLE): 0.794253852004609
#
# Training model for store 17 and family 22...
# Root Mean Squared Error (RMSE): 45.43235535286431
# Root Mean Squared Logarithmic Error (RMSLE): 1.0983959131149852
#
# Training model for store 17 and family 23...
# Root Mean Squared Error (RMSE): 2.6052597091578353
# Root Mean Squared Logarithmic Error (RMSLE): 0.5673454475505162
#
# Training model for store 17 and family 24...
# Root Mean Squared Error (RMSE): 59.061332090921816
# Root Mean Squared Logarithmic Error (RMSLE): 0.22554202110161334
#
# Training model for store 17 and family 25...
# Root Mean Squared Error (RMSE): 98.64717555806938
# Root Mean Squared Logarithmic Error (RMSLE): 0.3674354227513915
#
# Training model for store 17 and family 26...
# Root Mean Squared Error (RMSE): 1.3402056828417341
# Root Mean Squared Logarithmic Error (RMSLE): 0.44820237144099895
#
# Training model for store 17 and family 27...
# Root Mean Squared Error (RMSE): 5.7269384262229055
# Root Mean Squared Logarithmic Error (RMSLE): 0.5811446765053225
#
# Training model for store 17 and family 28...
# Root Mean Squared Error (RMSE): 115.41370007896613
# Root Mean Squared Logarithmic Error (RMSLE): 0.32799770873826245
#
# Training model for store 17 and family 29...
# Root Mean Squared Error (RMSE): 31.411707081689677
# Root Mean Squared Logarithmic Error (RMSLE): 0.4382676195282186
#
# Training model for store 17 and family 30...
# Root Mean Squared Error (RMSE): 634.1697045399967
# Root Mean Squared Logarithmic Error (RMSLE): 0.4573414079023485
#
# Training model for store 17 and family 31...
# Root Mean Squared Error (RMSE): 15.755695982526928
# Root Mean Squared Logarithmic Error (RMSLE): 1.349406570478441
#
# Training model for store 17 and family 32...
# Root Mean Squared Error (RMSE): 8.767734541641296
# Root Mean Squared Logarithmic Error (RMSLE): 0.6304439659161306
#
# Training model for store 18 and family 0...
# Root Mean Squared Error (RMSE): 4.737350023375803
# Root Mean Squared Logarithmic Error (RMSLE): 0.9388726463973613
#
# Training model for store 18 and family 1...
# Root Mean Squared Error (RMSE): 0.7600523880434956
# ...
#
# Training model for store 6 and family 32...
# Root Mean Squared Error (RMSE): 16.295814912096986
# Root Mean Squared Logarithmic Error (RMSLE): 0.4402840408729599
#
# Training model for store 7 and family 0...
# Root Mean Squared Error (RMSE): 2.7107448868523316
# Root Mean Squared Logarithmic Error (RMSLE): 0.39948355153539483
#
# Training model for store 7 and family 1...
# Root Mean Squared Error (RMSE): 0.31025996786186805
# Root Mean Squared Logarithmic Error (RMSLE): 0.21356107603467234
#
# Training model for store 7 and family 2...
# Root Mean Squared Error (RMSE): 3.2800284729027194
# Root Mean Squared Logarithmic Error (RMSLE): 0.49925764376392273
#
# Training model for store 7 and family 3...
# Root Mean Squared Error (RMSE): 730.7125510609934
# Root Mean Squared Logarithmic Error (RMSLE): 0.18734243524745176
#
# Training model for store 7 and family 4...
# Root Mean Squared Error (RMSE): 0.3613274896372471
# Root Mean Squared Logarithmic Error (RMSLE): 0.24936327922582577
#
# Training model for store 7 and family 5...
# Root Mean Squared Error (RMSE): 106.02256578600493
# Root Mean Squared Logarithmic Error (RMSLE): 0.1877330564917426
#
# Training model for store 7 and family 6...
# Root Mean Squared Error (RMSE): 11.770600085765603
# Root Mean Squared Logarithmic Error (RMSLE): 0.602156641436231
#
# Training model for store 7 and family 7...
# Root Mean Squared Error (RMSE): 205.11816331441165
# Root Mean Squared Logarithmic Error (RMSLE): 0.20224046024620618
#
# Training model for store 7 and family 8...
# Root Mean Squared Error (RMSE): 221.5618264360439
# Root Mean Squared Logarithmic Error (RMSLE): 0.17136716384029413
#
# Training model for store 7 and family 9...
# Root Mean Squared Error (RMSE): 34.82069221985038
# Root Mean Squared Logarithmic Error (RMSLE): 0.18543959598263357
#
# Training model for store 7 and family 10...
# Root Mean Squared Error (RMSE): 49.34855281850382
# Root Mean Squared Logarithmic Error (RMSLE): 0.17668532674200324
#
# Training model for store 7 and family 11...
# Root Mean Squared Error (RMSE): 58.20188724901432
# Root Mean Squared Logarithmic Error (RMSLE): 0.2484167958461676
#
# Training model for store 7 and family 12...
# Root Mean Squared Error (RMSE): 834.2428606844439
# Root Mean Squared Logarithmic Error (RMSLE): 0.21690159935664044
#
# Training model for store 7 and family 13...
# Root Mean Squared Error (RMSE): 13.906765731313078
# Root Mean Squared Logarithmic Error (RMSLE): 0.3613919859146607
#
# Training model for store 7 and family 14...
# Root Mean Squared Error (RMSE): 2.926102246353584
# Root Mean Squared Logarithmic Error (RMSLE): 0.6131865186409796
#
# Training model for store 7 and family 15...
# Root Mean Squared Error (RMSE): 19.608316862884507
# Root Mean Squared Logarithmic Error (RMSLE): 0.6762150637674526
#
# Training model for store 7 and family 16...
# Root Mean Squared Error (RMSE): 40.69660987410006
# Root Mean Squared Logarithmic Error (RMSLE): 0.7896827740506065
#
# Training model for store 7 and family 17...
# Root Mean Squared Error (RMSE): 0.9016187491236914
# Root Mean Squared Logarithmic Error (RMSLE): 0.5299359235457344
#
# Training model for store 7 and family 18...
# Root Mean Squared Error (RMSE): 45.31868999169676
# Root Mean Squared Logarithmic Error (RMSLE): 0.19124958273053128
#
# Training model for store 7 and family 19...
# Root Mean Squared Error (RMSE): 8.839510847641503
# Root Mean Squared Logarithmic Error (RMSLE): 0.6292919291072824
#
# Training model for store 7 and family 20...
# Root Mean Squared Error (RMSE): 13.193286084097782
# Root Mean Squared Logarithmic Error (RMSLE): 0.3022477189989387
#
# Training model for store 7 and family 21...
# Root Mean Squared Error (RMSE): 5.490157535423257
# Root Mean Squared Logarithmic Error (RMSLE): 0.7042513025019237
#
# Training model for store 7 and family 22...
# Root Mean Squared Error (RMSE): 141.13554961924424
# Root Mean Squared Logarithmic Error (RMSLE): 1.2690768551205767
#
# Training model for store 7 and family 23...
# Root Mean Squared Error (RMSE): 6.996928524977704
# Root Mean Squared Logarithmic Error (RMSLE): 0.5356642706421048
#
# Training model for store 7 and family 24...
# Root Mean Squared Error (RMSE): 157.9138935754787
# Root Mean Squared Logarithmic Error (RMSLE): 0.28615770966977827
#
# Training model for store 7 and family 25...
# Root Mean Squared Error (RMSE): 78.65710162189612
# Root Mean Squared Logarithmic Error (RMSLE): 0.2756984462531899
#
# Training model for store 7 and family 26...
# Root Mean Squared Error (RMSE): 3.929783616158186
# Root Mean Squared Logarithmic Error (RMSLE): 0.47218033111212
#
# Training model for store 7 and family 27...
# Root Mean Squared Error (RMSE): 5.615051666223575
# Root Mean Squared Logarithmic Error (RMSLE): 0.349676504857225
#
# Training model for store 7 and family 28...
# Root Mean Squared Error (RMSE): 120.15631669575907
# Root Mean Squared Logarithmic Error (RMSLE): 0.18575066783499203
#
# Training model for store 7 and family 29...
# Root Mean Squared Error (RMSE): 58.66258095691497
# Root Mean Squared Logarithmic Error (RMSLE): 0.39721464563881315
#
# Training model for store 7 and family 30...
# Root Mean Squared Error (RMSE): 1669.877903325445
# Root Mean Squared Logarithmic Error (RMSLE): 0.30521228468663464
#
# Training model for store 7 and family 31...
# Root Mean Squared Error (RMSE): 0.6889125067745053
# Root Mean Squared Logarithmic Error (RMSLE): 0.41537613631951786
#
# Training model for store 7 and family 32...
# Root Mean Squared Error (RMSE): 20.617606980537744
# Root Mean Squared Logarithmic Error (RMSLE): 0.433271981644563
#
# Training model for store 8 and family 0...
# Root Mean Squared Error (RMSE): 4.070409796162657
# Root Mean Squared Logarithmic Error (RMSLE): 0.7138259315113942
#
# Training model for store 8 and family 1...
# Root Mean Squared Error (RMSE): 1.0265231394892633
# Root Mean Squared Logarithmic Error (RMSLE): 0.5433473294598689
#
# Training model for store 8 and family 2...
# Root Mean Squared Error (RMSE): 6.374289462520198
# Root Mean Squared Logarithmic Error (RMSLE): 0.56619899422313
#
# Training model for store 8 and family 3...
# Root Mean Squared Error (RMSE): 1185.172978480327
# Root Mean Squared Logarithmic Error (RMSLE): 0.24813890504734842
#
# Training model for store 8 and family 4...
# Root Mean Squared Error (RMSE): 0.1806691738619873
# Root Mean Squared Logarithmic Error (RMSLE): 0.12485148763650683
#
# Training model for store 8 and family 5...
# Root Mean Squared Error (RMSE): 163.9231147024811
# Root Mean Squared Logarithmic Error (RMSLE): 0.1874814777758237
#
# Training model for store 8 and family 6...
# Root Mean Squared Error (RMSE): 10.056885207904541
# Root Mean Squared Logarithmic Error (RMSLE): 0.4508121581552943
#
# Training model for store 8 and family 7...
# Root Mean Squared Error (RMSE): 275.0932526821815
# Root Mean Squared Logarithmic Error (RMSLE): 0.22471343259099893
#
# Training model for store 8 and family 8...
# Root Mean Squared Error (RMSE): 334.52827589247136
# Root Mean Squared Logarithmic Error (RMSLE): 0.2305092008529035
#
# Training model for store 8 and family 9...
# Root Mean Squared Error (RMSE): 58.372499532656214
# Root Mean Squared Logarithmic Error (RMSLE): 0.19790161671954554
#
# Training model for store 8 and family 10...
# Root Mean Squared Error (RMSE): 100.45509574790665
# Root Mean Squared Logarithmic Error (RMSLE): 0.29873204583057383
#
# Training model for store 8 and family 11...
# Root Mean Squared Error (RMSE): 52.99226327863759
# Root Mean Squared Logarithmic Error (RMSLE): 0.30825597302324326
#
# Training model for store 8 and family 12...
# Root Mean Squared Error (RMSE): 1174.144621273515
# Root Mean Squared Logarithmic Error (RMSLE): 0.24894621713933912
#
# Training model for store 8 and family 13...
# Root Mean Squared Error (RMSE): 14.01847667144476
# Root Mean Squared Logarithmic Error (RMSLE): 0.36712687127995913
#
# Training model for store 8 and family 14...
# Root Mean Squared Error (RMSE): 3.2403050085698837
# Root Mean Squared Logarithmic Error (RMSLE): 0.6423685661740473
#
# Training model for store 8 and family 15...
# Root Mean Squared Error (RMSE): 25.35559130398787
# Root Mean Squared Logarithmic Error (RMSLE): 0.5405691100108486
#
# Training model for store 8 and family 16...
# Root Mean Squared Error (RMSE): 50.760877833339514
# Root Mean Squared Logarithmic Error (RMSLE): 0.5087405548175886
#
# Training model for store 8 and family 17...
# Root Mean Squared Error (RMSE): 1.6283142431390334
# Root Mean Squared Logarithmic Error (RMSLE): 0.9660521223665927
#
# Training model for store 8 and family 18...
# Root Mean Squared Error (RMSE): 83.42099468673766
# Root Mean Squared Logarithmic Error (RMSLE): 0.23101442468655417
#
# Training model for store 8 and family 19...
# Root Mean Squared Error (RMSE): 28.24910402318377
# Root Mean Squared Logarithmic Error (RMSLE): 0.7120988940590572
#
# Training model for store 8 and family 20...
# Root Mean Squared Error (RMSE): 22.648593237204015
# Root Mean Squared Logarithmic Error (RMSLE): 0.6589470391407366
#
# Training model for store 8 and family 21...
# Root Mean Squared Error (RMSE): 11.18428738067642
# Root Mean Squared Logarithmic Error (RMSLE): 0.4982407312495091
#
# Training model for store 8 and family 22...
# Root Mean Squared Error (RMSE): 91.22991783919416
# Root Mean Squared Logarithmic Error (RMSLE): 0.6134380600254118
#
# Training model for store 8 and family 23...
# Root Mean Squared Error (RMSE): 10.470116609010086
# Root Mean Squared Logarithmic Error (RMSLE): 0.5416235442843802
#
# Training model for store 8 and family 24...
# Root Mean Squared Error (RMSE): 228.45005060179815
# Root Mean Squared Logarithmic Error (RMSLE): 0.3989768287565148
#
# Training model for store 8 and family 25...
# Root Mean Squared Error (RMSE): 89.02600133084803
# Root Mean Squared Logarithmic Error (RMSLE): 0.24891433774501948
#
# Training model for store 8 and family 26...
# Root Mean Squared Error (RMSE): 10.933483849020842
# Root Mean Squared Logarithmic Error (RMSLE): 0.5197992403001763
#
# Training model for store 8 and family 27...
# Root Mean Squared Error (RMSE): 7.53756883965311
# Root Mean Squared Logarithmic Error (RMSLE): 0.38363828967171515
#
# Training model for store 8 and family 28...
# Root Mean Squared Error (RMSE): 200.21438709196553
# Root Mean Squared Logarithmic Error (RMSLE): 0.31412716184023814
#
# Training model for store 8 and family 29...
# Root Mean Squared Error (RMSE): 83.68980679603752
# Root Mean Squared Logarithmic Error (RMSLE): 0.46177071460061736
#
# Training model for store 8 and family 30...
# Root Mean Squared Error (RMSE): 1530.521943964539
# Root Mean Squared Logarithmic Error (RMSLE): 0.3145212163049629
#
# Training model for store 8 and family 31...
# Root Mean Squared Error (RMSE): 2.5618376313557865
# Root Mean Squared Logarithmic Error (RMSLE): 0.6940219315274827
#
# Training model for store 8 and family 32...
# Root Mean Squared Error (RMSE): 22.538404774057987
# Root Mean Squared Logarithmic Error (RMSLE): 0.4956788164687685
#
# Training model for store 9 and family 0...
# Root Mean Squared Error (RMSE): 5.491613998002319
# Root Mean Squared Logarithmic Error (RMSLE): 0.5905778575081364
#
# Training model for store 9 and family 1...
# Root Mean Squared Error (RMSE): 0.8176449376293493
# Root Mean Squared Logarithmic Error (RMSLE): 0.4162060760894049
#
# Training model for store 9 and family 2...
# Root Mean Squared Error (RMSE): 4.561943520358412
# Root Mean Squared Logarithmic Error (RMSLE): 0.5652372960251307
#
# Training model for store 9 and family 3...
# Root Mean Squared Error (RMSE): 2165.4783016719266
# Root Mean Squared Logarithmic Error (RMSLE): 0.8783524250958029
#
# Training model for store 9 and family 4...
# Root Mean Squared Error (RMSE): 1.659708120585598e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6597081205855979e-16
#
# Training model for store 9 and family 5...
# Root Mean Squared Error (RMSE): 105.09157184947766
# Root Mean Squared Logarithmic Error (RMSLE): 0.20814570908280897
#
# Training model for store 9 and family 6...
# Root Mean Squared Error (RMSE): 10.293490083525729
# Root Mean Squared Logarithmic Error (RMSLE): 0.5833038585183323
#
# Training model for store 9 and family 7...
# Root Mean Squared Error (RMSE): 654.778462428138
# Root Mean Squared Logarithmic Error (RMSLE): 0.3285749291604437
#
# Training model for store 9 and family 8...
# Root Mean Squared Error (RMSE): 162.6720596403909
# Root Mean Squared Logarithmic Error (RMSLE): 0.20984713207642186
#
# Training model for store 9 and family 9...
# Root Mean Squared Error (RMSE): 172.38110643125276
# Root Mean Squared Logarithmic Error (RMSLE): 0.28999315023380645
#
# Training model for store 9 and family 10...
# Root Mean Squared Error (RMSE): 83.29412892142327
# Root Mean Squared Logarithmic Error (RMSLE): 0.4213023724263635
#
# Training model for store 9 and family 11...
# Root Mean Squared Error (RMSE): 50.90931257894292
# Root Mean Squared Logarithmic Error (RMSLE): 0.48717150729346925
#
# Training model for store 9 and family 12...
# Root Mean Squared Error (RMSE): 1887.6437642448352
# Root Mean Squared Logarithmic Error (RMSLE): 0.2986740847902223
#
# Training model for store 9 and family 13...
# Root Mean Squared Error (RMSE): 6.834900316737752
# Root Mean Squared Logarithmic Error (RMSLE): 0.5458666924792642
#
# Training model for store 9 and family 14...
# Root Mean Squared Error (RMSE): 1.3506152607532773
# Root Mean Squared Logarithmic Error (RMSLE): 0.6678775345195896
# Training model for store 9 and family 15...
# Root Mean Squared Error (RMSE): 238.83248499078272
# Root Mean Squared Logarithmic Error (RMSLE): 1.3324800291026138
#
# Training model for store 9 and family 16...
# Root Mean Squared Error (RMSE): 21.494903446148534
# Root Mean Squared Logarithmic Error (RMSLE): 0.4940662272255977
#
# Training model for store 9 and family 17...
# Root Mean Squared Error (RMSE): 0.6817770877863553
# Root Mean Squared Logarithmic Error (RMSLE): 0.5197856599405088
#
# Training model for store 9 and family 18...
# Root Mean Squared Error (RMSE): 124.1485565202254
# Root Mean Squared Logarithmic Error (RMSLE): 0.3045089150912438
#
# Training model for store 9 and family 19...
# Root Mean Squared Error (RMSE): 10.191933960003478
# Root Mean Squared Logarithmic Error (RMSLE): 0.878468266935985
#
# Training model for store 9 and family 20...
# Root Mean Squared Error (RMSE): 4.221251715631201
# Root Mean Squared Logarithmic Error (RMSLE): 0.6051531734465718
#
# Training model for store 9 and family 21...
# Root Mean Squared Error (RMSE): 9.058826227371977
# Root Mean Squared Logarithmic Error (RMSLE): 0.9339334232611602
#
# Training model for store 9 and family 22...
# Root Mean Squared Error (RMSE): 45.38481319830114
# Root Mean Squared Logarithmic Error (RMSLE): 0.8495206318630424
#
# Training model for store 9 and family 23...
# Root Mean Squared Error (RMSE): 2.648053319275172
# Root Mean Squared Logarithmic Error (RMSLE): 0.6472091878463995
#
# Training model for store 9 and family 24...
# Root Mean Squared Error (RMSE): 106.78802416602163
# Root Mean Squared Logarithmic Error (RMSLE): 0.2666288037610414
#
# Training model for store 9 and family 25...
# Root Mean Squared Error (RMSE): 183.21354530189925
# Root Mean Squared Logarithmic Error (RMSLE): 0.42420818559020607
#
# Training model for store 9 and family 26...
# Root Mean Squared Error (RMSE): 3.442632929431691
# Root Mean Squared Logarithmic Error (RMSLE): 0.4595948581637761
#
# Training model for store 9 and family 27...
# Root Mean Squared Error (RMSE): 4.646968814258309
# Root Mean Squared Logarithmic Error (RMSLE): 0.5452819856761918
#
# Training model for store 9 and family 28...
# Root Mean Squared Error (RMSE): 125.70262064059457
# Root Mean Squared Logarithmic Error (RMSLE): 0.2902833683376527
#
# Training model for store 9 and family 29...
# Root Mean Squared Error (RMSE): 32.90714898523412
# Root Mean Squared Logarithmic Error (RMSLE): 0.3155520969844181
#
# Training model for store 9 and family 30...
# Root Mean Squared Error (RMSE): 465.2107399326183
# Root Mean Squared Logarithmic Error (RMSLE): 0.2799754830461461
#
# Training model for store 9 and family 31...
# Root Mean Squared Error (RMSE): 108.67278266476633
# Root Mean Squared Logarithmic Error (RMSLE): 2.5413579114803055
#
# Training model for store 9 and family 32...
# Root Mean Squared Error (RMSE): 8.148827923087946
# Root Mean Squared Logarithmic Error (RMSLE): 0.43883045490837275

# %%
avg_rmse = total_rmse / num_models
avg_rmsle = total_rmsle / num_models

# %%
print(f"Average Root Mean Squared Error (RMSE) across all models: {avg_rmse}")
print(f"Average Root Mean Squared Logarithmic Error (RMSLE) across all models: {avg_rmsle}")
# Out:
# Average Root Mean Squared Error (RMSE) across all models: 166.40377501251126
# Average Root Mean Squared Logarithmic Error (RMSLE) across all models: 0.5080600715924899
