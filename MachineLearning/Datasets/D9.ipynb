# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv("../../Data/Kaggle/StoreSales/processed_train_v2.csv")

# %%
train = train.drop(['id'], axis=1)

# %%
train.head()
# Out:
#          date  store_nbr  family  sales  onpromotion  typeholiday  dcoilwtico  \
# 0  2013-01-01          1       0    0.0            0            3       93.14
# 1  2013-01-01          1       1    0.0            0            3       93.14
# 2  2013-01-01          1       2    0.0            0            3       93.14
# 3  2013-01-01          1       3    0.0            0            3       93.14
# 4  2013-01-01          1       4    0.0            0            3       93.14
#
#    city  state  typestores  cluster  day_of_week  day  month  year
# 0    18     12           3       13            2    1      1  2013
# 1    18     12           3       13            2    1      1  2013
# 2    18     12           3       13            2    1      1  2013
# 3    18     12           3       13            2    1      1  2013
# 4    18     12           3       13            2    1      1  2013

# %%
train.tail()
# Out:
#                date  store_nbr  family     sales  onpromotion  typeholiday  \
# 3000883  2017-08-15          9      28   438.133            0            3
# 3000884  2017-08-15          9      29   154.553            1            3
# 3000885  2017-08-15          9      30  2419.729          148            3
# 3000886  2017-08-15          9      31   121.000            8            3
# 3000887  2017-08-15          9      32    16.000            0            3
#
#          dcoilwtico  city  state  typestores  cluster  day_of_week  day  \
# 3000883       47.57    18     12           1        6            2   15
# 3000884       47.57    18     12           1        6            2   15
# 3000885       47.57    18     12           1        6            2   15
# 3000886       47.57    18     12           1        6            2   15
# 3000887       47.57    18     12           1        6            2   15
#
#          month  year
# 3000883      8  2017
# 3000884      8  2017
# ...

# %%
split_index = int(0.8 * train.shape[0])

# %%
new_train = train.iloc[:split_index]
new_test = train.iloc[split_index:]

# %%
X_train = new_train.drop(['sales'], axis=1)
X_test = new_train['sales']

# %%
y_train = new_test.drop(['sales'], axis=1)
y_test = new_test['sales']

# %%
X_train
# Out:
#                date  store_nbr  family  onpromotion  typeholiday  dcoilwtico  \
# 0        2013-01-01          1       0            0            3       93.14
# 1        2013-01-01          1       1            0            3       93.14
# 2        2013-01-01          1       2            0            3       93.14
# 3        2013-01-01          1       3            0            3       93.14
# 4        2013-01-01          1       4            0            3       93.14
# ...             ...        ...     ...          ...          ...         ...
# 2400705  2016-09-12         19      21            0            4       46.28
# 2400706  2016-09-12         19      22            0            4       46.28
# 2400707  2016-09-12         19      23            0            4       46.28
# 2400708  2016-09-12         19      24            0            4       46.28
# 2400709  2016-09-12         19      25            8            4       46.28
#
# ...

# %%
y_train
# Out:
#                date  store_nbr  family  onpromotion  typeholiday  dcoilwtico  \
# 2400710  2016-09-12         19      26            0            4       46.28
# 2400711  2016-09-12         19      27            0            4       46.28
# 2400712  2016-09-12         19      28            0            4       46.28
# 2400713  2016-09-12         19      29            1            4       46.28
# 2400714  2016-09-12         19      30            1            4       46.28
# ...             ...        ...     ...          ...          ...         ...
# 3000883  2017-08-15          9      28            0            3       47.57
# 3000884  2017-08-15          9      29            1            3       47.57
# 3000885  2017-08-15          9      30          148            3       47.57
# 3000886  2017-08-15          9      31            8            3       47.57
# 3000887  2017-08-15          9      32            0            3       47.57
#
# ...
