# %%
import pandas as pd
import numpy as np
from darts import TimeSeries
from darts.models import LightGBMModel
from sklearn.metrics import mean_squared_error, mean_squared_log_error
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../Data/Kaggle/StoreSales/train_darts.csv", parse_dates=["date"])

# %%
df.head()
# Out:
#         date  store_nbr  family  sales  onpromotion  typeholiday  dcoilwtico  \
# 0 2013-01-01          1       0    0.0            0            3       93.14
# 1 2013-01-01          1       1    0.0            0            3       93.14
# 2 2013-01-01          1       2    0.0            0            3       93.14
# 3 2013-01-01          1       3    0.0            0            3       93.14
# 4 2013-01-01          1       4    0.0            0            3       93.14
#
#    city  state  typestores  cluster  day_of_week  day  month  year
# 0    18     12           3       13            2    1      1  2013
# 1    18     12           3       13            2    1      1  2013
# 2    18     12           3       13            2    1      1  2013
# 3    18     12           3       13            2    1      1  2013
# 4    18     12           3       13            2    1      1  2013

# %%
unique_combinations = df[['store_nbr', 'family']].drop_duplicates()

# %%
total_rmse = 0
total_rmsle = 0
num_models = 0

# %%
trained_models = {}

# %%
included_stores = {5, 8, 16, 19, 22, 25, 33, 37, 41, 47, 51}
excluded_families = {1, 4, 14, 17, 19, 20, 31}

# %%
for index, row in unique_combinations.iterrows():
    store_nbr = row['store_nbr']
    family = row['family']

    if store_nbr in included_stores and family not in excluded_families:
    
        print(f"\nTraining model for store {store_nbr} and family {family}...")
        
        df_subset = df[(df['store_nbr'] == store_nbr) & (df['family'] == family)]
        
        ts = TimeSeries.from_dataframe(df_subset, value_cols=["sales"])
    
        training_size = int(len(ts) - 30)
        
        train = ts[:training_size]
        val = ts[training_size:]
    
        model = LightGBMModel(lags=2)
        model.fit(train)
    
        trained_models[(store_nbr, family)] = model
    
        predictions = model.predict(n=len(val))
    
        val = val.pd_series().tolist()
        predictions = predictions.pd_series().tolist()
    
        predictions = np.maximum(predictions, 0)
    
        rmse = np.sqrt(mean_squared_error(val, predictions))
        rmsle = np.sqrt(mean_squared_error(np.log1p(val), np.log1p(predictions)))
    
        total_rmse += rmse
        total_rmsle += rmsle
        num_models += 1

        model.save(f"SavedModels/LightGBM/LGBM_S{store_nbr}P{family}.pkl")
    
        print(f"Root Mean Squared Error (RMSE): {rmse}")
        print(f"Root Mean Squared Logarithmic Error (RMSLE): {rmsle}")
# Out:
# Training model for store 16 and family 0...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000275 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 42
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 5.775424
# Root Mean Squared Error (RMSE): 2.9969725891365484
# Root Mean Squared Logarithmic Error (RMSLE): 0.6067764825178769
#
# Training model for store 16 and family 2...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000145 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 0.863196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Root Mean Squared Error (RMSE): 1.827462471947187
# Root Mean Squared Logarithmic Error (RMSLE): 0.6749289995575471
#
# Training model for store 16 and family 3...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000082 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 1079.389225
# Root Mean Squared Error (RMSE): 404.7102331725794
# Root Mean Squared Logarithmic Error (RMSLE): 0.2921185896027703
#
# Training model for store 16 and family 5...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000054 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 508
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 202.875303
# Root Mean Squared Error (RMSE): 58.7163593047142
# Root Mean Squared Logarithmic Error (RMSLE): 0.3750667433665419
#
# Training model for store 16 and family 6...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000114 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 3.586562
# Root Mean Squared Error (RMSE): 4.158559040119585
# Root Mean Squared Logarithmic Error (RMSLE): 0.7412828159095484
#
# Training model for store 16 and family 7...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000067 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 1003.578692
# Root Mean Squared Error (RMSE): 567.6708111361608
# Root Mean Squared Logarithmic Error (RMSLE): 0.4768770551919213
#
# Training model for store 16 and family 8...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000073 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 244.587167
# Root Mean Squared Error (RMSE): 76.32738757276013
# Root Mean Squared Logarithmic Error (RMSLE): 0.2837278964792163
#
# Training model for store 16 and family 9...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000100 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 504
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 214.944915
# Root Mean Squared Error (RMSE): 65.18874077381537
# Root Mean Squared Logarithmic Error (RMSLE): 0.3592490694628926
#
# Training model for store 16 and family 10...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000056 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 178.197337
# Root Mean Squared Error (RMSE): 125.90822734258616
# Root Mean Squared Logarithmic Error (RMSLE): 0.6812559073679405
#
# Training model for store 16 and family 11...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000104 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 41.705671
# Root Mean Squared Error (RMSE): 20.853583227945357
# Root Mean Squared Logarithmic Error (RMSLE): 0.4873480526020903
#
# Training model for store 16 and family 12...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000078 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 2566.603056
# Root Mean Squared Error (RMSE): 682.5997630795209
# Root Mean Squared Logarithmic Error (RMSLE): 0.30629685747633106
#
# Training model for store 16 and family 13...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000072 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 64
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 5.912833
# Root Mean Squared Error (RMSE): 3.37530602474565
# Root Mean Squared Logarithmic Error (RMSLE): 0.6417620992561217
#
# Training model for store 16 and family 15...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000142 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 106
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 12.593826
# Root Mean Squared Error (RMSE): 10.561610395543632
# Root Mean Squared Logarithmic Error (RMSLE): 0.8229250734524283
#
# Training model for store 16 and family 16...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000142 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 68
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 7.673123
# Root Mean Squared Error (RMSE): 6.005145418862407
# Root Mean Squared Logarithmic Error (RMSLE): 0.4305127634691241
#
# Training model for store 16 and family 18...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000150 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 500
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 133.914044
# Root Mean Squared Error (RMSE): 59.88658989394292
# Root Mean Squared Logarithmic Error (RMSLE): 0.346545869917682
#
# Training model for store 16 and family 21...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000069 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 3.944310
# Root Mean Squared Error (RMSE): 2.5038816956381162
# Root Mean Squared Logarithmic Error (RMSLE): 0.7555461301761298
#
# Training model for store 16 and family 22...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000095 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 248
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 36.020581
# Root Mean Squared Error (RMSE): 37.89314217732811
# Root Mean Squared Logarithmic Error (RMSLE): 1.059302223754023
#
# Training model for store 16 and family 23...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000146 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 16
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 0.564165
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Root Mean Squared Error (RMSE): 1.4594096493727782
# Root Mean Squared Logarithmic Error (RMSLE): 0.5465474979482086
#
# Training model for store 16 and family 24...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000056 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 76.784518
# Root Mean Squared Error (RMSE): 33.68324707363262
# Root Mean Squared Logarithmic Error (RMSLE): 0.5041638308961626
#
# Training model for store 16 and family 25...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000102 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 198.202785
# Root Mean Squared Error (RMSE): 68.02862543178485
# Root Mean Squared Logarithmic Error (RMSLE): 0.44862986209529754
#
# Training model for store 16 and family 26...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000181 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 16
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 0.252421
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Root Mean Squared Error (RMSE): 1.1013157540131306
# Root Mean Squared Logarithmic Error (RMSLE): 0.566482219658142
#
# Training model for store 16 and family 27...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000087 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 30
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 1.934019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Root Mean Squared Error (RMSE): 2.2645096119714285
# Root Mean Squared Logarithmic Error (RMSLE): 0.598656037542586
#
# Training model for store 16 and family 28...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000119 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 94.720924
# Root Mean Squared Error (RMSE): 38.901948994947354
# Root Mean Squared Logarithmic Error (RMSLE): 0.4811515306512828
#
# Training model for store 16 and family 29...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000063 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 156
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 41.914649
# Root Mean Squared Error (RMSE): 11.734516035500187
# Root Mean Squared Logarithmic Error (RMSLE): 0.34109760004562506
#
# Training model for store 16 and family 30...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000080 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 369.042310
# Root Mean Squared Error (RMSE): 233.62734592018174
# Root Mean Squared Logarithmic Error (RMSLE): 0.39176339030725293
#
# Training model for store 16 and family 32...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000069 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 36
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 2.803874
# Root Mean Squared Error (RMSE): 2.588716287342666
# Root Mean Squared Logarithmic Error (RMSLE): 1.0381451289435384
#
# Training model for store 19 and family 0...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000082 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 6.553874
# Root Mean Squared Error (RMSE): 3.455354541567296
# Root Mean Squared Logarithmic Error (RMSLE): 0.5512937164101208
#
# Training model for store 19 and family 2...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000157 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 22
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 1.575061
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Root Mean Squared Error (RMSE): 2.870289428940176
# Root Mean Squared Logarithmic Error (RMSLE): 0.6641678786864953
#
# Training model for store 19 and family 3...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000052 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 1947.283293
# Root Mean Squared Error (RMSE): 662.0098611120138
# Root Mean Squared Logarithmic Error (RMSLE): 0.23783814120884578
#
# Training model for store 19 and family 5...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000073 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 396
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 179.983051
# Root Mean Squared Error (RMSE): 55.8890232882634
# Root Mean Squared Logarithmic Error (RMSLE): 0.2802800681975467
#
# Training model for store 19 and family 6...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000094 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 72
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 5.242131
# Root Mean Squared Error (RMSE): 4.786453607773132
# Root Mean Squared Logarithmic Error (RMSLE): 0.8135674357632692
#
# Training model for store 19 and family 7...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000084 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 927.171913
# Root Mean Squared Error (RMSE): 392.48870949946956
# Root Mean Squared Logarithmic Error (RMSLE): 0.35545326045259706
#
# Training model for store 19 and family 8...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000094 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 288.636804
# Root Mean Squared Error (RMSE): 111.67946748216342
# Root Mean Squared Logarithmic Error (RMSLE): 0.31683695146623236
#
# Training model for store 19 and family 9...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000055 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 273.676150
# Root Mean Squared Error (RMSE): 71.68138484988388
# Root Mean Squared Logarithmic Error (RMSLE): 0.2541169339329587
#
# Training model for store 19 and family 10...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000112 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 288
# ...
#
# Training model for store 51 and family 26...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000174 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 80
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 10.855327
# Root Mean Squared Error (RMSE): 7.906432814503388
# Root Mean Squared Logarithmic Error (RMSLE): 0.3415861514754312
#
# Training model for store 51 and family 27...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000122 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 70
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 7.092615
# Root Mean Squared Error (RMSE): 5.37850190288453
# Root Mean Squared Logarithmic Error (RMSLE): 0.44379669550071865
#
# Training model for store 51 and family 28...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000094 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 843.505682
# Root Mean Squared Error (RMSE): 985.8722634068239
# Root Mean Squared Logarithmic Error (RMSLE): 0.6833449987065644
#
# Training model for store 51 and family 29...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000097 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 170.137932
# Root Mean Squared Error (RMSE): 61.21758084863938
# Root Mean Squared Logarithmic Error (RMSLE): 0.413892537253702
#
# Training model for store 51 and family 30...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000098 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 3328.574534
# Root Mean Squared Error (RMSE): 1674.1962205527625
# Root Mean Squared Logarithmic Error (RMSLE): 0.2787313762739
#
# Training model for store 51 and family 32...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000110 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 66.180202
# Root Mean Squared Error (RMSE): 21.469619430391308
# Root Mean Squared Logarithmic Error (RMSLE): 0.4240486959645221
#
# Training model for store 8 and family 0...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000103 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 5.280872
# Root Mean Squared Error (RMSE): 4.08726413921888
# Root Mean Squared Logarithmic Error (RMSLE): 0.714386412804384
#
# Training model for store 8 and family 2...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000095 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 52
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 7.134988
# Root Mean Squared Error (RMSE): 6.274883715875592
# Root Mean Squared Logarithmic Error (RMSLE): 0.5493821942985859
#
# Training model for store 8 and family 3...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000084 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 3756.634988
# Root Mean Squared Error (RMSE): 1077.0622187244958
# Root Mean Squared Logarithmic Error (RMSLE): 0.22686110669220771
#
# Training model for store 8 and family 5...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000106 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 752.308042
# Root Mean Squared Error (RMSE): 114.10633138052204
# Root Mean Squared Logarithmic Error (RMSLE): 0.1410250248586828
#
# Training model for store 8 and family 6...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000116 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 110
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 14.737288
# Root Mean Squared Error (RMSE): 9.128405985930693
# Root Mean Squared Logarithmic Error (RMSLE): 0.4565343200434751
#
# Training model for store 8 and family 7...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000098 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 1262.473971
# Root Mean Squared Error (RMSE): 246.46608306932373
# Root Mean Squared Logarithmic Error (RMSLE): 0.20337509857473007
#
# Training model for store 8 and family 8...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000082 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 1410.865012
# Root Mean Squared Error (RMSE): 299.8793445024536
# Root Mean Squared Logarithmic Error (RMSLE): 0.20948679805686854
#
# Training model for store 8 and family 9...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000082 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 278.508742
# Root Mean Squared Error (RMSE): 64.97744943543297
# Root Mean Squared Logarithmic Error (RMSLE): 0.22124134156929798
#
# Training model for store 8 and family 10...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000082 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 327.213075
# Root Mean Squared Error (RMSE): 87.94458576574195
# Root Mean Squared Logarithmic Error (RMSLE): 0.2641749031902821
#
# Training model for store 8 and family 11...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000099 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 238.970827
# Root Mean Squared Error (RMSE): 46.852822311336574
# Root Mean Squared Logarithmic Error (RMSLE): 0.2832688746811096
#
# Training model for store 8 and family 12...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000084 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 4696.072639
# Root Mean Squared Error (RMSE): 903.5414774996251
# Root Mean Squared Logarithmic Error (RMSLE): 0.1815917041911645
#
# Training model for store 8 and family 13...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000140 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 176
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 41.513317
# Root Mean Squared Error (RMSE): 14.963497417572757
# Root Mean Squared Logarithmic Error (RMSLE): 0.40494227501578967
#
# Training model for store 8 and family 15...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000167 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 184
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 29.551453
# Root Mean Squared Error (RMSE): 19.09573052164556
# Root Mean Squared Logarithmic Error (RMSLE): 0.44343096064707155
#
# Training model for store 8 and family 16...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000120 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 172
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 25.179177
# Root Mean Squared Error (RMSE): 53.4451868981242
# Root Mean Squared Logarithmic Error (RMSLE): 0.6054757201704088
#
# Training model for store 8 and family 18...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000131 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 508
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 230.802058
# Root Mean Squared Error (RMSE): 91.497547770031
# Root Mean Squared Logarithmic Error (RMSLE): 0.25356146748416164
#
# Training model for store 8 and family 21...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000098 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 106
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 22.378329
# Root Mean Squared Error (RMSE): 10.82661766629712
# Root Mean Squared Logarithmic Error (RMSLE): 0.4876704953570833
#
# Training model for store 8 and family 22...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000158 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 147.773002
# Root Mean Squared Error (RMSE): 75.22559773989607
# Root Mean Squared Logarithmic Error (RMSLE): 0.5113311306355429
#
# Training model for store 8 and family 23...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000114 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 88
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 8.038741
# Root Mean Squared Error (RMSE): 8.45169982799756
# Root Mean Squared Logarithmic Error (RMSLE): 0.42753363352529
#
# Training model for store 8 and family 24...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000118 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 520.521827
# Root Mean Squared Error (RMSE): 202.65267216756746
# Root Mean Squared Logarithmic Error (RMSLE): 0.37908585492962654
#
# Training model for store 8 and family 25...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000085 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 327.448547
# Root Mean Squared Error (RMSE): 78.63479698267278
# Root Mean Squared Logarithmic Error (RMSLE): 0.22736944040940057
#
# Training model for store 8 and family 26...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000131 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 78
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 9.992131
# Root Mean Squared Error (RMSE): 10.178507559247747
# Root Mean Squared Logarithmic Error (RMSLE): 0.47079260297857894
#
# Training model for store 8 and family 27...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000131 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 82
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 11.113801
# Root Mean Squared Error (RMSE): 6.3433946510033525
# Root Mean Squared Logarithmic Error (RMSLE): 0.30943668344892256
#
# Training model for store 8 and family 28...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000148 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 598.641433
# Root Mean Squared Error (RMSE): 157.54496014900442
# Root Mean Squared Logarithmic Error (RMSLE): 0.24639222848506806
#
# Training model for store 8 and family 29...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000102 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 213.168470
# Root Mean Squared Error (RMSE): 76.88313220542273
# Root Mean Squared Logarithmic Error (RMSLE): 0.4398311850868538
#
# Training model for store 8 and family 30...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000083 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 3034.543882
# Root Mean Squared Error (RMSE): 1703.678441660012
# Root Mean Squared Logarithmic Error (RMSLE): 0.3395456703276386
#
# Training model for store 8 and family 32...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000066 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1652, number of used features: 2
# [LightGBM] [Info] Start training from score 56.036923
# Root Mean Squared Error (RMSE): 20.43004699817054
# Root Mean Squared Logarithmic Error (RMSLE): 0.4672818606348918

# %%
avg_rmse = total_rmse / num_models
avg_rmsle = total_rmsle / num_models

# %%
print(f"Average Root Mean Squared Error (RMSE) across all models: {avg_rmse}")
print(f"Average Root Mean Squared Logarithmic Error (RMSLE) across all models: {avg_rmsle}")
# Out:
# Average Root Mean Squared Error (RMSE) across all models: 179.91202849927575
# Average Root Mean Squared Logarithmic Error (RMSLE) across all models: 0.47825641231131444
