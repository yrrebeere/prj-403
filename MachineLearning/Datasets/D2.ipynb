# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('../../Data/Pharmacy/D1.csv')

# %%
df.head()
# Out:
#    saleinvcode CustomerRef         date  invdiscperc  flatdisc  misccharges  \
# 0       115439         NaN  7/1/22 0:02          0.0       0.0            0
# 1       115440         NaN  7/1/22 0:03          0.0       3.0            0
# 2       115440         NaN  7/1/22 0:03          0.0       3.0            0
# 3       115440         NaN  7/1/22 0:03          0.0       3.0            0
# 4       115441         NaN  7/1/22 0:04          0.0       0.0            0
#
#    invsalestax remarks  looseqty  packqty  price  itemdiscperc  packunits  \
# 0            0     NaN         1        0  18.00           0.0          1
# 1            0     NaN         3        0   6.31           0.0         20
# 2            0     NaN         2        0   7.83           0.0         30
# 3            0     NaN         2        0  34.29           0.0         14
# 4            0     NaN         8        0   6.31           0.0         20
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348048 entries, 0 to 348047
# Data columns (total 20 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   saleinvcode   348048 non-null  int64
#  1   CustomerRef   590 non-null     object
#  2   date          348048 non-null  object
#  3   invdiscperc   348048 non-null  float64
#  4   flatdisc      348048 non-null  float64
#  5   misccharges   348048 non-null  int64
#  6   invsalestax   348048 non-null  int64
#  7   remarks       76429 non-null   object
#  8   looseqty      348048 non-null  int64
#  9   packqty       348048 non-null  int64
#  10  price         348048 non-null  float64
#  11  itemdiscperc  348048 non-null  float64
#  12  packunits     348048 non-null  int64
#  13  batch         348048 non-null  object
#  14  expiry        348048 non-null  object
#  15  salestax      348048 non-null  int64
#  16  itemname      348048 non-null  object
# ...

# %%
corr_matrix = df.corr(numeric_only=True)

# %%
print(corr_matrix)
# Out:
#               saleinvcode  invdiscperc  flatdisc  misccharges  invsalestax  \
# saleinvcode      1.000000     0.006366  0.001077          NaN          NaN
# invdiscperc      0.006366     1.000000  0.091591          NaN          NaN
# flatdisc         0.001077     0.091591  1.000000          NaN          NaN
# misccharges           NaN          NaN       NaN          NaN          NaN
# invsalestax           NaN          NaN       NaN          NaN          NaN
# looseqty         0.006968     0.116450  0.028431          NaN          NaN
# packqty               NaN          NaN       NaN          NaN          NaN
# price            0.023050    -0.084360 -0.052529          NaN          NaN
# itemdiscperc    -0.020194    -0.164554 -0.090229          NaN          NaN
# packunits       -0.019841    -0.070127 -0.031087          NaN          NaN
# salestax              NaN          NaN       NaN          NaN          NaN
# ...

# %%
columns_to_drop = ['saleinvcode', 'CustomerRef', 'invdiscperc', 'flatdisc', 'misccharges', 'invsalestax', 'remarks', 'packqty', 'itemdiscperc', 'batch', 'salestax', 'customer', 'rowid']
df = df.drop(columns=columns_to_drop, axis=1)

# %%
df.head()
# Out:
#           date  looseqty  price  packunits        expiry  \
# 0  7/1/22 0:02         1  18.00          1   7/5/24 0:00
# 1  7/1/22 0:03         3   6.31         20   2/8/24 0:00
# 2  7/1/22 0:03         2   7.83         30   8/1/25 0:00
# 3  7/1/22 0:03         2  34.29         14  10/1/24 0:00
# 4  7/1/22 0:04         8   6.31         20   2/8/24 0:00
#
#                       itemname datestring
# 0  PEDITRAL (LEMON) ORS SACHET   1/7/2022
# 1           SPIROMIDE 20MG TAB   1/7/2022
# 2      CARLOV 6.25MG TAB(30'S)   1/7/2022
# 3               NEXUM 40MG CAP   1/7/2022
# 4           SPIROMIDE 20MG TAB   1/7/2022

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348048 entries, 0 to 348047
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        348048 non-null  object
#  1   looseqty    348048 non-null  int64
#  2   price       348048 non-null  float64
#  3   packunits   348048 non-null  int64
#  4   expiry      348048 non-null  object
#  5   itemname    348048 non-null  object
#  6   datestring  348048 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 18.6+ MB

# %%
df.to_csv('../../Data/Pharmacy/D2.csv', index=False)
