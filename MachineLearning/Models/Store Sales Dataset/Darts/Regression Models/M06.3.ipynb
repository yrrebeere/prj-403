# %%
import pandas as pd
import numpy as np
from darts import TimeSeries
from darts.models import XGBModel
from sklearn.metrics import mean_squared_error, mean_squared_log_error
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../Data/Kaggle/StoreSales/train_darts.csv", parse_dates=["date"])

# %%
df.head()
# Out:
#         date  store_nbr  family  sales  onpromotion  typeholiday  dcoilwtico  \
# 0 2013-01-01          1       0    0.0            0            3       93.14
# 1 2013-01-01          1       1    0.0            0            3       93.14
# 2 2013-01-01          1       2    0.0            0            3       93.14
# 3 2013-01-01          1       3    0.0            0            3       93.14
# 4 2013-01-01          1       4    0.0            0            3       93.14
#
#    city  state  typestores  cluster  day_of_week  day  month  year
# 0    18     12           3       13            2    1      1  2013
# 1    18     12           3       13            2    1      1  2013
# 2    18     12           3       13            2    1      1  2013
# 3    18     12           3       13            2    1      1  2013
# 4    18     12           3       13            2    1      1  2013

# %%
unique_combinations = df[['store_nbr', 'family']].drop_duplicates()

# %%
total_rmse = 0
total_rmsle = 0
num_models = 0

# %%
trained_models = {}

# %%
for index, row in unique_combinations.iterrows():
    store_nbr = row['store_nbr']
    family = row['family']
    
    print(f"\nTraining model for store {store_nbr} and family {family}...")
    
    df_subset = df[(df['store_nbr'] == store_nbr) & (df['family'] == family)]
    
    ts = TimeSeries.from_dataframe(df_subset, value_cols=["sales"])

    split_ratio = 0.8
    training_size = int(len(ts) * split_ratio)
    train = ts[:training_size]
    val = ts[training_size:]

    model = XGBModel(lags=2)
    model.fit(train)

    trained_models[(store_nbr, family)] = model

    predictions = model.predict(n=len(val))

    val = val.pd_series().tolist()
    predictions = predictions.pd_series().tolist()

    predictions = np.maximum(predictions, 0)

    rmse = np.sqrt(mean_squared_error(val, predictions))
    rmsle = np.sqrt(mean_squared_error(np.log1p(val), np.log1p(predictions)))

    total_rmse += rmse
    total_rmsle += rmsle
    num_models += 1

    print(f"Root Mean Squared Error (RMSE): {rmse}")
    print(f"Root Mean Squared Logarithmic Error (RMSLE): {rmsle}")

    plt.figure(figsize=(12, 6))
    plt.plot(val, label='Actual')
    plt.plot(predictions, label='Predictions')
    plt.title(f"Model for store {store_nbr} and family {family}")
    plt.legend()
    plt.savefig(f"plots/M06.3_store{store_nbr}_family{family}.png")
    plt.close()
# Out:
# Training model for store 1 and family 0...
# Root Mean Squared Error (RMSE): 2.860497430714637
# Root Mean Squared Logarithmic Error (RMSLE): 0.6010571457354258
#
# Training model for store 1 and family 1...
# Root Mean Squared Error (RMSE): 1.669548658199223e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6695486581992227e-16
#
# Training model for store 1 and family 2...
# Root Mean Squared Error (RMSE): 2.5102156428121303
# Root Mean Squared Logarithmic Error (RMSLE): 0.5788124588910983
#
# Training model for store 1 and family 3...
# Root Mean Squared Error (RMSE): 1170.5828495775238
# Root Mean Squared Logarithmic Error (RMSLE): 0.8276763320038013
#
# Training model for store 1 and family 4...
# Root Mean Squared Error (RMSE): 1.231389651888243
# Root Mean Squared Logarithmic Error (RMSLE): 0.5971886853304212
#
# Training model for store 1 and family 5...
# Root Mean Squared Error (RMSE): 175.09817315468126
# Root Mean Squared Logarithmic Error (RMSLE): 0.6762570679804079
#
# Training model for store 1 and family 6...
# Root Mean Squared Error (RMSE): 10.624573825740761
# Root Mean Squared Logarithmic Error (RMSLE): 0.8494105122813207
#
# Training model for store 1 and family 7...
# Root Mean Squared Error (RMSE): 259.57676547073294
# Root Mean Squared Logarithmic Error (RMSLE): 0.6158143451330393
#
# Training model for store 1 and family 8...
# Root Mean Squared Error (RMSE): 352.4780820640092
# Root Mean Squared Logarithmic Error (RMSLE): 0.6957157051061725
#
# Training model for store 1 and family 9...
# Root Mean Squared Error (RMSE): 50.993164973345586
# Root Mean Squared Logarithmic Error (RMSLE): 0.5030840882893465
#
# Training model for store 1 and family 10...
# Root Mean Squared Error (RMSE): 42.695385876312784
# Root Mean Squared Logarithmic Error (RMSLE): 0.44224189866078684
#
# Training model for store 1 and family 11...
# Root Mean Squared Error (RMSE): 142.4826646678254
# Root Mean Squared Logarithmic Error (RMSLE): 0.6410515302013584
#
# Training model for store 1 and family 12...
# Root Mean Squared Error (RMSE): 1249.8674165079979
# Root Mean Squared Logarithmic Error (RMSLE): 0.7071424373423429
#
# Training model for store 1 and family 13...
# Root Mean Squared Error (RMSE): 13.205769658140966
# Root Mean Squared Logarithmic Error (RMSLE): 0.6624209979940362
#
# Training model for store 1 and family 14...
# Root Mean Squared Error (RMSE): 1.6906770465944776
# Root Mean Squared Logarithmic Error (RMSLE): 0.6105892156805551
#
# Training model for store 1 and family 15...
# Root Mean Squared Error (RMSE): 16.7313850152786
# Root Mean Squared Logarithmic Error (RMSLE): 0.8342992297198006
#
# Training model for store 1 and family 16...
# Root Mean Squared Error (RMSE): 21.113169821301113
# Root Mean Squared Logarithmic Error (RMSLE): 1.2068558704732173
#
# Training model for store 1 and family 17...
# Root Mean Squared Error (RMSE): 0.7065573334119899
# Root Mean Squared Logarithmic Error (RMSLE): 0.3857297458382013
#
# Training model for store 1 and family 18...
# Root Mean Squared Error (RMSE): 59.24202927367979
# Root Mean Squared Logarithmic Error (RMSLE): 0.483887246584306
#
# Training model for store 1 and family 19...
# Root Mean Squared Error (RMSE): 9.074027353040579
# Root Mean Squared Logarithmic Error (RMSLE): 0.6511627859850911
#
# Training model for store 1 and family 20...
# Root Mean Squared Error (RMSE): 14.428600834581603
# Root Mean Squared Logarithmic Error (RMSLE): 0.9273823719283276
#
# Training model for store 1 and family 21...
# Root Mean Squared Error (RMSE): 6.25228844455711
# Root Mean Squared Logarithmic Error (RMSLE): 0.9291795339218715
#
# Training model for store 1 and family 22...
# Root Mean Squared Error (RMSE): 75.80243128212162
# Root Mean Squared Logarithmic Error (RMSLE): 1.0280972718690289
#
# Training model for store 1 and family 23...
# Root Mean Squared Error (RMSE): 6.426815599635019
# Root Mean Squared Logarithmic Error (RMSLE): 0.9643848275791168
#
# Training model for store 1 and family 24...
# Root Mean Squared Error (RMSE): 216.58155579497003
# Root Mean Squared Logarithmic Error (RMSLE): 0.7431867884546225
#
# Training model for store 1 and family 25...
# Root Mean Squared Error (RMSE): 84.83301470808708
# Root Mean Squared Logarithmic Error (RMSLE): 0.6761937212820367
#
# Training model for store 1 and family 26...
# Root Mean Squared Error (RMSE): 3.25547640711661
# Root Mean Squared Logarithmic Error (RMSLE): 0.5396752410022366
#
# Training model for store 1 and family 27...
# Root Mean Squared Error (RMSE): 5.185267279883863
# Root Mean Squared Logarithmic Error (RMSLE): 0.5980434964278535
#
# Training model for store 1 and family 28...
# Root Mean Squared Error (RMSE): 137.46979025357794
# Root Mean Squared Logarithmic Error (RMSLE): 0.5799524313289955
#
# Training model for store 1 and family 29...
# Root Mean Squared Error (RMSE): 32.32510324086085
# Root Mean Squared Logarithmic Error (RMSLE): 0.48537721271448614
#
# Training model for store 1 and family 30...
# Root Mean Squared Error (RMSE): 2403.5059358525714
# Root Mean Squared Logarithmic Error (RMSLE): 2.9129992366789192
#
# Training model for store 1 and family 31...
# Root Mean Squared Error (RMSE): 0.6049334887873852
# Root Mean Squared Logarithmic Error (RMSLE): 0.35023737538385985
#
# Training model for store 1 and family 32...
# Root Mean Squared Error (RMSE): 13.860139036229986
# Root Mean Squared Logarithmic Error (RMSLE): 0.5190210669569199
#
# Training model for store 10 and family 0...
# Root Mean Squared Error (RMSE): 2.614738586113189
# Root Mean Squared Logarithmic Error (RMSLE): 0.7256153564638107
#
# Training model for store 10 and family 1...
# Root Mean Squared Error (RMSE): 1.3818080210167507
# Root Mean Squared Logarithmic Error (RMSLE): 0.809428262019517
#
# Training model for store 10 and family 2...
# Root Mean Squared Error (RMSE): 1.6391941110479684
# Root Mean Squared Logarithmic Error (RMSLE): 0.6090995614322442
#
# Training model for store 10 and family 3...
# Root Mean Squared Error (RMSE): 526.6868346281393
# Root Mean Squared Logarithmic Error (RMSLE): 0.6279877550215782
#
# Training model for store 10 and family 4...
# Root Mean Squared Error (RMSE): 1.669548658199223e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6695486581992227e-16
#
# Training model for store 10 and family 5...
# Root Mean Squared Error (RMSE): 33.606110297603315
# Root Mean Squared Logarithmic Error (RMSLE): 0.39446649414402357
#
# Training model for store 10 and family 6...
# Root Mean Squared Error (RMSE): 3.9431437264465368
# Root Mean Squared Logarithmic Error (RMSLE): 0.83852051229423
#
# Training model for store 10 and family 7...
# Root Mean Squared Error (RMSE): 287.66136679417224
# Root Mean Squared Logarithmic Error (RMSLE): 0.46718039827991886
#
# Training model for store 10 and family 8...
# Root Mean Squared Error (RMSE): 134.11131379893231
# Root Mean Squared Logarithmic Error (RMSLE): 0.5206097720506261
#
# Training model for store 10 and family 9...
# Root Mean Squared Error (RMSE): 93.45066894223918
# Root Mean Squared Logarithmic Error (RMSLE): 0.46115985334439746
#
# Training model for store 10 and family 10...
# Root Mean Squared Error (RMSE): 32.73783869223144
# Root Mean Squared Logarithmic Error (RMSLE): 0.7343738689886408
#
# Training model for store 10 and family 11...
# Root Mean Squared Error (RMSE): 111.41676184653478
# Root Mean Squared Logarithmic Error (RMSLE): 0.9398549148291504
#
# Training model for store 10 and family 12...
# Root Mean Squared Error (RMSE): 888.0895793450463
# Root Mean Squared Logarithmic Error (RMSLE): 0.530458506737906
#
# Training model for store 10 and family 13...
# Root Mean Squared Error (RMSE): 5.698697191192772
# Root Mean Squared Logarithmic Error (RMSLE): 0.861232658861106
#
# Training model for store 10 and family 14...
# Root Mean Squared Error (RMSE): 0.9227473331477517
# Root Mean Squared Logarithmic Error (RMSLE): 0.5848796817935553
#
# Training model for store 10 and family 15...
# Root Mean Squared Error (RMSE): 9.113115207184258
# Root Mean Squared Logarithmic Error (RMSLE): 0.7719173376816287
#
# Training model for store 10 and family 16...
# Root Mean Squared Error (RMSE): 4.2773616909443355
# Root Mean Squared Logarithmic Error (RMSLE): 0.582612938297795
#
# Training model for store 10 and family 17...
# Root Mean Squared Error (RMSE): 0.3858604086236427
# Root Mean Squared Logarithmic Error (RMSLE): 0.24980905179114118
#
# Training model for store 10 and family 18...
# Root Mean Squared Error (RMSE): 182.7771397796157
# Root Mean Squared Logarithmic Error (RMSLE): 3.8601796635664147
# Training model for store 10 and family 19...
# Root Mean Squared Error (RMSE): 7.2228000177388845
# Root Mean Squared Logarithmic Error (RMSLE): 1.1586561385026146
#
# Training model for store 10 and family 20...
# Root Mean Squared Error (RMSE): 0.004526861477643251
# Root Mean Squared Logarithmic Error (RMSLE): 0.004516646057816068
#
# Training model for store 10 and family 21...
# Root Mean Squared Error (RMSE): 3.240646542326898
# Root Mean Squared Logarithmic Error (RMSLE): 1.0069175402226724
#
# Training model for store 10 and family 22...
# Root Mean Squared Error (RMSE): 14.063126449528472
# Root Mean Squared Logarithmic Error (RMSLE): 0.8801850840106228
#
# Training model for store 10 and family 23...
# Root Mean Squared Error (RMSE): 1.013092813964505
# Root Mean Squared Logarithmic Error (RMSLE): 0.5423709752168363
#
# Training model for store 10 and family 24...
# Root Mean Squared Error (RMSE): 48.932862091848364
# Root Mean Squared Logarithmic Error (RMSLE): 0.41842772917996796
#
# Training model for store 10 and family 25...
# Root Mean Squared Error (RMSE): 76.79997910264628
# Root Mean Squared Logarithmic Error (RMSLE): 0.47877783664020274
#
# Training model for store 10 and family 26...
# Root Mean Squared Error (RMSE): 1.4371137291090954
# Root Mean Squared Logarithmic Error (RMSLE): 0.6788993898010225
#
# Training model for store 10 and family 27...
# Root Mean Squared Error (RMSE): 3.0019361297332794
# Root Mean Squared Logarithmic Error (RMSLE): 0.5815601852501965
#
# Training model for store 10 and family 28...
# Root Mean Squared Error (RMSE): 66.26638879608274
# Root Mean Squared Logarithmic Error (RMSLE): 0.48331502557496797
#
# Training model for store 10 and family 29...
# Root Mean Squared Error (RMSE): 13.142990768783601
# Root Mean Squared Logarithmic Error (RMSLE): 0.47687416784445863
#
# Training model for store 10 and family 30...
# Root Mean Squared Error (RMSE): 84.80860669390246
# Root Mean Squared Logarithmic Error (RMSLE): 0.439046151919904
#
# Training model for store 10 and family 31...
# Root Mean Squared Error (RMSE): 15.918060061717688
# Root Mean Squared Logarithmic Error (RMSLE): 2.5211123578690953
#
# Training model for store 10 and family 32...
# Root Mean Squared Error (RMSE): 2.9891522539364344
# Root Mean Squared Logarithmic Error (RMSLE): 0.9964381471309818
#
# Training model for store 11 and family 0...
# Root Mean Squared Error (RMSE): 4.606624330240524
# Root Mean Squared Logarithmic Error (RMSLE): 0.5902493244129471
#
# Training model for store 11 and family 1...
# Root Mean Squared Error (RMSE): 0.9793719144161447
# Root Mean Squared Logarithmic Error (RMSLE): 0.48940062290560704
#
# Training model for store 11 and family 2...
# Root Mean Squared Error (RMSE): 4.572518564615463
# Root Mean Squared Logarithmic Error (RMSLE): 0.5595386924634166
#
# Training model for store 11 and family 3...
# Root Mean Squared Error (RMSE): 1324.87028875237
# Root Mean Squared Logarithmic Error (RMSLE): 0.528920864403315
#
# Training model for store 11 and family 4...
# Root Mean Squared Error (RMSE): 1.669548658199223e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6695486581992227e-16
#
# Training model for store 11 and family 5...
# Root Mean Squared Error (RMSE): 187.25255980468066
# Root Mean Squared Logarithmic Error (RMSLE): 0.42974226350866235
#
# Training model for store 11 and family 6...
# Root Mean Squared Error (RMSE): 10.028668641959523
# Root Mean Squared Logarithmic Error (RMSLE): 0.6486689309383378
#
# Training model for store 11 and family 7...
# Root Mean Squared Error (RMSE): 764.4436379667177
# Root Mean Squared Logarithmic Error (RMSLE): 0.5307838233685208
#
# Training model for store 11 and family 8...
# Root Mean Squared Error (RMSE): 294.3767894704614
# Root Mean Squared Logarithmic Error (RMSLE): 0.5383085901431482
#
# Training model for store 11 and family 9...
# Root Mean Squared Error (RMSE): 209.52443331681496
# Root Mean Squared Logarithmic Error (RMSLE): 0.540210165500474
#
# Training model for store 11 and family 10...
# Root Mean Squared Error (RMSE): 141.7135497092141
# Root Mean Squared Logarithmic Error (RMSLE): 0.6817922516055543
#
# Training model for store 11 and family 11...
# Root Mean Squared Error (RMSE): 139.5147773987193
# Root Mean Squared Logarithmic Error (RMSLE): 0.6552221449777935
#
# Training model for store 11 and family 12...
# Root Mean Squared Error (RMSE): 2849.2084524553898
# Root Mean Squared Logarithmic Error (RMSLE): 0.6019283121957347
#
# Training model for store 11 and family 13...
# Root Mean Squared Error (RMSE): 19.20639038249256
# Root Mean Squared Logarithmic Error (RMSLE): 0.8012006234853972
#
# Training model for store 11 and family 14...
# Root Mean Squared Error (RMSE): 0.9915128318337043
# Root Mean Squared Logarithmic Error (RMSLE): 0.5189787180090519
#
# Training model for store 11 and family 15...
# Root Mean Squared Error (RMSE): 36.558083489383776
# Root Mean Squared Logarithmic Error (RMSLE): 0.7581520269801268
#
# Training model for store 11 and family 16...
# Root Mean Squared Error (RMSE): 17.519962279587542
# Root Mean Squared Logarithmic Error (RMSLE): 0.6078980303547553
#
# Training model for store 11 and family 17...
# Root Mean Squared Error (RMSE): 0.7192730439117678
# Root Mean Squared Logarithmic Error (RMSLE): 0.46412691103182036
#
# Training model for store 11 and family 18...
# Root Mean Squared Error (RMSE): 206.12240298041345
# Root Mean Squared Logarithmic Error (RMSLE): 0.4971878646905627
#
# Training model for store 11 and family 19...
# Root Mean Squared Error (RMSE): 9.856542639582711
# Root Mean Squared Logarithmic Error (RMSLE): 0.7270676254790632
#
# Training model for store 11 and family 20...
# Root Mean Squared Error (RMSE): 5.999735447747562
# Root Mean Squared Logarithmic Error (RMSLE): 0.7635884624231283
#
# Training model for store 11 and family 21...
# Root Mean Squared Error (RMSE): 4.881553505477176
# Root Mean Squared Logarithmic Error (RMSLE): 0.4965837031705255
#
# Training model for store 11 and family 22...
# Root Mean Squared Error (RMSE): 65.61759682224842
# Root Mean Squared Logarithmic Error (RMSLE): 1.284302167058667
#
# Training model for store 11 and family 23...
# Root Mean Squared Error (RMSE): 3.1829061777376744
# Root Mean Squared Logarithmic Error (RMSLE): 0.6682939985233213
#
# Training model for store 11 and family 24...
# Root Mean Squared Error (RMSE): 183.1544342518799
# Root Mean Squared Logarithmic Error (RMSLE): 0.4612914365706261
#
# Training model for store 11 and family 25...
# Root Mean Squared Error (RMSE): 183.7998598383661
# Root Mean Squared Logarithmic Error (RMSLE): 0.49638287449437823
#
# Training model for store 11 and family 26...
# Root Mean Squared Error (RMSE): 2.324257592173707
# Root Mean Squared Logarithmic Error (RMSLE): 0.6537460020215291
#
# Training model for store 11 and family 27...
# Root Mean Squared Error (RMSE): 10.830997742318202
# Root Mean Squared Logarithmic Error (RMSLE): 0.5269729971660819
#
# Training model for store 11 and family 28...
# Root Mean Squared Error (RMSE): 202.02358723399522
# Root Mean Squared Logarithmic Error (RMSLE): 0.6027085949023696
#
# Training model for store 11 and family 29...
# Root Mean Squared Error (RMSE): 32.461904016402144
# Root Mean Squared Logarithmic Error (RMSLE): 0.43938301026170506
#
# Training model for store 11 and family 30...
# Root Mean Squared Error (RMSE): 808.9343545545131
# Root Mean Squared Logarithmic Error (RMSLE): 0.5784819383924288
#
# Training model for store 11 and family 31...
# Root Mean Squared Error (RMSE): 16.304136882513472
# Root Mean Squared Logarithmic Error (RMSLE): 1.0732537265107223
#
# Training model for store 11 and family 32...
# Root Mean Squared Error (RMSE): 6.748878641031049
# Root Mean Squared Logarithmic Error (RMSLE): 0.6552618384161609
#
# Training model for store 12 and family 0...
# Root Mean Squared Error (RMSE): 3.7157587806869175
# Root Mean Squared Logarithmic Error (RMSLE): 0.5707212507703333
#
# Training model for store 12 and family 1...
# Root Mean Squared Error (RMSE): 0.622343180196768
# Root Mean Squared Logarithmic Error (RMSLE): 0.34637400457514794
#
# Training model for store 12 and family 2...
# Root Mean Squared Error (RMSE): 1.4832825581037739
# Root Mean Squared Logarithmic Error (RMSLE): 0.5915461529936523
#
# Training model for store 12 and family 3...
# Root Mean Squared Error (RMSE): 1155.344497862332
# Root Mean Squared Logarithmic Error (RMSLE): 1.0606195826693918
#
# Training model for store 12 and family 4...
# Root Mean Squared Error (RMSE): 1.669548658199223e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6695486581992227e-16
#
# Training model for store 12 and family 5...
# Root Mean Squared Error (RMSE): 79.74190914835306
# Root Mean Squared Logarithmic Error (RMSLE): 0.4276369882023135
#
# Training model for store 12 and family 6...
# Root Mean Squared Error (RMSE): 12.449226579603394
# Root Mean Squared Logarithmic Error (RMSLE): 0.6917387949612501
#
# Training model for store 12 and family 7...
# Root Mean Squared Error (RMSE): 445.0302895144857
# Root Mean Squared Logarithmic Error (RMSLE): 0.4833882887780362
#
# Training model for store 12 and family 8...
# Root Mean Squared Error (RMSE): 173.1413259739035
# Root Mean Squared Logarithmic Error (RMSLE): 0.5607029980224539
#
# Training model for store 12 and family 9...
# Root Mean Squared Error (RMSE): 54.08779015951407
# Root Mean Squared Logarithmic Error (RMSLE): 0.3640530160090269
#
# Training model for store 12 and family 10...
# Root Mean Squared Error (RMSE): 60.71337892485216
# Root Mean Squared Logarithmic Error (RMSLE): 0.7673640399670724
#
# Training model for store 12 and family 11...
# Root Mean Squared Error (RMSE): 61.8205443525319
# Root Mean Squared Logarithmic Error (RMSLE): 0.5624611789799732
#
# Training model for store 12 and family 12...
# Root Mean Squared Error (RMSE): 839.3266435527457
# Root Mean Squared Logarithmic Error (RMSLE): 0.509312713103879
#
# Training model for store 12 and family 13...
# Root Mean Squared Error (RMSE): 8.250252281111704
# Root Mean Squared Logarithmic Error (RMSLE): 0.8319421823551637
#
# Training model for store 12 and family 14...
# Root Mean Squared Error (RMSE): 1.7364608920677767
# Root Mean Squared Logarithmic Error (RMSLE): 0.5788785749403865
#
# Training model for store 12 and family 15...
# Root Mean Squared Error (RMSE): 10.377356780329526
# Root Mean Squared Logarithmic Error (RMSLE): 0.6200164046491183
#
# Training model for store 12 and family 16...
# Root Mean Squared Error (RMSE): 8.244077918727061
# Root Mean Squared Logarithmic Error (RMSLE): 0.5352980060942597
#
# Training model for store 12 and family 17...
# Root Mean Squared Error (RMSE): 0.5134348711015184
# Root Mean Squared Logarithmic Error (RMSLE): 0.31246819821531413
#
# Training model for store 12 and family 18...
# Root Mean Squared Error (RMSE): 51.751693932951035
# Root Mean Squared Logarithmic Error (RMSLE): 0.38086873217520933
#
# Training model for store 12 and family 19...
# Root Mean Squared Error (RMSE): 5.407016750018058
# Root Mean Squared Logarithmic Error (RMSLE): 1.2173259702493189
#
# Training model for store 12 and family 20...
# Root Mean Squared Error (RMSE): 0.0029897636268287897
# Root Mean Squared Logarithmic Error (RMSLE): 0.002985303171815898
#
# Training model for store 12 and family 21...
# Root Mean Squared Error (RMSE): 5.103434161209716
# Root Mean Squared Logarithmic Error (RMSLE): 1.001419980253628
#
# Training model for store 12 and family 22...
# Root Mean Squared Error (RMSE): 42.01784332867122
# Root Mean Squared Logarithmic Error (RMSLE): 1.1204516667946052
#
# Training model for store 12 and family 23...
# Root Mean Squared Error (RMSE): 1.4883933629261854
# Root Mean Squared Logarithmic Error (RMSLE): 0.5454631116415078
#
# Training model for store 12 and family 24...
# Root Mean Squared Error (RMSE): 632.5575209572132
# Root Mean Squared Logarithmic Error (RMSLE): 0.5173352251893105
#
# Training model for store 12 and family 25...
# Root Mean Squared Error (RMSE): 75.24513099285201
# Root Mean Squared Logarithmic Error (RMSLE): 0.4911600306417859
#
# Training model for store 12 and family 26...
# Root Mean Squared Error (RMSE): 1.566293237898067
# Root Mean Squared Logarithmic Error (RMSLE): 0.5883060665146276
#
# Training model for store 12 and family 27...
# Root Mean Squared Error (RMSE): 4.044446232655496
# Root Mean Squared Logarithmic Error (RMSLE): 0.5803313088357819
#
# Training model for store 12 and family 28...
# Root Mean Squared Error (RMSE): 73.44784914282843
# Root Mean Squared Logarithmic Error (RMSLE): 0.4761122024607317
#
# Training model for store 12 and family 29...
# Root Mean Squared Error (RMSE): 25.43625029013785
# Root Mean Squared Logarithmic Error (RMSLE): 0.5436533004109572
#
# Training model for store 12 and family 30...
# Root Mean Squared Error (RMSE): 80.05764337613753
# Root Mean Squared Logarithmic Error (RMSLE): 0.3910024795154392
#
# Training model for store 12 and family 31...
# Root Mean Squared Error (RMSE): 1.8823890679226438
# Root Mean Squared Logarithmic Error (RMSLE): 0.45152235302472604
#
# Training model for store 12 and family 32...
# Root Mean Squared Error (RMSE): 3.9810606517408913
# Root Mean Squared Logarithmic Error (RMSLE): 0.6895797203538228
#
# Training model for store 13 and family 0...
# Root Mean Squared Error (RMSE): 3.928017492753005
# Root Mean Squared Logarithmic Error (RMSLE): 0.5516664324714399
#
# Training model for store 13 and family 1...
# Root Mean Squared Error (RMSE): 1.669548658199223e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6695486581992227e-16
#
# Training model for store 13 and family 2...
# Root Mean Squared Error (RMSE): 2.3387494689613
# Root Mean Squared Logarithmic Error (RMSLE): 0.6882955689970676
#
# Training model for store 13 and family 3...
# Root Mean Squared Error (RMSE): 459.7324090880337
# Root Mean Squared Logarithmic Error (RMSLE): 0.48930604816808454
#
# Training model for store 13 and family 4...
# Root Mean Squared Error (RMSE): 1.669548658199223e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6695486581992227e-16
#
# Training model for store 13 and family 5...
# Root Mean Squared Error (RMSE): 58.30527172272242
# Root Mean Squared Logarithmic Error (RMSLE): 0.46427807626287504
#
# Training model for store 13 and family 6...
# Root Mean Squared Error (RMSE): 7.3783033690575
# Root Mean Squared Logarithmic Error (RMSLE): 0.6922808860862688
#
# Training model for store 13 and family 7...
# Root Mean Squared Error (RMSE): 386.1581155602585
# Root Mean Squared Logarithmic Error (RMSLE): 0.5792008727265129
#
# Training model for store 13 and family 8...
# Root Mean Squared Error (RMSE): 107.17807980491256
# Root Mean Squared Logarithmic Error (RMSLE): 0.45198602487412054
#
# Training model for store 13 and family 9...
# Root Mean Squared Error (RMSE): 99.09914135962163
# Root Mean Squared Logarithmic Error (RMSLE): 0.7230632808335611
#
# Training model for store 13 and family 10...
# Root Mean Squared Error (RMSE): 39.22931463585768
# Root Mean Squared Logarithmic Error (RMSLE): 0.8008227529088485
#
# Training model for store 13 and family 11...
# Root Mean Squared Error (RMSE): 56.608609973272614
# Root Mean Squared Logarithmic Error (RMSLE): 0.8096606740793729
#
# Training model for store 13 and family 12...
# Root Mean Squared Error (RMSE): 903.4548902611153
# Root Mean Squared Logarithmic Error (RMSLE): 0.516362765235747
#
# Training model for store 13 and family 13...
# Root Mean Squared Error (RMSE): 9.0128366320624
# Root Mean Squared Logarithmic Error (RMSLE): 1.0924671305184022
#
# Training model for store 13 and family 14...
# Root Mean Squared Error (RMSE): 3.1983710820856346
# Root Mean Squared Logarithmic Error (RMSLE): 0.4980360468063555
#
# Training model for store 13 and family 15...
# Root Mean Squared Error (RMSE): 13.085066521093122
# Root Mean Squared Logarithmic Error (RMSLE): 0.7884534662748753
#
# Training model for store 13 and family 16...
# Root Mean Squared Error (RMSE): 7.5308221306405665
# Root Mean Squared Logarithmic Error (RMSLE): 0.6414523502851385
#
# Training model for store 13 and family 17...
# Root Mean Squared Error (RMSE): 0.2807478955572987
# Root Mean Squared Logarithmic Error (RMSLE): 0.20360101940299585
#
# Training model for store 13 and family 18...
# Root Mean Squared Error (RMSE): 157.48020097454415
# Root Mean Squared Logarithmic Error (RMSLE): 3.6429343228924997
#
# Training model for store 13 and family 19...
# Root Mean Squared Error (RMSE): 3.5443948239433283
# Root Mean Squared Logarithmic Error (RMSLE): 1.0013559167717057
#
# Training model for store 13 and family 20...
# Root Mean Squared Error (RMSE): 0.009015453048050404
# Root Mean Squared Logarithmic Error (RMSLE): 0.008975056465345311
#
# Training model for store 13 and family 21...
# Root Mean Squared Error (RMSE): 3.3322620626660298
# Root Mean Squared Logarithmic Error (RMSLE): 0.9031004463291643
#
# Training model for store 13 and family 22...
# Root Mean Squared Error (RMSE): 43.65578315291903
# Root Mean Squared Logarithmic Error (RMSLE): 1.3680585585832536
#
# Training model for store 13 and family 23...
# Root Mean Squared Error (RMSE): 1.3552720440731818
# Root Mean Squared Logarithmic Error (RMSLE): 0.5578726729930416
#
# Training model for store 13 and family 24...
# Root Mean Squared Error (RMSE): 53.54675345960907
# Root Mean Squared Logarithmic Error (RMSLE): 0.4320430094288166
#
# Training model for store 13 and family 25...
# Root Mean Squared Error (RMSE): 81.89241750105921
# Root Mean Squared Logarithmic Error (RMSLE): 0.4793981206555358
#
# Training model for store 13 and family 26...
# Root Mean Squared Error (RMSE): 1.0516972592426854
# Root Mean Squared Logarithmic Error (RMSLE): 0.5606125167928665
#
# Training model for store 13 and family 27...
# Root Mean Squared Error (RMSE): 4.6219797161160106
# Root Mean Squared Logarithmic Error (RMSLE): 0.603929649609355
#
# Training model for store 13 and family 28...
# Root Mean Squared Error (RMSE): 62.287652715891916
# Root Mean Squared Logarithmic Error (RMSLE): 0.5817958586981539
#
# Training model for store 13 and family 29...
# Root Mean Squared Error (RMSE): 23.71556869265097
# Root Mean Squared Logarithmic Error (RMSLE): 0.741310885094457
#
# Training model for store 13 and family 30...
# Root Mean Squared Error (RMSE): 60.167990201800436
# Root Mean Squared Logarithmic Error (RMSLE): 0.40011460395911275
#
# Training model for store 13 and family 31...
# Root Mean Squared Error (RMSE): 1.8868548187196565
# Root Mean Squared Logarithmic Error (RMSLE): 0.36511698057386627
#
# Training model for store 13 and family 32...
# Root Mean Squared Error (RMSE): 2.4290921230372016
# Root Mean Squared Logarithmic Error (RMSLE): 0.7612312376743604
#
# Training model for store 14 and family 0...
# Root Mean Squared Error (RMSE): 3.7747469503940096
# Root Mean Squared Logarithmic Error (RMSLE): 0.643159893908337
#
# Training model for store 14 and family 1...
# Root Mean Squared Error (RMSE): 0.0037622484378516674
# Root Mean Squared Logarithmic Error (RMSLE): 0.003755188882192189
#
# Training model for store 14 and family 2...
# Root Mean Squared Error (RMSE): 1.8134006473121684
# Root Mean Squared Logarithmic Error (RMSLE): 0.6752082921748351
#
# Training model for store 14 and family 3...
# Root Mean Squared Error (RMSE): 937.8503430525217
# Root Mean Squared Logarithmic Error (RMSLE): 1.0906042289132485
#
# Training model for store 14 and family 4...
# Root Mean Squared Error (RMSE): 1.669548658199223e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6695486581992227e-16
#
# Training model for store 14 and family 5...
# Root Mean Squared Error (RMSE): 42.886582167991804
# Root Mean Squared Logarithmic Error (RMSLE): 0.3680476877478436
#
# Training model for store 14 and family 6...
# Root Mean Squared Error (RMSE): 6.96952408594452
# Root Mean Squared Logarithmic Error (RMSLE): 0.717252428392933
#
# Training model for store 14 and family 7...
# Root Mean Squared Error (RMSE): 883.4662239943021
# Root Mean Squared Logarithmic Error (RMSLE): 0.6130859167563657
#
# Training model for store 14 and family 8...
# Root Mean Squared Error (RMSE): 150.81116006781778
# Root Mean Squared Logarithmic Error (RMSLE): 0.4679173806382299
#
# Training model for store 14 and family 9...
# Root Mean Squared Error (RMSE): 80.38468845952484
# Root Mean Squared Logarithmic Error (RMSLE): 0.4272842079396925
#
# Training model for store 14 and family 10...
# Root Mean Squared Error (RMSE): 20.700214912011212
# Root Mean Squared Logarithmic Error (RMSLE): 0.5495016298818262
#
# Training model for store 14 and family 11...
# Root Mean Squared Error (RMSE): 206.12113238167237
# Root Mean Squared Logarithmic Error (RMSLE): 0.8450418799977452
#
# Training model for store 14 and family 12...
# Root Mean Squared Error (RMSE): 1052.2002658773538
# Root Mean Squared Logarithmic Error (RMSLE): 0.5364631338816818
#
# Training model for store 14 and family 13...
# Root Mean Squared Error (RMSE): 8.463328920125383
# Root Mean Squared Logarithmic Error (RMSLE): 1.0598478151100903
#
# Training model for store 14 and family 14...
# Root Mean Squared Error (RMSE): 0.9668857296067022
# Root Mean Squared Logarithmic Error (RMSLE): 0.46366429088512523
#
# Training model for store 14 and family 15...
# Root Mean Squared Error (RMSE): 30.583096823147336
# Root Mean Squared Logarithmic Error (RMSLE): 0.7493968489194427
#
# Training model for store 14 and family 16...
# Root Mean Squared Error (RMSE): 11.396530656381033
# Root Mean Squared Logarithmic Error (RMSLE): 0.5573172569901733
#
# Training model for store 14 and family 17...
# Root Mean Squared Error (RMSE): 0.43621476000543574
# Root Mean Squared Logarithmic Error (RMSLE): 0.2830904521994552
#
# Training model for store 14 and family 18...
# Root Mean Squared Error (RMSE): 213.9924066469192
# Root Mean Squared Logarithmic Error (RMSLE): 3.461823101584782
#
# Training model for store 14 and family 19...
# Root Mean Squared Error (RMSE): 2.5077877697748483
# Root Mean Squared Logarithmic Error (RMSLE): 0.674950565156682
#
# Training model for store 14 and family 20...
# Root Mean Squared Error (RMSE): 1.669548658199223e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6695486581992227e-16
#
# Training model for store 14 and family 21...
# Root Mean Squared Error (RMSE): 4.835157810632091
# Root Mean Squared Logarithmic Error (RMSLE): 1.0727247749466302
#
# Training model for store 14 and family 22...
# Root Mean Squared Error (RMSE): 28.189720637116263
# Root Mean Squared Logarithmic Error (RMSLE): 0.9591434365078647
#
# Training model for store 14 and family 23...
# Root Mean Squared Error (RMSE): 1.734940169409949
# Root Mean Squared Logarithmic Error (RMSLE): 0.59069276764106
#
# Training model for store 14 and family 24...
# Root Mean Squared Error (RMSE): 138.37452808260304
# Root Mean Squared Logarithmic Error (RMSLE): 0.5865887736903062
#
# Training model for store 14 and family 25...
# Root Mean Squared Error (RMSE): 106.97402972805861
# Root Mean Squared Logarithmic Error (RMSLE): 0.45394359570242954
#
# Training model for store 14 and family 26...
# Root Mean Squared Error (RMSE): 1.4615493172652612
# Root Mean Squared Logarithmic Error (RMSLE): 0.7028622790665747
#
# Training model for store 14 and family 27...
# Root Mean Squared Error (RMSE): 4.481722874195328
# Root Mean Squared Logarithmic Error (RMSLE): 0.6052946391918037
#
# Training model for store 14 and family 28...
# Root Mean Squared Error (RMSE): 74.50843951283058
# Root Mean Squared Logarithmic Error (RMSLE): 0.7227068984300211
#
# Training model for store 14 and family 29...
# Root Mean Squared Error (RMSE): 32.44576870601357
# Root Mean Squared Logarithmic Error (RMSLE): 0.45542271054494515
#
# Training model for store 14 and family 30...
# Root Mean Squared Error (RMSE): 116.97031536920996
# Root Mean Squared Logarithmic Error (RMSLE): 0.43199571934111297
#
# Training model for store 14 and family 31...
# Root Mean Squared Error (RMSE): 3.3841814402093813
# Root Mean Squared Logarithmic Error (RMSLE): 0.70597388835627
#
# Training model for store 14 and family 32...
# Root Mean Squared Error (RMSE): 3.901601743294366
# Root Mean Squared Logarithmic Error (RMSLE): 0.7057389053714782
#
# Training model for store 15 and family 0...
# Root Mean Squared Error (RMSE): 2.5225828737451974
# Root Mean Squared Logarithmic Error (RMSLE): 0.5670458952270727
#
# Training model for store 15 and family 1...
# Root Mean Squared Error (RMSE): 2.5247655638710746
# Root Mean Squared Logarithmic Error (RMSLE): 0.9378981669162498
#
# Training model for store 15 and family 2...
# Root Mean Squared Error (RMSE): 2.2868220996900988
# Root Mean Squared Logarithmic Error (RMSLE): 0.6612899740195303
#
# Training model for store 15 and family 3...
# Root Mean Squared Error (RMSE): 374.259775216246
# Root Mean Squared Logarithmic Error (RMSLE): 0.45523483785897484
#
# Training model for store 15 and family 4...
# Root Mean Squared Error (RMSE): 1.669548658199223e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6695486581992227e-16
#
# Training model for store 15 and family 5...
# Root Mean Squared Error (RMSE): 44.41396537997122
# Root Mean Squared Logarithmic Error (RMSLE): 0.38048261137244455
#
# Training model for store 15 and family 6...
# Root Mean Squared Error (RMSE): 5.117076141913684
# Root Mean Squared Logarithmic Error (RMSLE): 0.9463894268446293
#
# Training model for store 15 and family 7...
# Root Mean Squared Error (RMSE): 392.99438972355904
# Root Mean Squared Logarithmic Error (RMSLE): 0.4795937805441186
#
# Training model for store 15 and family 8...
# Root Mean Squared Error (RMSE): 102.29983515542163
# Root Mean Squared Logarithmic Error (RMSLE): 0.4143563370783167
#
# Training model for store 15 and family 9...
# Root Mean Squared Error (RMSE): 68.0589367170483
# Root Mean Squared Logarithmic Error (RMSLE): 0.37912255629837094
# Training model for store 15 and family 10...
# Root Mean Squared Error (RMSE): 47.61750785232398
# Root Mean Squared Logarithmic Error (RMSLE): 0.5493451125281849
#
# Training model for store 15 and family 11...
# Root Mean Squared Error (RMSE): 82.3237972071843
# Root Mean Squared Logarithmic Error (RMSLE): 0.5269387925708867
#
# Training model for store 15 and family 12...
# Root Mean Squared Error (RMSE): 796.1747190327004
# Root Mean Squared Logarithmic Error (RMSLE): 0.4923604790584909
#
# Training model for store 15 and family 13...
# Root Mean Squared Error (RMSE): 9.381745606465094
# Root Mean Squared Logarithmic Error (RMSLE): 0.8601314237201773
#
# Training model for store 15 and family 14...
# Root Mean Squared Error (RMSE): 1.2185358693543167
# Root Mean Squared Logarithmic Error (RMSLE): 0.5810632295891649
#
# Training model for store 15 and family 15...
# Root Mean Squared Error (RMSE): 90.74503366049312
# Root Mean Squared Logarithmic Error (RMSLE): 1.5100191597368327
#
# Training model for store 15 and family 16...
# Root Mean Squared Error (RMSE): 12.275874386947882
# Root Mean Squared Logarithmic Error (RMSLE): 0.6170445238205314
#
# Training model for store 15 and family 17...
# Root Mean Squared Error (RMSE): 0.3017617441583291
# Root Mean Squared Logarithmic Error (RMSLE): 0.1948863999915258
#
# Training model for store 15 and family 18...
# Root Mean Squared Error (RMSE): 60.71068538920525
# Root Mean Squared Logarithmic Error (RMSLE): 0.39327893584950924
#
# Training model for store 15 and family 19...
# Root Mean Squared Error (RMSE): 6.225026611405845
# Root Mean Squared Logarithmic Error (RMSLE): 0.7069029949630364
#
# Training model for store 15 and family 20...
# Root Mean Squared Error (RMSE): 0.009700112044811249
# Root Mean Squared Logarithmic Error (RMSLE): 0.009653367996549743
#
# Training model for store 15 and family 21...
# Root Mean Squared Error (RMSE): 3.7444911645006966
# Root Mean Squared Logarithmic Error (RMSLE): 0.7216641086904874
#
# Training model for store 15 and family 22...
# Root Mean Squared Error (RMSE): 24.552946977854724
# Root Mean Squared Logarithmic Error (RMSLE): 0.9425495110380433
#
# Training model for store 15 and family 23...
# Root Mean Squared Error (RMSE): 2.499176501603486
# Root Mean Squared Logarithmic Error (RMSLE): 1.0220049209350992
#
# Training model for store 15 and family 24...
# Root Mean Squared Error (RMSE): 34.42508836437584
# Root Mean Squared Logarithmic Error (RMSLE): 0.3634733837356669
#
# Training model for store 15 and family 25...
# Root Mean Squared Error (RMSE): 49.75990277358757
# Root Mean Squared Logarithmic Error (RMSLE): 0.3717451266804235
#
# Training model for store 15 and family 26...
# Root Mean Squared Error (RMSE): 1.7661120592055688
# Root Mean Squared Logarithmic Error (RMSLE): 0.779478225556583
#
# Training model for store 15 and family 27...
# Root Mean Squared Error (RMSE): 3.5865918895969795
# Root Mean Squared Logarithmic Error (RMSLE): 0.540980722529125
#
# Training model for store 15 and family 28...
# Root Mean Squared Error (RMSE): 46.45492799191467
# Root Mean Squared Logarithmic Error (RMSLE): 0.44694561186149756
#
# Training model for store 15 and family 29...
# Root Mean Squared Error (RMSE): 31.388414166643635
# Root Mean Squared Logarithmic Error (RMSLE): 0.9099574546790163
#
# Training model for store 15 and family 30...
# Root Mean Squared Error (RMSE): 225.56590538999623
# Root Mean Squared Logarithmic Error (RMSLE): 0.46589614957168013
#
# Training model for store 15 and family 31...
# Root Mean Squared Error (RMSE): 3.1427327874064455
# Root Mean Squared Logarithmic Error (RMSLE): 0.4951305161270256
#
# Training model for store 15 and family 32...
# Root Mean Squared Error (RMSE): 3.5850310468272903
# Root Mean Squared Logarithmic Error (RMSLE): 0.5252267075017495
#
# Training model for store 16 and family 0...
# Root Mean Squared Error (RMSE): 3.521301733350273
# Root Mean Squared Logarithmic Error (RMSLE): 0.7264229177139762
#
# Training model for store 16 and family 1...
# Root Mean Squared Error (RMSE): 0.30709507547587217
# Root Mean Squared Logarithmic Error (RMSLE): 0.17918566899897428
#
# Training model for store 16 and family 2...
# Root Mean Squared Error (RMSE): 1.4153632276529804
# Root Mean Squared Logarithmic Error (RMSLE): 0.6230029643907904
#
# Training model for store 16 and family 3...
# Root Mean Squared Error (RMSE): 474.55305699716496
# Root Mean Squared Logarithmic Error (RMSLE): 0.49868559031871545
#
# Training model for store 16 and family 4...
# Root Mean Squared Error (RMSE): 1.669548658199223e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6695486581992227e-16
#
# Training model for store 16 and family 5...
# Root Mean Squared Error (RMSE): 86.08285033730768
# Root Mean Squared Logarithmic Error (RMSLE): 0.5754493587486916
#
# Training model for store 16 and family 6...
# Root Mean Squared Error (RMSE): 5.471787734662844
# Root Mean Squared Logarithmic Error (RMSLE): 0.7238695937628051
#
# Training model for store 16 and family 7...
# Root Mean Squared Error (RMSE): 905.374971478599
# Root Mean Squared Logarithmic Error (RMSLE): 0.6289023694488505
#
# Training model for store 16 and family 8...
# Root Mean Squared Error (RMSE): 84.44169063676044
# Root Mean Squared Logarithmic Error (RMSLE): 0.42732861194568134
#
# Training model for store 16 and family 9...
# Root Mean Squared Error (RMSE): 61.534742914753956
# Root Mean Squared Logarithmic Error (RMSLE): 0.4482670099819612
#
# Training model for store 16 and family 10...
# Root Mean Squared Error (RMSE): 152.05923609121984
# Root Mean Squared Logarithmic Error (RMSLE): 0.8588409361774205
#
# Training model for store 16 and family 11...
# Root Mean Squared Error (RMSE): 82.28895318635946
# Root Mean Squared Logarithmic Error (RMSLE): 0.8105430908094511
#
# Training model for store 16 and family 12...
# Root Mean Squared Error (RMSE): 859.1918414335479
# Root Mean Squared Logarithmic Error (RMSLE): 0.5420787219230966
#
# Training model for store 16 and family 13...
# Root Mean Squared Error (RMSE): 10.148115680425397
# Root Mean Squared Logarithmic Error (RMSLE): 1.0305379879365808
#
# Training model for store 16 and family 14...
# Root Mean Squared Error (RMSE): 0.7763711127307903
# Root Mean Squared Logarithmic Error (RMSLE): 0.5112758076597482
#
# Training model for store 16 and family 15...
# Root Mean Squared Error (RMSE): 11.065806220490657
# Root Mean Squared Logarithmic Error (RMSLE): 0.675441772834696
#
# Training model for store 16 and family 16...
# Root Mean Squared Error (RMSE): 12.362232193430518
# Root Mean Squared Logarithmic Error (RMSLE): 0.6199065288618473
#
# Training model for store 16 and family 17...
# Root Mean Squared Error (RMSE): 0.3296249810009272
# Root Mean Squared Logarithmic Error (RMSLE): 0.215002198883731
#
# Training model for store 16 and family 18...
# Root Mean Squared Error (RMSE): 112.67267742925056
# Root Mean Squared Logarithmic Error (RMSLE): 0.579047884230311
#
# Training model for store 16 and family 19...
# Root Mean Squared Error (RMSE): 1.669548658199223e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6695486581992227e-16
#
# Training model for store 16 and family 20...
# Root Mean Squared Error (RMSE): 0.009784388355910778
# Root Mean Squared Logarithmic Error (RMSLE): 0.009736831188400668
#
# Training model for store 16 and family 21...
# Root Mean Squared Error (RMSE): 4.573913519755567
# Root Mean Squared Logarithmic Error (RMSLE): 1.2771057417749148
#
# Training model for store 16 and family 22...
# Root Mean Squared Error (RMSE): 60.47590700837088
# Root Mean Squared Logarithmic Error (RMSLE): 1.1740659270015952
#
# Training model for store 16 and family 23...
# Root Mean Squared Error (RMSE): 1.2232936858511603
# Root Mean Squared Logarithmic Error (RMSLE): 0.5259480898281385
#
# Training model for store 16 and family 24...
# Root Mean Squared Error (RMSE): 33.263480947933196
# Root Mean Squared Logarithmic Error (RMSLE): 0.5864369272172727
#
# Training model for store 16 and family 25...
# Root Mean Squared Error (RMSE): 80.4515728667053
# Root Mean Squared Logarithmic Error (RMSLE): 0.5603066069484802
#
# Training model for store 16 and family 26...
# Root Mean Squared Error (RMSE): 1.5826824947939833
# Root Mean Squared Logarithmic Error (RMSLE): 0.7159463737755792
#
# Training model for store 16 and family 27...
# Root Mean Squared Error (RMSE): 2.8441817633676223
# Root Mean Squared Logarithmic Error (RMSLE): 0.6967490005171711
# Training model for store 16 and family 28...
# Root Mean Squared Error (RMSE): 49.88683863600973
# Root Mean Squared Logarithmic Error (RMSLE): 0.610670707921535
#
# Training model for store 16 and family 29...
# Root Mean Squared Error (RMSE): 14.892438287519633
# Root Mean Squared Logarithmic Error (RMSLE): 0.44653681611805407
#
# Training model for store 16 and family 30...
# Root Mean Squared Error (RMSE): 317.1446252198254
# Root Mean Squared Logarithmic Error (RMSLE): 0.5824464513713153
#
# Training model for store 16 and family 31...
# Root Mean Squared Error (RMSE): 15.38274777412253
# Root Mean Squared Logarithmic Error (RMSLE): 1.2882920223152896
#
# Training model for store 16 and family 32...
# Root Mean Squared Error (RMSE): 2.8102419547680397
# Root Mean Squared Logarithmic Error (RMSLE): 1.035425812883573
#
# Training model for store 17 and family 0...
# Root Mean Squared Error (RMSE): 7.490148816015146
# Root Mean Squared Logarithmic Error (RMSLE): 0.694796468063326
#
# Training model for store 17 and family 1...
# Root Mean Squared Error (RMSE): 0.9145084185139433
# Root Mean Squared Logarithmic Error (RMSLE): 0.46538392454482347
#
# Training model for store 17 and family 2...
# Root Mean Squared Error (RMSE): 2.7847401897301487
# Root Mean Squared Logarithmic Error (RMSLE): 0.6625793462062866
#
# Training model for store 17 and family 3...
# Root Mean Squared Error (RMSE): 1389.1223818703238
# Root Mean Squared Logarithmic Error (RMSLE): 0.5896422404270364
#
# Training model for store 17 and family 4...
# Root Mean Squared Error (RMSE): 1.669548658199223e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6695486581992227e-16
#
# Training model for store 17 and family 5...
# Root Mean Squared Error (RMSE): 223.34351320759365
# Root Mean Squared Logarithmic Error (RMSLE): 0.7508876213541382
#
# Training model for store 17 and family 6...
# Root Mean Squared Error (RMSE): 8.756813553737592
# Root Mean Squared Logarithmic Error (RMSLE): 0.9984045039288082
#
# Training model for store 17 and family 7...
# Root Mean Squared Error (RMSE): 489.37769671532885
# Root Mean Squared Logarithmic Error (RMSLE): 0.542303826653079
#
# Training model for store 17 and family 8...
# Root Mean Squared Error (RMSE): 403.99764999631225
# Root Mean Squared Logarithmic Error (RMSLE): 0.6727562301366286
#
# Training model for store 17 and family 9...
# Root Mean Squared Error (RMSE): 271.19449159229725
# Root Mean Squared Logarithmic Error (RMSLE): 0.6845003280001263
#
# Training model for store 17 and family 10...
# Root Mean Squared Error (RMSE): 238.51894658675005
# Root Mean Squared Logarithmic Error (RMSLE): 0.7854016499358155
#
# Training model for store 17 and family 11...
# Root Mean Squared Error (RMSE): 141.42339691368417
# Root Mean Squared Logarithmic Error (RMSLE): 0.6627412457652174
#
# Training model for store 17 and family 12...
# Root Mean Squared Error (RMSE): 2357.089404354718
# Root Mean Squared Logarithmic Error (RMSLE): 0.6707645664223492
#
# Training model for store 17 and family 13...
# Root Mean Squared Error (RMSE): 12.511055349784304
# Root Mean Squared Logarithmic Error (RMSLE): 0.9850434578075226
#
# Training model for store 17 and family 14...
# Root Mean Squared Error (RMSE): 1.4980785812311526
# Root Mean Squared Logarithmic Error (RMSLE): 0.5823740063058328
#
# Training model for store 17 and family 15...
# Root Mean Squared Error (RMSE): 23.992219335013473
# Root Mean Squared Logarithmic Error (RMSLE): 0.766699153806254
#
# Training model for store 17 and family 16...
# Root Mean Squared Error (RMSE): 43.52834091947749
# Root Mean Squared Logarithmic Error (RMSLE): 1.4337000841182703
#
# Training model for store 17 and family 17...
# Root Mean Squared Error (RMSE): 0.7742755996609222
# Root Mean Squared Logarithmic Error (RMSLE): 0.4267454354688538
#
# Training model for store 17 and family 18...
# Root Mean Squared Error (RMSE): 127.43014849779712
# Root Mean Squared Logarithmic Error (RMSLE): 0.5090498400047508
#
# Training model for store 17 and family 19...
# Root Mean Squared Error (RMSE): 4.793177029688222
# Root Mean Squared Logarithmic Error (RMSLE): 0.9333753333021088
#
# Training model for store 17 and family 20...
# Root Mean Squared Error (RMSE): 0.03932259976863861
# Root Mean Squared Logarithmic Error (RMSLE): 0.03856915455876459
#
# Training model for store 17 and family 21...
# Root Mean Squared Error (RMSE): 5.0461847332665215
# Root Mean Squared Logarithmic Error (RMSLE): 0.6830416443619849
#
# Training model for store 17 and family 22...
# Root Mean Squared Error (RMSE): 49.225446032576365
# Root Mean Squared Logarithmic Error (RMSLE): 1.0810638728820257
#
# Training model for store 17 and family 23...
# Root Mean Squared Error (RMSE): 2.5049824235242224
# Root Mean Squared Logarithmic Error (RMSLE): 0.6282533369717629
#
# Training model for store 17 and family 24...
# Root Mean Squared Error (RMSE): 68.7268788973189
# Root Mean Squared Logarithmic Error (RMSLE): 0.4050933382949664
#
# Training model for store 17 and family 25...
# Root Mean Squared Error (RMSE): 158.82140924579676
# Root Mean Squared Logarithmic Error (RMSLE): 0.6431047952849032
#
# Training model for store 17 and family 26...
# Root Mean Squared Error (RMSE): 7.42580824768052
# Root Mean Squared Logarithmic Error (RMSLE): 1.3468391166575777
#
# Training model for store 17 and family 27...
# Root Mean Squared Error (RMSE): 8.354103758541077
# Root Mean Squared Logarithmic Error (RMSLE): 0.7030723593982847
#
# Training model for store 17 and family 28...
# Root Mean Squared Error (RMSE): 149.66337823910064
# Root Mean Squared Logarithmic Error (RMSLE): 0.5374943145837219
#
# Training model for store 17 and family 29...
# Root Mean Squared Error (RMSE): 30.924708948042515
# Root Mean Squared Logarithmic Error (RMSLE): 0.43601772705435676
#
# Training model for store 17 and family 30...
# Root Mean Squared Error (RMSE): 614.085502347555
# Root Mean Squared Logarithmic Error (RMSLE): 0.5882653111575563
#
# Training model for store 17 and family 31...
# Root Mean Squared Error (RMSE): 6.021826490979648
# Root Mean Squared Logarithmic Error (RMSLE): 1.5708683243605421
#
# Training model for store 17 and family 32...
# Root Mean Squared Error (RMSE): 8.350766451965283
# Root Mean Squared Logarithmic Error (RMSLE): 0.5730426945494361
#
# Training model for store 18 and family 0...
# Root Mean Squared Error (RMSE): 3.4843655471995167
# Root Mean Squared Logarithmic Error (RMSLE): 1.0065013616199467
#
# Training model for store 18 and family 1...
# Root Mean Squared Error (RMSE): 0.7529838102378622
# Root Mean Squared Logarithmic Error (RMSLE): 0.40306972110668704
#
# ...
# Root Mean Squared Logarithmic Error (RMSLE): 2.064072241837935
#
# Training model for store 6 and family 32...
# Root Mean Squared Error (RMSE): 18.645159029099123
# Root Mean Squared Logarithmic Error (RMSLE): 0.46958032964925367
#
# Training model for store 7 and family 0...
# Root Mean Squared Error (RMSE): 3.641745106217578
# Root Mean Squared Logarithmic Error (RMSLE): 0.6387604477970678
#
# Training model for store 7 and family 1...
# Root Mean Squared Error (RMSE): 0.4219496925306454
# Root Mean Squared Logarithmic Error (RMSLE): 0.2698389577204374
#
# Training model for store 7 and family 2...
# Root Mean Squared Error (RMSE): 2.8365319798927424
# Root Mean Squared Logarithmic Error (RMSLE): 0.5381049204552645
#
# Training model for store 7 and family 3...
# Root Mean Squared Error (RMSE): 1012.2138804427535
# Root Mean Squared Logarithmic Error (RMSLE): 0.5049779862405147
#
# Training model for store 7 and family 4...
# Root Mean Squared Error (RMSE): 1.683397722813915
# Root Mean Squared Logarithmic Error (RMSLE): 0.6175152067684467
#
# Training model for store 7 and family 5...
# Root Mean Squared Error (RMSE): 310.3597889846139
# Root Mean Squared Logarithmic Error (RMSLE): 0.5662722047649872
#
# Training model for store 7 and family 6...
# Root Mean Squared Error (RMSE): 9.901763907787185
# Root Mean Squared Logarithmic Error (RMSLE): 0.5251952410748633
#
# Training model for store 7 and family 7...
# Root Mean Squared Error (RMSE): 285.05055436858976
# Root Mean Squared Logarithmic Error (RMSLE): 0.4473093044635733
#
# Training model for store 7 and family 8...
# Root Mean Squared Error (RMSE): 294.1239161987196
# Root Mean Squared Logarithmic Error (RMSLE): 0.44098783023968896
#
# Training model for store 7 and family 9...
# Root Mean Squared Error (RMSE): 52.43557463163298
# Root Mean Squared Logarithmic Error (RMSLE): 0.4008639470192698
#
# Training model for store 7 and family 10...
# Root Mean Squared Error (RMSE): 55.79468043194211
# Root Mean Squared Logarithmic Error (RMSLE): 0.3587388030820316
#
# Training model for store 7 and family 11...
# Root Mean Squared Error (RMSE): 216.52615439231036
# Root Mean Squared Logarithmic Error (RMSLE): 0.5111068566121509
#
# Training model for store 7 and family 12...
# Root Mean Squared Error (RMSE): 1107.4745208343363
# Root Mean Squared Logarithmic Error (RMSLE): 0.5109788540906174
#
# Training model for store 7 and family 13...
# Root Mean Squared Error (RMSE): 16.517079176237797
# Root Mean Squared Logarithmic Error (RMSLE): 0.44332603193687625
#
# Training model for store 7 and family 14...
# Root Mean Squared Error (RMSE): 2.3972812050024683
# Root Mean Squared Logarithmic Error (RMSLE): 0.6108136692135968
#
# Training model for store 7 and family 15...
# Root Mean Squared Error (RMSE): 30.410923385369323
# Root Mean Squared Logarithmic Error (RMSLE): 0.7851856596786894
#
# Training model for store 7 and family 16...
# Root Mean Squared Error (RMSE): 24.198382749589445
# Root Mean Squared Logarithmic Error (RMSLE): 0.6366314049667231
#
# Training model for store 7 and family 17...
# Root Mean Squared Error (RMSE): 1.136069789235167
# Root Mean Squared Logarithmic Error (RMSLE): 0.5255485204491934
#
# Training model for store 7 and family 18...
# Root Mean Squared Error (RMSE): 64.72378034486012
# Root Mean Squared Logarithmic Error (RMSLE): 0.39127591704587156
#
# Training model for store 7 and family 19...
# Root Mean Squared Error (RMSE): 7.699206423402146
# Root Mean Squared Logarithmic Error (RMSLE): 0.5604187548227371
#
# Training model for store 7 and family 20...
# Root Mean Squared Error (RMSE): 36.087876211258255
# Root Mean Squared Logarithmic Error (RMSLE): 1.3209277174429068
#
# Training model for store 7 and family 21...
# Root Mean Squared Error (RMSE): 7.187966274689015
# Root Mean Squared Logarithmic Error (RMSLE): 0.9528966454856368
#
# Training model for store 7 and family 22...
# Root Mean Squared Error (RMSE): 142.74825959128253
# Root Mean Squared Logarithmic Error (RMSLE): 2.2439714093117544
#
# Training model for store 7 and family 23...
# Root Mean Squared Error (RMSE): 6.697967562793313
# Root Mean Squared Logarithmic Error (RMSLE): 0.4997199108568602
#
# Training model for store 7 and family 24...
# Root Mean Squared Error (RMSE): 167.95107505146484
# Root Mean Squared Logarithmic Error (RMSLE): 0.45460565986020085
#
# Training model for store 7 and family 25...
# Root Mean Squared Error (RMSE): 77.44007748199043
# Root Mean Squared Logarithmic Error (RMSLE): 0.4145822036133907
#
# Training model for store 7 and family 26...
# Root Mean Squared Error (RMSE): 4.580248296745732
# Root Mean Squared Logarithmic Error (RMSLE): 0.5516481432506789
# Training model for store 7 and family 27...
# Root Mean Squared Error (RMSE): 6.8335344785322265
# Root Mean Squared Logarithmic Error (RMSLE): 0.46676122165905
#
# Training model for store 7 and family 28...
# Root Mean Squared Error (RMSE): 155.01800556008618
# Root Mean Squared Logarithmic Error (RMSLE): 0.4131247089667356
#
# Training model for store 7 and family 29...
# Root Mean Squared Error (RMSE): 43.87987227541827
# Root Mean Squared Logarithmic Error (RMSLE): 0.37727937778328147
#
# Training model for store 7 and family 30...
# Root Mean Squared Error (RMSE): 1727.9400714055382
# Root Mean Squared Logarithmic Error (RMSLE): 0.5672191402019491
#
# Training model for store 7 and family 31...
# Root Mean Squared Error (RMSE): 0.9148557325788642
# Root Mean Squared Logarithmic Error (RMSLE): 0.47019829977910055
#
# Training model for store 7 and family 32...
# Root Mean Squared Error (RMSE): 22.120981618689857
# Root Mean Squared Logarithmic Error (RMSLE): 0.49395294796413675
#
# Training model for store 8 and family 0...
# Root Mean Squared Error (RMSE): 4.172204320050739
# Root Mean Squared Logarithmic Error (RMSLE): 0.6519213085442301
#
# Training model for store 8 and family 1...
# Root Mean Squared Error (RMSE): 0.7519341132661636
# Root Mean Squared Logarithmic Error (RMSLE): 0.42693620222254325
#
# Training model for store 8 and family 2...
# Root Mean Squared Error (RMSE): 6.659550314111272
# Root Mean Squared Logarithmic Error (RMSLE): 0.5727481791118106
#
# Training model for store 8 and family 3...
# Root Mean Squared Error (RMSE): 1960.2092128920915
# Root Mean Squared Logarithmic Error (RMSLE): 0.5806536475885214
#
# Training model for store 8 and family 4...
# Root Mean Squared Error (RMSE): 1.8384292095310533
# Root Mean Squared Logarithmic Error (RMSLE): 0.7486912613216963
#
# Training model for store 8 and family 5...
# Root Mean Squared Error (RMSE): 283.24597731611925
# Root Mean Squared Logarithmic Error (RMSLE): 0.4794281107454856
#
# Training model for store 8 and family 6...
# Root Mean Squared Error (RMSE): 14.236960804687701
# Root Mean Squared Logarithmic Error (RMSLE): 0.5219648418401657
#
# Training model for store 8 and family 7...
# Root Mean Squared Error (RMSE): 327.7586598261674
# Root Mean Squared Logarithmic Error (RMSLE): 0.4496332026380586
#
# Training model for store 8 and family 8...
# Root Mean Squared Error (RMSE): 476.7021755612731
# Root Mean Squared Logarithmic Error (RMSLE): 0.49462652682360564
#
# Training model for store 8 and family 9...
# Root Mean Squared Error (RMSE): 98.50899503698047
# Root Mean Squared Logarithmic Error (RMSLE): 0.43634825519805415
#
# Training model for store 8 and family 10...
# Root Mean Squared Error (RMSE): 121.45382605488489
# Root Mean Squared Logarithmic Error (RMSLE): 0.4532405354660713
#
# Training model for store 8 and family 11...
# Root Mean Squared Error (RMSE): 305.3730885760449
# Root Mean Squared Logarithmic Error (RMSLE): 0.5952435196719894
#
# Training model for store 8 and family 12...
# Root Mean Squared Error (RMSE): 1936.2529949640118
# Root Mean Squared Logarithmic Error (RMSLE): 0.5755271090858005
#
# Training model for store 8 and family 13...
# Root Mean Squared Error (RMSE): 19.017233151550858
# Root Mean Squared Logarithmic Error (RMSLE): 0.5051267263457306
#
# Training model for store 8 and family 14...
# Root Mean Squared Error (RMSE): 2.5439704435758683
# Root Mean Squared Logarithmic Error (RMSLE): 0.6150109805340442
#
# Training model for store 8 and family 15...
# Root Mean Squared Error (RMSE): 30.59189152036767
# Root Mean Squared Logarithmic Error (RMSLE): 0.6051402823839255
#
# Training model for store 8 and family 16...
# Root Mean Squared Error (RMSE): 34.90352651449997
# Root Mean Squared Logarithmic Error (RMSLE): 0.6122007648045926
#
# Training model for store 8 and family 17...
# Root Mean Squared Error (RMSE): 1.588211329120354
# Root Mean Squared Logarithmic Error (RMSLE): 0.6289641959468539
#
# Training model for store 8 and family 18...
# Root Mean Squared Error (RMSE): 154.0918874726135
# Root Mean Squared Logarithmic Error (RMSLE): 0.4917378270782879
#
# Training model for store 8 and family 19...
# Root Mean Squared Error (RMSE): 18.263669318818597
# Root Mean Squared Logarithmic Error (RMSLE): 0.5195699001536427
#
# Training model for store 8 and family 20...
# Root Mean Squared Error (RMSE): 32.45301223199821
# Root Mean Squared Logarithmic Error (RMSLE): 1.0165696047637094
#
# Training model for store 8 and family 21...
# Root Mean Squared Error (RMSE): 9.46183337516181
# Root Mean Squared Logarithmic Error (RMSLE): 0.4644969817385511
#
# Training model for store 8 and family 22...
# Root Mean Squared Error (RMSE): 114.37364926333804
# Root Mean Squared Logarithmic Error (RMSLE): 1.060229845333699
#
# Training model for store 8 and family 23...
# Root Mean Squared Error (RMSE): 8.891929431571999
# Root Mean Squared Logarithmic Error (RMSLE): 0.5027110256685898
#
# Training model for store 8 and family 24...
# Root Mean Squared Error (RMSE): 220.5716018811251
# Root Mean Squared Logarithmic Error (RMSLE): 0.4998449468435685
#
# Training model for store 8 and family 25...
# Root Mean Squared Error (RMSE): 164.34331224745546
# Root Mean Squared Logarithmic Error (RMSLE): 0.550312819665303
#
# Training model for store 8 and family 26...
# Root Mean Squared Error (RMSE): 12.156251163575398
# Root Mean Squared Logarithmic Error (RMSLE): 0.8039796572093966
#
# Training model for store 8 and family 27...
# Root Mean Squared Error (RMSE): 10.895877792175222
# Root Mean Squared Logarithmic Error (RMSLE): 0.5397029411610171
#
# Training model for store 8 and family 28...
# Root Mean Squared Error (RMSE): 221.56586536019609
# Root Mean Squared Logarithmic Error (RMSLE): 0.48394140293200427
#
# Training model for store 8 and family 29...
# Root Mean Squared Error (RMSE): 64.10659065413859
# Root Mean Squared Logarithmic Error (RMSLE): 0.4416400780765555
#
# Training model for store 8 and family 30...
# Root Mean Squared Error (RMSE): 1639.2531966742265
# Root Mean Squared Logarithmic Error (RMSLE): 0.5547810621019441
#
# Training model for store 8 and family 31...
# Root Mean Squared Error (RMSE): 1.4311542191273796
# Root Mean Squared Logarithmic Error (RMSLE): 0.5541707706768099
#
# Training model for store 8 and family 32...
# Root Mean Squared Error (RMSE): 21.57974998333623
# Root Mean Squared Logarithmic Error (RMSLE): 0.4944855632346692
#
# Training model for store 9 and family 0...
# Root Mean Squared Error (RMSE): 6.5972440108870485
# Root Mean Squared Logarithmic Error (RMSLE): 0.5923795553327895
#
# Training model for store 9 and family 1...
# Root Mean Squared Error (RMSE): 0.7819572118748224
# Root Mean Squared Logarithmic Error (RMSLE): 0.4198079518291146
#
# Training model for store 9 and family 2...
# Root Mean Squared Error (RMSE): 5.9907374009080545
# Root Mean Squared Logarithmic Error (RMSLE): 0.6286991655130261
#
# Training model for store 9 and family 3...
# Root Mean Squared Error (RMSE): 1643.6522965131626
# Root Mean Squared Logarithmic Error (RMSLE): 0.5831625915612085
#
# Training model for store 9 and family 4...
# Root Mean Squared Error (RMSE): 1.669548658199223e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6695486581992227e-16
#
# Training model for store 9 and family 5...
# Root Mean Squared Error (RMSE): 181.60959516230898
# Root Mean Squared Logarithmic Error (RMSLE): 0.44459455462790753
#
# Training model for store 9 and family 6...
# Root Mean Squared Error (RMSE): 13.279780556414412
# Root Mean Squared Logarithmic Error (RMSLE): 0.7925441805605209
#
# Training model for store 9 and family 7...
# Root Mean Squared Error (RMSE): 725.3444383600377
# Root Mean Squared Logarithmic Error (RMSLE): 0.5416773744665384
#
# Training model for store 9 and family 8...
# Root Mean Squared Error (RMSE): 371.55603805531945
# Root Mean Squared Logarithmic Error (RMSLE): 0.50920842567674
#
# Training model for store 9 and family 9...
# Root Mean Squared Error (RMSE): 194.00893317239633
# Root Mean Squared Logarithmic Error (RMSLE): 0.46316621270479913
#
# Training model for store 9 and family 10...
# Root Mean Squared Error (RMSE): 107.47776918068854
# Root Mean Squared Logarithmic Error (RMSLE): 0.5662603176089778
#
# Training model for store 9 and family 11...
# Root Mean Squared Error (RMSE): 265.4601991019326
# Root Mean Squared Logarithmic Error (RMSLE): 0.7407002262337519
#
# Training model for store 9 and family 12...
# Root Mean Squared Error (RMSE): 3401.665646035544
# Root Mean Squared Logarithmic Error (RMSLE): 0.6105487642213998
#
# Training model for store 9 and family 13...
# Root Mean Squared Error (RMSE): 10.391739069095824
# Root Mean Squared Logarithmic Error (RMSLE): 0.8782850811302954
#
# Training model for store 9 and family 14...
# Root Mean Squared Error (RMSE): 1.5135758215954964
# Root Mean Squared Logarithmic Error (RMSLE): 0.6616859985298033
#
# Training model for store 9 and family 15...
# Root Mean Squared Error (RMSE): 85.3767250836751
# Root Mean Squared Logarithmic Error (RMSLE): 0.8781237637742368
#
# Training model for store 9 and family 16...
# Root Mean Squared Error (RMSE): 26.823682769963874
# Root Mean Squared Logarithmic Error (RMSLE): 0.8145920736181498
#
# Training model for store 9 and family 17...
# Root Mean Squared Error (RMSE): 0.4037620695530676
# Root Mean Squared Logarithmic Error (RMSLE): 0.2895402139049762
#
# Training model for store 9 and family 18...
# Root Mean Squared Error (RMSE): 436.3889521108825
# Root Mean Squared Logarithmic Error (RMSLE): 3.745136329754628
#
# Training model for store 9 and family 19...
# Root Mean Squared Error (RMSE): 10.855841120597473
# Root Mean Squared Logarithmic Error (RMSLE): 0.6506308670115185
#
# Training model for store 9 and family 20...
# Root Mean Squared Error (RMSE): 10.908332239799744
# Root Mean Squared Logarithmic Error (RMSLE): 0.7148283921886052
#
# Training model for store 9 and family 21...
# Root Mean Squared Error (RMSE): 5.159207422055424
# Root Mean Squared Logarithmic Error (RMSLE): 0.7456809497450914
#
# Training model for store 9 and family 22...
# Root Mean Squared Error (RMSE): 60.95311167719699
# Root Mean Squared Logarithmic Error (RMSLE): 1.0939826444271559
#
# Training model for store 9 and family 23...
# Root Mean Squared Error (RMSE): 3.206771582038049
# Root Mean Squared Logarithmic Error (RMSLE): 0.6335407162570897
#
# Training model for store 9 and family 24...
# Root Mean Squared Error (RMSE): 117.49181021088773
# Root Mean Squared Logarithmic Error (RMSLE): 0.43366120670702335
#
# Training model for store 9 and family 25...
# Root Mean Squared Error (RMSE): 235.64314751271598
# Root Mean Squared Logarithmic Error (RMSLE): 0.5663905228179685
#
# Training model for store 9 and family 26...
# Root Mean Squared Error (RMSE): 3.986206602305707
# Root Mean Squared Logarithmic Error (RMSLE): 0.4901164052106733
#
# Training model for store 9 and family 27...
# Root Mean Squared Error (RMSE): 7.4224523503452176
# Root Mean Squared Logarithmic Error (RMSLE): 0.5355938524833057
#
# Training model for store 9 and family 28...
# Root Mean Squared Error (RMSE): 205.73797089479515
# Root Mean Squared Logarithmic Error (RMSLE): 0.5185265614884672
#
# Training model for store 9 and family 29...
# Root Mean Squared Error (RMSE): 55.60111731350917
# Root Mean Squared Logarithmic Error (RMSLE): 0.550388436320355
#
# Training model for store 9 and family 30...
# Root Mean Squared Error (RMSE): 643.2245915152112
# Root Mean Squared Logarithmic Error (RMSLE): 0.5434391512493995
#
# Training model for store 9 and family 31...
# Root Mean Squared Error (RMSE): 32.82803710735294
# Root Mean Squared Logarithmic Error (RMSLE): 1.1980033179181433
#
# Training model for store 9 and family 32...
# Root Mean Squared Error (RMSE): 10.56648967152894
# Root Mean Squared Logarithmic Error (RMSLE): 0.6477736248476206

# %%
avg_rmse = total_rmse / num_models
avg_rmsle = total_rmsle / num_models

# %%
print(f"Average Root Mean Squared Error (RMSE) across all models: {avg_rmse}")
print(f"Average Root Mean Squared Logarithmic Error (RMSLE) across all models: {avg_rmsle}")
# Out:
# Average Root Mean Squared Error (RMSE) across all models: 231.8516885931285
# Average Root Mean Squared Logarithmic Error (RMSLE) across all models: 0.763459383953906
