# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("../../Data/Kaggle/StoreSales/processed_train_v2.csv")

# %%
data = data.drop(['id'], axis=1)

# %%
data.head()
# Out:
#          date  store_nbr  family  sales  onpromotion  typeholiday  dcoilwtico  \
# 0  2013-01-01          1       0    0.0            0            3       93.14
# 1  2013-01-01          1       1    0.0            0            3       93.14
# 2  2013-01-01          1       2    0.0            0            3       93.14
# 3  2013-01-01          1       3    0.0            0            3       93.14
# 4  2013-01-01          1       4    0.0            0            3       93.14
#
#    city  state  typestores  cluster  day_of_week  day  month  year
# 0    18     12           3       13            2    1      1  2013
# 1    18     12           3       13            2    1      1  2013
# 2    18     12           3       13            2    1      1  2013
# 3    18     12           3       13            2    1      1  2013
# 4    18     12           3       13            2    1      1  2013

# %%
data.tail()
# Out:
#                date  store_nbr  family     sales  onpromotion  typeholiday  \
# 3000883  2017-08-15          9      28   438.133            0            3
# 3000884  2017-08-15          9      29   154.553            1            3
# 3000885  2017-08-15          9      30  2419.729          148            3
# 3000886  2017-08-15          9      31   121.000            8            3
# 3000887  2017-08-15          9      32    16.000            0            3
#
#          dcoilwtico  city  state  typestores  cluster  day_of_week  day  \
# 3000883       47.57    18     12           1        6            2   15
# 3000884       47.57    18     12           1        6            2   15
# 3000885       47.57    18     12           1        6            2   15
# 3000886       47.57    18     12           1        6            2   15
# 3000887       47.57    18     12           1        6            2   15
#
#          month  year
# 3000883      8  2017
# 3000884      8  2017
# ...

# %%
split_index = int(0.8 * data.shape[0])

# %%
train = data.iloc[:split_index]
test = data.iloc[split_index:]

# %%
train
# Out:
#                date  store_nbr  family    sales  onpromotion  typeholiday  \
# 0        2013-01-01          1       0    0.000            0            3
# 1        2013-01-01          1       1    0.000            0            3
# 2        2013-01-01          1       2    0.000            0            3
# 3        2013-01-01          1       3    0.000            0            3
# 4        2013-01-01          1       4    0.000            0            3
# ...             ...        ...     ...      ...          ...          ...
# 2400705  2016-09-12         19      21   26.000            0            4
# 2400706  2016-09-12         19      22    9.000            0            4
# 2400707  2016-09-12         19      23    1.000            0            4
# 2400708  2016-09-12         19      24  170.509            0            4
# 2400709  2016-09-12         19      25  181.000            8            4
#
#          dcoilwtico  city  state  typestores  cluster  day_of_week  day  \
# ...

# %%
test
# Out:
#                date  store_nbr  family     sales  onpromotion  typeholiday  \
# 2400710  2016-09-12         19      26     0.000            0            4
# 2400711  2016-09-12         19      27     4.000            0            4
# 2400712  2016-09-12         19      28    85.689            0            4
# 2400713  2016-09-12         19      29    62.000            1            4
# 2400714  2016-09-12         19      30   422.532            1            4
# ...             ...        ...     ...       ...          ...          ...
# 3000883  2017-08-15          9      28   438.133            0            3
# 3000884  2017-08-15          9      29   154.553            1            3
# 3000885  2017-08-15          9      30  2419.729          148            3
# 3000886  2017-08-15          9      31   121.000            8            3
# 3000887  2017-08-15          9      32    16.000            0            3
#
# ...

# %%
presentation_test = test[['date', 'sales']]

# %%
presentation_test.head()
# Out:
#                date    sales
# 2400710  2016-09-12    0.000
# 2400711  2016-09-12    4.000
# 2400712  2016-09-12   85.689
# 2400713  2016-09-12   62.000
# 2400714  2016-09-12  422.532

# %%
presentation_test.to_csv('../../Data/Kaggle/StoreSales/presentation_test.csv', index=False)
