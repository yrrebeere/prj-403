# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense

# %%
df = pd.read_csv('../../Data/Pharmacy/D5.csv')

# %%
df.head()
# Out:
#          date     itemname  packunits   expiry  price  looseqty
# 0  01/07/2022  PANADOL TAB        200  4/25/24   1.70        60
# 1  02/07/2022  PANADOL TAB        200  4/25/24   1.70        70
# 2  03/07/2022  PANADOL TAB        200  4/25/24   1.70        55
# 3  05/07/2022  PANADOL TAB        200  4/25/24   1.45        20
# 4  08/07/2022  PANADOL TAB        200  4/25/24   1.70        70

# %%
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df.set_index('date', inplace=True)

# %%
target_variable = 'looseqty'
df = df[[target_variable]]

# %%
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df)

# %%
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        sequences.append(seq)
    return np.array(sequences)

# %%
sequence_length = 10

# %%
sequences = create_sequences(df_scaled, sequence_length)

# %%
train_size = int(len(sequences) * 0.8)
train, test = sequences[:train_size], sequences[train_size:]

# %%
X_train, y_train = train[:, :-1], train[:, -1]
X_test, y_test = test[:, :-1], test[:, -1]

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
model = Sequential()
model.add(GRU(50, activation='relu', input_shape=(X_train.shape[1], 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=2)
# Out:
# Epoch 1/50
# 9/9 - 0s - loss: 0.0548 - val_loss: 0.0866 - 461ms/epoch - 51ms/step
# Epoch 2/50
# 9/9 - 0s - loss: 0.0229 - val_loss: 0.0333 - 20ms/epoch - 2ms/step
# Epoch 3/50
# 9/9 - 0s - loss: 0.0161 - val_loss: 0.0226 - 20ms/epoch - 2ms/step
# Epoch 4/50
# 9/9 - 0s - loss: 0.0164 - val_loss: 0.0258 - 19ms/epoch - 2ms/step
# Epoch 5/50
# 9/9 - 0s - loss: 0.0139 - val_loss: 0.0328 - 20ms/epoch - 2ms/step
# Epoch 6/50
# 9/9 - 0s - loss: 0.0137 - val_loss: 0.0309 - 19ms/epoch - 2ms/step
# Epoch 7/50
# 9/9 - 0s - loss: 0.0125 - val_loss: 0.0258 - 20ms/epoch - 2ms/step
# Epoch 8/50
# 9/9 - 0s - loss: 0.0122 - val_loss: 0.0243 - 19ms/epoch - 2ms/step
# Epoch 9/50
# 9/9 - 0s - loss: 0.0117 - val_loss: 0.0252 - 19ms/epoch - 2ms/step
# Epoch 10/50
# 9/9 - 0s - loss: 0.0114 - val_loss: 0.0255 - 19ms/epoch - 2ms/step
# Epoch 11/50
# 9/9 - 0s - loss: 0.0112 - val_loss: 0.0234 - 20ms/epoch - 2ms/step
# Epoch 12/50
# 9/9 - 0s - loss: 0.0109 - val_loss: 0.0240 - 20ms/epoch - 2ms/step
# Epoch 13/50
# 9/9 - 0s - loss: 0.0108 - val_loss: 0.0246 - 20ms/epoch - 2ms/step
# Epoch 14/50
# 9/9 - 0s - loss: 0.0107 - val_loss: 0.0232 - 21ms/epoch - 2ms/step
# Epoch 15/50
# 9/9 - 0s - loss: 0.0106 - val_loss: 0.0236 - 20ms/epoch - 2ms/step
# Epoch 16/50
# 9/9 - 0s - loss: 0.0105 - val_loss: 0.0237 - 20ms/epoch - 2ms/step
# Epoch 17/50
# 9/9 - 0s - loss: 0.0103 - val_loss: 0.0233 - 20ms/epoch - 2ms/step
# Epoch 18/50
# 9/9 - 0s - loss: 0.0106 - val_loss: 0.0233 - 20ms/epoch - 2ms/step
# Epoch 19/50
# 9/9 - 0s - loss: 0.0105 - val_loss: 0.0235 - 20ms/epoch - 2ms/step
# Epoch 20/50
# 9/9 - 0s - loss: 0.0105 - val_loss: 0.0233 - 21ms/epoch - 2ms/step
# Epoch 21/50
# 9/9 - 0s - loss: 0.0104 - val_loss: 0.0236 - 20ms/epoch - 2ms/step
# Epoch 22/50
# 9/9 - 0s - loss: 0.0105 - val_loss: 0.0233 - 21ms/epoch - 2ms/step
# Epoch 23/50
# 9/9 - 0s - loss: 0.0104 - val_loss: 0.0238 - 20ms/epoch - 2ms/step
# Epoch 24/50
# 9/9 - 0s - loss: 0.0105 - val_loss: 0.0233 - 20ms/epoch - 2ms/step
# Epoch 25/50
# 9/9 - 0s - loss: 0.0104 - val_loss: 0.0235 - 20ms/epoch - 2ms/step
# Epoch 26/50
# 9/9 - 0s - loss: 0.0104 - val_loss: 0.0234 - 20ms/epoch - 2ms/step
# Epoch 27/50
# 9/9 - 0s - loss: 0.0104 - val_loss: 0.0237 - 21ms/epoch - 2ms/step
# Epoch 28/50
# 9/9 - 0s - loss: 0.0104 - val_loss: 0.0235 - 20ms/epoch - 2ms/step
# Epoch 29/50
# 9/9 - 0s - loss: 0.0103 - val_loss: 0.0237 - 20ms/epoch - 2ms/step
# Epoch 30/50
# 9/9 - 0s - loss: 0.0103 - val_loss: 0.0234 - 20ms/epoch - 2ms/step
# Epoch 31/50
# 9/9 - 0s - loss: 0.0104 - val_loss: 0.0235 - 21ms/epoch - 2ms/step
# Epoch 32/50
# 9/9 - 0s - loss: 0.0103 - val_loss: 0.0238 - 20ms/epoch - 2ms/step
# Epoch 33/50
# 9/9 - 0s - loss: 0.0103 - val_loss: 0.0240 - 20ms/epoch - 2ms/step
# Epoch 34/50
# 9/9 - 0s - loss: 0.0104 - val_loss: 0.0236 - 20ms/epoch - 2ms/step
# Epoch 35/50
# 9/9 - 0s - loss: 0.0104 - val_loss: 0.0236 - 21ms/epoch - 2ms/step
# Epoch 36/50
# 9/9 - 0s - loss: 0.0108 - val_loss: 0.0236 - 20ms/epoch - 2ms/step
# Epoch 37/50
# 9/9 - 0s - loss: 0.0104 - val_loss: 0.0244 - 19ms/epoch - 2ms/step
# Epoch 38/50
# 9/9 - 0s - loss: 0.0105 - val_loss: 0.0236 - 20ms/epoch - 2ms/step
# Epoch 39/50
# 9/9 - 0s - loss: 0.0103 - val_loss: 0.0237 - 20ms/epoch - 2ms/step
# Epoch 40/50
# 9/9 - 0s - loss: 0.0103 - val_loss: 0.0237 - 20ms/epoch - 2ms/step
# Epoch 41/50
# 9/9 - 0s - loss: 0.0107 - val_loss: 0.0240 - 20ms/epoch - 2ms/step
# Epoch 42/50
# 9/9 - 0s - loss: 0.0105 - val_loss: 0.0244 - 20ms/epoch - 2ms/step
# Epoch 43/50
# 9/9 - 0s - loss: 0.0103 - val_loss: 0.0238 - 21ms/epoch - 2ms/step
# Epoch 44/50
# 9/9 - 0s - loss: 0.0105 - val_loss: 0.0238 - 21ms/epoch - 2ms/step
# Epoch 45/50
# 9/9 - 0s - loss: 0.0104 - val_loss: 0.0243 - 20ms/epoch - 2ms/step
# Epoch 46/50
# 9/9 - 0s - loss: 0.0103 - val_loss: 0.0238 - 20ms/epoch - 2ms/step
# Epoch 47/50
# 9/9 - 0s - loss: 0.0104 - val_loss: 0.0238 - 20ms/epoch - 2ms/step
# Epoch 48/50
# 9/9 - 0s - loss: 0.0103 - val_loss: 0.0239 - 20ms/epoch - 2ms/step
# Epoch 49/50
# 9/9 - 0s - loss: 0.0103 - val_loss: 0.0238 - 20ms/epoch - 2ms/step
# Epoch 50/50
# 9/9 - 0s - loss: 0.0103 - val_loss: 0.0238 - 20ms/epoch - 2ms/step

# %%
y_pred = model.predict(X_test)
# Out:
# 3/3 [==============================] - 0s 1ms/step

# %%
y_pred_inv = scaler.inverse_transform(np.concatenate((X_test[:, -1, :], y_pred), axis=1))[:, -1]

# %%
y_test_inv = scaler.inverse_transform(np.concatenate((X_test[:, -1, :], y_test.reshape(-1, 1)), axis=1))[:, -1]

# %%
rmsle = np.sqrt(mean_squared_error(np.log1p(y_test_inv), np.log1p(y_pred_inv)))

# %%
print(f"Root Mean Squared Logarithmic Error (RMSLE): {rmsle}")
# Out:
# Root Mean Squared Logarithmic Error (RMSLE): 0.3330187170946624

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='GRU Predictions')
plt.legend()
plt.show()
