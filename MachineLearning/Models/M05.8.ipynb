# %%
import pandas as pd
import numpy as np
from darts import TimeSeries
from darts.models import RandomForest
from sklearn.metrics import mean_squared_error, mean_squared_log_error

# %%
df = pd.read_csv("../../Data/Kaggle/StoreSales/train_darts.csv", parse_dates=["date"])

# %%
df.head()
# Out:
#         date  store_nbr  family  sales  onpromotion  typeholiday  dcoilwtico  \
# 0 2013-01-01          1       0    0.0            0            3       93.14
# 1 2013-01-01          1       1    0.0            0            3       93.14
# 2 2013-01-01          1       2    0.0            0            3       93.14
# 3 2013-01-01          1       3    0.0            0            3       93.14
# 4 2013-01-01          1       4    0.0            0            3       93.14
#
#    city  state  typestores  cluster  day_of_week  day  month  year
# 0    18     12           3       13            2    1      1  2013
# 1    18     12           3       13            2    1      1  2013
# 2    18     12           3       13            2    1      1  2013
# 3    18     12           3       13            2    1      1  2013
# 4    18     12           3       13            2    1      1  2013

# %%
unique_combinations = df[['store_nbr', 'family']].drop_duplicates()

# %%
total_rmse = 0
total_rmsle = 0
num_models = 0

# %%
trained_models = {}

# %%
included_stores = {5, 8, 16, 19, 22, 25, 33, 37, 41, 47, 51}
excluded_families = {1, 4, 14, 17, 19, 20, 31}

# %%
for index, row in unique_combinations.iterrows():
    store_nbr = row['store_nbr']
    family = row['family']
    
    if store_nbr in included_stores and family not in excluded_families:
    
        print(f"\nTraining model for store {store_nbr} and family {family}...")

        df_subset = df[(df['store_nbr'] == store_nbr) & (df['family'] == family)]

        ts = TimeSeries.from_dataframe(df_subset, value_cols=["sales"])

        training_size = int(len(ts) - 30)
        
        train = ts[:training_size]
        val = ts[training_size:]

        model = RandomForest(lags=2)
        model.fit(train)

        trained_models[(store_nbr, family)] = model

        predictions = model.predict(n=len(val))

        val = val.pd_series().tolist()
        predictions = predictions.pd_series().tolist()

        predictions = np.maximum(predictions, 0)

        rmse = np.sqrt(mean_squared_error(val, predictions))
        rmsle = np.sqrt(mean_squared_error(np.log1p(val), np.log1p(predictions)))

        total_rmse += rmse
        total_rmsle += rmsle
        num_models += 1
        
        model.save(f"SavedModels/RandomForest/RF_S{store_nbr}P{family}.pkl")

        print(f"Root Mean Squared Error (RMSE): {rmse}")
        print(f"Root Mean Squared Logarithmic Error (RMSLE): {rmsle}")
# Out:
# Training model for store 16 and family 0...
# Root Mean Squared Error (RMSE): 2.8558369933723973
# Root Mean Squared Logarithmic Error (RMSLE): 0.577224642456334
#
# Training model for store 16 and family 2...
# Root Mean Squared Error (RMSE): 1.9984948238108096
# Root Mean Squared Logarithmic Error (RMSLE): 0.7294715318184355
#
# Training model for store 16 and family 3...
# Root Mean Squared Error (RMSE): 372.47882869142154
# Root Mean Squared Logarithmic Error (RMSLE): 0.259786426100219
#
# Training model for store 16 and family 5...
# Root Mean Squared Error (RMSE): 72.73734675497022
# Root Mean Squared Logarithmic Error (RMSLE): 0.43481936877880145
#
# Training model for store 16 and family 6...
# Root Mean Squared Error (RMSE): 5.06180058670016
# Root Mean Squared Logarithmic Error (RMSLE): 0.91585165432302
#
# Training model for store 16 and family 7...
# Root Mean Squared Error (RMSE): 541.2414055927663
# Root Mean Squared Logarithmic Error (RMSLE): 0.46109512156557675
#
# Training model for store 16 and family 8...
# Root Mean Squared Error (RMSE): 82.39542712803932
# Root Mean Squared Logarithmic Error (RMSLE): 0.30203314914485685
#
# Training model for store 16 and family 9...
# Root Mean Squared Error (RMSE): 65.60853625203708
# Root Mean Squared Logarithmic Error (RMSLE): 0.34600680526278554
#
# Training model for store 16 and family 10...
# Root Mean Squared Error (RMSE): 121.9428055002783
# Root Mean Squared Logarithmic Error (RMSLE): 0.6374231803272311
#
# Training model for store 16 and family 11...
# Root Mean Squared Error (RMSE): 23.94229952455698
# Root Mean Squared Logarithmic Error (RMSLE): 0.6021586306039508
#
# Training model for store 16 and family 12...
# Root Mean Squared Error (RMSE): 678.7351847827595
# Root Mean Squared Logarithmic Error (RMSLE): 0.3020368248802602
#
# Training model for store 16 and family 13...
# Root Mean Squared Error (RMSE): 3.836378556010947
# Root Mean Squared Logarithmic Error (RMSLE): 0.7103291214337917
#
# Training model for store 16 and family 15...
# Root Mean Squared Error (RMSE): 9.630101433829841
# Root Mean Squared Logarithmic Error (RMSLE): 0.734484916998728
#
# Training model for store 16 and family 16...
# Root Mean Squared Error (RMSE): 6.740383307423774
# Root Mean Squared Logarithmic Error (RMSLE): 0.48179442501262054
#
# Training model for store 16 and family 18...
# Root Mean Squared Error (RMSE): 77.1297445712958
# Root Mean Squared Logarithmic Error (RMSLE): 0.41628809833829933
#
# Training model for store 16 and family 21...
# Root Mean Squared Error (RMSE): 2.5206912300823108
# Root Mean Squared Logarithmic Error (RMSLE): 0.7603123151428053
#
# Training model for store 16 and family 22...
# Root Mean Squared Error (RMSE): 35.74722379619303
# Root Mean Squared Logarithmic Error (RMSLE): 0.9662331397505081
#
# Training model for store 16 and family 23...
# Root Mean Squared Error (RMSE): 1.4596621425302085
# Root Mean Squared Logarithmic Error (RMSLE): 0.5460968425923357
#
# Training model for store 16 and family 24...
# Root Mean Squared Error (RMSE): 29.75128893139168
# Root Mean Squared Logarithmic Error (RMSLE): 0.462639312456951
#
# Training model for store 16 and family 25...
# Root Mean Squared Error (RMSE): 82.9124967952527
# Root Mean Squared Logarithmic Error (RMSLE): 0.5045097245022016
#
# Training model for store 16 and family 26...
# Root Mean Squared Error (RMSE): 1.1296755662159315
# Root Mean Squared Logarithmic Error (RMSLE): 0.5084970915838926
#
# Training model for store 16 and family 27...
# Root Mean Squared Error (RMSE): 2.3751523018389857
# Root Mean Squared Logarithmic Error (RMSLE): 0.5840204042889224
#
# Training model for store 16 and family 28...
# Root Mean Squared Error (RMSE): 47.20402123779812
# Root Mean Squared Logarithmic Error (RMSLE): 0.562827292599303
#
# Training model for store 16 and family 29...
# Root Mean Squared Error (RMSE): 13.133851184573691
# Root Mean Squared Logarithmic Error (RMSLE): 0.3672728171059581
#
# Training model for store 16 and family 30...
# Root Mean Squared Error (RMSE): 274.38699422613473
# Root Mean Squared Logarithmic Error (RMSLE): 0.44401813957109676
#
# Training model for store 16 and family 32...
# Root Mean Squared Error (RMSE): 2.5860115028667345
# Root Mean Squared Logarithmic Error (RMSLE): 1.0373580209028879
#
# Training model for store 19 and family 0...
# Root Mean Squared Error (RMSE): 3.734965283792691
# Root Mean Squared Logarithmic Error (RMSLE): 0.5620475994745291
#
# Training model for store 19 and family 2...
# Root Mean Squared Error (RMSE): 2.951301185189049
# Root Mean Squared Logarithmic Error (RMSLE): 0.6803699681275116
#
# Training model for store 19 and family 3...
# Root Mean Squared Error (RMSE): 628.3431023917851
# Root Mean Squared Logarithmic Error (RMSLE): 0.22356836765998897
#
# Training model for store 19 and family 5...
# Root Mean Squared Error (RMSE): 56.137235277520595
# Root Mean Squared Logarithmic Error (RMSLE): 0.27995903356070506
#
# Training model for store 19 and family 6...
# Root Mean Squared Error (RMSE): 6.1854107703054035
# Root Mean Squared Logarithmic Error (RMSLE): 0.7986432688569151
#
# Training model for store 19 and family 7...
# Root Mean Squared Error (RMSE): 363.0323070563647
# Root Mean Squared Logarithmic Error (RMSLE): 0.326000873574444
#
# Training model for store 19 and family 8...
# Root Mean Squared Error (RMSE): 112.08252219065847
# Root Mean Squared Logarithmic Error (RMSLE): 0.3085866147329501
#
# Training model for store 19 and family 9...
# Root Mean Squared Error (RMSE): 73.17451290442595
# Root Mean Squared Logarithmic Error (RMSLE): 0.24905960265373453
#
# Training model for store 19 and family 10...
# Root Mean Squared Error (RMSE): 46.79408006582363
# Root Mean Squared Logarithmic Error (RMSLE): 0.7051236930907994
#
# Training model for store 19 and family 11...
# Root Mean Squared Error (RMSE): 19.203663813887623
# Root Mean Squared Logarithmic Error (RMSLE): 0.4043847579547936
#
# Training model for store 19 and family 12...
# Root Mean Squared Error (RMSE): 1099.4766896653553
# Root Mean Squared Logarithmic Error (RMSLE): 0.3150414425689141
#
# Training model for store 19 and family 13...
# Root Mean Squared Error (RMSE): 52.73032188100294
# Root Mean Squared Logarithmic Error (RMSLE): 1.5136224277995336
#
# Training model for store 19 and family 15...
# Root Mean Squared Error (RMSE): 15.702480211786565
# Root Mean Squared Logarithmic Error (RMSLE): 0.7735608173112521
#
# Training model for store 19 and family 16...
# Root Mean Squared Error (RMSE): 22.06964703714515
# Root Mean Squared Logarithmic Error (RMSLE): 0.6664215709363768
#
# Training model for store 19 and family 18...
# Root Mean Squared Error (RMSE): 72.34181811186774
# Root Mean Squared Logarithmic Error (RMSLE): 0.3477689882430748
#
# Training model for store 19 and family 21...
# Root Mean Squared Error (RMSE): 3.115535223007287
# Root Mean Squared Logarithmic Error (RMSLE): 0.7215244707986989
#
# Training model for store 19 and family 22...
# Root Mean Squared Error (RMSE): 53.478957253382625
# Root Mean Squared Logarithmic Error (RMSLE): 0.9883104649939615
#
# Training model for store 19 and family 23...
# Root Mean Squared Error (RMSE): 2.3864964696729123
# Root Mean Squared Logarithmic Error (RMSLE): 0.6056197694264481
#
# Training model for store 19 and family 24...
# Root Mean Squared Error (RMSE): 49.97797986235396
# Root Mean Squared Logarithmic Error (RMSLE): 0.2973023240982904
#
# Training model for store 19 and family 25...
# Root Mean Squared Error (RMSE): 71.13454146100608
# Root Mean Squared Logarithmic Error (RMSLE): 0.3508654618652619
#
# Training model for store 19 and family 26...
# Root Mean Squared Error (RMSE): 1.3470002671539107
# Root Mean Squared Logarithmic Error (RMSLE): 0.5807081873169715
#
# Training model for store 19 and family 27...
# Root Mean Squared Error (RMSE): 2.887319738015058
# Root Mean Squared Logarithmic Error (RMSLE): 0.567954472821351
#
# Training model for store 19 and family 28...
# Root Mean Squared Error (RMSE): 74.87233067708297
# Root Mean Squared Logarithmic Error (RMSLE): 0.4383118634462924
#
# Training model for store 19 and family 29...
# Root Mean Squared Error (RMSE): 12.577707480917542
# Root Mean Squared Logarithmic Error (RMSLE): 0.43692555345600814
#
# Training model for store 19 and family 30...
# Root Mean Squared Error (RMSE): 133.1277510613981
# Root Mean Squared Logarithmic Error (RMSLE): 0.28356873478224337
#
# Training model for store 19 and family 32...
# Root Mean Squared Error (RMSE): 3.2352275657916936
# Root Mean Squared Logarithmic Error (RMSLE): 0.6605558168891527
#
# Training model for store 22 and family 0...
# Root Mean Squared Error (RMSE): 3.08066606024807
# Root Mean Squared Logarithmic Error (RMSLE): 0.6104093894624906
#
# Training model for store 22 and family 2...
# Root Mean Squared Error (RMSE): 2.3438292310291735
# Root Mean Squared Logarithmic Error (RMSLE): 0.6344324230697953
#
# Training model for store 22 and family 3...
# Root Mean Squared Error (RMSE): 659.2192931743831
# Root Mean Squared Logarithmic Error (RMSLE): 0.4229376208700166
#
# Training model for store 22 and family 5...
# Root Mean Squared Error (RMSE): 65.0857239820784
# Root Mean Squared Logarithmic Error (RMSLE): 0.3555408219340373
#
# Training model for store 22 and family 6...
# Root Mean Squared Error (RMSE): 9.55699988952658
# Root Mean Squared Logarithmic Error (RMSLE): 0.8105596546945859
#
# Training model for store 22 and family 7...
# Root Mean Squared Error (RMSE): 360.0916646216627
# Root Mean Squared Logarithmic Error (RMSLE): 0.4216621064091586
#
# Training model for store 22 and family 8...
# Root Mean Squared Error (RMSE): 70.08251705694536
# Root Mean Squared Logarithmic Error (RMSLE): 0.22517120161070164
#
# Training model for store 22 and family 9...
# Root Mean Squared Error (RMSE): 27.11178035589769
# Root Mean Squared Logarithmic Error (RMSLE): 0.17757220475103588
#
# Training model for store 22 and family 10...
# Root Mean Squared Error (RMSE): 31.008597280506716
# Root Mean Squared Logarithmic Error (RMSLE): 0.5289838852886494
#
# Training model for store 22 and family 11...
# Root Mean Squared Error (RMSE): 38.5286487356862
# Root Mean Squared Logarithmic Error (RMSLE): 0.5926427606917891
#
# Training model for store 22 and family 12...
# Root Mean Squared Error (RMSE): 478.7958162137532
# Root Mean Squared Logarithmic Error (RMSLE): 0.18327656579593776
#
# Training model for store 22 and family 13...
# Root Mean Squared Error (RMSE): 12.028343867273607
# Root Mean Squared Logarithmic Error (RMSLE): 0.822371203201922
#
# Training model for store 22 and family 15...
# Root Mean Squared Error (RMSE): 25.081168837544382
# Root Mean Squared Logarithmic Error (RMSLE): 0.8008618036157522
#
# Training model for store 22 and family 16...
# Root Mean Squared Error (RMSE): 8.080492054967939
# Root Mean Squared Logarithmic Error (RMSLE): 0.4760923987807142
#
# Training model for store 22 and family 18...
# Root Mean Squared Error (RMSE): 51.564993995877465
# Root Mean Squared Logarithmic Error (RMSLE): 0.30433414673039777
#
# Training model for store 22 and family 21...
# Root Mean Squared Error (RMSE): 3.6287263618085253
# Root Mean Squared Logarithmic Error (RMSLE): 0.767408843873447
#
# Training model for store 22 and family 22...
# Root Mean Squared Error (RMSE): 139.92448919989948
# Root Mean Squared Logarithmic Error (RMSLE): 1.1784506942869621
#
# Training model for store 22 and family 23...
# Root Mean Squared Error (RMSE): 1.721868598624687
# Root Mean Squared Logarithmic Error (RMSLE): 0.544931985061163
#
# Training model for store 22 and family 24...
# Root Mean Squared Error (RMSE): 36.70515228945847
# Root Mean Squared Logarithmic Error (RMSLE): 0.38207530817520285
#
# Training model for store 22 and family 25...
# Root Mean Squared Error (RMSE): 54.2341703180992
# Root Mean Squared Logarithmic Error (RMSLE): 0.34970162779159536
#
# Training model for store 22 and family 26...
# Root Mean Squared Error (RMSE): 1.2529347261436798
# Root Mean Squared Logarithmic Error (RMSLE): 0.5649566527116213
#
# Training model for store 22 and family 27...
# Root Mean Squared Error (RMSE): 3.5534952417079952
# Root Mean Squared Logarithmic Error (RMSLE): 0.49047985711204317
#
# Training model for store 22 and family 28...
# Root Mean Squared Error (RMSE): 85.54269748035128
# Root Mean Squared Logarithmic Error (RMSLE): 0.4989158638864314
#
# Training model for store 22 and family 29...
# Root Mean Squared Error (RMSE): 20.12246608420175
# Root Mean Squared Logarithmic Error (RMSLE): 0.5706506027501931
#
# Training model for store 22 and family 30...
# Root Mean Squared Error (RMSE): 262.42749690524624
# Root Mean Squared Logarithmic Error (RMSLE): 0.44825687742787035
#
# Training model for store 22 and family 32...
# Root Mean Squared Error (RMSE): 4.096288272971337
# Root Mean Squared Logarithmic Error (RMSLE): 0.8541015893847178
#
# Training model for store 25 and family 0...
# Root Mean Squared Error (RMSE): 2.747986284587645
# Root Mean Squared Logarithmic Error (RMSLE): 0.7665942723582939
#
# Training model for store 25 and family 2...
# Root Mean Squared Error (RMSE): 2.609466145137697
# Root Mean Squared Logarithmic Error (RMSLE): 0.5690982333582665
#
# Training model for store 25 and family 3...
# Root Mean Squared Error (RMSE): 1231.6641084281055
# Root Mean Squared Logarithmic Error (RMSLE): 0.4517516380357098
#
# Training model for store 25 and family 5...
# Root Mean Squared Error (RMSE): 185.11704089139027
# Root Mean Squared Logarithmic Error (RMSLE): 0.4455652144096217
#
# Training model for store 25 and family 6...
# Root Mean Squared Error (RMSE): 6.294614607545855
# Root Mean Squared Logarithmic Error (RMSLE): 0.5831655604572815
#
# Training model for store 25 and family 7...
# Root Mean Squared Error (RMSE): 201.1815507257335
# Root Mean Squared Logarithmic Error (RMSLE): 0.3605254885051804
#
# Training model for store 25 and family 8...
# Root Mean Squared Error (RMSE): 287.36125159225395
# Root Mean Squared Logarithmic Error (RMSLE): 0.4017700990847724
#
# Training model for store 25 and family 9...
# Root Mean Squared Error (RMSE): 71.38992847451676
# Root Mean Squared Logarithmic Error (RMSLE): 0.4719731349245382
#
# Training model for store 25 and family 10...
# Root Mean Squared Error (RMSE): 66.02041283421364
# Root Mean Squared Logarithmic Error (RMSLE): 0.38769793616809417
#
# Training model for store 25 and family 11...
# Root Mean Squared Error (RMSE): 191.07656481767782
# Root Mean Squared Logarithmic Error (RMSLE): 0.9606947182789599
#
# Training model for store 25 and family 12...
# Root Mean Squared Error (RMSE): 670.7017453881172
# Root Mean Squared Logarithmic Error (RMSLE): 0.2846920930684421
#
# Training model for store 25 and family 13...
# Root Mean Squared Error (RMSE): 19.890071463292177
# Root Mean Squared Logarithmic Error (RMSLE): 0.8332527163554395
#
# Training model for store 25 and family 15...
# Root Mean Squared Error (RMSE): 47.041898049772946
# Root Mean Squared Logarithmic Error (RMSLE): 1.1877623833982547
#
# Training model for store 25 and family 16...
# Root Mean Squared Error (RMSE): 36.68658183405299
# Root Mean Squared Logarithmic Error (RMSLE): 1.2259004283085542
#
# Training model for store 25 and family 18...
# Root Mean Squared Error (RMSE): 68.34833687202124
# Root Mean Squared Logarithmic Error (RMSLE): 0.4285215141161124
#
# Training model for store 25 and family 21...
# Root Mean Squared Error (RMSE): 4.469253838758038
# Root Mean Squared Logarithmic Error (RMSLE): 0.8245881169130254
#
# Training model for store 25 and family 22...
# Root Mean Squared Error (RMSE): 246.40053292691286
# Root Mean Squared Logarithmic Error (RMSLE): 1.0735117545291912
#
# Training model for store 25 and family 23...
# Root Mean Squared Error (RMSE): 12.48070280490313
# Root Mean Squared Logarithmic Error (RMSLE): 0.9781595565275388
#
# Training model for store 25 and family 24...
# Root Mean Squared Error (RMSE): 141.4900503354118
# Root Mean Squared Logarithmic Error (RMSLE): 0.5331756940802115
#
# Training model for store 25 and family 25...
# Root Mean Squared Error (RMSE): 51.347101330067616
# Root Mean Squared Logarithmic Error (RMSLE): 0.41969128151110374
#
# Training model for store 25 and family 26...
# Root Mean Squared Error (RMSE): 3.258728182634387
# Root Mean Squared Logarithmic Error (RMSLE): 0.47191505282115076
#
# Training model for store 25 and family 27...
# Root Mean Squared Error (RMSE): 5.814140384383256
# Root Mean Squared Logarithmic Error (RMSLE): 0.7118228386614845
#
# Training model for store 25 and family 28...
# Root Mean Squared Error (RMSE): 71.17729706435169
# Root Mean Squared Logarithmic Error (RMSLE): 0.3568720866107487
#
# Training model for store 25 and family 29...
# Root Mean Squared Error (RMSE): 16.450319712311135
# Root Mean Squared Logarithmic Error (RMSLE): 0.38810961522877796
#
# Training model for store 25 and family 30...
# Root Mean Squared Error (RMSE): 929.1930519275899
# Root Mean Squared Logarithmic Error (RMSLE): 0.490453250811112
#
# Training model for store 25 and family 32...
# Root Mean Squared Error (RMSE): 4.746887229919391
# Root Mean Squared Logarithmic Error (RMSLE): 0.8037408564669818
#
# Training model for store 33 and family 0...
# Root Mean Squared Error (RMSE): 3.8338573373662577
# Root Mean Squared Logarithmic Error (RMSLE): 0.48541217576296797
#
# Training model for store 33 and family 2...
# Root Mean Squared Error (RMSE): 2.4730479998646175
# Root Mean Squared Logarithmic Error (RMSLE): 0.7465326532352328
#
# Training model for store 33 and family 3...
# Root Mean Squared Error (RMSE): 1244.3519093702284
# Root Mean Squared Logarithmic Error (RMSLE): 0.4983525473535027
#
# Training model for store 33 and family 5...
# Root Mean Squared Error (RMSE): 73.0225689459544
# Root Mean Squared Logarithmic Error (RMSLE): 0.30384180395168225
#
# Training model for store 33 and family 6...
# Root Mean Squared Error (RMSE): 10.070967630681425
# Root Mean Squared Logarithmic Error (RMSLE): 0.9682907686649082
#
# Training model for store 33 and family 7...
# Root Mean Squared Error (RMSE): 315.0072215412306
# Root Mean Squared Logarithmic Error (RMSLE): 0.2897090370033804
#
# Training model for store 33 and family 8...
# Root Mean Squared Error (RMSE): 130.68044417444267
# Root Mean Squared Logarithmic Error (RMSLE): 0.3126755742733172
#
# Training model for store 33 and family 9...
# Root Mean Squared Error (RMSE): 53.92740786311039
# Root Mean Squared Logarithmic Error (RMSLE): 0.29309176018087063
#
# Training model for store 33 and family 10...
# Root Mean Squared Error (RMSE): 201.08350530807752
# Root Mean Squared Logarithmic Error (RMSLE): 0.7150074478097428
#
# Training model for store 33 and family 11...
# Root Mean Squared Error (RMSE): 51.054377486210896
# Root Mean Squared Logarithmic Error (RMSLE): 0.6831473015111936
#
# Training model for store 33 and family 12...
# Root Mean Squared Error (RMSE): 812.1527174931135
# Root Mean Squared Logarithmic Error (RMSLE): 0.2635532356249955
#
# Training model for store 33 and family 13...
# Root Mean Squared Error (RMSE): 3.2650443080972074
# Root Mean Squared Logarithmic Error (RMSLE): 0.6253590204980425
#
# Training model for store 33 and family 15...
# Root Mean Squared Error (RMSE): 24.39825799090074
# Root Mean Squared Logarithmic Error (RMSLE): 0.6791409357173055
#
# Training model for store 33 and family 16...
# Root Mean Squared Error (RMSE): 11.583083064046527
# Root Mean Squared Logarithmic Error (RMSLE): 0.6131392199961972
#
# Training model for store 33 and family 18...
# Root Mean Squared Error (RMSE): 120.43508862172193
# Root Mean Squared Logarithmic Error (RMSLE): 0.42801975113311247
#
# Training model for store 33 and family 21...
# Root Mean Squared Error (RMSE): 4.82664340199858
# Root Mean Squared Logarithmic Error (RMSLE): 0.33247462434324987
#
# Training model for store 33 and family 22...
# Root Mean Squared Error (RMSE): 70.16029527327642
# Root Mean Squared Logarithmic Error (RMSLE): 1.4922533617516
#
# Training model for store 33 and family 23...
# Root Mean Squared Error (RMSE): 1.2071540846524142
# Root Mean Squared Logarithmic Error (RMSLE): 0.5316547769961202
#
# Training model for store 33 and family 24...
# Root Mean Squared Error (RMSE): 105.62651315034589
# Root Mean Squared Logarithmic Error (RMSLE): 0.428466693454012
#
# Training model for store 33 and family 25...
# Root Mean Squared Error (RMSE): 88.72460255647078
# Root Mean Squared Logarithmic Error (RMSLE): 0.3941519116085157
#
# Training model for store 33 and family 26...
# Root Mean Squared Error (RMSE): 1.764227656725011
# Root Mean Squared Logarithmic Error (RMSLE): 0.5876810175444196
#
# Training model for store 33 and family 27...
# Root Mean Squared Error (RMSE): 2.6064889354648386
# Root Mean Squared Logarithmic Error (RMSLE): 0.5425203697098357
#
# Training model for store 33 and family 28...
# Root Mean Squared Error (RMSE): 72.5810540016884
# Root Mean Squared Logarithmic Error (RMSLE): 0.34086119708284185
#
# Training model for store 33 and family 29...
# Root Mean Squared Error (RMSE): 15.67975135224264
# Root Mean Squared Logarithmic Error (RMSLE): 0.6987002326123939
#
# Training model for store 33 and family 30...
# Root Mean Squared Error (RMSE): 529.8365646151482
# Root Mean Squared Logarithmic Error (RMSLE): 0.35500673890167234
#
# Training model for store 33 and family 32...
# Root Mean Squared Error (RMSE): 1.7764026765104282
# Root Mean Squared Logarithmic Error (RMSLE): 0.8419604577350316
#
# Training model for store 37 and family 0...
# Root Mean Squared Error (RMSE): 3.303239633269345
# Root Mean Squared Logarithmic Error (RMSLE): 0.693825128684681
#
# Training model for store 37 and family 2...
# Root Mean Squared Error (RMSE): 4.741087573067062
# Root Mean Squared Logarithmic Error (RMSLE): 0.5942758701355962
#
# Training model for store 37 and family 3...
# Root Mean Squared Error (RMSE): 795.0427921166676
# Root Mean Squared Logarithmic Error (RMSLE): 0.2769689668026033
#
# Training model for store 37 and family 5...
# Root Mean Squared Error (RMSE): 106.21832129766393
# Root Mean Squared Logarithmic Error (RMSLE): 0.222134788095495
#
# Training model for store 37 and family 6...
# Root Mean Squared Error (RMSE): 6.814892026959734
# Root Mean Squared Logarithmic Error (RMSLE): 0.7672273246589177
#
# Training model for store 37 and family 7...
# Root Mean Squared Error (RMSE): 276.1923098436292
# Root Mean Squared Logarithmic Error (RMSLE): 0.31030429493111367
#
# Training model for store 37 and family 8...
# Root Mean Squared Error (RMSE): 194.13735484574994
# Root Mean Squared Logarithmic Error (RMSLE): 0.23510621857947012
#
# Training model for store 37 and family 9...
# Root Mean Squared Error (RMSE): 32.82055556572712
# Root Mean Squared Logarithmic Error (RMSLE): 0.21910455008946084
#
# Training model for store 37 and family 10...
# Root Mean Squared Error (RMSE): 39.325198675512354
# Root Mean Squared Logarithmic Error (RMSLE): 0.3028033230018194
#
# Training model for store 37 and family 11...
# Root Mean Squared Error (RMSE): 51.044990540168385
# Root Mean Squared Logarithmic Error (RMSLE): 0.4108684512417166
#
# Training model for store 37 and family 12...
# Root Mean Squared Error (RMSE): 623.9958962418476
# Root Mean Squared Logarithmic Error (RMSLE): 0.1976212136937992
#
# Training model for store 37 and family 13...
# Root Mean Squared Error (RMSE): 29.659191335060175
# Root Mean Squared Logarithmic Error (RMSLE): 0.5141761660713509
#
# Training model for store 37 and family 15...
# Root Mean Squared Error (RMSE): 21.811210001115757
# Root Mean Squared Logarithmic Error (RMSLE): 0.6032129535061428
#
# Training model for store 37 and family 16...
# Root Mean Squared Error (RMSE): 26.04476284450014
# Root Mean Squared Logarithmic Error (RMSLE): 0.8498029786299084
#
# Training model for store 37 and family 18...
# Root Mean Squared Error (RMSE): 66.02575747616173
# Root Mean Squared Logarithmic Error (RMSLE): 0.2843428651556238
#
# Training model for store 37 and family 21...
# Root Mean Squared Error (RMSE): 3.728433178112368
# Root Mean Squared Logarithmic Error (RMSLE): 1.1073853334048784
#
# Training model for store 37 and family 22...
# Root Mean Squared Error (RMSE): 88.07557793032639
# Root Mean Squared Logarithmic Error (RMSLE): 0.6781801785581688
#
# Training model for store 37 and family 23...
# Root Mean Squared Error (RMSE): 4.581533111076603
# Root Mean Squared Logarithmic Error (RMSLE): 0.4892371953928733
#
# Training model for store 37 and family 24...
# Root Mean Squared Error (RMSE): 87.50004767435388
# Root Mean Squared Logarithmic Error (RMSLE): 0.3554841910935254
#
# Training model for store 37 and family 25...
# Root Mean Squared Error (RMSE): 60.210401025964
# Root Mean Squared Logarithmic Error (RMSLE): 0.18727450697748266
#
# Training model for store 37 and family 26...
# Root Mean Squared Error (RMSE): 6.83286733236142
# Root Mean Squared Logarithmic Error (RMSLE): 0.4443726955222929
#
# Training model for store 37 and family 27...
# Root Mean Squared Error (RMSE): 6.484097356900945
# Root Mean Squared Logarithmic Error (RMSLE): 0.43381517734893094
#
# Training model for store 37 and family 28...
# Root Mean Squared Error (RMSE): 41.66321056265784
# Root Mean Squared Logarithmic Error (RMSLE): 0.16086301947059106
#
# Training model for store 37 and family 29...
# Root Mean Squared Error (RMSE): 66.53391645862845
# Root Mean Squared Logarithmic Error (RMSLE): 0.699153382014486
#
# Training model for store 37 and family 30...
# Root Mean Squared Error (RMSE): 1014.7771470199283
# Root Mean Squared Logarithmic Error (RMSLE): 0.36868494334175805
#
# Training model for store 37 and family 32...
# Root Mean Squared Error (RMSE): 7.866953494223705
# Root Mean Squared Logarithmic Error (RMSLE): 0.5362742203710648
#
# Training model for store 41 and family 0...
# Root Mean Squared Error (RMSE): 4.898995622245366
# Root Mean Squared Logarithmic Error (RMSLE): 0.6081191608557078
#
# Training model for store 41 and family 2...
# Root Mean Squared Error (RMSE): 5.3745464499711035
# Root Mean Squared Logarithmic Error (RMSLE): 0.6726656760535353
#
# Training model for store 41 and family 3...
# Root Mean Squared Error (RMSE): 1426.6440013355352
# Root Mean Squared Logarithmic Error (RMSLE): 0.5039095059751614
#
# Training model for store 41 and family 5...
# Root Mean Squared Error (RMSE): 127.94882232460468
# Root Mean Squared Logarithmic Error (RMSLE): 0.2337644148198097
#
# Training model for store 41 and family 6...
# Root Mean Squared Error (RMSE): 7.234562423804142
# Root Mean Squared Logarithmic Error (RMSLE): 0.7324786890405437
#
# Training model for store 41 and family 7...
# Root Mean Squared Error (RMSE): 667.0460907038834
# Root Mean Squared Logarithmic Error (RMSLE): 0.4507762458367594
#
# Training model for store 41 and family 8...
# Root Mean Squared Error (RMSE): 194.51737429040455
# Root Mean Squared Logarithmic Error (RMSLE): 0.26467407412522015
#
# Training model for store 41 and family 9...
# Root Mean Squared Error (RMSE): 70.40605545887158
# Root Mean Squared Logarithmic Error (RMSLE): 0.29109117676561086
#
# Training model for store 41 and family 10...
# Root Mean Squared Error (RMSE): 47.64543090604962
# Root Mean Squared Logarithmic Error (RMSLE): 0.3384283203257995
#
# Training model for store 41 and family 11...
# Root Mean Squared Error (RMSE): 62.992360082427226
# Root Mean Squared Logarithmic Error (RMSLE): 0.4599720229312604
#
# Training model for store 41 and family 12...
# Root Mean Squared Error (RMSE): 1422.9496774318245
# Root Mean Squared Logarithmic Error (RMSLE): 0.36907886372397675
#
# Training model for store 41 and family 13...
# Root Mean Squared Error (RMSE): 40.92075448985441
# Root Mean Squared Logarithmic Error (RMSLE): 0.8001105119841618
#
# Training model for store 41 and family 15...
# Root Mean Squared Error (RMSE): 15.057466483567245
# Root Mean Squared Logarithmic Error (RMSLE): 0.6162017132509022
#
# Training model for store 41 and family 16...
# Root Mean Squared Error (RMSE): 28.28149996254388
# Root Mean Squared Logarithmic Error (RMSLE): 0.5993882787741538
#
# Training model for store 41 and family 18...
# Root Mean Squared Error (RMSE): 112.75895508407237
# Root Mean Squared Logarithmic Error (RMSLE): 0.4063810168193283
#
# Training model for store 41 and family 21...
# Root Mean Squared Error (RMSE): 4.943514721288028
# Root Mean Squared Logarithmic Error (RMSLE): 0.5812205898802785
#
# Training model for store 41 and family 22...
# Root Mean Squared Error (RMSE): 160.71195035845219
# Root Mean Squared Logarithmic Error (RMSLE): 1.0198159644190095
#
# Training model for store 41 and family 23...
# Root Mean Squared Error (RMSE): 8.226630174445543
# Root Mean Squared Logarithmic Error (RMSLE): 0.5880000447917922
#
# Training model for store 41 and family 24...
# Root Mean Squared Error (RMSE): 103.75308382371217
# Root Mean Squared Logarithmic Error (RMSLE): 0.4292179428376822
#
# Training model for store 41 and family 25...
# Root Mean Squared Error (RMSE): 395.22823428975465
# Root Mean Squared Logarithmic Error (RMSLE): 0.7576526805680627
#
# Training model for store 41 and family 26...
# Root Mean Squared Error (RMSE): 7.668347122106167
# Root Mean Squared Logarithmic Error (RMSLE): 0.6186563368701533
#
# Training model for store 41 and family 27...
# Root Mean Squared Error (RMSE): 3.6379960843902674
# Root Mean Squared Logarithmic Error (RMSLE): 0.39262234035266297
#
# Training model for store 41 and family 28...
# Root Mean Squared Error (RMSE): 45.8888713695642
# Root Mean Squared Logarithmic Error (RMSLE): 0.23164514252892685
#
# Training model for store 41 and family 29...
# Root Mean Squared Error (RMSE): 22.349459053454535
# Root Mean Squared Logarithmic Error (RMSLE): 0.3404660317210183
#
# Training model for store 41 and family 30...
# Root Mean Squared Error (RMSE): 542.7456090509974
# Root Mean Squared Logarithmic Error (RMSLE): 0.25085454355043657
#
# Training model for store 41 and family 32...
# Root Mean Squared Error (RMSE): 5.8064916134581965
# Root Mean Squared Logarithmic Error (RMSLE): 0.7527183857588378
#
# Training model for store 47 and family 0...
# Root Mean Squared Error (RMSE): 8.128604273707532
# Root Mean Squared Logarithmic Error (RMSLE): 0.543050456304117
#
# Training model for store 47 and family 2...
# Root Mean Squared Error (RMSE): 12.593027818635806
# Root Mean Squared Logarithmic Error (RMSLE): 0.6643367226606681
#
# Training model for store 47 and family 3...
# Root Mean Squared Error (RMSE): 2909.9063939652765
# Root Mean Squared Logarithmic Error (RMSLE): 0.289660360104713
#
# Training model for store 47 and family 5...
# Root Mean Squared Error (RMSE): 202.09505861466636
# Root Mean Squared Logarithmic Error (RMSLE): 0.16735823924454135
#
# Training model for store 47 and family 6...
# Root Mean Squared Error (RMSE): 17.269139042472506
# Root Mean Squared Logarithmic Error (RMSLE): 0.63950481013769
#
# Training model for store 47 and family 7...
# Root Mean Squared Error (RMSE): 788.0066621736138
# Root Mean Squared Logarithmic Error (RMSLE): 0.3129188017338011
#
# Training model for store 47 and family 8...
# Root Mean Squared Error (RMSE): 529.4178639631773
# Root Mean Squared Logarithmic Error (RMSLE): 0.23531307817118297
#
# Training model for store 47 and family 9...
# Root Mean Squared Error (RMSE): 228.22324478129914
# Root Mean Squared Logarithmic Error (RMSLE): 0.3363184514259804
#
# Training model for store 47 and family 10...
# Root Mean Squared Error (RMSE): 117.21722260806675
# Root Mean Squared Logarithmic Error (RMSLE): 0.3079330287092381
#
# Training model for store 47 and family 11...
# Root Mean Squared Error (RMSE): 110.8873489089606
# Root Mean Squared Logarithmic Error (RMSLE): 0.38851346902000616
#
# Training model for store 47 and family 12...
# Root Mean Squared Error (RMSE): 2878.462009357891
# Root Mean Squared Logarithmic Error (RMSLE): 0.29255804329776386
#
# Training model for store 47 and family 13...
# Root Mean Squared Error (RMSE): 22.610843890386235
# Root Mean Squared Logarithmic Error (RMSLE): 0.3738500281650698
#
# Training model for store 47 and family 15...
# Root Mean Squared Error (RMSE): 36.2299852077395
# Root Mean Squared Logarithmic Error (RMSLE): 0.5038733854522625
#
# Training model for store 47 and family 16...
# Root Mean Squared Error (RMSE): 46.152815969633245
# Root Mean Squared Logarithmic Error (RMSLE): 0.6340618512695093
#
# Training model for store 47 and family 18...
# Root Mean Squared Error (RMSE): 241.9100744147158
# Root Mean Squared Logarithmic Error (RMSLE): 0.3314737937707141
#
# Training model for store 47 and family 21...
# Root Mean Squared Error (RMSE): 13.32400498082232
# Root Mean Squared Logarithmic Error (RMSLE): 0.8159262487991279
#
# Training model for store 47 and family 22...
# Root Mean Squared Error (RMSE): 116.15734981204038
# Root Mean Squared Logarithmic Error (RMSLE): 0.6477570052944984
#
# Training model for store 47 and family 23...
# Root Mean Squared Error (RMSE): 8.986652335738071
# Root Mean Squared Logarithmic Error (RMSLE): 0.5406570928506017
#
# Training model for store 47 and family 24...
# Root Mean Squared Error (RMSE): 369.09147073769765
# Root Mean Squared Logarithmic Error (RMSLE): 0.33732861314847096
#
# Training model for store 47 and family 25...
# Root Mean Squared Error (RMSE): 245.43885732163142
# Root Mean Squared Logarithmic Error (RMSLE): 0.307279342866976
#
# Training model for store 47 and family 26...
# Root Mean Squared Error (RMSE): 13.05241079706371
# Root Mean Squared Logarithmic Error (RMSLE): 0.5641911731316136
#
# Training model for store 47 and family 27...
# Root Mean Squared Error (RMSE): 14.951360137242222
# Root Mean Squared Logarithmic Error (RMSLE): 0.45702378191984444
#
# Training model for store 47 and family 28...
# Root Mean Squared Error (RMSE): 496.4372674556057
# Root Mean Squared Logarithmic Error (RMSLE): 0.4116873344018345
#
# Training model for store 47 and family 29...
# Root Mean Squared Error (RMSE): 87.49070470070106
# Root Mean Squared Logarithmic Error (RMSLE): 0.3432268451113489
#
# Training model for store 47 and family 30...
# Root Mean Squared Error (RMSE): 1736.9497982202115
# Root Mean Squared Logarithmic Error (RMSLE): 0.2862734714447258
#
# Training model for store 47 and family 32...
# Root Mean Squared Error (RMSE): 32.06654439733647
# Root Mean Squared Logarithmic Error (RMSLE): 0.39102417444524007
#
# Training model for store 5 and family 0...
# Root Mean Squared Error (RMSE): 3.5009045120817697
# Root Mean Squared Logarithmic Error (RMSLE): 0.47078133452038495
#
# Training model for store 5 and family 2...
# Root Mean Squared Error (RMSE): 4.295289146672908
# Root Mean Squared Logarithmic Error (RMSLE): 0.5352518462471634
#
# Training model for store 5 and family 3...
# Root Mean Squared Error (RMSE): 477.01342392361806
# Root Mean Squared Logarithmic Error (RMSLE): 0.2394039754461589
#
# Training model for store 5 and family 5...
# Root Mean Squared Error (RMSE): 74.96586772853696
# Root Mean Squared Logarithmic Error (RMSLE): 0.20594575179594196
#
# Training model for store 5 and family 6...
# Root Mean Squared Error (RMSE): 11.223872465204789
# Root Mean Squared Logarithmic Error (RMSLE): 0.4698031358718103
#
# Training model for store 5 and family 7...
# Root Mean Squared Error (RMSE): 244.25520077028725
# Root Mean Squared Logarithmic Error (RMSLE): 0.2725526855707515
#
# Training model for store 5 and family 8...
# Root Mean Squared Error (RMSE): 114.1636230010989
# Root Mean Squared Logarithmic Error (RMSLE): 0.19654655083330888
#
# Training model for store 5 and family 9...
# Root Mean Squared Error (RMSE): 61.087857189768826
# Root Mean Squared Logarithmic Error (RMSLE): 0.2611763039606941
#
# Training model for store 5 and family 10...
# Root Mean Squared Error (RMSE): 40.47367893541812
# Root Mean Squared Logarithmic Error (RMSLE): 0.39539042630282006
#
# Training model for store 5 and family 11...
# Root Mean Squared Error (RMSE): 36.13860383698504
# Root Mean Squared Logarithmic Error (RMSLE): 0.35751902461469803
#
# Training model for store 5 and family 12...
# Root Mean Squared Error (RMSE): 557.6033140984042
# Root Mean Squared Logarithmic Error (RMSLE): 0.18543060031975586
#
# Training model for store 5 and family 13...
# Root Mean Squared Error (RMSE): 68.81674028243249
# Root Mean Squared Logarithmic Error (RMSLE): 1.4655501125073955
#
# Training model for store 5 and family 15...
# Root Mean Squared Error (RMSE): 15.271547203095333
# Root Mean Squared Logarithmic Error (RMSLE): 0.5708795074952246
#
# Training model for store 5 and family 16...
# Root Mean Squared Error (RMSE): 28.638174797107453
# Root Mean Squared Logarithmic Error (RMSLE): 0.7563598691539665
#
# Training model for store 5 and family 18...
# Root Mean Squared Error (RMSE): 64.85064265311657
# Root Mean Squared Logarithmic Error (RMSLE): 0.27745792747743264
#
# Training model for store 5 and family 21...
# Root Mean Squared Error (RMSE): 9.131466017545645
# Root Mean Squared Logarithmic Error (RMSLE): 0.6560465562528586
#
# Training model for store 5 and family 22...
# Root Mean Squared Error (RMSE): 39.85022510602013
# Root Mean Squared Logarithmic Error (RMSLE): 0.6708686795095449
#
# Training model for store 5 and family 23...
# Root Mean Squared Error (RMSE): 4.95762894871596
# Root Mean Squared Logarithmic Error (RMSLE): 0.6386720929782981
#
# Training model for store 5 and family 24...
# Root Mean Squared Error (RMSE): 42.77165008172275
# Root Mean Squared Logarithmic Error (RMSLE): 0.16138659549071477
#
# Training model for store 5 and family 25...
# Root Mean Squared Error (RMSE): 67.42292411455772
# Root Mean Squared Logarithmic Error (RMSLE): 0.26697391765377193
#
# Training model for store 5 and family 26...
# Root Mean Squared Error (RMSE): 2.1263452045249123
# Root Mean Squared Logarithmic Error (RMSLE): 0.618818467078363
#
# Training model for store 5 and family 27...
# Root Mean Squared Error (RMSE): 3.007745918181165
# Root Mean Squared Logarithmic Error (RMSLE): 0.36350833506216723
#
# Training model for store 5 and family 28...
# Root Mean Squared Error (RMSE): 51.16866461245668
# Root Mean Squared Logarithmic Error (RMSLE): 0.22631251929110047
#
# Training model for store 5 and family 29...
# Root Mean Squared Error (RMSE): 35.154219652580366
# Root Mean Squared Logarithmic Error (RMSLE): 0.48149376125103227
#
# Training model for store 5 and family 30...
# Root Mean Squared Error (RMSE): 351.33099825393185
# Root Mean Squared Logarithmic Error (RMSLE): 0.2131880660070804
#
# Training model for store 5 and family 32...
# Root Mean Squared Error (RMSE): 4.873710933725258
# Root Mean Squared Logarithmic Error (RMSLE): 0.45520687359929446
#
# Training model for store 51 and family 0...
# Root Mean Squared Error (RMSE): 3.657738863494129
# Root Mean Squared Logarithmic Error (RMSLE): 0.39746455037904627
#
# Training model for store 51 and family 2...
# Root Mean Squared Error (RMSE): 3.3514864061686342
# Root Mean Squared Logarithmic Error (RMSLE): 0.5325929509302672
#
# Training model for store 51 and family 3...
# Root Mean Squared Error (RMSE): 1095.0948068987757
# Root Mean Squared Logarithmic Error (RMSLE): 0.2349831157381533
#
# Training model for store 51 and family 5...
# Root Mean Squared Error (RMSE): 202.91321838611051
# Root Mean Squared Logarithmic Error (RMSLE): 0.22884336082074413
#
# Training model for store 51 and family 6...
# Root Mean Squared Error (RMSE): 7.861710100581929
# Root Mean Squared Logarithmic Error (RMSLE): 0.7519798536680583
#
# Training model for store 51 and family 7...
# Root Mean Squared Error (RMSE): 274.46535026672683
# Root Mean Squared Logarithmic Error (RMSLE): 0.19707711483658163
#
# Training model for store 51 and family 8...
# Root Mean Squared Error (RMSE): 281.9813428698194
# Root Mean Squared Logarithmic Error (RMSLE): 0.18011992938970878
#
# Training model for store 51 and family 9...
# Root Mean Squared Error (RMSE): 71.52574529994827
# Root Mean Squared Logarithmic Error (RMSLE): 0.26169077503534055
#
# Training model for store 51 and family 10...
# Root Mean Squared Error (RMSE): 76.52733094226554
# Root Mean Squared Logarithmic Error (RMSLE): 0.22725228275611717
#
# Training model for store 51 and family 11...
# Root Mean Squared Error (RMSE): 82.9653972920078
# Root Mean Squared Logarithmic Error (RMSLE): 0.29949986969053544
#
# Training model for store 51 and family 12...
# Root Mean Squared Error (RMSE): 1119.1792228369861
# Root Mean Squared Logarithmic Error (RMSLE): 0.21411265115704362
#
# Training model for store 51 and family 13...
# Root Mean Squared Error (RMSE): 27.412559371162317
# Root Mean Squared Logarithmic Error (RMSLE): 0.6346563433414636
#
# Training model for store 51 and family 15...
# Root Mean Squared Error (RMSE): 20.203979516627335
# Root Mean Squared Logarithmic Error (RMSLE): 0.6042708154700327
#
# Training model for store 51 and family 16...
# Root Mean Squared Error (RMSE): 64.65374486730576
# Root Mean Squared Logarithmic Error (RMSLE): 1.0735733270440517
#
# Training model for store 51 and family 18...
# Root Mean Squared Error (RMSE): 99.43192064590393
# Root Mean Squared Logarithmic Error (RMSLE): 0.2896341044957809
#
# Training model for store 51 and family 21...
# Root Mean Squared Error (RMSE): 4.147231377116148
# Root Mean Squared Logarithmic Error (RMSLE): 0.5355350270901476
#
# Training model for store 51 and family 22...
# Root Mean Squared Error (RMSE): 124.41761355336637
# Root Mean Squared Logarithmic Error (RMSLE): 0.723278353821831
#
# Training model for store 51 and family 23...
# Root Mean Squared Error (RMSE): 6.391997330521547
# Root Mean Squared Logarithmic Error (RMSLE): 0.6049566805169552
#
# Training model for store 51 and family 24...
# Root Mean Squared Error (RMSE): 264.94221828082254
# Root Mean Squared Logarithmic Error (RMSLE): 0.3390142259787274
#
# Training model for store 51 and family 25...
# Root Mean Squared Error (RMSE): 84.71938631278995
# Root Mean Squared Logarithmic Error (RMSLE): 0.276360599581646
#
# Training model for store 51 and family 26...
# Root Mean Squared Error (RMSE): 8.516993797571015
# Root Mean Squared Logarithmic Error (RMSLE): 0.3876656129630149
#
# Training model for store 51 and family 27...
# Root Mean Squared Error (RMSE): 5.769205744207458
# Root Mean Squared Logarithmic Error (RMSLE): 0.4600910035536845
#
# Training model for store 51 and family 28...
# Root Mean Squared Error (RMSE): 906.9447081847886
# Root Mean Squared Logarithmic Error (RMSLE): 0.5668213715169348
#
# Training model for store 51 and family 29...
# Root Mean Squared Error (RMSE): 59.31913289484853
# Root Mean Squared Logarithmic Error (RMSLE): 0.40154478653438874
#
# Training model for store 51 and family 30...
# Root Mean Squared Error (RMSE): 1978.1953168282282
# Root Mean Squared Logarithmic Error (RMSLE): 0.3281658374973848
#
# Training model for store 51 and family 32...
# Root Mean Squared Error (RMSE): 21.929852142388565
# Root Mean Squared Logarithmic Error (RMSLE): 0.42739829637072924
#
# Training model for store 8 and family 0...
# Root Mean Squared Error (RMSE): 4.070416348990255
# Root Mean Squared Logarithmic Error (RMSLE): 0.7138999136080307
#
# Training model for store 8 and family 2...
# Root Mean Squared Error (RMSE): 6.414699395286186
# Root Mean Squared Logarithmic Error (RMSLE): 0.573964479595604
#
# Training model for store 8 and family 3...
# Root Mean Squared Error (RMSE): 1062.1814425354391
# Root Mean Squared Logarithmic Error (RMSLE): 0.21958602357363183
#
# Training model for store 8 and family 5...
# Root Mean Squared Error (RMSE): 115.81656769286418
# Root Mean Squared Logarithmic Error (RMSLE): 0.14492134768519688
#
# Training model for store 8 and family 6...
# Root Mean Squared Error (RMSE): 10.622065302242094
# Root Mean Squared Logarithmic Error (RMSLE): 0.5018858377614553
#
# Training model for store 8 and family 7...
# Root Mean Squared Error (RMSE): 232.7525209673714
# Root Mean Squared Logarithmic Error (RMSLE): 0.1943118861825564
#
# Training model for store 8 and family 8...
# Root Mean Squared Error (RMSE): 351.439421198378
# Root Mean Squared Logarithmic Error (RMSLE): 0.24385833319177852
#
# Training model for store 8 and family 9...
# Root Mean Squared Error (RMSE): 69.45423293090249
# Root Mean Squared Logarithmic Error (RMSLE): 0.2372776034696485
#
# Training model for store 8 and family 10...
# Root Mean Squared Error (RMSE): 103.55039273704517
# Root Mean Squared Logarithmic Error (RMSLE): 0.3104459208705367
#
# Training model for store 8 and family 11...
# Root Mean Squared Error (RMSE): 56.91396051455502
# Root Mean Squared Logarithmic Error (RMSLE): 0.32036742041124283
#
# Training model for store 8 and family 12...
# Root Mean Squared Error (RMSE): 941.2348726327558
# Root Mean Squared Logarithmic Error (RMSLE): 0.19332743314613066
#
# Training model for store 8 and family 13...
# Root Mean Squared Error (RMSE): 18.641923125805114
# Root Mean Squared Logarithmic Error (RMSLE): 0.49388251059798205
#
# Training model for store 8 and family 15...
# Root Mean Squared Error (RMSE): 18.600630187062045
# Root Mean Squared Logarithmic Error (RMSLE): 0.41404376466796705
#
# Training model for store 8 and family 16...
# Root Mean Squared Error (RMSE): 51.1674006483103
# Root Mean Squared Logarithmic Error (RMSLE): 0.5234843538097663
#
# Training model for store 8 and family 18...
# Root Mean Squared Error (RMSE): 81.46219841128767
# Root Mean Squared Logarithmic Error (RMSLE): 0.2278976164090136
#
# Training model for store 8 and family 21...
# Root Mean Squared Error (RMSE): 12.402354839764755
# Root Mean Squared Logarithmic Error (RMSLE): 0.5386899262683539
#
# Training model for store 8 and family 22...
# Root Mean Squared Error (RMSE): 102.2934483018793
# Root Mean Squared Logarithmic Error (RMSLE): 0.7684062733021579
#
# Training model for store 8 and family 23...
# Root Mean Squared Error (RMSE): 10.665240319519128
# Root Mean Squared Logarithmic Error (RMSLE): 0.5651064358379797
#
# Training model for store 8 and family 24...
# Root Mean Squared Error (RMSE): 189.74553250669447
# Root Mean Squared Logarithmic Error (RMSLE): 0.3586257422631954
#
# Training model for store 8 and family 25...
# Root Mean Squared Error (RMSE): 93.14507123746985
# Root Mean Squared Logarithmic Error (RMSLE): 0.2677909883429472
#
# Training model for store 8 and family 26...
# Root Mean Squared Error (RMSE): 10.8277449742897
# Root Mean Squared Logarithmic Error (RMSLE): 0.4906670665860135
#
# Training model for store 8 and family 27...
# Root Mean Squared Error (RMSE): 7.703509237808293
# Root Mean Squared Logarithmic Error (RMSLE): 0.399990719530294
#
# Training model for store 8 and family 28...
# Root Mean Squared Error (RMSE): 183.9894388894018
# Root Mean Squared Logarithmic Error (RMSLE): 0.2835638430014659
#
# Training model for store 8 and family 29...
# Root Mean Squared Error (RMSE): 84.11784306575254
# Root Mean Squared Logarithmic Error (RMSLE): 0.4756844738676075
#
# Training model for store 8 and family 30...
# Root Mean Squared Error (RMSE): 1097.2288121838112
# Root Mean Squared Logarithmic Error (RMSLE): 0.22661038839289682
#
# Training model for store 8 and family 32...
# Root Mean Squared Error (RMSE): 18.626923294022717
# Root Mean Squared Logarithmic Error (RMSLE): 0.4411560565989845

# %%
avg_rmse = total_rmse / num_models
avg_rmsle = total_rmsle / num_models

# %%
print(f"Average Root Mean Squared Error (RMSE) across all models: {avg_rmse}")
print(f"Average Root Mean Squared Logarithmic Error (RMSLE) across all models: {avg_rmsle}")
# Out:
# Average Root Mean Squared Error (RMSE) across all models: 179.20772421600785
# Average Root Mean Squared Logarithmic Error (RMSLE) across all models: 0.499004359134454
