# %%
import pandas as pd
import numpy as np
from darts import TimeSeries
from darts.models import RandomForest
from sklearn.metrics import mean_squared_error, mean_squared_log_error
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../Data/Kaggle/StoreSales/train_darts.csv", parse_dates=["date"])

# %%
df.head()
# Out:
#         date  store_nbr  family  sales  onpromotion  typeholiday  dcoilwtico  \
# 0 2013-01-01          1       0    0.0            0            3       93.14
# 1 2013-01-01          1       1    0.0            0            3       93.14
# 2 2013-01-01          1       2    0.0            0            3       93.14
# 3 2013-01-01          1       3    0.0            0            3       93.14
# 4 2013-01-01          1       4    0.0            0            3       93.14
#
#    city  state  typestores  cluster  day_of_week  day  month  year
# 0    18     12           3       13            2    1      1  2013
# 1    18     12           3       13            2    1      1  2013
# 2    18     12           3       13            2    1      1  2013
# 3    18     12           3       13            2    1      1  2013
# 4    18     12           3       13            2    1      1  2013

# %%
unique_combinations = df[['store_nbr', 'family']].drop_duplicates()

# %%
total_rmse = 0
total_rmsle = 0
num_models = 0

# %%
trained_models = {}

# %%
for index, row in unique_combinations.iterrows():
    store_nbr = row['store_nbr']
    family = row['family']
    
    print(f"\nTraining model for store {store_nbr} and family {family}...")
    
    df_subset = df[(df['store_nbr'] == store_nbr) & (df['family'] == family)]
    
    ts = TimeSeries.from_dataframe(df_subset, value_cols=["sales"])

    split_ratio = 0.8
    training_size = int(len(ts) * split_ratio)
    train = ts[:training_size]
    val = ts[training_size:]

    model = RandomForest(lags=2)
    model.fit(train)

    trained_models[(store_nbr, family)] = model

    predictions = model.predict(n=len(val))

    val = val.pd_series().tolist()
    predictions = predictions.pd_series().tolist()

    predictions = np.maximum(predictions, 0)

    rmse = np.sqrt(mean_squared_error(val, predictions))
    rmsle = np.sqrt(mean_squared_error(np.log1p(val), np.log1p(predictions)))
    
    if rmse > 0:
        total_rmse += rmse
        total_rmsle += rmsle
        num_models += 1

    print(f"Root Mean Squared Error (RMSE): {rmse}")
    print(f"Root Mean Squared Logarithmic Error (RMSLE): {rmsle}")
# Out:
# Training model for store 1 and family 0...
# Root Mean Squared Error (RMSE): 2.8754934324748604
# Root Mean Squared Logarithmic Error (RMSLE): 0.6005822221465849
#
# Training model for store 1 and family 1...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 1 and family 2...
# Root Mean Squared Error (RMSE): 2.510285031345538
# Root Mean Squared Logarithmic Error (RMSLE): 0.5788748542349766
#
# Training model for store 1 and family 3...
# Root Mean Squared Error (RMSE): 812.7139270337742
# Root Mean Squared Logarithmic Error (RMSLE): 0.634084462828037
#
# Training model for store 1 and family 4...
# Root Mean Squared Error (RMSE): 1.231389651888243
# Root Mean Squared Logarithmic Error (RMSLE): 0.5971886853304214
#
# Training model for store 1 and family 5...
# Root Mean Squared Error (RMSE): 167.3757818939828
# Root Mean Squared Logarithmic Error (RMSLE): 0.624225262025108
#
# Training model for store 1 and family 6...
# Root Mean Squared Error (RMSE): 10.896304997325785
# Root Mean Squared Logarithmic Error (RMSLE): 0.8377844192877485
#
# Training model for store 1 and family 7...
# Root Mean Squared Error (RMSE): 284.86506516761733
# Root Mean Squared Logarithmic Error (RMSLE): 0.6576135432936168
#
# Training model for store 1 and family 8...
# Root Mean Squared Error (RMSE): 398.1805253182656
# Root Mean Squared Logarithmic Error (RMSLE): 0.7789585823257096
#
# Training model for store 1 and family 9...
# Root Mean Squared Error (RMSE): 49.351886279892355
# Root Mean Squared Logarithmic Error (RMSLE): 0.4869652425542115
#
# Training model for store 1 and family 10...
# Root Mean Squared Error (RMSE): 42.15864796737463
# Root Mean Squared Logarithmic Error (RMSLE): 0.43003937872377246
#
# Training model for store 1 and family 11...
# Root Mean Squared Error (RMSE): 143.41024671866785
# Root Mean Squared Logarithmic Error (RMSLE): 0.6502821625458659
#
# Training model for store 1 and family 12...
# Root Mean Squared Error (RMSE): 1210.1843860863928
# Root Mean Squared Logarithmic Error (RMSLE): 0.7166019179009188
#
# Training model for store 1 and family 13...
# Root Mean Squared Error (RMSE): 15.11928681105142
# Root Mean Squared Logarithmic Error (RMSLE): 0.7347321171276964
#
# Training model for store 1 and family 14...
# Root Mean Squared Error (RMSE): 1.69154309159986
# Root Mean Squared Logarithmic Error (RMSLE): 0.6098302979337872
#
# Training model for store 1 and family 15...
# Root Mean Squared Error (RMSE): 18.036336245703552
# Root Mean Squared Logarithmic Error (RMSLE): 0.8786190360095149
#
# Training model for store 1 and family 16...
# Root Mean Squared Error (RMSE): 19.948584155034553
# Root Mean Squared Logarithmic Error (RMSLE): 1.1352940228213608
#
# Training model for store 1 and family 17...
# Root Mean Squared Error (RMSE): 0.7065884466599364
# Root Mean Squared Logarithmic Error (RMSLE): 0.3857373317233834
#
# Training model for store 1 and family 18...
# Root Mean Squared Error (RMSE): 63.68563915785057
# Root Mean Squared Logarithmic Error (RMSLE): 0.4899971259058626
#
# Training model for store 1 and family 19...
# Root Mean Squared Error (RMSE): 7.424724343367471
# Root Mean Squared Logarithmic Error (RMSLE): 0.5847153955747806
#
# Training model for store 1 and family 20...
# Root Mean Squared Error (RMSE): 14.105135915632827
# Root Mean Squared Logarithmic Error (RMSLE): 0.9014554912198169
#
# Training model for store 1 and family 21...
# Root Mean Squared Error (RMSE): 5.38380684327785
# Root Mean Squared Logarithmic Error (RMSLE): 0.8589546043564742
#
# Training model for store 1 and family 22...
# Root Mean Squared Error (RMSE): 72.20082590874149
# Root Mean Squared Logarithmic Error (RMSLE): 1.1241219380634766
#
# Training model for store 1 and family 23...
# Root Mean Squared Error (RMSE): 4.252221854293343
# Root Mean Squared Logarithmic Error (RMSLE): 0.5763505142996465
#
# Training model for store 1 and family 24...
# Root Mean Squared Error (RMSE): 219.27445552713004
# Root Mean Squared Logarithmic Error (RMSLE): 0.7472492301046544
#
# Training model for store 1 and family 25...
# Root Mean Squared Error (RMSE): 85.3394472799439
# Root Mean Squared Logarithmic Error (RMSLE): 0.6749109652109305
#
# Training model for store 1 and family 26...
# Root Mean Squared Error (RMSE): 3.333193139465615
# Root Mean Squared Logarithmic Error (RMSLE): 0.5658923348685823
#
# Training model for store 1 and family 27...
# Root Mean Squared Error (RMSE): 5.0881629349537105
# Root Mean Squared Logarithmic Error (RMSLE): 0.5881013549743513
#
# Training model for store 1 and family 28...
# Root Mean Squared Error (RMSE): 150.3572064232321
# Root Mean Squared Logarithmic Error (RMSLE): 0.632606395307894
#
# Training model for store 1 and family 29...
# Root Mean Squared Error (RMSE): 33.76347441435777
# Root Mean Squared Logarithmic Error (RMSLE): 0.5073994615740349
#
# Training model for store 1 and family 30...
# Root Mean Squared Error (RMSE): 1038.5374852574391
# Root Mean Squared Logarithmic Error (RMSLE): 0.6106428629796838
#
# Training model for store 1 and family 31...
# Root Mean Squared Error (RMSE): 0.6054100487068705
# Root Mean Squared Logarithmic Error (RMSLE): 0.3505909828576287
#
# Training model for store 1 and family 32...
# Root Mean Squared Error (RMSE): 12.992906907366024
# Root Mean Squared Logarithmic Error (RMSLE): 0.5033191108389153
#
# Training model for store 10 and family 0...
# Root Mean Squared Error (RMSE): 2.620787021673206
# Root Mean Squared Logarithmic Error (RMSLE): 0.7276924498577261
#
# Training model for store 10 and family 1...
# Root Mean Squared Error (RMSE): 1.3785049755032655
# Root Mean Squared Logarithmic Error (RMSLE): 0.8094670150729137
#
# Training model for store 10 and family 2...
# Root Mean Squared Error (RMSE): 1.639632902134253
# Root Mean Squared Logarithmic Error (RMSLE): 0.608869205317612
#
# Training model for store 10 and family 3...
# Root Mean Squared Error (RMSE): 447.20604347390537
# Root Mean Squared Logarithmic Error (RMSLE): 0.55541110342388
#
# Training model for store 10 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 10 and family 5...
# Root Mean Squared Error (RMSE): 35.677372519323214
# Root Mean Squared Logarithmic Error (RMSLE): 0.4143037191382986
#
# Training model for store 10 and family 6...
# Root Mean Squared Error (RMSE): 4.092744257540032
# Root Mean Squared Logarithmic Error (RMSLE): 0.89573858146012
#
# Training model for store 10 and family 7...
# Root Mean Squared Error (RMSE): 614.0059085841721
# Root Mean Squared Logarithmic Error (RMSLE): 0.5347163767288704
#
# Training model for store 10 and family 8...
# Root Mean Squared Error (RMSE): 129.7363448364417
# Root Mean Squared Logarithmic Error (RMSLE): 0.49981982448546713
#
# Training model for store 10 and family 9...
# Root Mean Squared Error (RMSE): 83.7451085109021
# Root Mean Squared Logarithmic Error (RMSLE): 0.42524636112036895
#
# Training model for store 10 and family 10...
# Root Mean Squared Error (RMSE): 35.923925271623105
# Root Mean Squared Logarithmic Error (RMSLE): 0.8031785096830063
#
# Training model for store 10 and family 11...
# Root Mean Squared Error (RMSE): 77.39301159167091
# Root Mean Squared Logarithmic Error (RMSLE): 0.7015847308829369
#
# Training model for store 10 and family 12...
# Root Mean Squared Error (RMSE): 871.7865625918901
# Root Mean Squared Logarithmic Error (RMSLE): 0.5251918946701776
#
# Training model for store 10 and family 13...
# Root Mean Squared Error (RMSE): 5.7217753281591435
# Root Mean Squared Logarithmic Error (RMSLE): 0.868431242680714
#
# Training model for store 10 and family 14...
# Root Mean Squared Error (RMSE): 0.9198554425482162
# Root Mean Squared Logarithmic Error (RMSLE): 0.5829995875721758
#
# Training model for store 10 and family 15...
# Root Mean Squared Error (RMSE): 9.065622500475289
# Root Mean Squared Logarithmic Error (RMSLE): 0.7577299697570711
#
# Training model for store 10 and family 16...
# Root Mean Squared Error (RMSE): 4.765479596463085
# Root Mean Squared Logarithmic Error (RMSLE): 0.610237405343454
#
# Training model for store 10 and family 17...
# Root Mean Squared Error (RMSE): 0.3858557687985283
# Root Mean Squared Logarithmic Error (RMSLE): 0.24980168873196423
#
# Training model for store 10 and family 18...
# Root Mean Squared Error (RMSE): 60.52097039249842
# Root Mean Squared Logarithmic Error (RMSLE): 0.43121055668239144
#
# Training model for store 10 and family 19...
# Root Mean Squared Error (RMSE): 8.390358456444659
# Root Mean Squared Logarithmic Error (RMSLE): 1.3206007569935554
#
# Training model for store 10 and family 20...
# Root Mean Squared Error (RMSE): 0.004360160865610357
# Root Mean Squared Logarithmic Error (RMSLE): 0.0043506829045262645
#
# Training model for store 10 and family 21...
# Root Mean Squared Error (RMSE): 3.2069647666686203
# Root Mean Squared Logarithmic Error (RMSLE): 0.9925623998794655
#
# Training model for store 10 and family 22...
# Root Mean Squared Error (RMSE): 16.05866455558286
# Root Mean Squared Logarithmic Error (RMSLE): 1.0532010421817892
#
# Training model for store 10 and family 23...
# Root Mean Squared Error (RMSE): 1.0124992081855717
# Root Mean Squared Logarithmic Error (RMSLE): 0.541805745959057
#
# Training model for store 10 and family 24...
# Root Mean Squared Error (RMSE): 48.56774557542232
# Root Mean Squared Logarithmic Error (RMSLE): 0.41588894501368795
#
# Training model for store 10 and family 25...
# Root Mean Squared Error (RMSE): 71.25239546597481
# Root Mean Squared Logarithmic Error (RMSLE): 0.452272491074895
#
# Training model for store 10 and family 26...
# Root Mean Squared Error (RMSE): 1.437708902353363
# Root Mean Squared Logarithmic Error (RMSLE): 0.6794508911728879
#
# Training model for store 10 and family 27...
# Root Mean Squared Error (RMSE): 3.076411774979405
# Root Mean Squared Logarithmic Error (RMSLE): 0.5941083536238729
#
# Training model for store 10 and family 28...
# Root Mean Squared Error (RMSE): 63.37652363533698
# Root Mean Squared Logarithmic Error (RMSLE): 0.4750005179731985
#
# Training model for store 10 and family 29...
# Root Mean Squared Error (RMSE): 20.433786398078123
# Root Mean Squared Logarithmic Error (RMSLE): 0.8883228142732393
#
# Training model for store 10 and family 30...
# Root Mean Squared Error (RMSE): 79.84401714323461
# Root Mean Squared Logarithmic Error (RMSLE): 0.40514282010937114
#
# Training model for store 10 and family 31...
# Root Mean Squared Error (RMSE): 10.106584278158143
# Root Mean Squared Logarithmic Error (RMSLE): 2.2972405326235075
#
# Training model for store 10 and family 32...
# Root Mean Squared Error (RMSE): 2.9922409483180976
# Root Mean Squared Logarithmic Error (RMSLE): 0.997338877912133
#
# Training model for store 11 and family 0...
# Root Mean Squared Error (RMSE): 4.583915988626614
# Root Mean Squared Logarithmic Error (RMSLE): 0.5858862826511848
#
# Training model for store 11 and family 1...
# Root Mean Squared Error (RMSE): 0.9797539973824952
# Root Mean Squared Logarithmic Error (RMSLE): 0.4897679873737211
#
# Training model for store 11 and family 2...
# Root Mean Squared Error (RMSE): 4.584235436333761
# Root Mean Squared Logarithmic Error (RMSLE): 0.5604877231587013
#
# Training model for store 11 and family 3...
# Root Mean Squared Error (RMSE): 1776.2422573274534
# Root Mean Squared Logarithmic Error (RMSLE): 0.6120769341189382
#
# Training model for store 11 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 11 and family 5...
# Root Mean Squared Error (RMSE): 183.6437395511839
# Root Mean Squared Logarithmic Error (RMSLE): 0.4192734367987426
#
# Training model for store 11 and family 6...
# Root Mean Squared Error (RMSE): 10.328105073047332
# Root Mean Squared Logarithmic Error (RMSLE): 0.677618903747915
#
# Training model for store 11 and family 7...
# Root Mean Squared Error (RMSE): 770.3224358460203
# Root Mean Squared Logarithmic Error (RMSLE): 0.5328349112217506
#
# Training model for store 11 and family 8...
# Root Mean Squared Error (RMSE): 283.00700872263894
# Root Mean Squared Logarithmic Error (RMSLE): 0.5174120459961572
#
# Training model for store 11 and family 9...
# Root Mean Squared Error (RMSE): 169.16094090772665
# Root Mean Squared Logarithmic Error (RMSLE): 0.4553787777155547
#
# Training model for store 11 and family 10...
# Root Mean Squared Error (RMSE): 140.72652820153854
# Root Mean Squared Logarithmic Error (RMSLE): 0.7137235172918742
#
# Training model for store 11 and family 11...
# Root Mean Squared Error (RMSE): 136.11378948555267
# Root Mean Squared Logarithmic Error (RMSLE): 0.6290724896778316
#
# Training model for store 11 and family 12...
# Root Mean Squared Error (RMSE): 2892.9965417162325
# Root Mean Squared Logarithmic Error (RMSLE): 0.5996653010972783
#
# Training model for store 11 and family 13...
# Root Mean Squared Error (RMSE): 20.120351458294667
# Root Mean Squared Logarithmic Error (RMSLE): 0.9261848186606856
#
# Training model for store 11 and family 14...
# Root Mean Squared Error (RMSE): 0.992649371011222
# Root Mean Squared Logarithmic Error (RMSLE): 0.5215243117510778
#
# Training model for store 11 and family 15...
# Root Mean Squared Error (RMSE): 33.07494498771838
# Root Mean Squared Logarithmic Error (RMSLE): 0.7183408706184087
#
# Training model for store 11 and family 16...
# Root Mean Squared Error (RMSE): 17.178344732180516
# Root Mean Squared Logarithmic Error (RMSLE): 0.6253545614570275
#
# Training model for store 11 and family 17...
# Root Mean Squared Error (RMSE): 0.723844427039822
# Root Mean Squared Logarithmic Error (RMSLE): 0.4683373708780782
#
# Training model for store 11 and family 18...
# Root Mean Squared Error (RMSE): 187.86744583222827
# Root Mean Squared Logarithmic Error (RMSLE): 0.47166210178922097
#
# Training model for store 11 and family 19...
# Root Mean Squared Error (RMSE): 9.747856318296112
# Root Mean Squared Logarithmic Error (RMSLE): 0.713457154627037
#
# Training model for store 11 and family 20...
# Root Mean Squared Error (RMSE): 6.007655391224418
# Root Mean Squared Logarithmic Error (RMSLE): 0.7661183785105844
#
# Training model for store 11 and family 21...
# Root Mean Squared Error (RMSE): 5.16880056684238
# Root Mean Squared Logarithmic Error (RMSLE): 0.5164590072088174
#
# Training model for store 11 and family 22...
# Root Mean Squared Error (RMSE): 56.687635755593554
# Root Mean Squared Logarithmic Error (RMSLE): 1.0235100447927652
#
# Training model for store 11 and family 23...
# Root Mean Squared Error (RMSE): 3.209349128021953
# Root Mean Squared Logarithmic Error (RMSLE): 0.7500225676776475
#
# Training model for store 11 and family 24...
# Root Mean Squared Error (RMSE): 179.37700833688206
# Root Mean Squared Logarithmic Error (RMSLE): 0.4522957683225493
#
# Training model for store 11 and family 25...
# Root Mean Squared Error (RMSE): 226.78324719755105
# Root Mean Squared Logarithmic Error (RMSLE): 0.5774657696052743
#
# Training model for store 11 and family 26...
# Root Mean Squared Error (RMSE): 2.327059290474891
# Root Mean Squared Logarithmic Error (RMSLE): 0.6549752282977579
#
# Training model for store 11 and family 27...
# Root Mean Squared Error (RMSE): 13.781678571952243
# Root Mean Squared Logarithmic Error (RMSLE): 0.6790910958376681
#
# Training model for store 11 and family 28...
# Root Mean Squared Error (RMSE): 207.15688484822013
# Root Mean Squared Logarithmic Error (RMSLE): 0.6163821190998192
#
# Training model for store 11 and family 29...
# Root Mean Squared Error (RMSE): 31.322239181111467
# Root Mean Squared Logarithmic Error (RMSLE): 0.4237831252654997
#
# Training model for store 11 and family 30...
# Root Mean Squared Error (RMSE): 756.4634593462638
# Root Mean Squared Logarithmic Error (RMSLE): 0.5278125289448072
#
# Training model for store 11 and family 31...
# Root Mean Squared Error (RMSE): 44.21262013530171
# Root Mean Squared Logarithmic Error (RMSLE): 2.5333696370341263
#
# Training model for store 11 and family 32...
# Root Mean Squared Error (RMSE): 7.454298562472946
# Root Mean Squared Logarithmic Error (RMSLE): 0.7559115008803067
#
# Training model for store 12 and family 0...
# Root Mean Squared Error (RMSE): 3.750472179633673
# Root Mean Squared Logarithmic Error (RMSLE): 0.5714307520649711
#
# Training model for store 12 and family 1...
# Root Mean Squared Error (RMSE): 0.6228485512119492
# Root Mean Squared Logarithmic Error (RMSLE): 0.3468050691563719
#
# Training model for store 12 and family 2...
# Root Mean Squared Error (RMSE): 1.4832222907705186
# Root Mean Squared Logarithmic Error (RMSLE): 0.591751969950748
#
# Training model for store 12 and family 3...
# Root Mean Squared Error (RMSE): 469.9294354231828
# Root Mean Squared Logarithmic Error (RMSLE): 0.4679647914792447
#
# Training model for store 12 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 12 and family 5...
# Root Mean Squared Error (RMSE): 87.36770748616578
# Root Mean Squared Logarithmic Error (RMSLE): 0.447894340069924
#
# Training model for store 12 and family 6...
# Root Mean Squared Error (RMSE): 12.772707124864885
# Root Mean Squared Logarithmic Error (RMSLE): 0.6857817014985351
#
# Training model for store 12 and family 7...
# Root Mean Squared Error (RMSE): 455.5605571404264
# Root Mean Squared Logarithmic Error (RMSLE): 0.5014491874059991
#
# Training model for store 12 and family 8...
# Root Mean Squared Error (RMSE): 179.55862029082263
# Root Mean Squared Logarithmic Error (RMSLE): 0.5192889155854664
#
# Training model for store 12 and family 9...
# Root Mean Squared Error (RMSE): 80.41828821197818
# Root Mean Squared Logarithmic Error (RMSLE): 0.4655958230302265
#
# Training model for store 12 and family 10...
# Root Mean Squared Error (RMSE): 72.73180073865431
# Root Mean Squared Logarithmic Error (RMSLE): 0.9025382562729262
#
# Training model for store 12 and family 11...
# Root Mean Squared Error (RMSE): 62.50561492289554
# Root Mean Squared Logarithmic Error (RMSLE): 0.5515396135490381
#
# Training model for store 12 and family 12...
# Root Mean Squared Error (RMSE): 884.3867148301212
# Root Mean Squared Logarithmic Error (RMSLE): 0.5188893583429139
#
# Training model for store 12 and family 13...
# Root Mean Squared Error (RMSE): 7.873240662401902
# Root Mean Squared Logarithmic Error (RMSLE): 0.8104071345636605
#
# Training model for store 12 and family 14...
# Root Mean Squared Error (RMSE): 1.735316535265248
# Root Mean Squared Logarithmic Error (RMSLE): 0.5739814940063116
#
# Training model for store 12 and family 15...
# Root Mean Squared Error (RMSE): 11.106486376330253
# Root Mean Squared Logarithmic Error (RMSLE): 0.6646615731639438
#
# Training model for store 12 and family 16...
# Root Mean Squared Error (RMSE): 9.0065621772032
# Root Mean Squared Logarithmic Error (RMSLE): 0.5928502027270215
#
# Training model for store 12 and family 17...
# Root Mean Squared Error (RMSE): 0.5134862277415363
# Root Mean Squared Logarithmic Error (RMSLE): 0.312422262333363
#
# Training model for store 12 and family 18...
# Root Mean Squared Error (RMSE): 54.42748058350657
# Root Mean Squared Logarithmic Error (RMSLE): 0.3904224282119731
#
# Training model for store 12 and family 19...
# Root Mean Squared Error (RMSE): 5.40591951362391
# Root Mean Squared Logarithmic Error (RMSLE): 1.2162370942377991
#
# Training model for store 12 and family 20...
# Root Mean Squared Error (RMSE): 0.0029374419688967483
# Root Mean Squared Logarithmic Error (RMSLE): 0.0029331361163036623
#
# Training model for store 12 and family 21...
# Root Mean Squared Error (RMSE): 5.055914012230287
# Root Mean Squared Logarithmic Error (RMSLE): 1.0062108968869294
#
# Training model for store 12 and family 22...
# Root Mean Squared Error (RMSE): 37.080313869318
# Root Mean Squared Logarithmic Error (RMSLE): 0.9408372054922967
#
# Training model for store 12 and family 23...
# Root Mean Squared Error (RMSE): 1.49375471632979
# Root Mean Squared Logarithmic Error (RMSLE): 0.5450905470554938
#
# Training model for store 12 and family 24...
# Root Mean Squared Error (RMSE): 630.9860162201077
# Root Mean Squared Logarithmic Error (RMSLE): 0.516233630983383
#
# Training model for store 12 and family 25...
# Root Mean Squared Error (RMSE): 69.63980691881858
# Root Mean Squared Logarithmic Error (RMSLE): 0.4631123845924741
#
# Training model for store 12 and family 26...
# Root Mean Squared Error (RMSE): 1.6507345969567329
# Root Mean Squared Logarithmic Error (RMSLE): 0.6331843204632109
#
# Training model for store 12 and family 27...
# Root Mean Squared Error (RMSE): 4.025835451828577
# Root Mean Squared Logarithmic Error (RMSLE): 0.5774799783794693
#
# Training model for store 12 and family 28...
# Root Mean Squared Error (RMSE): 72.86296952298134
# Root Mean Squared Logarithmic Error (RMSLE): 0.4822824109404721
#
# Training model for store 12 and family 29...
# Root Mean Squared Error (RMSE): 23.0208682776929
# Root Mean Squared Logarithmic Error (RMSLE): 0.5068653649534076
#
# Training model for store 12 and family 30...
# Root Mean Squared Error (RMSE): 82.10944943000293
# Root Mean Squared Logarithmic Error (RMSLE): 0.3908112799240562
#
# Training model for store 12 and family 31...
# Root Mean Squared Error (RMSE): 8.252451774374522
# Root Mean Squared Logarithmic Error (RMSLE): 2.1072973106195767
#
# Training model for store 12 and family 32...
# Root Mean Squared Error (RMSE): 3.9911211939177025
# Root Mean Squared Logarithmic Error (RMSLE): 0.6916168655823958
#
# Training model for store 13 and family 0...
# Root Mean Squared Error (RMSE): 3.9211149396148537
# Root Mean Squared Logarithmic Error (RMSLE): 0.5511016666673789
#
# Training model for store 13 and family 1...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 13 and family 2...
# Root Mean Squared Error (RMSE): 2.3387550984850796
# Root Mean Squared Logarithmic Error (RMSLE): 0.6882969859286029
#
# Training model for store 13 and family 3...
# Root Mean Squared Error (RMSE): 468.6690035296085
# Root Mean Squared Logarithmic Error (RMSLE): 0.48898297919881845
#
# Training model for store 13 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 13 and family 5...
# Root Mean Squared Error (RMSE): 71.32361495058875
# Root Mean Squared Logarithmic Error (RMSLE): 0.542857376721238
#
# Training model for store 13 and family 6...
# Root Mean Squared Error (RMSE): 7.39695759330439
# Root Mean Squared Logarithmic Error (RMSLE): 0.6858132415618671
#
# Training model for store 13 and family 7...
# Root Mean Squared Error (RMSE): 330.9767413607788
# Root Mean Squared Logarithmic Error (RMSLE): 0.5097618379530766
#
# Training model for store 13 and family 8...
# Root Mean Squared Error (RMSE): 107.60848465857954
# Root Mean Squared Logarithmic Error (RMSLE): 0.4493897747053005
#
# Training model for store 13 and family 9...
# Root Mean Squared Error (RMSE): 67.37118614820591
# Root Mean Squared Logarithmic Error (RMSLE): 0.4824011629165282
#
# Training model for store 13 and family 10...
# Root Mean Squared Error (RMSE): 41.48719065365344
# Root Mean Squared Logarithmic Error (RMSLE): 0.7995453301166182
#
# Training model for store 13 and family 11...
# Root Mean Squared Error (RMSE): 250.36375682730167
# Root Mean Squared Logarithmic Error (RMSLE): 1.9534344733436984
#
# Training model for store 13 and family 12...
# Root Mean Squared Error (RMSE): 828.763125565627
# Root Mean Squared Logarithmic Error (RMSLE): 0.5096857074243938
#
# Training model for store 13 and family 13...
# Root Mean Squared Error (RMSE): 9.540905032658983
# Root Mean Squared Logarithmic Error (RMSLE): 1.1037984805441405
#
# Training model for store 13 and family 14...
# Root Mean Squared Error (RMSE): 3.198242389760398
# Root Mean Squared Logarithmic Error (RMSLE): 0.49790459349448024
#
# Training model for store 13 and family 15...
# Root Mean Squared Error (RMSE): 13.025143999918134
# Root Mean Squared Logarithmic Error (RMSLE): 0.7899793136699226
#
# Training model for store 13 and family 16...
# Root Mean Squared Error (RMSE): 7.591620748786081
# Root Mean Squared Logarithmic Error (RMSLE): 0.6333796429212036
#
# Training model for store 13 and family 17...
# Root Mean Squared Error (RMSE): 0.280079495652706
# Root Mean Squared Logarithmic Error (RMSLE): 0.2026796505536274
#
# Training model for store 13 and family 18...
# Root Mean Squared Error (RMSE): 62.40089748688583
# Root Mean Squared Logarithmic Error (RMSLE): 0.4662135348609288
#
# Training model for store 13 and family 19...
# Root Mean Squared Error (RMSE): 3.400793594290482
# Root Mean Squared Logarithmic Error (RMSLE): 0.9719115753303819
#
# Training model for store 13 and family 20...
# Root Mean Squared Error (RMSE): 0.009315396977922363
# Root Mean Squared Logarithmic Error (RMSLE): 0.00927227625176058
#
# Training model for store 13 and family 21...
# Root Mean Squared Error (RMSE): 2.877920257184968
# Root Mean Squared Logarithmic Error (RMSLE): 0.7422936730393394
#
# Training model for store 13 and family 22...
# Root Mean Squared Error (RMSE): 40.86326535039536
# Root Mean Squared Logarithmic Error (RMSLE): 0.9801504086020162
#
# Training model for store 13 and family 23...
# Root Mean Squared Error (RMSE): 1.3553124769837481
# Root Mean Squared Logarithmic Error (RMSLE): 0.5578726544264614
#
# Training model for store 13 and family 24...
# Root Mean Squared Error (RMSE): 50.966581153084896
# Root Mean Squared Logarithmic Error (RMSLE): 0.4363339788182073
#
# Training model for store 13 and family 25...
# Root Mean Squared Error (RMSE): 82.06117584114612
# Root Mean Squared Logarithmic Error (RMSLE): 0.4799160002820677
#
# Training model for store 13 and family 26...
# Root Mean Squared Error (RMSE): 1.0526797337318972
# Root Mean Squared Logarithmic Error (RMSLE): 0.5615326537200611
#
# Training model for store 13 and family 27...
# Root Mean Squared Error (RMSE): 4.626641451986203
# Root Mean Squared Logarithmic Error (RMSLE): 0.6043481782713191
#
# Training model for store 13 and family 28...
# Root Mean Squared Error (RMSE): 67.39367191881504
# Root Mean Squared Logarithmic Error (RMSLE): 0.6103132362121102
#
# Training model for store 13 and family 29...
# Root Mean Squared Error (RMSE): 22.912341968671086
# Root Mean Squared Logarithmic Error (RMSLE): 0.7200679719301172
#
# Training model for store 13 and family 30...
# Root Mean Squared Error (RMSE): 58.27527148150482
# Root Mean Squared Logarithmic Error (RMSLE): 0.397875646374849
#
# Training model for store 13 and family 31...
# Root Mean Squared Error (RMSE): 4.093605569157811
# Root Mean Squared Logarithmic Error (RMSLE): 1.3633043872668185
#
# Training model for store 13 and family 32...
# Root Mean Squared Error (RMSE): 2.4055728760826094
# Root Mean Squared Logarithmic Error (RMSLE): 0.7550944981621407
#
# Training model for store 14 and family 0...
# Root Mean Squared Error (RMSE): 3.839210479429445
# Root Mean Squared Logarithmic Error (RMSLE): 0.6542373172432911
#
# Training model for store 14 and family 1...
# Root Mean Squared Error (RMSE): 0.003654247879301571
# Root Mean Squared Logarithmic Error (RMSLE): 0.0036475873367705597
#
# Training model for store 14 and family 2...
# Root Mean Squared Error (RMSE): 1.8145486392956227
# Root Mean Squared Logarithmic Error (RMSLE): 0.6741827103186769
#
# Training model for store 14 and family 3...
# Root Mean Squared Error (RMSE): 398.09869779385514
# Root Mean Squared Logarithmic Error (RMSLE): 0.4758863282696656
#
# Training model for store 14 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 14 and family 5...
# Root Mean Squared Error (RMSE): 48.055108339469406
# Root Mean Squared Logarithmic Error (RMSLE): 0.38311933398374276
#
# Training model for store 14 and family 6...
# Root Mean Squared Error (RMSE): 6.408177791753219
# Root Mean Squared Logarithmic Error (RMSLE): 0.6741195821226393
#
# Training model for store 14 and family 7...
# Root Mean Squared Error (RMSE): 873.1421936070741
# Root Mean Squared Logarithmic Error (RMSLE): 0.602898735299761
#
# Training model for store 14 and family 8...
# Root Mean Squared Error (RMSE): 146.622990872394
# Root Mean Squared Logarithmic Error (RMSLE): 0.45444840484101306
#
# Training model for store 14 and family 9...
# Root Mean Squared Error (RMSE): 75.7876608862262
# Root Mean Squared Logarithmic Error (RMSLE): 0.39877288817225803
#
# Training model for store 14 and family 10...
# Root Mean Squared Error (RMSE): 21.450051225920713
# Root Mean Squared Logarithmic Error (RMSLE): 0.576706217520552
#
# Training model for store 14 and family 11...
# Root Mean Squared Error (RMSE): 202.77499944347633
# Root Mean Squared Logarithmic Error (RMSLE): 0.735471336534163
#
# Training model for store 14 and family 12...
# Root Mean Squared Error (RMSE): 1040.6468918322191
# Root Mean Squared Logarithmic Error (RMSLE): 0.5227558700768581
#
# Training model for store 14 and family 13...
# Root Mean Squared Error (RMSE): 8.404924902098283
# Root Mean Squared Logarithmic Error (RMSLE): 1.024037598557363
#
# Training model for store 14 and family 14...
# Root Mean Squared Error (RMSE): 0.9670153468315358
# Root Mean Squared Logarithmic Error (RMSLE): 0.4637390499551418
#
# Training model for store 14 and family 15...
# Root Mean Squared Error (RMSE): 30.603326004676124
# Root Mean Squared Logarithmic Error (RMSLE): 0.778541783066735
#
# Training model for store 14 and family 16...
# Root Mean Squared Error (RMSE): 11.369596635754178
# Root Mean Squared Logarithmic Error (RMSLE): 0.5521236981894235
#
# Training model for store 14 and family 17...
# Root Mean Squared Error (RMSE): 0.4362198893426146
# Root Mean Squared Logarithmic Error (RMSLE): 0.2830850683864392
#
# Training model for store 14 and family 18...
# Root Mean Squared Error (RMSE): 88.96890959151025
# Root Mean Squared Logarithmic Error (RMSLE): 0.4609688545786841
#
# Training model for store 14 and family 19...
# Root Mean Squared Error (RMSE): 2.5075598147496807
# Root Mean Squared Logarithmic Error (RMSLE): 0.674667556175055
#
# Training model for store 14 and family 20...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 14 and family 21...
# Root Mean Squared Error (RMSE): 3.421109223852552
# Root Mean Squared Logarithmic Error (RMSLE): 0.8809587077461841
#
# Training model for store 14 and family 22...
# Root Mean Squared Error (RMSE): 28.89456992366689
# Root Mean Squared Logarithmic Error (RMSLE): 0.9615677461599093
#
# Training model for store 14 and family 23...
# Root Mean Squared Error (RMSE): 1.5619439019655559
# Root Mean Squared Logarithmic Error (RMSLE): 0.5600570193475192
#
# Training model for store 14 and family 24...
# Root Mean Squared Error (RMSE): 132.13607141558475
# Root Mean Squared Logarithmic Error (RMSLE): 0.5863705219853476
#
# Training model for store 14 and family 25...
# Root Mean Squared Error (RMSE): 109.28741496148064
# Root Mean Squared Logarithmic Error (RMSLE): 0.46533541155411157
#
# Training model for store 14 and family 26...
# Root Mean Squared Error (RMSE): 1.4633027204532059
# Root Mean Squared Logarithmic Error (RMSLE): 0.7045066964206028
#
# Training model for store 14 and family 27...
# Root Mean Squared Error (RMSE): 4.473627304698819
# Root Mean Squared Logarithmic Error (RMSLE): 0.6036300524696745
#
# Training model for store 14 and family 28...
# Root Mean Squared Error (RMSE): 61.803111580417536
# Root Mean Squared Logarithmic Error (RMSLE): 0.6647050612614038
#
# Training model for store 14 and family 29...
# Root Mean Squared Error (RMSE): 31.242096670975283
# Root Mean Squared Logarithmic Error (RMSLE): 0.4373546773652113
#
# Training model for store 14 and family 30...
# Root Mean Squared Error (RMSE): 112.09138061816871
# Root Mean Squared Logarithmic Error (RMSLE): 0.4189453209836246
#
# Training model for store 14 and family 31...
# Root Mean Squared Error (RMSE): 7.145216255327336
# Root Mean Squared Logarithmic Error (RMSLE): 1.9175293520505519
#
# Training model for store 14 and family 32...
# Root Mean Squared Error (RMSE): 4.099946281931203
# Root Mean Squared Logarithmic Error (RMSLE): 0.6960937399574284
#
# Training model for store 15 and family 0...
# Root Mean Squared Error (RMSE): 2.516774922189799
# Root Mean Squared Logarithmic Error (RMSLE): 0.5660983973873699
#
# Training model for store 15 and family 1...
# Root Mean Squared Error (RMSE): 2.524296668883056
# Root Mean Squared Logarithmic Error (RMSLE): 0.9373638346222943
#
# Training model for store 15 and family 2...
# Root Mean Squared Error (RMSE): 2.2841754317281175
# Root Mean Squared Logarithmic Error (RMSLE): 0.6616977095955965
#
# Training model for store 15 and family 3...
# Root Mean Squared Error (RMSE): 372.91545951833973
# Root Mean Squared Logarithmic Error (RMSLE): 0.44717328153672925
#
# Training model for store 15 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 15 and family 5...
# Root Mean Squared Error (RMSE): 40.56212580525331
# Root Mean Squared Logarithmic Error (RMSLE): 0.36353867752803515
#
# Training model for store 15 and family 6...
# Root Mean Squared Error (RMSE): 5.801035607877432
# Root Mean Squared Logarithmic Error (RMSLE): 0.9784792634066619
#
# Training model for store 15 and family 7...
# Root Mean Squared Error (RMSE): 388.0216471966159
# Root Mean Squared Logarithmic Error (RMSLE): 0.4779186887682792
#
# Training model for store 15 and family 8...
# Root Mean Squared Error (RMSE): 107.04804419180269
# Root Mean Squared Logarithmic Error (RMSLE): 0.4129704355326134
#
# Training model for store 15 and family 9...
# Root Mean Squared Error (RMSE): 67.98885425715594
# Root Mean Squared Logarithmic Error (RMSLE): 0.38432362980866724
#
# Training model for store 15 and family 10...
# Root Mean Squared Error (RMSE): 49.91349176551324
# Root Mean Squared Logarithmic Error (RMSLE): 0.5688682746430969
#
# Training model for store 15 and family 11...
# Root Mean Squared Error (RMSE): 82.76957281998608
# Root Mean Squared Logarithmic Error (RMSLE): 0.5275526617500709
#
# Training model for store 15 and family 12...
# Root Mean Squared Error (RMSE): 760.476951542843
# Root Mean Squared Logarithmic Error (RMSLE): 0.49520015953353014
#
# Training model for store 15 and family 13...
# Root Mean Squared Error (RMSE): 9.318028764171467
# Root Mean Squared Logarithmic Error (RMSLE): 0.8065674700219145
#
# Training model for store 15 and family 14...
# Root Mean Squared Error (RMSE): 1.2196794914410116
# Root Mean Squared Logarithmic Error (RMSLE): 0.5825382638537357
#
# Training model for store 15 and family 15...
# Root Mean Squared Error (RMSE): 58.70693243078461
# Root Mean Squared Logarithmic Error (RMSLE): 1.177250421960692
#
# Training model for store 15 and family 16...
# Root Mean Squared Error (RMSE): 8.266882370955585
# Root Mean Squared Logarithmic Error (RMSLE): 0.42134760872844307
#
# Training model for store 15 and family 17...
# Root Mean Squared Error (RMSE): 0.30170468515151494
# Root Mean Squared Logarithmic Error (RMSLE): 0.19475927208881694
#
# Training model for store 15 and family 18...
# Root Mean Squared Error (RMSE): 65.88500293608276
# Root Mean Squared Logarithmic Error (RMSLE): 0.406952530678219
#
# Training model for store 15 and family 19...
# Root Mean Squared Error (RMSE): 6.606803446489362
# Root Mean Squared Logarithmic Error (RMSLE): 0.7529716164378407
#
# Training model for store 15 and family 20...
# Root Mean Squared Error (RMSE): 0.010007814933456474
# Root Mean Squared Logarithmic Error (RMSLE): 0.009958068381111034
#
# Training model for store 15 and family 21...
# Root Mean Squared Error (RMSE): 3.565796236668385
# Root Mean Squared Logarithmic Error (RMSLE): 0.6679722409595431
#
# Training model for store 15 and family 22...
# Root Mean Squared Error (RMSE): 24.300224152146352
# Root Mean Squared Logarithmic Error (RMSLE): 0.8580259792165301
#
# Training model for store 15 and family 23...
# Root Mean Squared Error (RMSE): 2.4998688830327
# Root Mean Squared Logarithmic Error (RMSLE): 1.0227206799953086
#
# Training model for store 15 and family 24...
# Root Mean Squared Error (RMSE): 31.917289583770607
# Root Mean Squared Logarithmic Error (RMSLE): 0.3555724177310272
#
# Training model for store 15 and family 25...
# Root Mean Squared Error (RMSE): 60.12819054304808
# Root Mean Squared Logarithmic Error (RMSLE): 0.398474173685889
#
# Training model for store 15 and family 26...
# Root Mean Squared Error (RMSE): 1.7679302619765485
# Root Mean Squared Logarithmic Error (RMSLE): 0.7812699388583955
#
# Training model for store 15 and family 27...
# Root Mean Squared Error (RMSE): 3.669830284747512
# Root Mean Squared Logarithmic Error (RMSLE): 0.5522908235471027
#
# Training model for store 15 and family 28...
# Root Mean Squared Error (RMSE): 46.29359632063757
# Root Mean Squared Logarithmic Error (RMSLE): 0.4483562565703875
#
# Training model for store 15 and family 29...
# Root Mean Squared Error (RMSE): 33.497289174186406
# Root Mean Squared Logarithmic Error (RMSLE): 1.0238742341766451
#
# Training model for store 15 and family 30...
# Root Mean Squared Error (RMSE): 218.30396988824657
# Root Mean Squared Logarithmic Error (RMSLE): 0.44742273148369305
#
# Training model for store 15 and family 31...
# Root Mean Squared Error (RMSE): 12.750603581014689
# Root Mean Squared Logarithmic Error (RMSLE): 2.272957284992535
#
# Training model for store 15 and family 32...
# Root Mean Squared Error (RMSE): 3.5418982057476738
# Root Mean Squared Logarithmic Error (RMSLE): 0.5234187116006541
#
# Training model for store 16 and family 0...
# Root Mean Squared Error (RMSE): 3.5892530761504102
# Root Mean Squared Logarithmic Error (RMSLE): 0.7359500748028746
#
# Training model for store 16 and family 1...
# Root Mean Squared Error (RMSE): 0.30713025986547693
# Root Mean Squared Logarithmic Error (RMSLE): 0.17916477067606315
#
# Training model for store 16 and family 2...
# Root Mean Squared Error (RMSE): 1.4153280775766948
# Root Mean Squared Logarithmic Error (RMSLE): 0.6220175339642163
#
# Training model for store 16 and family 3...
# Root Mean Squared Error (RMSE): 489.5944071432339
# Root Mean Squared Logarithmic Error (RMSLE): 0.49799167624120355
#
# Training model for store 16 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 16 and family 5...
# Root Mean Squared Error (RMSE): 54.78839386484513
# Root Mean Squared Logarithmic Error (RMSLE): 0.4608804607162547
#
# Training model for store 16 and family 6...
# Root Mean Squared Error (RMSE): 5.633614297725423
# Root Mean Squared Logarithmic Error (RMSLE): 0.7523166530699646
#
# Training model for store 16 and family 7...
# Root Mean Squared Error (RMSE): 925.2723478149117
# Root Mean Squared Logarithmic Error (RMSLE): 0.6377460683444168
#
# Training model for store 16 and family 8...
# Root Mean Squared Error (RMSE): 85.67641237865337
# Root Mean Squared Logarithmic Error (RMSLE): 0.4269198517428557
#
# Training model for store 16 and family 9...
# Root Mean Squared Error (RMSE): 67.36514166098392
# Root Mean Squared Logarithmic Error (RMSLE): 0.45180295735174586
#
# Training model for store 16 and family 10...
# Root Mean Squared Error (RMSE): 143.17971223071086
# Root Mean Squared Logarithmic Error (RMSLE): 0.8241224473658725
#
# Training model for store 16 and family 11...
# Root Mean Squared Error (RMSE): 80.3442893399433
# Root Mean Squared Logarithmic Error (RMSLE): 0.7352528121479719
#
# Training model for store 16 and family 12...
# Root Mean Squared Error (RMSE): 917.6829612284679
# Root Mean Squared Logarithmic Error (RMSLE): 0.5579220192438195
#
# Training model for store 16 and family 13...
# Root Mean Squared Error (RMSE): 10.22009853147575
# Root Mean Squared Logarithmic Error (RMSLE): 1.051757246101956
#
# Training model for store 16 and family 14...
# Root Mean Squared Error (RMSE): 0.7696891352010123
# Root Mean Squared Logarithmic Error (RMSLE): 0.5061576436301067
#
# Training model for store 16 and family 15...
# Root Mean Squared Error (RMSE): 12.349829778696156
# Root Mean Squared Logarithmic Error (RMSLE): 0.711933892793703
#
# Training model for store 16 and family 16...
# Root Mean Squared Error (RMSE): 12.251591943674384
# Root Mean Squared Logarithmic Error (RMSLE): 0.59880901805631
#
# Training model for store 16 and family 17...
# Root Mean Squared Error (RMSE): 0.32951115091034705
# Root Mean Squared Logarithmic Error (RMSLE): 0.21478606136543105
#
# Training model for store 16 and family 18...
# Root Mean Squared Error (RMSE): 91.92286256446451
# Root Mean Squared Logarithmic Error (RMSLE): 0.5179045683181126
#
# Training model for store 16 and family 19...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 16 and family 20...
# Root Mean Squared Error (RMSE): 0.00926749961429794
# Root Mean Squared Logarithmic Error (RMSLE): 0.009224819827043743
#
# Training model for store 16 and family 21...
# Root Mean Squared Error (RMSE): 4.290651620712022
# Root Mean Squared Logarithmic Error (RMSLE): 1.2149389032911206
#
# Training model for store 16 and family 22...
# Root Mean Squared Error (RMSE): 61.25524372061468
# Root Mean Squared Logarithmic Error (RMSLE): 1.151689233861988
#
# Training model for store 16 and family 23...
# Root Mean Squared Error (RMSE): 1.221047277756174
# Root Mean Squared Logarithmic Error (RMSLE): 0.5268268933435756
#
# Training model for store 16 and family 24...
# Root Mean Squared Error (RMSE): 32.860094944759645
# Root Mean Squared Logarithmic Error (RMSLE): 0.5747159669469615
#
# Training model for store 16 and family 25...
# Root Mean Squared Error (RMSE): 85.00623755691767
# Root Mean Squared Logarithmic Error (RMSLE): 0.5782785275989625
#
# Training model for store 16 and family 26...
# Root Mean Squared Error (RMSE): 1.5829664027107786
# Root Mean Squared Logarithmic Error (RMSLE): 0.7162361961520888
#
# Training model for store 16 and family 27...
# Root Mean Squared Error (RMSE): 2.8460679080311935
# Root Mean Squared Logarithmic Error (RMSLE): 0.6973453883704612
#
# Training model for store 16 and family 28...
# Root Mean Squared Error (RMSE): 39.31338897039819
# Root Mean Squared Logarithmic Error (RMSLE): 0.5186569776198838
#
# Training model for store 16 and family 29...
# Root Mean Squared Error (RMSE): 12.842021393576838
# Root Mean Squared Logarithmic Error (RMSLE): 0.40778298236746524
#
# Training model for store 16 and family 30...
# Root Mean Squared Error (RMSE): 261.4358913807038
# Root Mean Squared Logarithmic Error (RMSLE): 0.5513592214711318
#
# Training model for store 16 and family 31...
# Root Mean Squared Error (RMSE): 15.382759869386955
# Root Mean Squared Logarithmic Error (RMSLE): 1.2883063442801599
#
# Training model for store 16 and family 32...
# Root Mean Squared Error (RMSE): 2.7804805248277553
# Root Mean Squared Logarithmic Error (RMSLE): 1.0310376669045072
#
# Training model for store 17 and family 0...
# Root Mean Squared Error (RMSE): 7.21428148643264
# Root Mean Squared Logarithmic Error (RMSLE): 0.649756668387549
#
# Training model for store 17 and family 1...
# Root Mean Squared Error (RMSE): 0.914579189891152
# Root Mean Squared Logarithmic Error (RMSLE): 0.46545819086760704
#
# Training model for store 17 and family 2...
# Root Mean Squared Error (RMSE): 2.5540022325316127
# Root Mean Squared Logarithmic Error (RMSLE): 0.6982254202241083
#
# Training model for store 17 and family 3...
# Root Mean Squared Error (RMSE): 1159.3062896383144
# Root Mean Squared Logarithmic Error (RMSLE): 0.5406487705538858
#
# Training model for store 17 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 17 and family 5...
# Root Mean Squared Error (RMSE): 220.9712232339183
# Root Mean Squared Logarithmic Error (RMSLE): 0.7286319591479965
#
# Training model for store 17 and family 6...
# Root Mean Squared Error (RMSE): 7.823068871669749
# Root Mean Squared Logarithmic Error (RMSLE): 0.8121678028400251
#
# Training model for store 17 and family 7...
# Root Mean Squared Error (RMSE): 465.15895425078236
# Root Mean Squared Logarithmic Error (RMSLE): 0.5219677538457457
#
# Training model for store 17 and family 8...
# Root Mean Squared Error (RMSE): 420.92999326628797
# Root Mean Squared Logarithmic Error (RMSLE): 0.6798841928526266
#
# Training model for store 17 and family 9...
# Root Mean Squared Error (RMSE): 216.40079849425382
# Root Mean Squared Logarithmic Error (RMSLE): 0.564545495223326
#
# Training model for store 17 and family 10...
# Root Mean Squared Error (RMSE): 235.0220780598343
# Root Mean Squared Logarithmic Error (RMSLE): 0.7623238060321289
#
# Training model for store 17 and family 11...
# Root Mean Squared Error (RMSE): 142.39603065157658
# Root Mean Squared Logarithmic Error (RMSLE): 0.6502947842609338
#
# Training model for store 17 and family 12...
# Root Mean Squared Error (RMSE): 2374.569059509729
# Root Mean Squared Logarithmic Error (RMSLE): 0.6834446666550813
#
# Training model for store 17 and family 13...
# Root Mean Squared Error (RMSE): 13.235382563944915
# Root Mean Squared Logarithmic Error (RMSLE): 1.046494404035786
#
# Training model for store 17 and family 14...
# Root Mean Squared Error (RMSE): 1.5012726548538575
# Root Mean Squared Logarithmic Error (RMSLE): 0.5829090259744274
#
# Training model for store 17 and family 15...
# Root Mean Squared Error (RMSE): 21.289463007488933
# Root Mean Squared Logarithmic Error (RMSLE): 0.7642701462577608
#
# Training model for store 17 and family 16...
# Root Mean Squared Error (RMSE): 37.95804194368088
# Root Mean Squared Logarithmic Error (RMSLE): 0.919128884869222
#
# Training model for store 17 and family 17...
# Root Mean Squared Error (RMSE): 0.7745387280930743
# Root Mean Squared Logarithmic Error (RMSLE): 0.4269691487634237
#
# Training model for store 17 and family 18...
# Root Mean Squared Error (RMSE): 117.25875534992255
# Root Mean Squared Logarithmic Error (RMSLE): 0.464299073695121
#
# Training model for store 17 and family 19...
# Root Mean Squared Error (RMSE): 4.795068066670448
# Root Mean Squared Logarithmic Error (RMSLE): 0.9352088873500136
#
# Training model for store 17 and family 20...
# Root Mean Squared Error (RMSE): 0.03810441255994304
# Root Mean Squared Logarithmic Error (RMSLE): 0.037396369819668415
#
# Training model for store 17 and family 21...
# Root Mean Squared Error (RMSE): 6.368241157161396
# Root Mean Squared Logarithmic Error (RMSLE): 0.8491628216747955
#
# Training model for store 17 and family 22...
# Root Mean Squared Error (RMSE): 50.829805566976226
# Root Mean Squared Logarithmic Error (RMSLE): 1.0503406715837142
#
# Training model for store 17 and family 23...
# Root Mean Squared Error (RMSE): 2.4939717732561277
# Root Mean Squared Logarithmic Error (RMSLE): 0.6288805689868229
#
# Training model for store 17 and family 24...
# Root Mean Squared Error (RMSE): 66.2789323132159
# Root Mean Squared Logarithmic Error (RMSLE): 0.3951502483712691
#
# Training model for store 17 and family 25...
# Root Mean Squared Error (RMSE): 159.61675146571784
# Root Mean Squared Logarithmic Error (RMSLE): 0.6457510417959381
#
# Training model for store 17 and family 26...
# Root Mean Squared Error (RMSE): 6.120412958290927
# Root Mean Squared Logarithmic Error (RMSLE): 1.2264732344636298
#
# Training model for store 17 and family 27...
# Root Mean Squared Error (RMSE): 8.371927178084022
# Root Mean Squared Logarithmic Error (RMSLE): 0.7064351405752034
#
# Training model for store 17 and family 28...
# Root Mean Squared Error (RMSE): 148.98138695942092
# Root Mean Squared Logarithmic Error (RMSLE): 0.5128197441611271
#
# Training model for store 17 and family 29...
# Root Mean Squared Error (RMSE): 36.34671803512684
# Root Mean Squared Logarithmic Error (RMSLE): 0.5294421475551984
#
# Training model for store 17 and family 30...
# Root Mean Squared Error (RMSE): 634.5845919489844
# Root Mean Squared Logarithmic Error (RMSLE): 0.5868089056660624
#
# Training model for store 17 and family 31...
# Root Mean Squared Error (RMSE): 6.0016893736620585
# Root Mean Squared Logarithmic Error (RMSLE): 1.5911359015909858
#
# Training model for store 17 and family 32...
# Root Mean Squared Error (RMSE): 8.407556888694918
# Root Mean Squared Logarithmic Error (RMSLE): 0.6112740039696895
#
# Training model for store 18 and family 0...
# Root Mean Squared Error (RMSE): 3.5108198753428037
# Root Mean Squared Logarithmic Error (RMSLE): 1.0170714495736608
#
# Training model for store 18 and family 1...
# Root Mean Squared Error (RMSE): 0.7528417453571213
# Root Mean Squared Logarithmic Error (RMSLE): 0.4029359742324477
#
# Training model for store 18 and family 2...
# Root Mean Squared Error (RMSE): 3.9235181679720643
# Root Mean Squared Logarithmic Error (RMSLE): 0.8693626969634433
#
# Training model for store 18 and family 3...
# Root Mean Squared Error (RMSE): 2404.3048558289383
# Root Mean Squared Logarithmic Error (RMSLE): 6.797966552085739
#
# Training model for store 18 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 18 and family 5...
# ...
# Root Mean Squared Logarithmic Error (RMSLE): 0.4271079856843946
#
# Training model for store 6 and family 32...
# Root Mean Squared Error (RMSE): 19.736577535948047
# Root Mean Squared Logarithmic Error (RMSLE): 0.48167753868105534
#
# Training model for store 7 and family 0...
# Root Mean Squared Error (RMSE): 3.642092258442528
# Root Mean Squared Logarithmic Error (RMSLE): 0.6367163258773184
#
# Training model for store 7 and family 1...
# Root Mean Squared Error (RMSE): 0.42194969253064546
# Root Mean Squared Logarithmic Error (RMSLE): 0.2698389577204375
#
# Training model for store 7 and family 2...
# Root Mean Squared Error (RMSE): 2.8365381832923084
# Root Mean Squared Logarithmic Error (RMSLE): 0.5379825075434694
#
# Training model for store 7 and family 3...
# Root Mean Squared Error (RMSE): 952.7759845575564
# Root Mean Squared Logarithmic Error (RMSLE): 0.495227829774145
#
# Training model for store 7 and family 4...
# Root Mean Squared Error (RMSE): 1.683397722813915
# Root Mean Squared Logarithmic Error (RMSLE): 0.6175152067684468
#
# Training model for store 7 and family 5...
# Root Mean Squared Error (RMSE): 302.81768303884553
# Root Mean Squared Logarithmic Error (RMSLE): 0.5553642159699592
#
# Training model for store 7 and family 6...
# Root Mean Squared Error (RMSE): 10.133085917167076
# Root Mean Squared Logarithmic Error (RMSLE): 0.5738796234011944
#
# Training model for store 7 and family 7...
# Root Mean Squared Error (RMSE): 267.35491177394294
# Root Mean Squared Logarithmic Error (RMSLE): 0.44795696621405134
#
# Training model for store 7 and family 8...
# Root Mean Squared Error (RMSE): 277.60830968363643
# Root Mean Squared Logarithmic Error (RMSLE): 0.43785227932045084
#
# Training model for store 7 and family 9...
# Root Mean Squared Error (RMSE): 52.24247727608861
# Root Mean Squared Logarithmic Error (RMSLE): 0.39272235206148864
#
# Training model for store 7 and family 10...
# Root Mean Squared Error (RMSE): 53.008166000764874
# Root Mean Squared Logarithmic Error (RMSLE): 0.3489809995446638
#
# Training model for store 7 and family 11...
# Root Mean Squared Error (RMSE): 218.96266325920726
# Root Mean Squared Logarithmic Error (RMSLE): 0.5270673095771372
#
# Training model for store 7 and family 12...
# Root Mean Squared Error (RMSE): 1122.715958200843
# Root Mean Squared Logarithmic Error (RMSLE): 0.5093758488730862
#
# Training model for store 7 and family 13...
# Root Mean Squared Error (RMSE): 16.500716696816056
# Root Mean Squared Logarithmic Error (RMSLE): 0.4254115525789012
#
# Training model for store 7 and family 14...
# Root Mean Squared Error (RMSE): 2.400230617424832
# Root Mean Squared Logarithmic Error (RMSLE): 0.6114436972893436
#
# Training model for store 7 and family 15...
# Root Mean Squared Error (RMSE): 29.742878029467615
# Root Mean Squared Logarithmic Error (RMSLE): 0.750666935436458
#
# Training model for store 7 and family 16...
# Root Mean Squared Error (RMSE): 25.83557213605514
# Root Mean Squared Logarithmic Error (RMSLE): 0.813548740380837
#
# Training model for store 7 and family 17...
# Root Mean Squared Error (RMSE): 1.1343764002241927
# Root Mean Squared Logarithmic Error (RMSLE): 0.5246302255207249
#
# Training model for store 7 and family 18...
# Root Mean Squared Error (RMSE): 62.48703122387403
# Root Mean Squared Logarithmic Error (RMSLE): 0.37527631276979656
#
# Training model for store 7 and family 19...
# Root Mean Squared Error (RMSE): 8.310683551062345
# Root Mean Squared Logarithmic Error (RMSLE): 0.6336605166060849
#
# Training model for store 7 and family 20...
# Root Mean Squared Error (RMSE): 32.42909719878862
# Root Mean Squared Logarithmic Error (RMSLE): 1.057148185996039
#
# Training model for store 7 and family 21...
# Root Mean Squared Error (RMSE): 6.408169703427178
# Root Mean Squared Logarithmic Error (RMSLE): 0.9152766993935443
#
# Training model for store 7 and family 22...
# Root Mean Squared Error (RMSE): 123.97251903699465
# Root Mean Squared Logarithmic Error (RMSLE): 1.141425529635361
#
# Training model for store 7 and family 23...
# Root Mean Squared Error (RMSE): 6.083266157840695
# Root Mean Squared Logarithmic Error (RMSLE): 0.46311654292779897
#
# Training model for store 7 and family 24...
# Root Mean Squared Error (RMSE): 160.7557690006508
# Root Mean Squared Logarithmic Error (RMSLE): 0.44650540802482563
#
# Training model for store 7 and family 25...
# Root Mean Squared Error (RMSE): 74.63232371017644
# Root Mean Squared Logarithmic Error (RMSLE): 0.4104678687999291
#
# Training model for store 7 and family 26...
# Root Mean Squared Error (RMSE): 4.256186014280088
# Root Mean Squared Logarithmic Error (RMSLE): 0.5184679989531357
#
# Training model for store 7 and family 27...
# Root Mean Squared Error (RMSE): 7.607633078401527
# Root Mean Squared Logarithmic Error (RMSLE): 0.5226863718637768
#
# Training model for store 7 and family 28...
# Root Mean Squared Error (RMSE): 165.2246603224431
# Root Mean Squared Logarithmic Error (RMSLE): 0.4277978517849176
#
# Training model for store 7 and family 29...
# Root Mean Squared Error (RMSE): 44.16184364556211
# Root Mean Squared Logarithmic Error (RMSLE): 0.38137386770653836
#
# Training model for store 7 and family 30...
# Root Mean Squared Error (RMSE): 1456.902438998746
# Root Mean Squared Logarithmic Error (RMSLE): 0.5256938418754881
#
# Training model for store 7 and family 31...
# Root Mean Squared Error (RMSE): 3.9579053243746105
# Root Mean Squared Logarithmic Error (RMSLE): 1.434142202435908
#
# Training model for store 7 and family 32...
# Root Mean Squared Error (RMSE): 20.77893947093843
# Root Mean Squared Logarithmic Error (RMSLE): 0.4770265266496826
#
# Training model for store 8 and family 0...
# Root Mean Squared Error (RMSE): 4.176120629978457
# Root Mean Squared Logarithmic Error (RMSLE): 0.6544693672251229
#
# Training model for store 8 and family 1...
# Root Mean Squared Error (RMSE): 0.7519267859434609
# Root Mean Squared Logarithmic Error (RMSLE): 0.42692850136736954
#
# Training model for store 8 and family 2...
# Root Mean Squared Error (RMSE): 6.648209211524706
# Root Mean Squared Logarithmic Error (RMSLE): 0.5711939532729119
#
# Training model for store 8 and family 3...
# Root Mean Squared Error (RMSE): 3241.014434148337
# Root Mean Squared Logarithmic Error (RMSLE): 0.9514629630807936
#
# Training model for store 8 and family 4...
# Root Mean Squared Error (RMSE): 1.8384292095310533
# Root Mean Squared Logarithmic Error (RMSLE): 0.7486912613216964
#
# Training model for store 8 and family 5...
# Root Mean Squared Error (RMSE): 244.99438720358103
# Root Mean Squared Logarithmic Error (RMSLE): 0.4487634285006723
#
# Training model for store 8 and family 6...
# Root Mean Squared Error (RMSE): 15.706867744540633
# Root Mean Squared Logarithmic Error (RMSLE): 0.5865590924075345
#
# Training model for store 8 and family 7...
# Root Mean Squared Error (RMSE): 325.9653564049839
# Root Mean Squared Logarithmic Error (RMSLE): 0.44494132921226154
#
# Training model for store 8 and family 8...
# Root Mean Squared Error (RMSE): 499.0295191012465
# Root Mean Squared Logarithmic Error (RMSLE): 0.498248719257014
#
# Training model for store 8 and family 9...
# Root Mean Squared Error (RMSE): 95.50548373277162
# Root Mean Squared Logarithmic Error (RMSLE): 0.4278017928676434
#
# Training model for store 8 and family 10...
# Root Mean Squared Error (RMSE): 119.39744514100617
# Root Mean Squared Logarithmic Error (RMSLE): 0.4506587789887961
#
# Training model for store 8 and family 11...
# Root Mean Squared Error (RMSE): 311.2550245268075
# Root Mean Squared Logarithmic Error (RMSLE): 0.6224253701634429
#
# Training model for store 8 and family 12...
# Root Mean Squared Error (RMSE): 1887.2621265772955
# Root Mean Squared Logarithmic Error (RMSLE): 0.572929808155172
#
# Training model for store 8 and family 13...
# Root Mean Squared Error (RMSE): 20.342970777838588
# Root Mean Squared Logarithmic Error (RMSLE): 0.5292276596889292
#
# Training model for store 8 and family 14...
# Root Mean Squared Error (RMSE): 2.545347031784264
# Root Mean Squared Logarithmic Error (RMSLE): 0.6153483646620506
#
# Training model for store 8 and family 15...
# Root Mean Squared Error (RMSE): 27.35257849921326
# Root Mean Squared Logarithmic Error (RMSLE): 0.5648578153533734
#
# Training model for store 8 and family 16...
# Root Mean Squared Error (RMSE): 81.96257524103164
# Root Mean Squared Logarithmic Error (RMSLE): 1.1676718468636393
#
# Training model for store 8 and family 17...
# Root Mean Squared Error (RMSE): 1.5871454418761946
# Root Mean Squared Logarithmic Error (RMSLE): 0.6282828639368057
#
# Training model for store 8 and family 18...
# Root Mean Squared Error (RMSE): 138.6551632511989
# Root Mean Squared Logarithmic Error (RMSLE): 0.46740151187972145
#
# Training model for store 8 and family 19...
# Root Mean Squared Error (RMSE): 24.607655101568657
# Root Mean Squared Logarithmic Error (RMSLE): 0.6417737371427743
#
# Training model for store 8 and family 20...
# Root Mean Squared Error (RMSE): 32.011180052411945
# Root Mean Squared Logarithmic Error (RMSLE): 0.9903130816236602
#
# Training model for store 8 and family 21...
# Root Mean Squared Error (RMSE): 11.221457143108646
# Root Mean Squared Logarithmic Error (RMSLE): 0.5412670205979456
#
# Training model for store 8 and family 22...
# Root Mean Squared Error (RMSE): 116.4914577600765
# Root Mean Squared Logarithmic Error (RMSLE): 1.0151197311241935
#
# Training model for store 8 and family 23...
# Root Mean Squared Error (RMSE): 15.039163504419061
# Root Mean Squared Logarithmic Error (RMSLE): 0.9939958348212377
#
# Training model for store 8 and family 24...
# Root Mean Squared Error (RMSE): 212.57323473556264
# Root Mean Squared Logarithmic Error (RMSLE): 0.4933345568828852
#
# Training model for store 8 and family 25...
# Root Mean Squared Error (RMSE): 148.0209986404847
# Root Mean Squared Logarithmic Error (RMSLE): 0.48836472431394456
#
# Training model for store 8 and family 26...
# Root Mean Squared Error (RMSE): 10.773583936574566
# Root Mean Squared Logarithmic Error (RMSLE): 0.5203418908405034
#
# Training model for store 8 and family 27...
# Root Mean Squared Error (RMSE): 10.227572376675951
# Root Mean Squared Logarithmic Error (RMSLE): 0.4809879852208417
#
# Training model for store 8 and family 28...
# Root Mean Squared Error (RMSE): 221.3019173486687
# Root Mean Squared Logarithmic Error (RMSLE): 0.47224301779984956
#
# Training model for store 8 and family 29...
# Root Mean Squared Error (RMSE): 70.28171764332475
# Root Mean Squared Logarithmic Error (RMSLE): 0.4618035967732304
#
# Training model for store 8 and family 30...
# Root Mean Squared Error (RMSE): 1799.6863284834017
# Root Mean Squared Logarithmic Error (RMSLE): 0.5746730904850005
#
# Training model for store 8 and family 31...
# Root Mean Squared Error (RMSE): 4.983567842634081
# Root Mean Squared Logarithmic Error (RMSLE): 1.5072319892754011
#
# Training model for store 8 and family 32...
# Root Mean Squared Error (RMSE): 21.100666749696014
# Root Mean Squared Logarithmic Error (RMSLE): 0.4879993014219878
#
# Training model for store 9 and family 0...
# Root Mean Squared Error (RMSE): 8.007874661513405
# Root Mean Squared Logarithmic Error (RMSLE): 0.6516674502385879
#
# Training model for store 9 and family 1...
# Root Mean Squared Error (RMSE): 0.7821568741980526
# Root Mean Squared Logarithmic Error (RMSLE): 0.41996726432636333
#
# Training model for store 9 and family 2...
# Root Mean Squared Error (RMSE): 7.044414306340061
# Root Mean Squared Logarithmic Error (RMSLE): 0.8292170388032071
#
# Training model for store 9 and family 3...
# Root Mean Squared Error (RMSE): 1353.0674087728898
# Root Mean Squared Logarithmic Error (RMSLE): 0.5408700505561199
#
# Training model for store 9 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 9 and family 5...
# Root Mean Squared Error (RMSE): 180.17592674759103
# Root Mean Squared Logarithmic Error (RMSLE): 0.44088581008044114
#
# Training model for store 9 and family 6...
# Root Mean Squared Error (RMSE): 15.509712121808164
# Root Mean Squared Logarithmic Error (RMSLE): 0.9655601058251727
#
# Training model for store 9 and family 7...
# Root Mean Squared Error (RMSE): 716.3635872284583
# Root Mean Squared Logarithmic Error (RMSLE): 0.5425453095337
#
# Training model for store 9 and family 8...
# Root Mean Squared Error (RMSE): 419.1916312397991
# Root Mean Squared Logarithmic Error (RMSLE): 0.5685495467734636
#
# Training model for store 9 and family 9...
# Root Mean Squared Error (RMSE): 190.98724390834963
# Root Mean Squared Logarithmic Error (RMSLE): 0.45624391160624583
#
# Training model for store 9 and family 10...
# Root Mean Squared Error (RMSE): 107.86737879974295
# Root Mean Squared Logarithmic Error (RMSLE): 0.5592836471363551
#
# Training model for store 9 and family 11...
# Root Mean Squared Error (RMSE): 266.4051907781853
# Root Mean Squared Logarithmic Error (RMSLE): 0.7460302165067421
#
# Training model for store 9 and family 12...
# Root Mean Squared Error (RMSE): 3399.9454640492127
# Root Mean Squared Logarithmic Error (RMSLE): 0.631089208828963
#
# Training model for store 9 and family 13...
# Root Mean Squared Error (RMSE): 9.865594219177384
# Root Mean Squared Logarithmic Error (RMSLE): 0.871726135196286
#
# Training model for store 9 and family 14...
# Root Mean Squared Error (RMSE): 1.52441509719464
# Root Mean Squared Logarithmic Error (RMSLE): 0.6668975939703525
#
# Training model for store 9 and family 15...
# Root Mean Squared Error (RMSE): 84.11865909412873
# Root Mean Squared Logarithmic Error (RMSLE): 0.894725755959793
#
# Training model for store 9 and family 16...
# Root Mean Squared Error (RMSE): 18.891640035411424
# Root Mean Squared Logarithmic Error (RMSLE): 0.5043823878557702
#
# Training model for store 9 and family 17...
# Root Mean Squared Error (RMSE): 0.40150908594039336
# Root Mean Squared Logarithmic Error (RMSLE): 0.2871607369321077
#
# Training model for store 9 and family 18...
# Root Mean Squared Error (RMSE): 170.90460854967114
# Root Mean Squared Logarithmic Error (RMSLE): 0.4632043812749752
#
# Training model for store 9 and family 19...
# Root Mean Squared Error (RMSE): 10.977319783213266
# Root Mean Squared Logarithmic Error (RMSLE): 0.6998704067143294
#
# Training model for store 9 and family 20...
# Root Mean Squared Error (RMSE): 10.731339188524398
# Root Mean Squared Logarithmic Error (RMSLE): 0.6804369950712909
#
# Training model for store 9 and family 21...
# Root Mean Squared Error (RMSE): 6.843833285437429
# Root Mean Squared Logarithmic Error (RMSLE): 0.8748474045162669
#
# Training model for store 9 and family 22...
# Root Mean Squared Error (RMSE): 56.154224159865
# Root Mean Squared Logarithmic Error (RMSLE): 1.023442477636642
#
# Training model for store 9 and family 23...
# Root Mean Squared Error (RMSE): 3.2090160061008657
# Root Mean Squared Logarithmic Error (RMSLE): 0.6324039436817895
#
# Training model for store 9 and family 24...
# Root Mean Squared Error (RMSE): 112.57901026270994
# Root Mean Squared Logarithmic Error (RMSLE): 0.41894065078786025
#
# Training model for store 9 and family 25...
# Root Mean Squared Error (RMSE): 233.99272214399443
# Root Mean Squared Logarithmic Error (RMSLE): 0.5689362956561216
#
# Training model for store 9 and family 26...
# Root Mean Squared Error (RMSE): 3.9351017922054545
# Root Mean Squared Logarithmic Error (RMSLE): 0.4878633626102188
#
# Training model for store 9 and family 27...
# Root Mean Squared Error (RMSE): 7.331892550092642
# Root Mean Squared Logarithmic Error (RMSLE): 0.5608560168333678
#
# Training model for store 9 and family 28...
# Root Mean Squared Error (RMSE): 191.4637898100364
# Root Mean Squared Logarithmic Error (RMSLE): 0.4886862547190859
#
# Training model for store 9 and family 29...
# Root Mean Squared Error (RMSE): 56.71785821171187
# Root Mean Squared Logarithmic Error (RMSLE): 0.5620039225558217
#
# Training model for store 9 and family 30...
# Root Mean Squared Error (RMSE): 621.0104747094912
# Root Mean Squared Logarithmic Error (RMSLE): 0.534255937321328
#
# Training model for store 9 and family 31...
# Root Mean Squared Error (RMSE): 90.17435587553018
# Root Mean Squared Logarithmic Error (RMSLE): 3.5058001259281233
#
# Training model for store 9 and family 32...
# Root Mean Squared Error (RMSE): 10.214868679312728
# Root Mean Squared Logarithmic Error (RMSLE): 0.6368679731394367

# %%
avg_rmse = total_rmse / num_models
avg_rmsle = total_rmsle / num_models

# %%
print(f"Average Root Mean Squared Error (RMSE) across all models: {avg_rmse}")
print(f"Average Root Mean Squared Logarithmic Error (RMSLE) across all models: {avg_rmsle}")
# Out:
# Average Root Mean Squared Error (RMSE) across all models: 224.14517415031307
# Average Root Mean Squared Logarithmic Error (RMSLE) across all models: 0.7706459304868941
