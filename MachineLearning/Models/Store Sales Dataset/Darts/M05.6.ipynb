# %%
import pandas as pd
import numpy as np
from darts import TimeSeries
from darts.models import RandomForest
from sklearn.metrics import mean_squared_error, mean_squared_log_error
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../Data/Kaggle/StoreSales/train_darts.csv", parse_dates=["date"])

# %%
df.head()
# Out:
#         date  store_nbr  family  sales  onpromotion  typeholiday  dcoilwtico  \
# 0 2013-01-01          1       0    0.0            0            3       93.14
# 1 2013-01-01          1       1    0.0            0            3       93.14
# 2 2013-01-01          1       2    0.0            0            3       93.14
# 3 2013-01-01          1       3    0.0            0            3       93.14
# 4 2013-01-01          1       4    0.0            0            3       93.14
#
#    city  state  typestores  cluster  day_of_week  day  month  year
# 0    18     12           3       13            2    1      1  2013
# 1    18     12           3       13            2    1      1  2013
# 2    18     12           3       13            2    1      1  2013
# 3    18     12           3       13            2    1      1  2013
# 4    18     12           3       13            2    1      1  2013

# %%
unique_combinations = df[['store_nbr', 'family']].drop_duplicates()

# %%
total_rmse = 0
total_rmsle = 0
num_models = 0

# %%
trained_models = {}

# %%
for index, row in unique_combinations.iterrows():
    store_nbr = row['store_nbr']
    family = row['family']
    
    print(f"\nTraining model for store {store_nbr} and family {family}...")
    
    df_subset = df[(df['store_nbr'] == store_nbr) & (df['family'] == family)]
    
    ts = TimeSeries.from_dataframe(df_subset, value_cols=["sales"])

    split_ratio = 0.8
    training_size = int(len(ts) * split_ratio)
    train = ts[:training_size]
    val = ts[training_size:]

    model = RandomForest(lags=2)
    model.fit(train)

    trained_models[(store_nbr, family)] = model

    predictions = model.predict(n=len(val))

    val = val.pd_series().tolist()
    predictions = predictions.pd_series().tolist()

    predictions = np.maximum(predictions, 0)

    rmse = np.sqrt(mean_squared_error(val, predictions))
    rmsle = np.sqrt(mean_squared_error(np.log1p(val), np.log1p(predictions)))

    total_rmse += rmse
    total_rmsle += rmsle
    num_models += 1

    print(f"Root Mean Squared Error (RMSE): {rmse}")
    print(f"Root Mean Squared Logarithmic Error (RMSLE): {rmsle}")

    plt.figure(figsize=(12, 6))
    plt.plot(val, label='Actual')
    plt.plot(predictions, label='Predictions')
    plt.title(f"Model for store {store_nbr} and family {family}")
    plt.legend()
    plt.savefig(f"plots/M05.6_store{store_nbr}_family{family}.png")
    plt.close()
# Out:
# Training model for store 1 and family 0...
# Root Mean Squared Error (RMSE): 2.8560137175621243
# Root Mean Squared Logarithmic Error (RMSLE): 0.6012867405294068
#
# Training model for store 1 and family 1...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 1 and family 2...
# Root Mean Squared Error (RMSE): 2.5138190765516484
# Root Mean Squared Logarithmic Error (RMSLE): 0.5794790165175364
#
# Training model for store 1 and family 3...
# Root Mean Squared Error (RMSE): 1101.6176907157596
# Root Mean Squared Logarithmic Error (RMSLE): 0.775502946212333
#
# Training model for store 1 and family 4...
# Root Mean Squared Error (RMSE): 1.231389651888243
# Root Mean Squared Logarithmic Error (RMSLE): 0.5971886853304214
#
# Training model for store 1 and family 5...
# Root Mean Squared Error (RMSE): 165.61632644684008
# Root Mean Squared Logarithmic Error (RMSLE): 0.6286613769367948
#
# Training model for store 1 and family 6...
# Root Mean Squared Error (RMSE): 11.07910406823546
# Root Mean Squared Logarithmic Error (RMSLE): 0.8895438266020222
#
# Training model for store 1 and family 7...
# Root Mean Squared Error (RMSE): 281.1197713182224
# Root Mean Squared Logarithmic Error (RMSLE): 0.655795988211015
#
# Training model for store 1 and family 8...
# Root Mean Squared Error (RMSE): 394.30129825770945
# Root Mean Squared Logarithmic Error (RMSLE): 0.7703352877998116
#
# Training model for store 1 and family 9...
# Root Mean Squared Error (RMSE): 50.06108650973775
# Root Mean Squared Logarithmic Error (RMSLE): 0.4870246923594228
#
# Training model for store 1 and family 10...
# Root Mean Squared Error (RMSE): 44.44872470603905
# Root Mean Squared Logarithmic Error (RMSLE): 0.45644713873487164
#
# Training model for store 1 and family 11...
# Root Mean Squared Error (RMSE): 144.95458374999706
# Root Mean Squared Logarithmic Error (RMSLE): 0.6601986865833797
#
# Training model for store 1 and family 12...
# Root Mean Squared Error (RMSE): 1197.9495830761346
# Root Mean Squared Logarithmic Error (RMSLE): 0.6820859109564581
#
# Training model for store 1 and family 13...
# Root Mean Squared Error (RMSE): 14.55557819114176
# Root Mean Squared Logarithmic Error (RMSLE): 0.7050972991942368
#
# Training model for store 1 and family 14...
# Root Mean Squared Error (RMSE): 1.6921738706421028
# Root Mean Squared Logarithmic Error (RMSLE): 0.6093230140002437
#
# Training model for store 1 and family 15...
# Root Mean Squared Error (RMSE): 17.89971773123865
# Root Mean Squared Logarithmic Error (RMSLE): 0.9327917163463432
#
# Training model for store 1 and family 16...
# Root Mean Squared Error (RMSE): 18.645681192027606
# Root Mean Squared Logarithmic Error (RMSLE): 0.9718022886644226
#
# Training model for store 1 and family 17...
# Root Mean Squared Error (RMSE): 0.7066086077582729
# Root Mean Squared Logarithmic Error (RMSLE): 0.38574226559007835
#
# Training model for store 1 and family 18...
# Root Mean Squared Error (RMSE): 60.943027784922606
# Root Mean Squared Logarithmic Error (RMSLE): 0.4932443919503592
#
# Training model for store 1 and family 19...
# Root Mean Squared Error (RMSE): 7.959945970362601
# Root Mean Squared Logarithmic Error (RMSLE): 0.636925308195349
#
# Training model for store 1 and family 20...
# Root Mean Squared Error (RMSE): 14.520705754514582
# Root Mean Squared Logarithmic Error (RMSLE): 0.942633818575759
#
# Training model for store 1 and family 21...
# Root Mean Squared Error (RMSE): 5.5241059353634006
# Root Mean Squared Logarithmic Error (RMSLE): 0.8097079052622421
#
# Training model for store 1 and family 22...
# Root Mean Squared Error (RMSE): 72.88708611598297
# Root Mean Squared Logarithmic Error (RMSLE): 0.9778728076150117
#
# Training model for store 1 and family 23...
# Root Mean Squared Error (RMSE): 4.255617704004543
# Root Mean Squared Logarithmic Error (RMSLE): 0.5749053816138099
#
# Training model for store 1 and family 24...
# Root Mean Squared Error (RMSE): 215.60774514333448
# Root Mean Squared Logarithmic Error (RMSLE): 0.7396210052463285
#
# Training model for store 1 and family 25...
# Root Mean Squared Error (RMSE): 78.9948693749163
# Root Mean Squared Logarithmic Error (RMSLE): 0.6058191636157481
#
# Training model for store 1 and family 26...
# Root Mean Squared Error (RMSE): 3.0866526516766335
# Root Mean Squared Logarithmic Error (RMSLE): 0.534714397643962
#
# Training model for store 1 and family 27...
# Root Mean Squared Error (RMSE): 5.005570114241103
# Root Mean Squared Logarithmic Error (RMSLE): 0.5808045547094987
#
# Training model for store 1 and family 28...
# Root Mean Squared Error (RMSE): 141.9437411658751
# Root Mean Squared Logarithmic Error (RMSLE): 0.588752644879879
#
# Training model for store 1 and family 29...
# Root Mean Squared Error (RMSE): 31.60009597631284
# Root Mean Squared Logarithmic Error (RMSLE): 0.4792837965800549
#
# Training model for store 1 and family 30...
# Root Mean Squared Error (RMSE): 1062.1144568150285
# Root Mean Squared Logarithmic Error (RMSLE): 0.6219545938549821
#
# Training model for store 1 and family 31...
# Root Mean Squared Error (RMSE): 0.6046406611247539
# Root Mean Squared Logarithmic Error (RMSLE): 0.3500232648485848
#
# Training model for store 1 and family 32...
# Root Mean Squared Error (RMSE): 13.790398502225225
# Root Mean Squared Logarithmic Error (RMSLE): 0.5292897296310892
#
# Training model for store 10 and family 0...
# Root Mean Squared Error (RMSE): 2.6127921406732777
# Root Mean Squared Logarithmic Error (RMSLE): 0.7248600914908794
#
# Training model for store 10 and family 1...
# Root Mean Squared Error (RMSE): 1.3679683633512367
# Root Mean Squared Logarithmic Error (RMSLE): 0.8019322665774572
#
# Training model for store 10 and family 2...
# Root Mean Squared Error (RMSE): 1.6372492960761433
# Root Mean Squared Logarithmic Error (RMSLE): 0.6098009479832631
#
# Training model for store 10 and family 3...
# Root Mean Squared Error (RMSE): 496.6988550739278
# Root Mean Squared Logarithmic Error (RMSLE): 0.574321303458672
#
# Training model for store 10 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 10 and family 5...
# Root Mean Squared Error (RMSE): 35.66651562132219
# Root Mean Squared Logarithmic Error (RMSLE): 0.4141400810914554
#
# Training model for store 10 and family 6...
# Root Mean Squared Error (RMSE): 4.110523981046379
# Root Mean Squared Logarithmic Error (RMSLE): 0.899379003546405
#
# Training model for store 10 and family 7...
# Root Mean Squared Error (RMSE): 314.54181095528537
# Root Mean Squared Logarithmic Error (RMSLE): 0.49437374835325565
#
# Training model for store 10 and family 8...
# Root Mean Squared Error (RMSE): 129.42021914274935
# Root Mean Squared Logarithmic Error (RMSLE): 0.4996338675201046
#
# Training model for store 10 and family 9...
# Root Mean Squared Error (RMSE): 82.71468666925148
# Root Mean Squared Logarithmic Error (RMSLE): 0.42764041661817215
#
# Training model for store 10 and family 10...
# Root Mean Squared Error (RMSE): 33.495849850193224
# Root Mean Squared Logarithmic Error (RMSLE): 0.71838163976118
#
# Training model for store 10 and family 11...
# Root Mean Squared Error (RMSE): 76.55280382567302
# Root Mean Squared Logarithmic Error (RMSLE): 0.6932082194114575
#
# Training model for store 10 and family 12...
# Root Mean Squared Error (RMSE): 881.4659849824774
# Root Mean Squared Logarithmic Error (RMSLE): 0.5315920625738184
#
# Training model for store 10 and family 13...
# Root Mean Squared Error (RMSE): 5.72668987338316
# Root Mean Squared Logarithmic Error (RMSLE): 0.9219595261761804
#
# Training model for store 10 and family 14...
# Root Mean Squared Error (RMSE): 0.9257109834363618
# Root Mean Squared Logarithmic Error (RMSLE): 0.5867959662235634
#
# Training model for store 10 and family 15...
# Root Mean Squared Error (RMSE): 8.738278843928835
# Root Mean Squared Logarithmic Error (RMSLE): 0.7705856388782881
#
# Training model for store 10 and family 16...
# Root Mean Squared Error (RMSE): 4.34023320878348
# Root Mean Squared Logarithmic Error (RMSLE): 0.5871787926921094
#
# Training model for store 10 and family 17...
# Root Mean Squared Error (RMSE): 0.38612529176132665
# Root Mean Squared Logarithmic Error (RMSLE): 0.2502281656590224
#
# Training model for store 10 and family 18...
# Root Mean Squared Error (RMSE): 60.10881312886143
# Root Mean Squared Logarithmic Error (RMSLE): 0.4339693676393891
#
# Training model for store 10 and family 19...
# Root Mean Squared Error (RMSE): 5.39158550025922
# Root Mean Squared Logarithmic Error (RMSLE): 1.0630911486201398
#
# Training model for store 10 and family 20...
# Root Mean Squared Error (RMSE): 0.00482831192612576
# Root Mean Squared Logarithmic Error (RMSLE): 0.004816693012913061
#
# Training model for store 10 and family 21...
# Root Mean Squared Error (RMSE): 3.169811189391918
# Root Mean Squared Logarithmic Error (RMSLE): 0.9828209543271321
#
# Training model for store 10 and family 22...
# Root Mean Squared Error (RMSE): 13.601610387725495
# Root Mean Squared Logarithmic Error (RMSLE): 0.8890172749979991
#
# Training model for store 10 and family 23...
# Root Mean Squared Error (RMSE): 1.0125376862760722
# Root Mean Squared Logarithmic Error (RMSLE): 0.5418474339803673
#
# Training model for store 10 and family 24...
# Root Mean Squared Error (RMSE): 49.98427097806565
# Root Mean Squared Logarithmic Error (RMSLE): 0.42017815942854686
#
# Training model for store 10 and family 25...
# Root Mean Squared Error (RMSE): 75.92701127294642
# Root Mean Squared Logarithmic Error (RMSLE): 0.48809834466609536
#
# Training model for store 10 and family 26...
# Root Mean Squared Error (RMSE): 1.437159246058602
# Root Mean Squared Logarithmic Error (RMSLE): 0.6789415391875457
#
# Training model for store 10 and family 27...
# Root Mean Squared Error (RMSE): 2.9521662688558292
# Root Mean Squared Logarithmic Error (RMSLE): 0.5746174335919007
#
# Training model for store 10 and family 28...
# Root Mean Squared Error (RMSE): 59.28087028473598
# Root Mean Squared Logarithmic Error (RMSLE): 0.4538078648786091
#
# Training model for store 10 and family 29...
# Root Mean Squared Error (RMSE): 21.057636173916652
# Root Mean Squared Logarithmic Error (RMSLE): 0.9259793214435564
#
# Training model for store 10 and family 30...
# Root Mean Squared Error (RMSE): 78.48941927417218
# Root Mean Squared Logarithmic Error (RMSLE): 0.407293288991
#
# Training model for store 10 and family 31...
# Root Mean Squared Error (RMSE): 10.942648942343482
# Root Mean Squared Logarithmic Error (RMSLE): 2.392764853502366
#
# Training model for store 10 and family 32...
# Root Mean Squared Error (RMSE): 3.0618029516540957
# Root Mean Squared Logarithmic Error (RMSLE): 1.014398506181253
#
# Training model for store 11 and family 0...
# Root Mean Squared Error (RMSE): 4.549324849350594
# Root Mean Squared Logarithmic Error (RMSLE): 0.5859218839486089
#
# Training model for store 11 and family 1...
# Root Mean Squared Error (RMSE): 0.9800484151504277
# Root Mean Squared Logarithmic Error (RMSLE): 0.49005162331076824
#
# Training model for store 11 and family 2...
# Root Mean Squared Error (RMSE): 4.569898380049999
# Root Mean Squared Logarithmic Error (RMSLE): 0.5593294842355703
#
# Training model for store 11 and family 3...
# Root Mean Squared Error (RMSE): 1680.9411481030659
# Root Mean Squared Logarithmic Error (RMSLE): 0.5976325857700191
#
# Training model for store 11 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 11 and family 5...
# Root Mean Squared Error (RMSE): 185.55771552621493
# Root Mean Squared Logarithmic Error (RMSLE): 0.425006888891734
#
# Training model for store 11 and family 6...
# Root Mean Squared Error (RMSE): 10.95538844558934
# Root Mean Squared Logarithmic Error (RMSLE): 0.7161296719216891
#
# Training model for store 11 and family 7...
# Root Mean Squared Error (RMSE): 767.4708057533685
# Root Mean Squared Logarithmic Error (RMSLE): 0.5269878806493578
#
# Training model for store 11 and family 8...
# Root Mean Squared Error (RMSE): 300.9462834395224
# Root Mean Squared Logarithmic Error (RMSLE): 0.5534734497336723
#
# Training model for store 11 and family 9...
# Root Mean Squared Error (RMSE): 184.9526466049168
# Root Mean Squared Logarithmic Error (RMSLE): 0.48577562365437177
#
# Training model for store 11 and family 10...
# Root Mean Squared Error (RMSE): 138.9555363969584
# Root Mean Squared Logarithmic Error (RMSLE): 0.716688835850707
#
# Training model for store 11 and family 11...
# Root Mean Squared Error (RMSE): 138.98175480921213
# Root Mean Squared Logarithmic Error (RMSLE): 0.6456177575056057
#
# Training model for store 11 and family 12...
# Root Mean Squared Error (RMSE): 2685.6512386153713
# Root Mean Squared Logarithmic Error (RMSLE): 0.5871107948981663
#
# Training model for store 11 and family 13...
# Root Mean Squared Error (RMSE): 18.747853963144347
# Root Mean Squared Logarithmic Error (RMSLE): 0.8353670290234537
#
# Training model for store 11 and family 14...
# Root Mean Squared Error (RMSE): 0.9915245352486045
# Root Mean Squared Logarithmic Error (RMSLE): 0.519006615266521
#
# Training model for store 11 and family 15...
# Root Mean Squared Error (RMSE): 32.39168508015448
# Root Mean Squared Logarithmic Error (RMSLE): 0.7105051505595417
#
# Training model for store 11 and family 16...
# Root Mean Squared Error (RMSE): 18.44614994917399
# Root Mean Squared Logarithmic Error (RMSLE): 0.640794841209466
#
# Training model for store 11 and family 17...
# Root Mean Squared Error (RMSE): 0.7176162119321686
# Root Mean Squared Logarithmic Error (RMSLE): 0.4625577419991936
#
# Training model for store 11 and family 18...
# Root Mean Squared Error (RMSE): 187.86192850146173
# Root Mean Squared Logarithmic Error (RMSLE): 0.458387660083433
#
# Training model for store 11 and family 19...
# Root Mean Squared Error (RMSE): 13.404603167116539
# Root Mean Squared Logarithmic Error (RMSLE): 0.8496632698536313
#
# Training model for store 11 and family 20...
# Root Mean Squared Error (RMSE): 6.004334654825874
# Root Mean Squared Logarithmic Error (RMSLE): 0.7650132227554799
#
# Training model for store 11 and family 21...
# Root Mean Squared Error (RMSE): 5.736077517364531
# Root Mean Squared Logarithmic Error (RMSLE): 0.5824615382311633
#
# Training model for store 11 and family 22...
# Root Mean Squared Error (RMSE): 48.77059020181645
# Root Mean Squared Logarithmic Error (RMSLE): 0.9755866428645777
#
# Training model for store 11 and family 23...
# Root Mean Squared Error (RMSE): 3.1494009054867305
# Root Mean Squared Logarithmic Error (RMSLE): 0.7547924861009002
#
# Training model for store 11 and family 24...
# Root Mean Squared Error (RMSE): 177.51766887986147
# Root Mean Squared Logarithmic Error (RMSLE): 0.44718967564255097
#
# Training model for store 11 and family 25...
# Root Mean Squared Error (RMSE): 224.7523609238249
# Root Mean Squared Logarithmic Error (RMSLE): 0.5621483628710385
#
# Training model for store 11 and family 26...
# Root Mean Squared Error (RMSE): 2.3283056653904537
# Root Mean Squared Logarithmic Error (RMSLE): 0.6554721137802394
#
# Training model for store 11 and family 27...
# Root Mean Squared Error (RMSE): 10.758139623115085
# Root Mean Squared Logarithmic Error (RMSLE): 0.5228927771049934
#
# Training model for store 11 and family 28...
# Root Mean Squared Error (RMSE): 229.42791811447285
# Root Mean Squared Logarithmic Error (RMSLE): 0.6432111695146323
#
# Training model for store 11 and family 29...
# Root Mean Squared Error (RMSE): 32.35789901519199
# Root Mean Squared Logarithmic Error (RMSLE): 0.4364041466601957
#
# Training model for store 11 and family 30...
# Root Mean Squared Error (RMSE): 765.5852420950708
# Root Mean Squared Logarithmic Error (RMSLE): 0.5492714691710379
#
# Training model for store 11 and family 31...
# Root Mean Squared Error (RMSE): 43.58236667353516
# Root Mean Squared Logarithmic Error (RMSLE): 2.5330892597493455
#
# Training model for store 11 and family 32...
# Root Mean Squared Error (RMSE): 7.022000956125292
# Root Mean Squared Logarithmic Error (RMSLE): 0.6955816137827447
#
# Training model for store 12 and family 0...
# Root Mean Squared Error (RMSE): 3.7088153990634227
# Root Mean Squared Logarithmic Error (RMSLE): 0.5706849578609519
#
# Training model for store 12 and family 1...
# Root Mean Squared Error (RMSE): 0.6222001128305793
# Root Mean Squared Logarithmic Error (RMSLE): 0.34627456030813536
#
# Training model for store 12 and family 2...
# Root Mean Squared Error (RMSE): 1.4833373102148104
# Root Mean Squared Logarithmic Error (RMSLE): 0.5914259477962327
#
# Training model for store 12 and family 3...
# Root Mean Squared Error (RMSE): 488.03166922948753
# Root Mean Squared Logarithmic Error (RMSLE): 0.4801744584212487
#
# Training model for store 12 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 12 and family 5...
# Root Mean Squared Error (RMSE): 81.96041641616941
# Root Mean Squared Logarithmic Error (RMSLE): 0.4339792264955705
#
# Training model for store 12 and family 6...
# Root Mean Squared Error (RMSE): 12.44880442171717
# Root Mean Squared Logarithmic Error (RMSLE): 0.6857072220050859
#
# Training model for store 12 and family 7...
# Root Mean Squared Error (RMSE): 443.5838641466025
# Root Mean Squared Logarithmic Error (RMSLE): 0.49000237436203903
#
# Training model for store 12 and family 8...
# Root Mean Squared Error (RMSE): 176.40857052997578
# Root Mean Squared Logarithmic Error (RMSLE): 0.5146757926054057
#
# Training model for store 12 and family 9...
# Root Mean Squared Error (RMSE): 83.7434061124805
# Root Mean Squared Logarithmic Error (RMSLE): 0.4762980504819641
#
# Training model for store 12 and family 10...
# Root Mean Squared Error (RMSE): 71.42309084117092
# Root Mean Squared Logarithmic Error (RMSLE): 0.8927680391850217
#
# Training model for store 12 and family 11...
# Root Mean Squared Error (RMSE): 63.20981500212704
# Root Mean Squared Logarithmic Error (RMSLE): 0.5859447190290332
#
# Training model for store 12 and family 12...
# Root Mean Squared Error (RMSE): 906.4793605597181
# Root Mean Squared Logarithmic Error (RMSLE): 0.5227974250911448
#
# Training model for store 12 and family 13...
# Root Mean Squared Error (RMSE): 8.047402977689528
# Root Mean Squared Logarithmic Error (RMSLE): 0.7848899243515272
#
# Training model for store 12 and family 14...
# Root Mean Squared Error (RMSE): 1.7362860243357414
# Root Mean Squared Logarithmic Error (RMSLE): 0.5782328161171143
#
# Training model for store 12 and family 15...
# Root Mean Squared Error (RMSE): 10.147799135576063
# Root Mean Squared Logarithmic Error (RMSLE): 0.6241668130040683
#
# Training model for store 12 and family 16...
# Root Mean Squared Error (RMSE): 8.265834517498803
# Root Mean Squared Logarithmic Error (RMSLE): 0.5046289153374591
#
# Training model for store 12 and family 17...
# Root Mean Squared Error (RMSE): 0.5133929679248136
# Root Mean Squared Logarithmic Error (RMSLE): 0.31250697773486746
#
# Training model for store 12 and family 18...
# Root Mean Squared Error (RMSE): 52.82114916636461
# Root Mean Squared Logarithmic Error (RMSLE): 0.38755499453515885
#
# Training model for store 12 and family 19...
# Root Mean Squared Error (RMSE): 5.405568632007694
# Root Mean Squared Logarithmic Error (RMSLE): 1.215889767022628
#
# Training model for store 12 and family 20...
# Root Mean Squared Error (RMSE): 0.003103292388107761
# Root Mean Squared Logarithmic Error (RMSLE): 0.0030984871151626646
#
# Training model for store 12 and family 21...
# Root Mean Squared Error (RMSE): 6.434305977400636
# Root Mean Squared Logarithmic Error (RMSLE): 1.1543791311876945
#
# Training model for store 12 and family 22...
# Root Mean Squared Error (RMSE): 39.088499328818706
# Root Mean Squared Logarithmic Error (RMSLE): 0.9911832819022003
#
# Training model for store 12 and family 23...
# Root Mean Squared Error (RMSE): 1.4928196371898579
# Root Mean Squared Logarithmic Error (RMSLE): 0.5451377425803443
#
# Training model for store 12 and family 24...
# Root Mean Squared Error (RMSE): 629.8742933473214
# Root Mean Squared Logarithmic Error (RMSLE): 0.502135717541379
#
# Training model for store 12 and family 25...
# Root Mean Squared Error (RMSE): 68.95508762340431
# Root Mean Squared Logarithmic Error (RMSLE): 0.4694917421656062
#
# Training model for store 12 and family 26...
# Root Mean Squared Error (RMSE): 1.652361189321931
# Root Mean Squared Logarithmic Error (RMSLE): 0.634171683293904
#
# Training model for store 12 and family 27...
# Root Mean Squared Error (RMSE): 4.020647837435205
# Root Mean Squared Logarithmic Error (RMSLE): 0.5767230121833653
#
# Training model for store 12 and family 28...
# Root Mean Squared Error (RMSE): 67.47298010290558
# Root Mean Squared Logarithmic Error (RMSLE): 0.4594030130993009
#
# Training model for store 12 and family 29...
# Root Mean Squared Error (RMSE): 23.90003989324812
# Root Mean Squared Logarithmic Error (RMSLE): 0.5284429140608942
#
# Training model for store 12 and family 30...
# Root Mean Squared Error (RMSE): 78.51418208759812
# Root Mean Squared Logarithmic Error (RMSLE): 0.3723523140618115
#
# Training model for store 12 and family 31...
# Root Mean Squared Error (RMSE): 9.488430494623291
# Root Mean Squared Logarithmic Error (RMSLE): 2.1562191671683806
#
# Training model for store 12 and family 32...
# Root Mean Squared Error (RMSE): 3.995565857961742
# Root Mean Squared Logarithmic Error (RMSLE): 0.6924689852897332
#
# Training model for store 13 and family 0...
# Root Mean Squared Error (RMSE): 3.947183115323858
# Root Mean Squared Logarithmic Error (RMSLE): 0.5786990167691003
#
# Training model for store 13 and family 1...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 13 and family 2...
# Root Mean Squared Error (RMSE): 2.33115467806162
# Root Mean Squared Logarithmic Error (RMSLE): 0.6864394540189636
#
# Training model for store 13 and family 3...
# Root Mean Squared Error (RMSE): 455.66734962399175
# Root Mean Squared Logarithmic Error (RMSLE): 0.4907528738454716
#
# Training model for store 13 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 13 and family 5...
# Root Mean Squared Error (RMSE): 78.81086018555585
# Root Mean Squared Logarithmic Error (RMSLE): 0.5529567774313426
#
# Training model for store 13 and family 6...
# Root Mean Squared Error (RMSE): 7.396116886746667
# Root Mean Squared Logarithmic Error (RMSLE): 0.6857575034810297
#
# Training model for store 13 and family 7...
# Root Mean Squared Error (RMSE): 352.15481207138953
# Root Mean Squared Logarithmic Error (RMSLE): 0.5126209137459574
#
# Training model for store 13 and family 8...
# Root Mean Squared Error (RMSE): 104.3387022988821
# Root Mean Squared Logarithmic Error (RMSLE): 0.43370006473975536
#
# Training model for store 13 and family 9...
# Root Mean Squared Error (RMSE): 67.11527596624087
# Root Mean Squared Logarithmic Error (RMSLE): 0.48542429193689246
#
# Training model for store 13 and family 10...
# Root Mean Squared Error (RMSE): 41.24703172411589
# Root Mean Squared Logarithmic Error (RMSLE): 0.8122991212619154
#
# Training model for store 13 and family 11...
# Root Mean Squared Error (RMSE): 54.0064404716438
# Root Mean Squared Logarithmic Error (RMSLE): 0.6671540896867076
#
# Training model for store 13 and family 12...
# Root Mean Squared Error (RMSE): 843.9912954242028
# Root Mean Squared Logarithmic Error (RMSLE): 0.5221863401506697
#
# Training model for store 13 and family 13...
# Root Mean Squared Error (RMSE): 9.205489669468337
# Root Mean Squared Logarithmic Error (RMSLE): 1.0354922406530969
#
# Training model for store 13 and family 14...
# Root Mean Squared Error (RMSE): 3.198428546570442
# Root Mean Squared Logarithmic Error (RMSLE): 0.4984131148228105
#
# Training model for store 13 and family 15...
# Root Mean Squared Error (RMSE): 12.970954366080132
# Root Mean Squared Logarithmic Error (RMSLE): 0.7642009725228285
#
# Training model for store 13 and family 16...
# Root Mean Squared Error (RMSE): 6.641708805914721
# Root Mean Squared Logarithmic Error (RMSLE): 0.5488157694068726
#
# Training model for store 13 and family 17...
# Root Mean Squared Error (RMSE): 0.2811818045871218
# Root Mean Squared Logarithmic Error (RMSLE): 0.2041937662153387
#
# Training model for store 13 and family 18...
# Root Mean Squared Error (RMSE): 61.53205898736203
# Root Mean Squared Logarithmic Error (RMSLE): 0.45407653464421505
#
# Training model for store 13 and family 19...
# Root Mean Squared Error (RMSE): 3.6106867727301
# Root Mean Squared Logarithmic Error (RMSLE): 1.0140152786246235
#
# Training model for store 13 and family 20...
# Root Mean Squared Error (RMSE): 0.010155233183124578
# Root Mean Squared Logarithmic Error (RMSLE): 0.010104015264029436
#
# Training model for store 13 and family 21...
# Root Mean Squared Error (RMSE): 2.8851730988514857
# Root Mean Squared Logarithmic Error (RMSLE): 0.7276999671417864
#
# Training model for store 13 and family 22...
# Root Mean Squared Error (RMSE): 40.58609275739094
# Root Mean Squared Logarithmic Error (RMSLE): 1.0208240855308706
#
# Training model for store 13 and family 23...
# Root Mean Squared Error (RMSE): 1.3523053861148895
# Root Mean Squared Logarithmic Error (RMSLE): 0.5590081170174673
#
# Training model for store 13 and family 24...
# Root Mean Squared Error (RMSE): 50.89635042279314
# Root Mean Squared Logarithmic Error (RMSLE): 0.43083444466667514
#
# Training model for store 13 and family 25...
# Root Mean Squared Error (RMSE): 85.61666074494585
# Root Mean Squared Logarithmic Error (RMSLE): 0.49225670004783195
#
# Training model for store 13 and family 26...
# Root Mean Squared Error (RMSE): 1.0523795426618021
# Root Mean Squared Logarithmic Error (RMSLE): 0.5612512336381807
#
# Training model for store 13 and family 27...
# Root Mean Squared Error (RMSE): 4.622433711177383
# Root Mean Squared Logarithmic Error (RMSLE): 0.6040123681805952
#
# Training model for store 13 and family 28...
# Root Mean Squared Error (RMSE): 65.68455503668258
# Root Mean Squared Logarithmic Error (RMSLE): 0.6121163019280229
#
# Training model for store 13 and family 29...
# Root Mean Squared Error (RMSE): 16.62560219118154
# Root Mean Squared Logarithmic Error (RMSLE): 0.5108418360977648
#
# Training model for store 13 and family 30...
# Root Mean Squared Error (RMSE): 57.586697998325725
# Root Mean Squared Logarithmic Error (RMSLE): 0.39072132006439686
#
# Training model for store 13 and family 31...
# Root Mean Squared Error (RMSE): 3.9826351085669396
# Root Mean Squared Logarithmic Error (RMSLE): 1.3202707830828835
#
# Training model for store 13 and family 32...
# Root Mean Squared Error (RMSE): 2.404605951478305
# Root Mean Squared Logarithmic Error (RMSLE): 0.752899575215374
#
# Training model for store 14 and family 0...
# Root Mean Squared Error (RMSE): 3.837062487258795
# Root Mean Squared Logarithmic Error (RMSLE): 0.6574707219662088
#
# Training model for store 14 and family 1...
# Root Mean Squared Error (RMSE): 0.003723150555111856
# Root Mean Squared Logarithmic Error (RMSLE): 0.003716236785440335
#
# Training model for store 14 and family 2...
# Root Mean Squared Error (RMSE): 1.8121237108277308
# Root Mean Squared Logarithmic Error (RMSLE): 0.6764626555810146
#
# Training model for store 14 and family 3...
# Root Mean Squared Error (RMSE): 403.7079221046197
# Root Mean Squared Logarithmic Error (RMSLE): 0.47275500147754407
#
# Training model for store 14 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 14 and family 5...
# Root Mean Squared Error (RMSE): 51.64547963319347
# Root Mean Squared Logarithmic Error (RMSLE): 0.3995905201178297
#
# Training model for store 14 and family 6...
# Root Mean Squared Error (RMSE): 6.431330558876996
# Root Mean Squared Logarithmic Error (RMSLE): 0.6761483646166973
#
# Training model for store 14 and family 7...
# Root Mean Squared Error (RMSE): 879.3062360331047
# Root Mean Squared Logarithmic Error (RMSLE): 0.609970243591304
#
# Training model for store 14 and family 8...
# Root Mean Squared Error (RMSE): 152.3201710055113
# Root Mean Squared Logarithmic Error (RMSLE): 0.46639266985987005
#
# Training model for store 14 and family 9...
# Root Mean Squared Error (RMSE): 73.46868320126649
# Root Mean Squared Logarithmic Error (RMSLE): 0.39525188023814867
#
# Training model for store 14 and family 10...
# Root Mean Squared Error (RMSE): 21.65595178500682
# Root Mean Squared Logarithmic Error (RMSLE): 0.5847523324513443
#
# Training model for store 14 and family 11...
# Root Mean Squared Error (RMSE): 202.53209627036375
# Root Mean Squared Logarithmic Error (RMSLE): 0.7408011257465793
#
# Training model for store 14 and family 12...
# Root Mean Squared Error (RMSE): 1080.3313312392866
# Root Mean Squared Logarithmic Error (RMSLE): 0.5290628298338941
#
# Training model for store 14 and family 13...
# Root Mean Squared Error (RMSE): 8.410638423823539
# Root Mean Squared Logarithmic Error (RMSLE): 1.0230568280546917
#
# Training model for store 14 and family 14...
# Root Mean Squared Error (RMSE): 0.9679144413902724
# Root Mean Squared Logarithmic Error (RMSLE): 0.4642568189173025
#
# Training model for store 14 and family 15...
# Root Mean Squared Error (RMSE): 32.14503616785415
# Root Mean Squared Logarithmic Error (RMSLE): 0.8569102259036501
#
# Training model for store 14 and family 16...
# Root Mean Squared Error (RMSE): 11.610331811158087
# Root Mean Squared Logarithmic Error (RMSLE): 0.5796475699243884
#
# Training model for store 14 and family 17...
# Root Mean Squared Error (RMSE): 0.4362373116025772
# Root Mean Squared Logarithmic Error (RMSLE): 0.28306700132650453
#
# Training model for store 14 and family 18...
# Root Mean Squared Error (RMSE): 87.6739746872357
# Root Mean Squared Logarithmic Error (RMSLE): 0.4637480209206891
#
# Training model for store 14 and family 19...
# Root Mean Squared Error (RMSE): 2.5082125282688876
# Root Mean Squared Logarithmic Error (RMSLE): 0.6754794629379484
#
# Training model for store 14 and family 20...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 14 and family 21...
# Root Mean Squared Error (RMSE): 3.3604634721206215
# Root Mean Squared Logarithmic Error (RMSLE): 0.9033381487881845
#
# Training model for store 14 and family 22...
# Root Mean Squared Error (RMSE): 27.383467968220597
# Root Mean Squared Logarithmic Error (RMSLE): 0.9480107631320175
#
# Training model for store 14 and family 23...
# Root Mean Squared Error (RMSE): 1.7366877516029209
# Root Mean Squared Logarithmic Error (RMSLE): 0.591279274247059
#
# Training model for store 14 and family 24...
# Root Mean Squared Error (RMSE): 139.39339555584203
# Root Mean Squared Logarithmic Error (RMSLE): 0.5902989222986902
#
# Training model for store 14 and family 25...
# Root Mean Squared Error (RMSE): 115.9872703605346
# Root Mean Squared Logarithmic Error (RMSLE): 0.4930850325073578
#
# Training model for store 14 and family 26...
# Root Mean Squared Error (RMSE): 1.461950179424514
# Root Mean Squared Logarithmic Error (RMSLE): 0.703237689268023
#
# Training model for store 14 and family 27...
# Root Mean Squared Error (RMSE): 4.545432240626479
# Root Mean Squared Logarithmic Error (RMSLE): 0.6187219152084511
#
# Training model for store 14 and family 28...
# Root Mean Squared Error (RMSE): 58.46747301340771
# Root Mean Squared Logarithmic Error (RMSLE): 0.6379563665430807
#
# Training model for store 14 and family 29...
# Root Mean Squared Error (RMSE): 32.1481793594456
# Root Mean Squared Logarithmic Error (RMSLE): 0.445411696202697
#
# Training model for store 14 and family 30...
# Root Mean Squared Error (RMSE): 111.29731726472674
# Root Mean Squared Logarithmic Error (RMSLE): 0.411157071928855
#
# Training model for store 14 and family 31...
# Root Mean Squared Error (RMSE): 6.5975503208440855
# Root Mean Squared Logarithmic Error (RMSLE): 1.8467178412514575
#
# Training model for store 14 and family 32...
# Root Mean Squared Error (RMSE): 3.904097512365853
# Root Mean Squared Logarithmic Error (RMSLE): 0.7040823882298515
#
# Training model for store 15 and family 0...
# Root Mean Squared Error (RMSE): 2.5246858175572373
# Root Mean Squared Logarithmic Error (RMSLE): 0.5674633517241785
#
# Training model for store 15 and family 1...
# Root Mean Squared Error (RMSE): 2.5240381527946494
# Root Mean Squared Logarithmic Error (RMSLE): 0.9370694324258703
#
# Training model for store 15 and family 2...
# Root Mean Squared Error (RMSE): 2.292820381412555
# Root Mean Squared Logarithmic Error (RMSLE): 0.6606085973362102
#
# Training model for store 15 and family 3...
# Root Mean Squared Error (RMSE): 384.8801366559268
# Root Mean Squared Logarithmic Error (RMSLE): 0.44672205494039946
#
# Training model for store 15 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 15 and family 5...
# Root Mean Squared Error (RMSE): 40.39290872233472
# Root Mean Squared Logarithmic Error (RMSLE): 0.36358915908694056
#
# Training model for store 15 and family 6...
# Root Mean Squared Error (RMSE): 6.2449626192650385
# Root Mean Squared Logarithmic Error (RMSLE): 1.0819026035991226
#
# Training model for store 15 and family 7...
# Root Mean Squared Error (RMSE): 372.8459382079682
# Root Mean Squared Logarithmic Error (RMSLE): 0.46706498230020593
#
# Training model for store 15 and family 8...
# Root Mean Squared Error (RMSE): 107.59149649657297
# Root Mean Squared Logarithmic Error (RMSLE): 0.4179839473984481
#
# Training model for store 15 and family 9...
# Root Mean Squared Error (RMSE): 73.13821417314718
# Root Mean Squared Logarithmic Error (RMSLE): 0.39665453097788833
#
# Training model for store 15 and family 10...
# Root Mean Squared Error (RMSE): 52.27376386883826
# Root Mean Squared Logarithmic Error (RMSLE): 0.5943682995661914
#
# Training model for store 15 and family 11...
# Root Mean Squared Error (RMSE): 82.93900630520038
# Root Mean Squared Logarithmic Error (RMSLE): 0.5239244583775167
#
# Training model for store 15 and family 12...
# Root Mean Squared Error (RMSE): 765.050979971278
# Root Mean Squared Logarithmic Error (RMSLE): 0.49487182113393735
#
# Training model for store 15 and family 13...
# Root Mean Squared Error (RMSE): 9.17343580557616
# Root Mean Squared Logarithmic Error (RMSLE): 0.7784057071714688
#
# Training model for store 15 and family 14...
# Root Mean Squared Error (RMSE): 1.215970973929203
# Root Mean Squared Logarithmic Error (RMSLE): 0.5775179657149543
#
# Training model for store 15 and family 15...
# Root Mean Squared Error (RMSE): 55.889353486273166
# Root Mean Squared Logarithmic Error (RMSLE): 1.446203928828847
#
# Training model for store 15 and family 16...
# Root Mean Squared Error (RMSE): 10.818297736304503
# Root Mean Squared Logarithmic Error (RMSLE): 0.5681394597107847
#
# Training model for store 15 and family 17...
# Root Mean Squared Error (RMSE): 0.30177295592195863
# Root Mean Squared Logarithmic Error (RMSLE): 0.19491127151343937
#
# Training model for store 15 and family 18...
# Root Mean Squared Error (RMSE): 55.904016278447415
# Root Mean Squared Logarithmic Error (RMSLE): 0.38085560382766664
#
# Training model for store 15 and family 19...
# Root Mean Squared Error (RMSE): 6.2245327976051685
# Root Mean Squared Logarithmic Error (RMSLE): 0.6997492413324548
#
# Training model for store 15 and family 20...
# Root Mean Squared Error (RMSE): 0.009145066878254629
# Root Mean Squared Logarithmic Error (RMSLE): 0.009103503959092898
#
# Training model for store 15 and family 21...
# Root Mean Squared Error (RMSE): 3.616284456358369
# Root Mean Squared Logarithmic Error (RMSLE): 0.6846104038525841
#
# Training model for store 15 and family 22...
# Root Mean Squared Error (RMSE): 25.99925496297789
# Root Mean Squared Logarithmic Error (RMSLE): 0.9526509589158737
#
# Training model for store 15 and family 23...
# Root Mean Squared Error (RMSE): 2.499976584916623
# Root Mean Squared Logarithmic Error (RMSLE): 1.0228174892108275
#
# Training model for store 15 and family 24...
# Root Mean Squared Error (RMSE): 32.07299165533726
# Root Mean Squared Logarithmic Error (RMSLE): 0.35080050048087413
#
# Training model for store 15 and family 25...
# Root Mean Squared Error (RMSE): 56.956012356038535
# Root Mean Squared Logarithmic Error (RMSLE): 0.40112125462325504
#
# Training model for store 15 and family 26...
# Root Mean Squared Error (RMSE): 1.766279586282346
# Root Mean Squared Logarithmic Error (RMSLE): 0.7796430699733694
#
# Training model for store 15 and family 27...
# Root Mean Squared Error (RMSE): 3.4664718817999876
# Root Mean Squared Logarithmic Error (RMSLE): 0.5247050539020269
#
# Training model for store 15 and family 28...
# Root Mean Squared Error (RMSE): 46.38339317827628
# Root Mean Squared Logarithmic Error (RMSLE): 0.4529995808921624
#
# Training model for store 15 and family 29...
# Root Mean Squared Error (RMSE): 27.004577247395282
# Root Mean Squared Logarithmic Error (RMSLE): 0.7159753996516439
#
# Training model for store 15 and family 30...
# Root Mean Squared Error (RMSE): 226.07778056397785
# Root Mean Squared Logarithmic Error (RMSLE): 0.46491505048522724
#
# Training model for store 15 and family 31...
# Root Mean Squared Error (RMSE): 6.183356543125326
# Root Mean Squared Logarithmic Error (RMSLE): 1.838731203765591
#
# Training model for store 15 and family 32...
# Root Mean Squared Error (RMSE): 3.4994606082694477
# Root Mean Squared Logarithmic Error (RMSLE): 0.5354023942154303
#
# Training model for store 16 and family 0...
# Root Mean Squared Error (RMSE): 3.6174022288551138
# Root Mean Squared Logarithmic Error (RMSLE): 0.7398088637107094
#
# Training model for store 16 and family 1...
# Root Mean Squared Error (RMSE): 0.3071309446656056
# Root Mean Squared Logarithmic Error (RMSLE): 0.17916439247886848
#
# Training model for store 16 and family 2...
# Root Mean Squared Error (RMSE): 1.4149816245232287
# Root Mean Squared Logarithmic Error (RMSLE): 0.6217870404823884
#
# Training model for store 16 and family 3...
# Root Mean Squared Error (RMSE): 486.94930882514035
# Root Mean Squared Logarithmic Error (RMSLE): 0.48540232303795494
#
# Training model for store 16 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 16 and family 5...
# Root Mean Squared Error (RMSE): 73.84830628791121
# Root Mean Squared Logarithmic Error (RMSLE): 0.5351595055077116
#
# Training model for store 16 and family 6...
# Root Mean Squared Error (RMSE): 5.584103294633797
# Root Mean Squared Logarithmic Error (RMSLE): 0.7408116226409922
#
# Training model for store 16 and family 7...
# Root Mean Squared Error (RMSE): 915.6235823193058
# Root Mean Squared Logarithmic Error (RMSLE): 0.6391620582816729
#
# Training model for store 16 and family 8...
# Root Mean Squared Error (RMSE): 84.33414956350465
# Root Mean Squared Logarithmic Error (RMSLE): 0.43811699385620606
#
# Training model for store 16 and family 9...
# Root Mean Squared Error (RMSE): 69.75266428186202
# Root Mean Squared Logarithmic Error (RMSLE): 0.4663854244615906
#
# Training model for store 16 and family 10...
# Root Mean Squared Error (RMSE): 134.131926890592
# Root Mean Squared Logarithmic Error (RMSLE): 0.7709199045742952
#
# Training model for store 16 and family 11...
# Root Mean Squared Error (RMSE): 80.14049292123192
# Root Mean Squared Logarithmic Error (RMSLE): 0.7403837799530322
#
# Training model for store 16 and family 12...
# Root Mean Squared Error (RMSE): 932.6195124411254
# Root Mean Squared Logarithmic Error (RMSLE): 0.5524007394021406
#
# Training model for store 16 and family 13...
# Root Mean Squared Error (RMSE): 10.113392721690262
# Root Mean Squared Logarithmic Error (RMSLE): 0.9515877115309422
#
# Training model for store 16 and family 14...
# Root Mean Squared Error (RMSE): 0.7740646307251928
# Root Mean Squared Logarithmic Error (RMSLE): 0.5095212917029665
#
# Training model for store 16 and family 15...
# Root Mean Squared Error (RMSE): 10.665549268624758
# Root Mean Squared Logarithmic Error (RMSLE): 0.6336869037524548
#
# Training model for store 16 and family 16...
# Root Mean Squared Error (RMSE): 12.215406530250268
# Root Mean Squared Logarithmic Error (RMSLE): 0.5866749755101767
#
# Training model for store 16 and family 17...
# Root Mean Squared Error (RMSE): 0.329336381733559
# Root Mean Squared Logarithmic Error (RMSLE): 0.21445146596461545
#
# Training model for store 16 and family 18...
# Root Mean Squared Error (RMSE): 77.62057875843458
# Root Mean Squared Logarithmic Error (RMSLE): 0.4581903772391333
#
# Training model for store 16 and family 19...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 16 and family 20...
# Root Mean Squared Error (RMSE): 0.010363945950241022
# Root Mean Squared Logarithmic Error (RMSLE): 0.010310608470383757
#
# Training model for store 16 and family 21...
# Root Mean Squared Error (RMSE): 4.2395326840412135
# Root Mean Squared Logarithmic Error (RMSLE): 1.2170151287219
#
# Training model for store 16 and family 22...
# Root Mean Squared Error (RMSE): 59.79779471973885
# Root Mean Squared Logarithmic Error (RMSLE): 1.1596412750079763
#
# Training model for store 16 and family 23...
# Root Mean Squared Error (RMSE): 1.2252672251693626
# Root Mean Squared Logarithmic Error (RMSLE): 0.5252915261882894
#
# Training model for store 16 and family 24...
# Root Mean Squared Error (RMSE): 33.36182697275767
# Root Mean Squared Logarithmic Error (RMSLE): 0.579541236476172
#
# Training model for store 16 and family 25...
# Root Mean Squared Error (RMSE): 84.28565993302097
# Root Mean Squared Logarithmic Error (RMSLE): 0.5936826637680321
#
# Training model for store 16 and family 26...
# Root Mean Squared Error (RMSE): 1.5835614230466037
# Root Mean Squared Logarithmic Error (RMSLE): 0.716849529103327
#
# Training model for store 16 and family 27...
# Root Mean Squared Error (RMSE): 2.8407009780736105
# Root Mean Squared Logarithmic Error (RMSLE): 0.6966056180356869
#
# Training model for store 16 and family 28...
# Root Mean Squared Error (RMSE): 39.37150467305548
# Root Mean Squared Logarithmic Error (RMSLE): 0.5223568795617856
#
# Training model for store 16 and family 29...
# Root Mean Squared Error (RMSE): 16.086060659889636
# Root Mean Squared Logarithmic Error (RMSLE): 0.47404313718660707
#
# Training model for store 16 and family 30...
# Root Mean Squared Error (RMSE): 268.7429482174866
# Root Mean Squared Logarithmic Error (RMSLE): 0.5631532921250854
#
# Training model for store 16 and family 31...
# Root Mean Squared Error (RMSE): 15.382739921203886
# Root Mean Squared Logarithmic Error (RMSLE): 1.288282724438001
#
# Training model for store 16 and family 32...
# Root Mean Squared Error (RMSE): 2.8015339939999153
# Root Mean Squared Logarithmic Error (RMSLE): 1.0316336932432644
#
# Training model for store 17 and family 0...
# Root Mean Squared Error (RMSE): 7.376207459546993
# Root Mean Squared Logarithmic Error (RMSLE): 0.6750879106405427
#
# Training model for store 17 and family 1...
# Root Mean Squared Error (RMSE): 0.914813498556315
# Root Mean Squared Logarithmic Error (RMSLE): 0.46570428986550133
#
# Training model for store 17 and family 2...
# Root Mean Squared Error (RMSE): 2.7624208001103385
# Root Mean Squared Logarithmic Error (RMSLE): 0.657909171486241
#
# Training model for store 17 and family 3...
# Root Mean Squared Error (RMSE): 1121.3506224863145
# Root Mean Squared Logarithmic Error (RMSLE): 0.5264562014085582
#
# Training model for store 17 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 17 and family 5...
# Root Mean Squared Error (RMSE): 214.63059871238943
# Root Mean Squared Logarithmic Error (RMSLE): 0.7174316522900605
#
# Training model for store 17 and family 6...
# Root Mean Squared Error (RMSE): 8.014683862877785
# Root Mean Squared Logarithmic Error (RMSLE): 0.8265443215096459
#
# Training model for store 17 and family 7...
# Root Mean Squared Error (RMSE): 438.41190777129634
# Root Mean Squared Logarithmic Error (RMSLE): 0.5085885048440452
#
# Training model for store 17 and family 8...
# Root Mean Squared Error (RMSE): 407.833996339597
# Root Mean Squared Logarithmic Error (RMSLE): 0.6623904360519584
#
# Training model for store 17 and family 9...
# Root Mean Squared Error (RMSE): 224.54645176520808
# Root Mean Squared Logarithmic Error (RMSLE): 0.5699993646121175
#
# Training model for store 17 and family 10...
# Root Mean Squared Error (RMSE): 232.8593540064719
# Root Mean Squared Logarithmic Error (RMSLE): 0.7457805210357226
#
# Training model for store 17 and family 11...
# Root Mean Squared Error (RMSE): 142.2285700135446
# Root Mean Squared Logarithmic Error (RMSLE): 0.6511311845146246
#
# Training model for store 17 and family 12...
# Root Mean Squared Error (RMSE): 2325.828536355073
# Root Mean Squared Logarithmic Error (RMSLE): 0.6609783576486739
#
# Training model for store 17 and family 13...
# Root Mean Squared Error (RMSE): 12.573011601597255
# Root Mean Squared Logarithmic Error (RMSLE): 0.9900312907838491
#
# Training model for store 17 and family 14...
# Root Mean Squared Error (RMSE): 1.4967802433831265
# Root Mean Squared Logarithmic Error (RMSLE): 0.5821618472987157
#
# Training model for store 17 and family 15...
# Root Mean Squared Error (RMSE): 17.91678808557542
# Root Mean Squared Logarithmic Error (RMSLE): 0.6274647950765058
#
# Training model for store 17 and family 16...
# Root Mean Squared Error (RMSE): 35.8775103174756
# Root Mean Squared Logarithmic Error (RMSLE): 0.7500431851212374
#
# Training model for store 17 and family 17...
# Root Mean Squared Error (RMSE): 0.7741359082591538
# Root Mean Squared Logarithmic Error (RMSLE): 0.42662687950535366
#
# Training model for store 17 and family 18...
# Root Mean Squared Error (RMSE): 120.387834186943
# Root Mean Squared Logarithmic Error (RMSLE): 0.4670218476828737
#
# Training model for store 17 and family 19...
# Root Mean Squared Error (RMSE): 4.7942353115611445
# Root Mean Squared Logarithmic Error (RMSLE): 0.9343985575690958
#
# Training model for store 17 and family 20...
# Root Mean Squared Error (RMSE): 0.039911302809480895
# Root Mean Squared Logarithmic Error (RMSLE): 0.03913542375612953
#
# Training model for store 17 and family 21...
# Root Mean Squared Error (RMSE): 5.349530635456938
# Root Mean Squared Logarithmic Error (RMSLE): 0.7566793089482188
#
# Training model for store 17 and family 22...
# Root Mean Squared Error (RMSE): 49.46779920562956
# Root Mean Squared Logarithmic Error (RMSLE): 1.1203472351345247
#
# Training model for store 17 and family 23...
# Root Mean Squared Error (RMSE): 2.5104313707258976
# Root Mean Squared Logarithmic Error (RMSLE): 0.6284481234108338
#
# Training model for store 17 and family 24...
# Root Mean Squared Error (RMSE): 63.86458105562655
# Root Mean Squared Logarithmic Error (RMSLE): 0.3909735652708095
#
# Training model for store 17 and family 25...
# Root Mean Squared Error (RMSE): 161.5533775980522
# Root Mean Squared Logarithmic Error (RMSLE): 0.6502531066784037
#
# Training model for store 17 and family 26...
# Root Mean Squared Error (RMSE): 2.9181859459351625
# Root Mean Squared Logarithmic Error (RMSLE): 0.7770606855992435
#
# Training model for store 17 and family 27...
# Root Mean Squared Error (RMSE): 8.450204555464211
# Root Mean Squared Logarithmic Error (RMSLE): 0.7180837716936601
#
# Training model for store 17 and family 28...
# Root Mean Squared Error (RMSE): 143.91426796879395
# Root Mean Squared Logarithmic Error (RMSLE): 0.5024665005627128
#
# Training model for store 17 and family 29...
# Root Mean Squared Error (RMSE): 29.3036618013593
# Root Mean Squared Logarithmic Error (RMSLE): 0.4187712349684881
#
# Training model for store 17 and family 30...
# Root Mean Squared Error (RMSE): 570.5457429940066
# Root Mean Squared Logarithmic Error (RMSLE): 0.534073072879398
#
# Training model for store 17 and family 31...
# Root Mean Squared Error (RMSE): 6.049352603117573
# Root Mean Squared Logarithmic Error (RMSLE): 1.580094137084013
#
# Training model for store 17 and family 32...
# Root Mean Squared Error (RMSE): 8.656285691352174
# Root Mean Squared Logarithmic Error (RMSLE): 0.6233833705158395
#
# Training model for store 18 and family 0...
# Root Mean Squared Error (RMSE): 3.4645338238555374
# Root Mean Squared Logarithmic Error (RMSLE): 1.001164617176114
#
# Training model for store 18 and family 1...
# Root Mean Squared Error (RMSE): 0.7534297837000969
# Root Mean Squared Logarithmic Error (RMSLE): 0.40349083707201233
#
# Training model for store 18 and family 2...
# Root Mean Squared Error (RMSE): 3.9315851780871656
# Root Mean Squared Logarithmic Error (RMSLE): 0.8713553272567144
#
# Training model for store 18 and family 3...
# Root Mean Squared Error (RMSE): 2404.3048558289383
# Root Mean Squared Logarithmic Error (RMSLE): 6.797966552085739
#
# Training model for store 18 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 18 and family 5...
# ...
# Root Mean Squared Logarithmic Error (RMSLE): 0.434572237718787
#
# Training model for store 6 and family 32...
# Root Mean Squared Error (RMSE): 18.940879849534564
# Root Mean Squared Logarithmic Error (RMSLE): 0.46297564329718627
#
# Training model for store 7 and family 0...
# Root Mean Squared Error (RMSE): 3.4460770430832532
# Root Mean Squared Logarithmic Error (RMSLE): 0.6369330675325936
#
# Training model for store 7 and family 1...
# Root Mean Squared Error (RMSE): 0.42194969253064546
# Root Mean Squared Logarithmic Error (RMSLE): 0.2698389577204375
#
# Training model for store 7 and family 2...
# Root Mean Squared Error (RMSE): 2.7680778604034146
# Root Mean Squared Logarithmic Error (RMSLE): 0.5244220361972629
#
# Training model for store 7 and family 3...
# Root Mean Squared Error (RMSE): 935.1700963317161
# Root Mean Squared Logarithmic Error (RMSLE): 0.4991880111260386
#
# Training model for store 7 and family 4...
# Root Mean Squared Error (RMSE): 1.683397722813915
# Root Mean Squared Logarithmic Error (RMSLE): 0.6175152067684468
#
# Training model for store 7 and family 5...
# Root Mean Squared Error (RMSE): 315.19828130523
# Root Mean Squared Logarithmic Error (RMSLE): 0.5761783295162703
#
# Training model for store 7 and family 6...
# Root Mean Squared Error (RMSE): 9.953670098880556
# Root Mean Squared Logarithmic Error (RMSLE): 0.5535258356270679
#
# Training model for store 7 and family 7...
# Root Mean Squared Error (RMSE): 286.26854185869007
# Root Mean Squared Logarithmic Error (RMSLE): 0.44979672214354993
#
# Training model for store 7 and family 8...
# Root Mean Squared Error (RMSE): 271.55525700429854
# Root Mean Squared Logarithmic Error (RMSLE): 0.4296229038747565
#
# Training model for store 7 and family 9...
# Root Mean Squared Error (RMSE): 49.52725776233091
# Root Mean Squared Logarithmic Error (RMSLE): 0.37762336155271464
#
# Training model for store 7 and family 10...
# Root Mean Squared Error (RMSE): 55.215601741900464
# Root Mean Squared Logarithmic Error (RMSLE): 0.351357091413315
#
# Training model for store 7 and family 11...
# Root Mean Squared Error (RMSE): 215.58083111889655
# Root Mean Squared Logarithmic Error (RMSLE): 0.5093144322403265
#
# Training model for store 7 and family 12...
# Root Mean Squared Error (RMSE): 1140.4416889146032
# Root Mean Squared Logarithmic Error (RMSLE): 0.5237468099163773
#
# Training model for store 7 and family 13...
# Root Mean Squared Error (RMSE): 18.302890067857657
# Root Mean Squared Logarithmic Error (RMSLE): 0.4673495833306188
#
# Training model for store 7 and family 14...
# Root Mean Squared Error (RMSE): 2.3924962684933293
# Root Mean Squared Logarithmic Error (RMSLE): 0.6097834835100377
#
# Training model for store 7 and family 15...
# Root Mean Squared Error (RMSE): 29.09980512414878
# Root Mean Squared Logarithmic Error (RMSLE): 0.6740043040622871
#
# Training model for store 7 and family 16...
# Root Mean Squared Error (RMSE): 23.81074311473621
# Root Mean Squared Logarithmic Error (RMSLE): 0.6251491495408538
#
# Training model for store 7 and family 17...
# Root Mean Squared Error (RMSE): 1.1366388144939177
# Root Mean Squared Logarithmic Error (RMSLE): 0.5258604571226863
#
# Training model for store 7 and family 18...
# Root Mean Squared Error (RMSE): 62.53891268372077
# Root Mean Squared Logarithmic Error (RMSLE): 0.37377940041926183
#
# Training model for store 7 and family 19...
# Root Mean Squared Error (RMSE): 8.996280476382276
# Root Mean Squared Logarithmic Error (RMSLE): 0.7477969622768773
#
# Training model for store 7 and family 20...
# Root Mean Squared Error (RMSE): 32.47423298969902
# Root Mean Squared Logarithmic Error (RMSLE): 1.0429092966114233
#
# Training model for store 7 and family 21...
# Root Mean Squared Error (RMSE): 6.835884091561919
# Root Mean Squared Logarithmic Error (RMSLE): 0.9083598248083615
#
# Training model for store 7 and family 22...
# Root Mean Squared Error (RMSE): 119.45018804240502
# Root Mean Squared Logarithmic Error (RMSLE): 1.108687180012333
#
# Training model for store 7 and family 23...
# Root Mean Squared Error (RMSE): 6.588012025306284
# Root Mean Squared Logarithmic Error (RMSLE): 0.5090949696257855
#
# Training model for store 7 and family 24...
# Root Mean Squared Error (RMSE): 164.39570508472323
# Root Mean Squared Logarithmic Error (RMSLE): 0.4459361205734094
#
# Training model for store 7 and family 25...
# Root Mean Squared Error (RMSE): 70.24263629520227
# Root Mean Squared Logarithmic Error (RMSLE): 0.39563162113429046
#
# Training model for store 7 and family 26...
# Root Mean Squared Error (RMSE): 4.6440867961708605
# Root Mean Squared Logarithmic Error (RMSLE): 0.5878353277756466
#
# Training model for store 7 and family 27...
# Root Mean Squared Error (RMSE): 6.758764531888442
# Root Mean Squared Logarithmic Error (RMSLE): 0.47151366132866657
#
# Training model for store 7 and family 28...
# Root Mean Squared Error (RMSE): 156.93818156802047
# Root Mean Squared Logarithmic Error (RMSLE): 0.42121510041449756
#
# Training model for store 7 and family 29...
# Root Mean Squared Error (RMSE): 44.321500029014715
# Root Mean Squared Logarithmic Error (RMSLE): 0.3826027638188432
#
# Training model for store 7 and family 30...
# Root Mean Squared Error (RMSE): 1462.792375161644
# Root Mean Squared Logarithmic Error (RMSLE): 0.5272039420448866
#
# Training model for store 7 and family 31...
# Root Mean Squared Error (RMSE): 5.097684488091166
# Root Mean Squared Logarithmic Error (RMSLE): 1.565538700905359
#
# Training model for store 7 and family 32...
# Root Mean Squared Error (RMSE): 20.77173612824807
# Root Mean Squared Logarithmic Error (RMSLE): 0.4737673715923413
#
# Training model for store 8 and family 0...
# Root Mean Squared Error (RMSE): 4.090676831637072
# Root Mean Squared Logarithmic Error (RMSLE): 0.6211279345230314
#
# Training model for store 8 and family 1...
# Root Mean Squared Error (RMSE): 0.7520381886039984
# Root Mean Squared Logarithmic Error (RMSLE): 0.42704561559474563
#
# Training model for store 8 and family 2...
# Root Mean Squared Error (RMSE): 6.623846212308299
# Root Mean Squared Logarithmic Error (RMSLE): 0.5682380875230472
#
# Training model for store 8 and family 3...
# Root Mean Squared Error (RMSE): 2984.561795821482
# Root Mean Squared Logarithmic Error (RMSLE): 0.8715555173766311
#
# Training model for store 8 and family 4...
# Root Mean Squared Error (RMSE): 1.8384292095310533
# Root Mean Squared Logarithmic Error (RMSLE): 0.7486912613216964
#
# Training model for store 8 and family 5...
# Root Mean Squared Error (RMSE): 257.6761994956514
# Root Mean Squared Logarithmic Error (RMSLE): 0.46646842226950186
#
# Training model for store 8 and family 6...
# Root Mean Squared Error (RMSE): 14.254768653607195
# Root Mean Squared Logarithmic Error (RMSLE): 0.540809129910468
#
# Training model for store 8 and family 7...
# Root Mean Squared Error (RMSE): 322.518152566923
# Root Mean Squared Logarithmic Error (RMSLE): 0.4478354653761123
#
# Training model for store 8 and family 8...
# Root Mean Squared Error (RMSE): 467.4533295765603
# Root Mean Squared Logarithmic Error (RMSLE): 0.4818616702319298
#
# Training model for store 8 and family 9...
# Root Mean Squared Error (RMSE): 97.13929970232725
# Root Mean Squared Logarithmic Error (RMSLE): 0.42450579225529406
#
# Training model for store 8 and family 10...
# Root Mean Squared Error (RMSE): 118.59621239336981
# Root Mean Squared Logarithmic Error (RMSLE): 0.4538923901897788
#
# Training model for store 8 and family 11...
# Root Mean Squared Error (RMSE): 310.0620932154955
# Root Mean Squared Logarithmic Error (RMSLE): 0.6217013500519754
#
# Training model for store 8 and family 12...
# Root Mean Squared Error (RMSE): 2036.0455133907287
# Root Mean Squared Logarithmic Error (RMSLE): 0.5884147767253346
#
# Training model for store 8 and family 13...
# Root Mean Squared Error (RMSE): 21.838177329077322
# Root Mean Squared Logarithmic Error (RMSLE): 0.5478535461564296
#
# Training model for store 8 and family 14...
# Root Mean Squared Error (RMSE): 2.550181300838974
# Root Mean Squared Logarithmic Error (RMSLE): 0.6162965449664607
#
# Training model for store 8 and family 15...
# Root Mean Squared Error (RMSE): 24.736557602205757
# Root Mean Squared Logarithmic Error (RMSLE): 0.5165234874262419
#
# Training model for store 8 and family 16...
# Root Mean Squared Error (RMSE): 26.10932324432135
# Root Mean Squared Logarithmic Error (RMSLE): 0.6300046045366504
#
# Training model for store 8 and family 17...
# Root Mean Squared Error (RMSE): 1.5885933764497326
# Root Mean Squared Logarithmic Error (RMSLE): 0.6292096690623135
#
# Training model for store 8 and family 18...
# Root Mean Squared Error (RMSE): 132.77681569060178
# Root Mean Squared Logarithmic Error (RMSLE): 0.4440619144289036
#
# Training model for store 8 and family 19...
# Root Mean Squared Error (RMSE): 22.8221509023519
# Root Mean Squared Logarithmic Error (RMSLE): 0.5953630891860096
#
# Training model for store 8 and family 20...
# Root Mean Squared Error (RMSE): 31.85858791555501
# Root Mean Squared Logarithmic Error (RMSLE): 0.9763633780592663
#
# Training model for store 8 and family 21...
# Root Mean Squared Error (RMSE): 10.196457690057406
# Root Mean Squared Logarithmic Error (RMSLE): 0.49916125208105017
#
# Training model for store 8 and family 22...
# Root Mean Squared Error (RMSE): 116.05843366223378
# Root Mean Squared Logarithmic Error (RMSLE): 1.0225040672555321
#
# Training model for store 8 and family 23...
# Root Mean Squared Error (RMSE): 8.655167061841553
# Root Mean Squared Logarithmic Error (RMSLE): 0.4922530303448038
#
# Training model for store 8 and family 24...
# Root Mean Squared Error (RMSE): 207.6789373843189
# Root Mean Squared Logarithmic Error (RMSLE): 0.4864312912033442
#
# Training model for store 8 and family 25...
# Root Mean Squared Error (RMSE): 146.83364911843648
# Root Mean Squared Logarithmic Error (RMSLE): 0.48641767794376284
#
# Training model for store 8 and family 26...
# Root Mean Squared Error (RMSE): 11.105999861289474
# Root Mean Squared Logarithmic Error (RMSLE): 0.5393238822713872
#
# Training model for store 8 and family 27...
# Root Mean Squared Error (RMSE): 9.50097094917996
# Root Mean Squared Logarithmic Error (RMSLE): 0.43221125537112576
#
# Training model for store 8 and family 28...
# Root Mean Squared Error (RMSE): 217.62973725799392
# Root Mean Squared Logarithmic Error (RMSLE): 0.4766034879086115
#
# Training model for store 8 and family 29...
# Root Mean Squared Error (RMSE): 70.7005009013909
# Root Mean Squared Logarithmic Error (RMSLE): 0.4605471537612655
#
# Training model for store 8 and family 30...
# Root Mean Squared Error (RMSE): 1941.4802846732796
# Root Mean Squared Logarithmic Error (RMSLE): 0.6028751467976419
#
# Training model for store 8 and family 31...
# Root Mean Squared Error (RMSE): 4.895302068673008
# Root Mean Squared Logarithmic Error (RMSLE): 1.495022658050343
#
# Training model for store 8 and family 32...
# Root Mean Squared Error (RMSE): 20.677708138815586
# Root Mean Squared Logarithmic Error (RMSLE): 0.48617667533071485
#
# Training model for store 9 and family 0...
# Root Mean Squared Error (RMSE): 7.337599998132287
# Root Mean Squared Logarithmic Error (RMSLE): 0.6390886620101494
#
# Training model for store 9 and family 1...
# Root Mean Squared Error (RMSE): 0.7820789110273692
# Root Mean Squared Logarithmic Error (RMSLE): 0.41989351753623805
#
# Training model for store 9 and family 2...
# Root Mean Squared Error (RMSE): 5.931637594901929
# Root Mean Squared Logarithmic Error (RMSLE): 0.6210622213242091
#
# Training model for store 9 and family 3...
# Root Mean Squared Error (RMSE): 1954.4536345103566
# Root Mean Squared Logarithmic Error (RMSLE): 0.7533131612545473
#
# Training model for store 9 and family 4...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 9 and family 5...
# Root Mean Squared Error (RMSE): 178.31784738311632
# Root Mean Squared Logarithmic Error (RMSLE): 0.44017933992554903
#
# Training model for store 9 and family 6...
# Root Mean Squared Error (RMSE): 13.135072102969845
# Root Mean Squared Logarithmic Error (RMSLE): 0.8273477150558223
#
# Training model for store 9 and family 7...
# Root Mean Squared Error (RMSE): 738.8138642728896
# Root Mean Squared Logarithmic Error (RMSLE): 0.5432861183864997
#
# Training model for store 9 and family 8...
# Root Mean Squared Error (RMSE): 412.61110945069873
# Root Mean Squared Logarithmic Error (RMSLE): 0.569941853736726
#
# Training model for store 9 and family 9...
# Root Mean Squared Error (RMSE): 200.8617906695661
# Root Mean Squared Logarithmic Error (RMSLE): 0.4650040029700531
#
# Training model for store 9 and family 10...
# Root Mean Squared Error (RMSE): 104.5365756241146
# Root Mean Squared Logarithmic Error (RMSLE): 0.5521547526425707
#
# Training model for store 9 and family 11...
# Root Mean Squared Error (RMSE): 267.6435633563932
# Root Mean Squared Logarithmic Error (RMSLE): 0.7417053965202755
#
# Training model for store 9 and family 12...
# Root Mean Squared Error (RMSE): 3505.005139081402
# Root Mean Squared Logarithmic Error (RMSLE): 0.6439222697146533
#
# Training model for store 9 and family 13...
# Root Mean Squared Error (RMSE): 9.87899464159202
# Root Mean Squared Logarithmic Error (RMSLE): 0.8527964295812372
#
# Training model for store 9 and family 14...
# Root Mean Squared Error (RMSE): 1.5167212513558863
# Root Mean Squared Logarithmic Error (RMSLE): 0.6632160750623949
#
# Training model for store 9 and family 15...
# Root Mean Squared Error (RMSE): 84.23736478585906
# Root Mean Squared Logarithmic Error (RMSLE): 0.8286255391503665
#
# Training model for store 9 and family 16...
# Root Mean Squared Error (RMSE): 23.206869466413146
# Root Mean Squared Logarithmic Error (RMSLE): 0.6578067081356656
#
# Training model for store 9 and family 17...
# Root Mean Squared Error (RMSE): 0.4010587020051251
# Root Mean Squared Logarithmic Error (RMSLE): 0.2866821947742384
#
# Training model for store 9 and family 18...
# Root Mean Squared Error (RMSE): 169.74400305741628
# Root Mean Squared Logarithmic Error (RMSLE): 0.48880232364354353
#
# Training model for store 9 and family 19...
# Root Mean Squared Error (RMSE): 11.092866148444303
# Root Mean Squared Logarithmic Error (RMSLE): 0.693946158836226
#
# Training model for store 9 and family 20...
# Root Mean Squared Error (RMSE): 10.893236899265293
# Root Mean Squared Logarithmic Error (RMSLE): 0.7150437672252774
#
# Training model for store 9 and family 21...
# Root Mean Squared Error (RMSE): 6.270626657266732
# Root Mean Squared Logarithmic Error (RMSLE): 0.8317569606311664
#
# Training model for store 9 and family 22...
# Root Mean Squared Error (RMSE): 57.79908551912417
# Root Mean Squared Logarithmic Error (RMSLE): 0.9802225967037868
#
# Training model for store 9 and family 23...
# Root Mean Squared Error (RMSE): 3.6098782138126104
# Root Mean Squared Logarithmic Error (RMSLE): 0.7485785500723534
#
# Training model for store 9 and family 24...
# Root Mean Squared Error (RMSE): 115.75155743307779
# Root Mean Squared Logarithmic Error (RMSLE): 0.42709041357367944
#
# Training model for store 9 and family 25...
# Root Mean Squared Error (RMSE): 218.59948396362608
# Root Mean Squared Logarithmic Error (RMSLE): 0.5302116954991588
#
# Training model for store 9 and family 26...
# Root Mean Squared Error (RMSE): 3.9707174781302688
# Root Mean Squared Logarithmic Error (RMSLE): 0.4890148759335241
#
# Training model for store 9 and family 27...
# Root Mean Squared Error (RMSE): 8.649951200689685
# Root Mean Squared Logarithmic Error (RMSLE): 0.7017197334548236
#
# Training model for store 9 and family 28...
# Root Mean Squared Error (RMSE): 189.76293520275118
# Root Mean Squared Logarithmic Error (RMSLE): 0.48379597394174134
#
# Training model for store 9 and family 29...
# Root Mean Squared Error (RMSE): 55.972830556499694
# Root Mean Squared Logarithmic Error (RMSLE): 0.5572096410715308
#
# Training model for store 9 and family 30...
# Root Mean Squared Error (RMSE): 636.7181321349539
# Root Mean Squared Logarithmic Error (RMSLE): 0.5499202165143163
#
# Training model for store 9 and family 31...
# Root Mean Squared Error (RMSE): 103.93080964931438
# Root Mean Squared Logarithmic Error (RMSLE): 3.6471022456362845
#
# Training model for store 9 and family 32...
# Root Mean Squared Error (RMSE): 10.00170729622219
# Root Mean Squared Logarithmic Error (RMSLE): 0.6250568163861429

# %%
avg_rmse = total_rmse / num_models
avg_rmsle = total_rmsle / num_models

# %%
print(f"Average Root Mean Squared Error (RMSE) across all models: {avg_rmse}")
print(f"Average Root Mean Squared Logarithmic Error (RMSLE) across all models: {avg_rmsle}")
# Out:
# Average Root Mean Squared Error (RMSE) across all models: 219.98350599458203
# Average Root Mean Squared Logarithmic Error (RMSLE) across all models: 0.7491666546394734
