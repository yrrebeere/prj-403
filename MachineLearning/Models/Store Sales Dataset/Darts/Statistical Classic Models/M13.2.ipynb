# %%
import pandas as pd
from darts import TimeSeries
from darts.models import ARIMA
from darts.metrics import rmse, rmsle

# %%
df = pd.read_csv("../../../../../Data/Kaggle/StoreSales/train_darts.csv", parse_dates=["date"])

# %%
df.head()
# Out:
#         date  store_nbr  family  sales  onpromotion  typeholiday  dcoilwtico  \
# 0 2013-01-01          1       0    0.0            0            3       93.14
# 1 2013-01-01          1       1    0.0            0            3       93.14
# 2 2013-01-01          1       2    0.0            0            3       93.14
# 3 2013-01-01          1       3    0.0            0            3       93.14
# 4 2013-01-01          1       4    0.0            0            3       93.14
#
#    city  state  typestores  cluster  day_of_week  day  month  year
# 0    18     12           3       13            2    1      1  2013
# 1    18     12           3       13            2    1      1  2013
# 2    18     12           3       13            2    1      1  2013
# 3    18     12           3       13            2    1      1  2013
# 4    18     12           3       13            2    1      1  2013

# %%
unique_combinations = df[['store_nbr', 'family']].drop_duplicates()

# %%
total_rmse = 0
total_rmsle = 0
num_models = 0

# %%
for index, row in unique_combinations.iterrows():
    store_nbr = row['store_nbr']
    family = row['family']
    
    print(f"\nTraining model for store {store_nbr} and family {family}...")
    
    df_subset = df[(df['store_nbr'] == store_nbr) & (df['family'] == family)]
    
    ts = TimeSeries.from_dataframe(df_subset, value_cols=["sales"])

    training_size = len(ts) - 16
    
    train = ts[:training_size]
    val = ts[training_size:]

    model = ARIMA()
    model.fit(train)

    predictions = model.predict(n=len(val))
    
    rmse_val = rmse(val, predictions)
    rmsle_val = rmsle(val, predictions)

    total_rmse += rmse_val
    total_rmsle += rmsle_val
    num_models += 1

    print(f"Root Mean Squared Error (RMSE): {rmse_val}")
    print(f"Root Mean Squared Logarithmic Error (RMSLE): {rmsle_val}")
# Out:
# Training model for store 1 and family 0...
# Root Mean Squared Error (RMSE): 2.5114803731597846
# Root Mean Squared Logarithmic Error (RMSLE): 0.5386196794044079
#
# Training model for store 1 and family 1...
# /Users/yrrebeere/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 1 and family 2...
# Root Mean Squared Error (RMSE): 2.615008453425778
# Root Mean Squared Logarithmic Error (RMSLE): 0.49781725589765435
#
# Training model for store 1 and family 3...
# Root Mean Squared Error (RMSE): 470.1430451216493
# Root Mean Squared Logarithmic Error (RMSLE): 0.3147510652123492
#
# Training model for store 1 and family 4...
# Root Mean Squared Error (RMSE): 0.25
# Root Mean Squared Logarithmic Error (RMSLE): 0.17328679513998632
#
# Training model for store 1 and family 5...
# Root Mean Squared Error (RMSE): 73.67563515922346
# Root Mean Squared Logarithmic Error (RMSLE): 0.3059477962590445
#
# Training model for store 1 and family 6...
# Root Mean Squared Error (RMSE): 8.597042187757397
# Root Mean Squared Logarithmic Error (RMSLE): 0.9656976267703804
#
# Training model for store 1 and family 7...
# Root Mean Squared Error (RMSE): 166.45237553671268
# Root Mean Squared Logarithmic Error (RMSLE): 0.3692404408323015
#
# Training model for store 1 and family 8...
# Root Mean Squared Error (RMSE): 133.95169977321189
# Root Mean Squared Logarithmic Error (RMSLE): 0.26930920538385794
#
# Training model for store 1 and family 9...
# Root Mean Squared Error (RMSE): 30.672208638878043
# Root Mean Squared Logarithmic Error (RMSLE): 0.31345726055751155
#
# Training model for store 1 and family 10...
# Root Mean Squared Error (RMSE): 26.39468316521064
# Root Mean Squared Logarithmic Error (RMSLE): 0.2843510001741883
#
# Training model for store 1 and family 11...
# Root Mean Squared Error (RMSE): 44.27410440808524
# Root Mean Squared Logarithmic Error (RMSLE): 0.42279686802180727
#
# Training model for store 1 and family 12...
# Root Mean Squared Error (RMSE): 528.9303709760338
# Root Mean Squared Logarithmic Error (RMSLE): 0.29312637464597946
#
# Training model for store 1 and family 13...
# Root Mean Squared Error (RMSE): 7.1447846364611305
# Root Mean Squared Logarithmic Error (RMSLE): 0.4667832321260103
#
# Training model for store 1 and family 14...
# Root Mean Squared Error (RMSE): 1.282554394045943
# Root Mean Squared Logarithmic Error (RMSLE): 0.6038013712473068
#
# Training model for store 1 and family 15...
# Root Mean Squared Error (RMSE): 15.86283233543359
# Root Mean Squared Logarithmic Error (RMSLE): 0.7008622745357823
#
# Training model for store 1 and family 16...
# Root Mean Squared Error (RMSE): 10.547457512092745
# Root Mean Squared Logarithmic Error (RMSLE): 0.4525467865642111
#
# Training model for store 1 and family 17...
# Root Mean Squared Error (RMSE): 1.0490003309436169
# Root Mean Squared Logarithmic Error (RMSLE): 0.7019340504372636
#
# Training model for store 1 and family 18...
# Root Mean Squared Error (RMSE): 51.18239660560436
# Root Mean Squared Logarithmic Error (RMSLE): 0.38776727763401625
#
# Training model for store 1 and family 19...
# Root Mean Squared Error (RMSE): 6.884919171361412
# Root Mean Squared Logarithmic Error (RMSLE): 0.4817587071449651
#
# Training model for store 1 and family 20...
# Root Mean Squared Error (RMSE): 8.261289847057366
# Root Mean Squared Logarithmic Error (RMSLE): 0.488521852220262
#
# Training model for store 1 and family 21...
# Root Mean Squared Error (RMSE): 8.072795679127918
# Root Mean Squared Logarithmic Error (RMSLE): 0.9188074390699963
#
# Training model for store 1 and family 22...
# Root Mean Squared Error (RMSE): 24.28726188180911
# Root Mean Squared Logarithmic Error (RMSLE): 0.2881376857469873
#
# Training model for store 1 and family 23...
# Root Mean Squared Error (RMSE): 3.7669698082391636
# Root Mean Squared Logarithmic Error (RMSLE): 0.47971073039619666
#
# Training model for store 1 and family 24...
# Root Mean Squared Error (RMSE): 116.11697633631611
# Root Mean Squared Logarithmic Error (RMSLE): 0.42387416926795196
#
# Training model for store 1 and family 25...
# Root Mean Squared Error (RMSE): 64.17605285434351
# Root Mean Squared Logarithmic Error (RMSLE): 0.4603094393866007
#
# Training model for store 1 and family 26...
# Root Mean Squared Error (RMSE): 1.588230606437033
# Root Mean Squared Logarithmic Error (RMSLE): 0.3158238383995276
#
# Training model for store 1 and family 27...
# Root Mean Squared Error (RMSE): 4.746326079085335
# Root Mean Squared Logarithmic Error (RMSLE): 0.6975706450335762
#
# Training model for store 1 and family 28...
# Root Mean Squared Error (RMSE): 73.04615703370914
# Root Mean Squared Logarithmic Error (RMSLE): 0.27075740234531515
#
# Training model for store 1 and family 29...
# Root Mean Squared Error (RMSE): 23.183188202010044
# Root Mean Squared Logarithmic Error (RMSLE): 0.4612936605838162
#
# Training model for store 1 and family 30...
# Root Mean Squared Error (RMSE): 511.88921722920617
# Root Mean Squared Logarithmic Error (RMSLE): 0.26360409333773616
#
# Training model for store 1 and family 31...
# Root Mean Squared Error (RMSE): 4.115396593362859e-86
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 1 and family 32...
# Root Mean Squared Error (RMSE): 15.200678424816164
# Root Mean Squared Logarithmic Error (RMSLE): 0.4259933271253423
#
# Training model for store 10 and family 0...
# Root Mean Squared Error (RMSE): 1.5945630502098191
# Root Mean Squared Logarithmic Error (RMSLE): 0.6249277888243925
#
# Training model for store 10 and family 1...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 10 and family 2...
# Root Mean Squared Error (RMSE): 2.1210587151447307
# Root Mean Squared Logarithmic Error (RMSLE): 0.5944310791169682
#
# Training model for store 10 and family 3...
# Root Mean Squared Error (RMSE): 270.2254544871207
# Root Mean Squared Logarithmic Error (RMSLE): 0.18736083023609937
#
# Training model for store 10 and family 4...
# /Users/yrrebeere/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 10 and family 5...
# Root Mean Squared Error (RMSE): 26.363143861041035
# Root Mean Squared Logarithmic Error (RMSLE): 0.2419229208485177
#
# Training model for store 10 and family 6...
# Root Mean Squared Error (RMSE): 1.9986467935118943
# Root Mean Squared Logarithmic Error (RMSLE): 0.40974100630233073
#
# Training model for store 10 and family 7...
# Root Mean Squared Error (RMSE): 572.1104499944407
# Root Mean Squared Logarithmic Error (RMSLE): 0.5130824985338225
#
# Training model for store 10 and family 8...
# Root Mean Squared Error (RMSE): 94.13941470390273
# Root Mean Squared Logarithmic Error (RMSLE): 0.2972469145512428
#
# Training model for store 10 and family 9...
# Root Mean Squared Error (RMSE): 73.56524868497316
# Root Mean Squared Logarithmic Error (RMSLE): 0.27549338449562655
#
# Training model for store 10 and family 10...
# Root Mean Squared Error (RMSE): 37.98991702664432
# Root Mean Squared Logarithmic Error (RMSLE): 0.7163795532311059
#
# Training model for store 10 and family 11...
# Root Mean Squared Error (RMSE): 8.79996936346262
# Root Mean Squared Logarithmic Error (RMSLE): 0.22734983961884098
#
# Training model for store 10 and family 12...
# Root Mean Squared Error (RMSE): 666.2638086637733
# Root Mean Squared Logarithmic Error (RMSLE): 0.2530944165830248
#
# Training model for store 10 and family 13...
# Root Mean Squared Error (RMSE): 5.326566503275159
# Root Mean Squared Logarithmic Error (RMSLE): 1.0268818608216785
#
# Training model for store 10 and family 14...
# Root Mean Squared Error (RMSE): 0.6510168850736667
# Root Mean Squared Logarithmic Error (RMSLE): 0.39301351362513187
#
# Training model for store 10 and family 15...
# Root Mean Squared Error (RMSE): 6.87180882206774
# Root Mean Squared Logarithmic Error (RMSLE): 0.4997641461466765
#
# Training model for store 10 and family 16...
# Root Mean Squared Error (RMSE): 3.8650318293467834
# Root Mean Squared Logarithmic Error (RMSLE): 0.4386064811706328
#
# Training model for store 10 and family 17...
# Root Mean Squared Error (RMSE): 0.24662288684533423
# Root Mean Squared Logarithmic Error (RMSLE): 0.17068638209854287
#
# Training model for store 10 and family 18...
# Root Mean Squared Error (RMSE): 37.1908734356841
# Root Mean Squared Logarithmic Error (RMSLE): 0.20747907541851338
#
# Training model for store 10 and family 19...
# Root Mean Squared Error (RMSE): 3.7393488492707134
# Root Mean Squared Logarithmic Error (RMSLE): 0.8388154536304264
#
# Training model for store 10 and family 20...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 10 and family 21...
# Root Mean Squared Error (RMSE): 1.7849834553336856
# Root Mean Squared Logarithmic Error (RMSLE): 0.5913221513918251
#
# Training model for store 10 and family 22...
# Root Mean Squared Error (RMSE): 12.670860339356365
# Root Mean Squared Logarithmic Error (RMSLE): 0.6714906362474345
#
# Training model for store 10 and family 23...
# Root Mean Squared Error (RMSE): 0.5175196681248863
# Root Mean Squared Logarithmic Error (RMSLE): 0.3577650140060387
#
# Training model for store 10 and family 24...
# Root Mean Squared Error (RMSE): 37.67345447665666
# Root Mean Squared Logarithmic Error (RMSLE): 0.18551560793783778
#
# Training model for store 10 and family 25...
# Root Mean Squared Error (RMSE): 48.16910255804152
# Root Mean Squared Logarithmic Error (RMSLE): 0.24459373126886746
#
# Training model for store 10 and family 26...
# Root Mean Squared Error (RMSE): 0.9302809873662693
# Root Mean Squared Logarithmic Error (RMSLE): 0.5652606702715249
#
# Training model for store 10 and family 27...
# Root Mean Squared Error (RMSE): 2.432967438942842
# Root Mean Squared Logarithmic Error (RMSLE): 0.5304772497578862
#
# Training model for store 10 and family 28...
# Root Mean Squared Error (RMSE): 30.437783718080148
# Root Mean Squared Logarithmic Error (RMSLE): 0.21294452092457913
#
# Training model for store 10 and family 29...
# Root Mean Squared Error (RMSE): 12.655467823402537
# Root Mean Squared Logarithmic Error (RMSLE): 0.4453616550869988
#
# Training model for store 10 and family 30...
# Root Mean Squared Error (RMSE): 57.87518508700569
# Root Mean Squared Logarithmic Error (RMSLE): 0.20638094170816385
#
# Training model for store 10 and family 31...
# Root Mean Squared Error (RMSE): 5.332682251925386
# Root Mean Squared Logarithmic Error (RMSLE): 1.164423769986
#
# Training model for store 10 and family 32...
# Root Mean Squared Error (RMSE): 2.759153560759448
# Root Mean Squared Logarithmic Error (RMSLE): 0.707203376697883
#
# Training model for store 11 and family 0...
# Root Mean Squared Error (RMSE): 4.585868928977191
# Root Mean Squared Logarithmic Error (RMSLE): 0.5098988398297419
#
# Training model for store 11 and family 1...
# Root Mean Squared Error (RMSE): 0.422262160344247
# Root Mean Squared Logarithmic Error (RMSLE): 0.31992956862664673
#
# Training model for store 11 and family 2...
# Root Mean Squared Error (RMSE): 2.742056586266079
# Root Mean Squared Logarithmic Error (RMSLE): 0.4459436763599182
#
# Training model for store 11 and family 3...
# Root Mean Squared Error (RMSE): 1014.0263253751262
# Root Mean Squared Logarithmic Error (RMSLE): 0.20764666319095337
#
# Training model for store 11 and family 4...
# /Users/yrrebeere/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 11 and family 5...
# Root Mean Squared Error (RMSE): 370.7797969240306
# Root Mean Squared Logarithmic Error (RMSLE): 0.33012574697677394
#
# Training model for store 11 and family 6...
# Root Mean Squared Error (RMSE): 5.835856573844748
# Root Mean Squared Logarithmic Error (RMSLE): 0.30686809657363256
#
# Training model for store 11 and family 7...
# Root Mean Squared Error (RMSE): 519.7671318368157
# Root Mean Squared Logarithmic Error (RMSLE): 0.24049765531634967
#
# Training model for store 11 and family 8...
# Root Mean Squared Error (RMSE): 104.17759359116951
# Root Mean Squared Logarithmic Error (RMSLE): 0.15770877680167733
#
# Training model for store 11 and family 9...
# Root Mean Squared Error (RMSE): 98.28694236296778
# Root Mean Squared Logarithmic Error (RMSLE): 0.1748232691945422
#
# Training model for store 11 and family 10...
# Root Mean Squared Error (RMSE): 157.7294572171236
# Root Mean Squared Logarithmic Error (RMSLE): 0.5153356631470547
#
# Training model for store 11 and family 11...
# Root Mean Squared Error (RMSE): 27.290012053116673
# Root Mean Squared Logarithmic Error (RMSLE): 0.31601240200815706
#
# Training model for store 11 and family 12...
# Root Mean Squared Error (RMSE): 1592.3880183749698
# Root Mean Squared Logarithmic Error (RMSLE): 0.1934073732527984
#
# Training model for store 11 and family 13...
# Root Mean Squared Error (RMSE): 18.56142715241052
# Root Mean Squared Logarithmic Error (RMSLE): 0.5898715370865419
#
# Training model for store 11 and family 14...
# Root Mean Squared Error (RMSE): 0.9717168160676999
# Root Mean Squared Logarithmic Error (RMSLE): 0.48884275957218154
#
# Training model for store 11 and family 15...
# Root Mean Squared Error (RMSE): 13.189507958201894
# Root Mean Squared Logarithmic Error (RMSLE): 0.6099765880246275
#
# Training model for store 11 and family 16...
# Root Mean Squared Error (RMSE): 9.487859927715972
# Root Mean Squared Logarithmic Error (RMSLE): 0.45830465163580475
#
# Training model for store 11 and family 17...
# Root Mean Squared Error (RMSE): 0.3301883431890441
# Root Mean Squared Logarithmic Error (RMSLE): 0.233780183820347
#
# Training model for store 11 and family 18...
# Root Mean Squared Error (RMSE): 163.5510365376758
# Root Mean Squared Logarithmic Error (RMSLE): 0.30263373795112997
#
# Training model for store 11 and family 19...
# Root Mean Squared Error (RMSE): 13.188452443960477
# Root Mean Squared Logarithmic Error (RMSLE): 1.194827381883348
#
# Training model for store 11 and family 20...
# Root Mean Squared Error (RMSE): 2.0767277705015124
# Root Mean Squared Logarithmic Error (RMSLE): 0.6828258961395406
#
# Training model for store 11 and family 21...
# Root Mean Squared Error (RMSE): 5.437829595425881
# Root Mean Squared Logarithmic Error (RMSLE): 0.3891627902119546
#
# Training model for store 11 and family 22...
# Root Mean Squared Error (RMSE): 22.4529885781255
# Root Mean Squared Logarithmic Error (RMSLE): 0.6002713314584857
#
# Training model for store 11 and family 23...
# Root Mean Squared Error (RMSE): 1.9892844249182489
# Root Mean Squared Logarithmic Error (RMSLE): 0.6070716946370884
#
# Training model for store 11 and family 24...
# Root Mean Squared Error (RMSE): 160.14891537107323
# Root Mean Squared Logarithmic Error (RMSLE): 0.21991367131154477
#
# Training model for store 11 and family 25...
# Root Mean Squared Error (RMSE): 162.42964033814062
# Root Mean Squared Logarithmic Error (RMSLE): 0.3578650428053344
#
# Training model for store 11 and family 26...
# Root Mean Squared Error (RMSE): 3.0146320660494537
# Root Mean Squared Logarithmic Error (RMSLE): 0.7189793366421402
#
# Training model for store 11 and family 27...
# Root Mean Squared Error (RMSE): 6.774214316631474
# Root Mean Squared Logarithmic Error (RMSLE): 0.40484112296499986
#
# Training model for store 11 and family 28...
# Root Mean Squared Error (RMSE): 103.67659603640931
# Root Mean Squared Logarithmic Error (RMSLE): 0.2703103392636328
#
# Training model for store 11 and family 29...
# Root Mean Squared Error (RMSE): 30.40500621034283
# Root Mean Squared Logarithmic Error (RMSLE): 0.3804493529079352
#
# Training model for store 11 and family 30...
# Root Mean Squared Error (RMSE): 378.1329191162487
# Root Mean Squared Logarithmic Error (RMSLE): 0.20708923260065024
#
# Training model for store 11 and family 31...
# Root Mean Squared Error (RMSE): 17.611722095782707
# Root Mean Squared Logarithmic Error (RMSLE): 1.0324214988650184
#
# Training model for store 11 and family 32...
# Root Mean Squared Error (RMSE): 6.939786481437332
# Root Mean Squared Logarithmic Error (RMSLE): 0.5507415863735501
#
# Training model for store 12 and family 0...
# Root Mean Squared Error (RMSE): 4.0776650466841255
# Root Mean Squared Logarithmic Error (RMSLE): 0.506061467572012
#
# Training model for store 12 and family 1...
# Root Mean Squared Error (RMSE): 3.694599165388903e-54
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 12 and family 2...
# Root Mean Squared Error (RMSE): 1.4166466538271982
# Root Mean Squared Logarithmic Error (RMSLE): 0.6267258267275341
#
# Training model for store 12 and family 3...
# Root Mean Squared Error (RMSE): 248.8012122070205
# Root Mean Squared Logarithmic Error (RMSLE): 0.1441987484893863
#
# Training model for store 12 and family 4...
# /Users/yrrebeere/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 12 and family 5...
# Root Mean Squared Error (RMSE): 35.48275459835977
# Root Mean Squared Logarithmic Error (RMSLE): 0.175927122829976
#
# Training model for store 12 and family 6...
# Root Mean Squared Error (RMSE): 15.94001418678672
# Root Mean Squared Logarithmic Error (RMSLE): 0.7589212411287831
#
# Training model for store 12 and family 7...
# Root Mean Squared Error (RMSE): 876.0911196492991
# Root Mean Squared Logarithmic Error (RMSLE): 0.7201642725155566
#
# Training model for store 12 and family 8...
# Root Mean Squared Error (RMSE): 53.76732294269456
# Root Mean Squared Logarithmic Error (RMSLE): 0.1483863285181243
#
# Training model for store 12 and family 9...
# Root Mean Squared Error (RMSE): 35.88744107607205
# Root Mean Squared Logarithmic Error (RMSLE): 0.16576755465960555
#
# Training model for store 12 and family 10...
# Root Mean Squared Error (RMSE): 44.793334879304645
# Root Mean Squared Logarithmic Error (RMSLE): 0.5937633176641872
#
# Training model for store 12 and family 11...
# Root Mean Squared Error (RMSE): 21.779221373659333
# Root Mean Squared Logarithmic Error (RMSLE): 0.4166853590678967
#
# Training model for store 12 and family 12...
# Root Mean Squared Error (RMSE): 432.87263437255905
# Root Mean Squared Logarithmic Error (RMSLE): 0.15341075070210303
#
# Training model for store 12 and family 13...
# Root Mean Squared Error (RMSE): 8.541965497236331
# Root Mean Squared Logarithmic Error (RMSLE): 0.8657983322578875
#
# Training model for store 12 and family 14...
# Root Mean Squared Error (RMSE): 0.6041245656881942
# Root Mean Squared Logarithmic Error (RMSLE): 0.3677093357153053
#
# Training model for store 12 and family 15...
# Root Mean Squared Error (RMSE): 4.920218540206297
# Root Mean Squared Logarithmic Error (RMSLE): 0.37791437379656273
#
# Training model for store 12 and family 16...
# Root Mean Squared Error (RMSE): 6.884737395659296
# Root Mean Squared Logarithmic Error (RMSLE): 0.26332450403887864
#
# Training model for store 12 and family 17...
# Root Mean Squared Error (RMSE): 0.5418970614572305
# Root Mean Squared Logarithmic Error (RMSLE): 0.41477328846387346
#
# Training model for store 12 and family 18...
# Root Mean Squared Error (RMSE): 32.26411776246967
# Root Mean Squared Logarithmic Error (RMSLE): 0.19083767837677082
#
# Training model for store 12 and family 19...
# Root Mean Squared Error (RMSE): 4.3473202434526454
# Root Mean Squared Logarithmic Error (RMSLE): 0.5939232694631076
#
# Training model for store 12 and family 20...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 12 and family 21...
# Root Mean Squared Error (RMSE): 3.4867799091851315
# Root Mean Squared Logarithmic Error (RMSLE): 0.6659048563260028
#
# Training model for store 12 and family 22...
# Root Mean Squared Error (RMSE): 18.35385395202608
# Root Mean Squared Logarithmic Error (RMSLE): 0.6253438833156743
#
# Training model for store 12 and family 23...
# Root Mean Squared Error (RMSE): 1.145195881815457
# Root Mean Squared Logarithmic Error (RMSLE): 0.49233508815887145
#
# Training model for store 12 and family 24...
# Root Mean Squared Error (RMSE): 44.587194842732956
# Root Mean Squared Logarithmic Error (RMSLE): 0.30117868230280864
#
# Training model for store 12 and family 25...
# Root Mean Squared Error (RMSE): 53.96853757215333
# Root Mean Squared Logarithmic Error (RMSLE): 0.26335580465849806
#
# Training model for store 12 and family 26...
# Root Mean Squared Error (RMSE): 1.4158973235079757
# Root Mean Squared Logarithmic Error (RMSLE): 0.5177301967740451
#
# Training model for store 12 and family 27...
# Root Mean Squared Error (RMSE): 4.408123200092821
# Root Mean Squared Logarithmic Error (RMSLE): 0.4889422739455556
#
# Training model for store 12 and family 28...
# Root Mean Squared Error (RMSE): 20.624362382187872
# Root Mean Squared Logarithmic Error (RMSLE): 0.1356156547349093
#
# Training model for store 12 and family 29...
# Root Mean Squared Error (RMSE): 11.910134754234225
# Root Mean Squared Logarithmic Error (RMSLE): 0.343501613426738
#
# Training model for store 12 and family 30...
# Root Mean Squared Error (RMSE): 54.86410650427345
# Root Mean Squared Logarithmic Error (RMSLE): 0.15061798726800976
#
# Training model for store 12 and family 31...
# Root Mean Squared Error (RMSE): 7.968688725254614
# Root Mean Squared Logarithmic Error (RMSLE): 1.6488034876281468
#
# Training model for store 12 and family 32...
# Root Mean Squared Error (RMSE): 2.941643009794775
# Root Mean Squared Logarithmic Error (RMSLE): 0.7404028645256738
#
# Training model for store 13 and family 0...
# Root Mean Squared Error (RMSE): 3.386527356559627
# Root Mean Squared Logarithmic Error (RMSLE): 0.4733033598743652
#
# Training model for store 13 and family 1...
# /Users/yrrebeere/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 13 and family 2...
# Root Mean Squared Error (RMSE): 2.290198602701808
# Root Mean Squared Logarithmic Error (RMSLE): 0.5091072232676094
#
# Training model for store 13 and family 3...
# Root Mean Squared Error (RMSE): 378.01759658675553
# Root Mean Squared Logarithmic Error (RMSLE): 0.2214937415994677
#
# Training model for store 13 and family 4...
# /Users/yrrebeere/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 13 and family 5...
# Root Mean Squared Error (RMSE): 28.648793965946847
# Root Mean Squared Logarithmic Error (RMSLE): 0.26284852342863957
#
# Training model for store 13 and family 6...
# Root Mean Squared Error (RMSE): 5.360886791387691
# Root Mean Squared Logarithmic Error (RMSLE): 0.6885900875290795
#
# Training model for store 13 and family 7...
# Root Mean Squared Error (RMSE): 618.3913185129414
# Root Mean Squared Logarithmic Error (RMSLE): 0.5120835362844725
#
# Training model for store 13 and family 8...
# Root Mean Squared Error (RMSE): 47.20884733339848
# Root Mean Squared Logarithmic Error (RMSLE): 0.1573560242584002
#
# Training model for store 13 and family 9...
# Root Mean Squared Error (RMSE): 30.80736768434657
# Root Mean Squared Logarithmic Error (RMSLE): 0.20290549610208441
#
# Training model for store 13 and family 10...
# Root Mean Squared Error (RMSE): 26.717553773581297
# Root Mean Squared Logarithmic Error (RMSLE): 0.48511162497852073
#
# Training model for store 13 and family 11...
# Root Mean Squared Error (RMSE): 11.12565438352674
# Root Mean Squared Logarithmic Error (RMSLE): 0.32213987042689657
#
# Training model for store 13 and family 12...
# Root Mean Squared Error (RMSE): 696.3685720585858
# Root Mean Squared Logarithmic Error (RMSLE): 0.2246266173837924
#
# Training model for store 13 and family 13...
# Root Mean Squared Error (RMSE): 9.768510987950782
# Root Mean Squared Logarithmic Error (RMSLE): 0.9206927874818791
#
# Training model for store 13 and family 14...
# Root Mean Squared Error (RMSE): 0.24043346566124243
# Root Mean Squared Logarithmic Error (RMSLE): 0.173701797869458
#
# Training model for store 13 and family 15...
# Root Mean Squared Error (RMSE): 11.257533253271987
# Root Mean Squared Logarithmic Error (RMSLE): 0.6097532123800324
#
# Training model for store 13 and family 16...
# Root Mean Squared Error (RMSE): 3.9307145099729075
# Root Mean Squared Logarithmic Error (RMSLE): 0.3576886125060382
#
# Training model for store 13 and family 17...
# Root Mean Squared Error (RMSE): 0.09730175395951783
# Root Mean Squared Logarithmic Error (RMSLE): 0.0924966414370096
#
# Training model for store 13 and family 18...
# Root Mean Squared Error (RMSE): 28.16733331226266
# Root Mean Squared Logarithmic Error (RMSLE): 0.19379042554073544
#
# Training model for store 13 and family 19...
# Root Mean Squared Error (RMSE): 1.271079042605894
# Root Mean Squared Logarithmic Error (RMSLE): 0.5036342632073783
#
# Training model for store 13 and family 20...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 13 and family 21...
# Root Mean Squared Error (RMSE): 3.178007293255388
# Root Mean Squared Logarithmic Error (RMSLE): 0.7049445998173397
#
# Training model for store 13 and family 22...
# Root Mean Squared Error (RMSE): 29.559222089436116
# Root Mean Squared Logarithmic Error (RMSLE): 0.7030166125519013
#
# Training model for store 13 and family 23...
# Root Mean Squared Error (RMSE): 1.6771279695517702
# Root Mean Squared Logarithmic Error (RMSLE): 0.6554836726028471
#
# Training model for store 13 and family 24...
# Root Mean Squared Error (RMSE): 42.33985010298104
# Root Mean Squared Logarithmic Error (RMSLE): 0.35686775791910014
#
# Training model for store 13 and family 25...
# Root Mean Squared Error (RMSE): 58.836328196635534
# Root Mean Squared Logarithmic Error (RMSLE): 0.2895778698597977
#
# Training model for store 13 and family 26...
# Root Mean Squared Error (RMSE): 0.6198401968728567
# Root Mean Squared Logarithmic Error (RMSLE): 0.4115270501016327
#
# Training model for store 13 and family 27...
# Root Mean Squared Error (RMSE): 2.023050700417635
# Root Mean Squared Logarithmic Error (RMSLE): 0.35048532918934233
#
# Training model for store 13 and family 28...
# Root Mean Squared Error (RMSE): 24.5425090898858
# Root Mean Squared Logarithmic Error (RMSLE): 0.24542088464879006
#
# Training model for store 13 and family 29...
# Root Mean Squared Error (RMSE): 6.4500692740249495
# Root Mean Squared Logarithmic Error (RMSLE): 0.27040172864686435
#
# Training model for store 13 and family 30...
# Root Mean Squared Error (RMSE): 42.62792119057995
# Root Mean Squared Logarithmic Error (RMSLE): 0.19838946215070644
#
# Training model for store 13 and family 31...
# Root Mean Squared Error (RMSE): 8.613216588476108
# Root Mean Squared Logarithmic Error (RMSLE): 1.5376886699221222
#
# Training model for store 13 and family 32...
# Root Mean Squared Error (RMSE): 1.7673020593027924
# Root Mean Squared Logarithmic Error (RMSLE): 0.7385608382129398
#
# Training model for store 14 and family 0...
# Root Mean Squared Error (RMSE): 2.5808811701949232
# Root Mean Squared Logarithmic Error (RMSLE): 0.6665939842877195
#
# Training model for store 14 and family 1...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 14 and family 2...
# Root Mean Squared Error (RMSE): 1.8944832426974054
# Root Mean Squared Logarithmic Error (RMSLE): 0.523072072758056
#
# Training model for store 14 and family 3...
# Root Mean Squared Error (RMSE): 492.48987892102207
# Root Mean Squared Logarithmic Error (RMSLE): 0.27144838310158725
#
# Training model for store 14 and family 4...
# /Users/yrrebeere/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 14 and family 5...
# Root Mean Squared Error (RMSE): 33.490075127033165
# Root Mean Squared Logarithmic Error (RMSLE): 0.18430111923011738
#
# Training model for store 14 and family 6...
# Root Mean Squared Error (RMSE): 9.11228308689502
# Root Mean Squared Logarithmic Error (RMSLE): 0.6547978625522792
#
# Training model for store 14 and family 7...
# Root Mean Squared Error (RMSE): 1570.5540869618862
# Root Mean Squared Logarithmic Error (RMSLE): 0.9668247017128523
#
# Training model for store 14 and family 8...
# Root Mean Squared Error (RMSE): 65.89025768616396
# Root Mean Squared Logarithmic Error (RMSLE): 0.18023711067093623
#
# Training model for store 14 and family 9...
# Root Mean Squared Error (RMSE): 57.82024007308579
# Root Mean Squared Logarithmic Error (RMSLE): 0.2289169329326625
#
# Training model for store 14 and family 10...
# Root Mean Squared Error (RMSE): 19.862538266526776
# Root Mean Squared Logarithmic Error (RMSLE): 0.5907345174138839
#
# Training model for store 14 and family 11...
# Root Mean Squared Error (RMSE): 19.037809030391127
# Root Mean Squared Logarithmic Error (RMSLE): 0.3762286904178238
#
# Training model for store 14 and family 12...
# Root Mean Squared Error (RMSE): 649.008707733331
# Root Mean Squared Logarithmic Error (RMSLE): 0.20719471766498865
#
# Training model for store 14 and family 13...
# Root Mean Squared Error (RMSE): 16.48230073468284
# Root Mean Squared Logarithmic Error (RMSLE): 1.7737404293996129
#
# Training model for store 14 and family 14...
# Root Mean Squared Error (RMSE): 0.7070327260941236
# Root Mean Squared Logarithmic Error (RMSLE): 0.44667079413258703
#
# Training model for store 14 and family 15...
# Root Mean Squared Error (RMSE): 6.024184907280356
# Root Mean Squared Logarithmic Error (RMSLE): 0.6415131381315459
#
# Training model for store 14 and family 16...
# Root Mean Squared Error (RMSE): 10.950180827821956
# Root Mean Squared Logarithmic Error (RMSLE): 0.41890714299978143
#
# Training model for store 14 and family 17...
# Root Mean Squared Error (RMSE): 0.3504147412900977
# Root Mean Squared Logarithmic Error (RMSLE): 0.2839680269151148
#
# Training model for store 14 and family 18...
# Root Mean Squared Error (RMSE): 49.25387590400592
# Root Mean Squared Logarithmic Error (RMSLE): 0.2664525625104678
#
# Training model for store 14 and family 19...
# Root Mean Squared Error (RMSE): 1.544665668033979
# Root Mean Squared Logarithmic Error (RMSLE): 0.8141000005680903
#
# Training model for store 14 and family 20...
# /Users/yrrebeere/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 14 and family 21...
# Root Mean Squared Error (RMSE): 2.703523442308779
# Root Mean Squared Logarithmic Error (RMSLE): 0.6588724661803368
#
# Training model for store 14 and family 22...
# Root Mean Squared Error (RMSE): 20.427133026527148
# Root Mean Squared Logarithmic Error (RMSLE): 1.1741930350678347
#
# Training model for store 14 and family 23...
# Root Mean Squared Error (RMSE): 1.3320260393404735
# Root Mean Squared Logarithmic Error (RMSLE): 0.49436688652501415
#
# Training model for store 14 and family 24...
# Root Mean Squared Error (RMSE): 82.61145703900888
# Root Mean Squared Logarithmic Error (RMSLE): 0.33934755645045783
#
# Training model for store 14 and family 25...
# Root Mean Squared Error (RMSE): 66.86546131407442
# Root Mean Squared Logarithmic Error (RMSLE): 0.25721839599828517
#
# Training model for store 14 and family 26...
# Root Mean Squared Error (RMSE): 1.4261220177619818
# Root Mean Squared Logarithmic Error (RMSLE): 0.7415119905655393
#
# Training model for store 14 and family 27...
# Root Mean Squared Error (RMSE): 3.6330809327474274
# Root Mean Squared Logarithmic Error (RMSLE): 0.509605279172428
#
# Training model for store 14 and family 28...
# Root Mean Squared Error (RMSE): 36.762307119675555
# Root Mean Squared Logarithmic Error (RMSLE): 0.3952616005077593
#
# Training model for store 14 and family 29...
# Root Mean Squared Error (RMSE): 19.75083010384072
# Root Mean Squared Logarithmic Error (RMSLE): 0.20631734447439115
#
# Training model for store 14 and family 30...
# Root Mean Squared Error (RMSE): 66.47822570303704
# Root Mean Squared Logarithmic Error (RMSLE): 0.16484583680485929
#
# Training model for store 14 and family 31...
# Root Mean Squared Error (RMSE): 4.8563996269540635
# Root Mean Squared Logarithmic Error (RMSLE): 1.2212810357520232
#
# Training model for store 14 and family 32...
# Root Mean Squared Error (RMSE): 2.564722668561031
# Root Mean Squared Logarithmic Error (RMSLE): 0.4386897992277093
#
# Training model for store 15 and family 0...
# Root Mean Squared Error (RMSE): 2.1774115675737273
# Root Mean Squared Logarithmic Error (RMSLE): 0.40385285888187583
#
# Training model for store 15 and family 1...
# Root Mean Squared Error (RMSE): 0.8340365766687317
# Root Mean Squared Logarithmic Error (RMSLE): 0.4905462249997015
#
# Training model for store 15 and family 2...
# Root Mean Squared Error (RMSE): 2.035334967224459
# Root Mean Squared Logarithmic Error (RMSLE): 0.4893166932282779
#
# Training model for store 15 and family 3...
# Root Mean Squared Error (RMSE): 343.2714404567392
# Root Mean Squared Logarithmic Error (RMSLE): 0.19868045016067312
#
# Training model for store 15 and family 4...
# /Users/yrrebeere/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 15 and family 5...
# Root Mean Squared Error (RMSE): 30.79868366349798
# Root Mean Squared Logarithmic Error (RMSLE): 0.20680678561317076
#
# Training model for store 15 and family 6...
# Root Mean Squared Error (RMSE): 5.2428710972974
# Root Mean Squared Logarithmic Error (RMSLE): 0.8831615865073354
#
# Training model for store 15 and family 7...
# Root Mean Squared Error (RMSE): 308.7380564140895
# Root Mean Squared Logarithmic Error (RMSLE): 0.30449590076220046
#
# Training model for store 15 and family 8...
# Root Mean Squared Error (RMSE): 48.32725472879723
# Root Mean Squared Logarithmic Error (RMSLE): 0.16287593387872285
#
# Training model for store 15 and family 9...
# Root Mean Squared Error (RMSE): 55.29593018431542
# Root Mean Squared Logarithmic Error (RMSLE): 0.22902465386519785
#
# Training model for store 15 and family 10...
# Root Mean Squared Error (RMSE): 33.81101860060113
# Root Mean Squared Logarithmic Error (RMSLE): 0.29733246864470125
#
# Training model for store 15 and family 11...
# Root Mean Squared Error (RMSE): 13.088886899042937
# Root Mean Squared Logarithmic Error (RMSLE): 0.201758387167761
#
# Training model for store 15 and family 12...
# Root Mean Squared Error (RMSE): 496.71100711610006
# Root Mean Squared Logarithmic Error (RMSLE): 0.17915097617331938
#
# Training model for store 15 and family 13...
# Root Mean Squared Error (RMSE): 9.515224598380517
# Root Mean Squared Logarithmic Error (RMSLE): 1.112199869307306
#
# Training model for store 15 and family 14...
# Root Mean Squared Error (RMSE): 1.447654906739975
# Root Mean Squared Logarithmic Error (RMSLE): 0.5635870199629112
#
# Training model for store 15 and family 15...
# Root Mean Squared Error (RMSE): 6.787327266176728
# Root Mean Squared Logarithmic Error (RMSLE): 0.5749880729872449
#
# Training model for store 15 and family 16...
# Root Mean Squared Error (RMSE): 5.450262152033836
# Root Mean Squared Logarithmic Error (RMSLE): 0.2976014068937943
#
# Training model for store 15 and family 17...
# Root Mean Squared Error (RMSE): 0.3756923367837992
# Root Mean Squared Logarithmic Error (RMSLE): 0.26512251236233836
#
# Training model for store 15 and family 18...
# Root Mean Squared Error (RMSE): 52.83845903493156
# Root Mean Squared Logarithmic Error (RMSLE): 0.2283193053487115
#
# Training model for store 15 and family 19...
# Root Mean Squared Error (RMSE): 3.334977603565309
# Root Mean Squared Logarithmic Error (RMSLE): 0.406441207368264
#
# Training model for store 15 and family 20...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 15 and family 21...
# Root Mean Squared Error (RMSE): 2.5991285301067313
# Root Mean Squared Logarithmic Error (RMSLE): 0.6508612920748326
#
# Training model for store 15 and family 22...
# Root Mean Squared Error (RMSE): 12.56474542370134
# Root Mean Squared Logarithmic Error (RMSLE): 0.5888441701605429
#
# Training model for store 15 and family 23...
# Root Mean Squared Error (RMSE): 1.294345788903679
# Root Mean Squared Logarithmic Error (RMSLE): 0.49778676273267886
#
# Training model for store 15 and family 24...
# Root Mean Squared Error (RMSE): 27.189617487266595
# Root Mean Squared Logarithmic Error (RMSLE): 0.21436226560030305
#
# Training model for store 15 and family 25...
# Root Mean Squared Error (RMSE): 66.66303288920403
# Root Mean Squared Logarithmic Error (RMSLE): 0.29979973513327673
#
# Training model for store 15 and family 26...
# Root Mean Squared Error (RMSE): 1.1567559068018383
# Root Mean Squared Logarithmic Error (RMSLE): 0.6760916778299555
#
# Training model for store 15 and family 27...
# Root Mean Squared Error (RMSE): 3.5949453515665493
# Root Mean Squared Logarithmic Error (RMSLE): 0.5135011684844838
#
# Training model for store 15 and family 28...
# Root Mean Squared Error (RMSE): 23.7522165590014
# Root Mean Squared Logarithmic Error (RMSLE): 0.22425268297161105
#
# Training model for store 15 and family 29...
# Root Mean Squared Error (RMSE): 10.880017980808896
# Root Mean Squared Logarithmic Error (RMSLE): 0.22350762441614502
#
# Training model for store 15 and family 30...
# Root Mean Squared Error (RMSE): 134.86610346404896
# Root Mean Squared Logarithmic Error (RMSLE): 0.19451183381266496
#
# Training model for store 15 and family 31...
# Root Mean Squared Error (RMSE): 8.415016339853418
# Root Mean Squared Logarithmic Error (RMSLE): 1.48649006848721
#
# Training model for store 15 and family 32...
# Root Mean Squared Error (RMSE): 3.2847505102603405
# Root Mean Squared Logarithmic Error (RMSLE): 0.5685704505730167
#
# Training model for store 16 and family 0...
# Root Mean Squared Error (RMSE): 3.021466431451741
# Root Mean Squared Logarithmic Error (RMSLE): 0.6358840862791865
#
# Training model for store 16 and family 1...
# Root Mean Squared Error (RMSE): 0.6370467180430339
# Root Mean Squared Logarithmic Error (RMSLE): 0.38421510652138163
#
# Training model for store 16 and family 2...
# Root Mean Squared Error (RMSE): 1.9206790276870829
# Root Mean Squared Logarithmic Error (RMSLE): 0.8352453549948888
#
# Training model for store 16 and family 3...
# Root Mean Squared Error (RMSE): 362.8137544139221
# Root Mean Squared Logarithmic Error (RMSLE): 0.22966262119919173
#
# Training model for store 16 and family 4...
# /Users/yrrebeere/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 16 and family 5...
# Root Mean Squared Error (RMSE): 33.20227115340526
# Root Mean Squared Logarithmic Error (RMSLE): 0.21118235392821935
#
# Training model for store 16 and family 6...
# Root Mean Squared Error (RMSE): 4.354782797044448
# Root Mean Squared Logarithmic Error (RMSLE): 0.8908101760217859
#
# Training model for store 16 and family 7...
# Root Mean Squared Error (RMSE): 623.7007341785082
# Root Mean Squared Logarithmic Error (RMSLE): 0.6259592543660508
#
# Training model for store 16 and family 8...
# Root Mean Squared Error (RMSE): 44.45557642814464
# Root Mean Squared Logarithmic Error (RMSLE): 0.17125057498482885
#
# Training model for store 16 and family 9...
# Root Mean Squared Error (RMSE): 36.23570187288435
# Root Mean Squared Logarithmic Error (RMSLE): 0.22654095375200844
#
# Training model for store 16 and family 10...
# Root Mean Squared Error (RMSE): 138.26301919048373
# Root Mean Squared Logarithmic Error (RMSLE): 0.5900533154228123
#
# Training model for store 16 and family 11...
# Root Mean Squared Error (RMSE): 23.369038926815175
# Root Mean Squared Logarithmic Error (RMSLE): 0.5410962818894196
#
# Training model for store 16 and family 12...
# Root Mean Squared Error (RMSE): 299.4685505593153
# Root Mean Squared Logarithmic Error (RMSLE): 0.14159812181603193
#
# Training model for store 16 and family 13...
# Root Mean Squared Error (RMSE): 3.8585908368004556
# Root Mean Squared Logarithmic Error (RMSLE): 0.7222846646956694
#
# Training model for store 16 and family 14...
# Root Mean Squared Error (RMSE): 0.5739848692553137
# Root Mean Squared Logarithmic Error (RMSLE): 0.36838963647120737
#
# Training model for store 16 and family 15...
# Root Mean Squared Error (RMSE): 7.42204432010931
# Root Mean Squared Logarithmic Error (RMSLE): 0.6514320315972151
#
# Training model for store 16 and family 16...
# Root Mean Squared Error (RMSE): 5.234772579763214
# Root Mean Squared Logarithmic Error (RMSLE): 0.3438142263720275
#
# Training model for store 16 and family 17...
# Root Mean Squared Error (RMSE): 0.6384361587454319
# Root Mean Squared Logarithmic Error (RMSLE): 0.38437180468033794
#
# Training model for store 16 and family 18...
# Root Mean Squared Error (RMSE): 37.01883364493193
# Root Mean Squared Logarithmic Error (RMSLE): 0.21794931449327165
#
# Training model for store 16 and family 19...
# /Users/yrrebeere/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 16 and family 20...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 16 and family 21...
# Root Mean Squared Error (RMSE): 2.026122473221442
# Root Mean Squared Logarithmic Error (RMSLE): 0.5154917421966135
#
# Training model for store 16 and family 22...
# Root Mean Squared Error (RMSE): 27.124342223025295
# Root Mean Squared Logarithmic Error (RMSLE): 0.6460986661243584
#
# Training model for store 16 and family 23...
# Root Mean Squared Error (RMSE): 1.6143675920040061
# Root Mean Squared Logarithmic Error (RMSLE): 0.5475226629900188
#
# Training model for store 16 and family 24...
# Root Mean Squared Error (RMSE): 14.475035052004761
# Root Mean Squared Logarithmic Error (RMSLE): 0.28770313112810714
#
# Training model for store 16 and family 25...
# Root Mean Squared Error (RMSE): 30.624821913850273
# Root Mean Squared Logarithmic Error (RMSLE): 0.21517009178721494
#
# Training model for store 16 and family 26...
# Root Mean Squared Error (RMSE): 1.0466529671629985
# Root Mean Squared Logarithmic Error (RMSLE): 0.48576508324991613
#
# Training model for store 16 and family 27...
# Root Mean Squared Error (RMSE): 2.746827415205134
# Root Mean Squared Logarithmic Error (RMSLE): 0.5445531841284733
#
# Training model for store 16 and family 28...
# Root Mean Squared Error (RMSE): 23.7123887428606
# Root Mean Squared Logarithmic Error (RMSLE): 0.2921552925202369
#
# Training model for store 16 and family 29...
# Root Mean Squared Error (RMSE): 11.402150045602445
# Root Mean Squared Logarithmic Error (RMSLE): 0.3046870308809226
#
# Training model for store 16 and family 30...
# Root Mean Squared Error (RMSE): 145.1615358180573
# Root Mean Squared Logarithmic Error (RMSLE): 0.22283809705438798
#
# Training model for store 16 and family 31...
# Root Mean Squared Error (RMSE): 8.357613835958738e-88
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 16 and family 32...
# Root Mean Squared Error (RMSE): 1.6929494305273387
# Root Mean Squared Logarithmic Error (RMSLE): 0.6429282934224483
#
# Training model for store 17 and family 0...
# Root Mean Squared Error (RMSE): 6.696962565865463
# Root Mean Squared Logarithmic Error (RMSLE): 0.6151299375924615
#
# Training model for store 17 and family 1...
# Root Mean Squared Error (RMSE): 0.924756515037327
# Root Mean Squared Logarithmic Error (RMSLE): 0.5323417179297311
#
# Training model for store 17 and family 2...
# Root Mean Squared Error (RMSE): 2.309887633373196
# Root Mean Squared Logarithmic Error (RMSLE): 0.6127415246570727
#
# Training model for store 17 and family 3...
# Root Mean Squared Error (RMSE): 401.0781486519507
# Root Mean Squared Logarithmic Error (RMSLE): 0.13248235424901764
#
# Training model for store 17 and family 4...
# /Users/yrrebeere/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 17 and family 5...
# Root Mean Squared Error (RMSE): 41.168769340379846
# Root Mean Squared Logarithmic Error (RMSLE): 0.11764592628148308
#
# Training model for store 17 and family 6...
# Root Mean Squared Error (RMSE): 9.539827200760572
# Root Mean Squared Logarithmic Error (RMSLE): 0.9353607512866221
#
# Training model for store 17 and family 7...
# Root Mean Squared Error (RMSE): 374.80081489795043
# Root Mean Squared Logarithmic Error (RMSLE): 0.26947532451814926
#
# Training model for store 17 and family 8...
# Root Mean Squared Error (RMSE): 151.3514589787982
# Root Mean Squared Logarithmic Error (RMSLE): 0.1817403436062009
#
# Training model for store 17 and family 9...
# Root Mean Squared Error (RMSE): 103.329878251282
# Root Mean Squared Logarithmic Error (RMSLE): 0.20102827888613237
#
# Training model for store 17 and family 10...
# Root Mean Squared Error (RMSE): 55.81271861048673
# Root Mean Squared Logarithmic Error (RMSLE): 0.28355948843336987
#
# Training model for store 17 and family 11...
# Root Mean Squared Error (RMSE): 27.397387630238637
# Root Mean Squared Logarithmic Error (RMSLE): 0.3007295428357449
#
# Training model for store 17 and family 12...
# Root Mean Squared Error (RMSE): 559.4371408310911
# Root Mean Squared Logarithmic Error (RMSLE): 0.11644584535776574
#
# Training model for store 17 and family 13...
# Root Mean Squared Error (RMSE): 11.968877194899026
# Root Mean Squared Logarithmic Error (RMSLE): 0.6539935973317784
#
# Training model for store 17 and family 14...
# Root Mean Squared Error (RMSE): 1.466721869697006
# Root Mean Squared Logarithmic Error (RMSLE): 0.6533826257528056
#
# Training model for store 17 and family 15...
# Root Mean Squared Error (RMSE): 11.726054310432717
# Root Mean Squared Logarithmic Error (RMSLE): 0.43479450091948196
#
# Training model for store 17 and family 16...
# Root Mean Squared Error (RMSE): 8.005005325144577
# Root Mean Squared Logarithmic Error (RMSLE): 0.2905057592791602
#
# Training model for store 17 and family 17...
# Root Mean Squared Error (RMSE): 0.556423473054738
# Root Mean Squared Logarithmic Error (RMSLE): 0.42986009844885886
#
# Training model for store 17 and family 18...
# Root Mean Squared Error (RMSE): 47.777127653598434
# Root Mean Squared Logarithmic Error (RMSLE): 0.15719946530130086
#
# Training model for store 17 and family 19...
# Root Mean Squared Error (RMSE): 1.4660280358917797
# Root Mean Squared Logarithmic Error (RMSLE): 0.8793717859170954
#
# Training model for store 17 and family 20...
# Root Mean Squared Error (RMSE): 0.0
# Root Mean Squared Logarithmic Error (RMSLE): 0.0
#
# Training model for store 17 and family 21...
# Root Mean Squared Error (RMSE): 10.884042682573062
# ...
# Root Mean Squared Logarithmic Error (RMSLE): 2.064072241837935
#
# Training model for store 6 and family 32...
# Root Mean Squared Error (RMSE): 18.645159029099123
# Root Mean Squared Logarithmic Error (RMSLE): 0.46958032964925367
#
# Training model for store 7 and family 0...
# Root Mean Squared Error (RMSE): 3.641745106217578
# Root Mean Squared Logarithmic Error (RMSLE): 0.6387604477970678
#
# Training model for store 7 and family 1...
# Root Mean Squared Error (RMSE): 0.4219496925306454
# Root Mean Squared Logarithmic Error (RMSLE): 0.2698389577204374
#
# Training model for store 7 and family 2...
# Root Mean Squared Error (RMSE): 2.8365319798927424
# Root Mean Squared Logarithmic Error (RMSLE): 0.5381049204552645
#
# Training model for store 7 and family 3...
# Root Mean Squared Error (RMSE): 1012.2138804427535
# Root Mean Squared Logarithmic Error (RMSLE): 0.5049779862405147
#
# Training model for store 7 and family 4...
# Root Mean Squared Error (RMSE): 1.683397722813915
# Root Mean Squared Logarithmic Error (RMSLE): 0.6175152067684467
#
# Training model for store 7 and family 5...
# Root Mean Squared Error (RMSE): 310.3597889846139
# Root Mean Squared Logarithmic Error (RMSLE): 0.5662722047649872
#
# Training model for store 7 and family 6...
# Root Mean Squared Error (RMSE): 9.901763907787185
# Root Mean Squared Logarithmic Error (RMSLE): 0.5251952410748633
#
# Training model for store 7 and family 7...
# Root Mean Squared Error (RMSE): 285.05055436858976
# Root Mean Squared Logarithmic Error (RMSLE): 0.4473093044635733
#
# Training model for store 7 and family 8...
# Root Mean Squared Error (RMSE): 294.1239161987196
# Root Mean Squared Logarithmic Error (RMSLE): 0.44098783023968896
#
# Training model for store 7 and family 9...
# Root Mean Squared Error (RMSE): 52.43557463163298
# Root Mean Squared Logarithmic Error (RMSLE): 0.4008639470192698
#
# Training model for store 7 and family 10...
# Root Mean Squared Error (RMSE): 55.79468043194211
# Root Mean Squared Logarithmic Error (RMSLE): 0.3587388030820316
#
# Training model for store 7 and family 11...
# Root Mean Squared Error (RMSE): 216.52615439231036
# Root Mean Squared Logarithmic Error (RMSLE): 0.5111068566121509
#
# Training model for store 7 and family 12...
# Root Mean Squared Error (RMSE): 1107.4745208343363
# Root Mean Squared Logarithmic Error (RMSLE): 0.5109788540906174
#
# Training model for store 7 and family 13...
# Root Mean Squared Error (RMSE): 16.517079176237797
# Root Mean Squared Logarithmic Error (RMSLE): 0.44332603193687625
#
# Training model for store 7 and family 14...
# Root Mean Squared Error (RMSE): 2.3972812050024683
# Root Mean Squared Logarithmic Error (RMSLE): 0.6108136692135968
#
# Training model for store 7 and family 15...
# Root Mean Squared Error (RMSE): 30.410923385369323
# Root Mean Squared Logarithmic Error (RMSLE): 0.7851856596786894
#
# Training model for store 7 and family 16...
# Root Mean Squared Error (RMSE): 24.198382749589445
# Root Mean Squared Logarithmic Error (RMSLE): 0.6366314049667231
#
# Training model for store 7 and family 17...
# Root Mean Squared Error (RMSE): 1.136069789235167
# Root Mean Squared Logarithmic Error (RMSLE): 0.5255485204491934
#
# Training model for store 7 and family 18...
# Root Mean Squared Error (RMSE): 64.72378034486012
# Root Mean Squared Logarithmic Error (RMSLE): 0.39127591704587156
#
# Training model for store 7 and family 19...
# Root Mean Squared Error (RMSE): 7.699206423402146
# Root Mean Squared Logarithmic Error (RMSLE): 0.5604187548227371
#
# Training model for store 7 and family 20...
# Root Mean Squared Error (RMSE): 36.087876211258255
# Root Mean Squared Logarithmic Error (RMSLE): 1.3209277174429068
#
# Training model for store 7 and family 21...
# Root Mean Squared Error (RMSE): 7.187966274689015
# Root Mean Squared Logarithmic Error (RMSLE): 0.9528966454856368
#
# Training model for store 7 and family 22...
# Root Mean Squared Error (RMSE): 142.74825959128253
# Root Mean Squared Logarithmic Error (RMSLE): 2.2439714093117544
#
# Training model for store 7 and family 23...
# Root Mean Squared Error (RMSE): 6.697967562793313
# Root Mean Squared Logarithmic Error (RMSLE): 0.4997199108568602
#
# Training model for store 7 and family 24...
# Root Mean Squared Error (RMSE): 167.95107505146484
# Root Mean Squared Logarithmic Error (RMSLE): 0.45460565986020085
#
# Training model for store 7 and family 25...
# Root Mean Squared Error (RMSE): 77.44007748199043
# Root Mean Squared Logarithmic Error (RMSLE): 0.4145822036133907
#
# Training model for store 7 and family 26...
# Root Mean Squared Error (RMSE): 4.580248296745732
# Root Mean Squared Logarithmic Error (RMSLE): 0.5516481432506789
# Training model for store 7 and family 27...
# Root Mean Squared Error (RMSE): 6.8335344785322265
# Root Mean Squared Logarithmic Error (RMSLE): 0.46676122165905
#
# Training model for store 7 and family 28...
# Root Mean Squared Error (RMSE): 155.01800556008618
# Root Mean Squared Logarithmic Error (RMSLE): 0.4131247089667356
#
# Training model for store 7 and family 29...
# Root Mean Squared Error (RMSE): 43.87987227541827
# Root Mean Squared Logarithmic Error (RMSLE): 0.37727937778328147
#
# Training model for store 7 and family 30...
# Root Mean Squared Error (RMSE): 1727.9400714055382
# Root Mean Squared Logarithmic Error (RMSLE): 0.5672191402019491
#
# Training model for store 7 and family 31...
# Root Mean Squared Error (RMSE): 0.9148557325788642
# Root Mean Squared Logarithmic Error (RMSLE): 0.47019829977910055
#
# Training model for store 7 and family 32...
# Root Mean Squared Error (RMSE): 22.120981618689857
# Root Mean Squared Logarithmic Error (RMSLE): 0.49395294796413675
#
# Training model for store 8 and family 0...
# Root Mean Squared Error (RMSE): 4.172204320050739
# Root Mean Squared Logarithmic Error (RMSLE): 0.6519213085442301
#
# Training model for store 8 and family 1...
# Root Mean Squared Error (RMSE): 0.7519341132661636
# Root Mean Squared Logarithmic Error (RMSLE): 0.42693620222254325
#
# Training model for store 8 and family 2...
# Root Mean Squared Error (RMSE): 6.659550314111272
# Root Mean Squared Logarithmic Error (RMSLE): 0.5727481791118106
#
# Training model for store 8 and family 3...
# Root Mean Squared Error (RMSE): 1960.2092128920915
# Root Mean Squared Logarithmic Error (RMSLE): 0.5806536475885214
#
# Training model for store 8 and family 4...
# Root Mean Squared Error (RMSE): 1.8384292095310533
# Root Mean Squared Logarithmic Error (RMSLE): 0.7486912613216963
#
# Training model for store 8 and family 5...
# Root Mean Squared Error (RMSE): 283.24597731611925
# Root Mean Squared Logarithmic Error (RMSLE): 0.4794281107454856
#
# Training model for store 8 and family 6...
# Root Mean Squared Error (RMSE): 14.236960804687701
# Root Mean Squared Logarithmic Error (RMSLE): 0.5219648418401657
#
# Training model for store 8 and family 7...
# Root Mean Squared Error (RMSE): 327.7586598261674
# Root Mean Squared Logarithmic Error (RMSLE): 0.4496332026380586
#
# Training model for store 8 and family 8...
# Root Mean Squared Error (RMSE): 476.7021755612731
# Root Mean Squared Logarithmic Error (RMSLE): 0.49462652682360564
#
# Training model for store 8 and family 9...
# Root Mean Squared Error (RMSE): 98.50899503698047
# Root Mean Squared Logarithmic Error (RMSLE): 0.43634825519805415
#
# Training model for store 8 and family 10...
# Root Mean Squared Error (RMSE): 121.45382605488489
# Root Mean Squared Logarithmic Error (RMSLE): 0.4532405354660713
#
# Training model for store 8 and family 11...
# Root Mean Squared Error (RMSE): 305.3730885760449
# Root Mean Squared Logarithmic Error (RMSLE): 0.5952435196719894
#
# Training model for store 8 and family 12...
# Root Mean Squared Error (RMSE): 1936.2529949640118
# Root Mean Squared Logarithmic Error (RMSLE): 0.5755271090858005
#
# Training model for store 8 and family 13...
# Root Mean Squared Error (RMSE): 19.017233151550858
# Root Mean Squared Logarithmic Error (RMSLE): 0.5051267263457306
#
# Training model for store 8 and family 14...
# Root Mean Squared Error (RMSE): 2.5439704435758683
# Root Mean Squared Logarithmic Error (RMSLE): 0.6150109805340442
#
# Training model for store 8 and family 15...
# Root Mean Squared Error (RMSE): 30.59189152036767
# Root Mean Squared Logarithmic Error (RMSLE): 0.6051402823839255
#
# Training model for store 8 and family 16...
# Root Mean Squared Error (RMSE): 34.90352651449997
# Root Mean Squared Logarithmic Error (RMSLE): 0.6122007648045926
#
# Training model for store 8 and family 17...
# Root Mean Squared Error (RMSE): 1.588211329120354
# Root Mean Squared Logarithmic Error (RMSLE): 0.6289641959468539
#
# Training model for store 8 and family 18...
# Root Mean Squared Error (RMSE): 154.0918874726135
# Root Mean Squared Logarithmic Error (RMSLE): 0.4917378270782879
#
# Training model for store 8 and family 19...
# Root Mean Squared Error (RMSE): 18.263669318818597
# Root Mean Squared Logarithmic Error (RMSLE): 0.5195699001536427
#
# Training model for store 8 and family 20...
# Root Mean Squared Error (RMSE): 32.45301223199821
# Root Mean Squared Logarithmic Error (RMSLE): 1.0165696047637094
#
# Training model for store 8 and family 21...
# Root Mean Squared Error (RMSE): 9.46183337516181
# Root Mean Squared Logarithmic Error (RMSLE): 0.4644969817385511
#
# Training model for store 8 and family 22...
# Root Mean Squared Error (RMSE): 114.37364926333804
# Root Mean Squared Logarithmic Error (RMSLE): 1.060229845333699
#
# Training model for store 8 and family 23...
# Root Mean Squared Error (RMSE): 8.891929431571999
# Root Mean Squared Logarithmic Error (RMSLE): 0.5027110256685898
#
# Training model for store 8 and family 24...
# Root Mean Squared Error (RMSE): 220.5716018811251
# Root Mean Squared Logarithmic Error (RMSLE): 0.4998449468435685
#
# Training model for store 8 and family 25...
# Root Mean Squared Error (RMSE): 164.34331224745546
# Root Mean Squared Logarithmic Error (RMSLE): 0.550312819665303
#
# Training model for store 8 and family 26...
# Root Mean Squared Error (RMSE): 12.156251163575398
# Root Mean Squared Logarithmic Error (RMSLE): 0.8039796572093966
#
# Training model for store 8 and family 27...
# Root Mean Squared Error (RMSE): 10.895877792175222
# Root Mean Squared Logarithmic Error (RMSLE): 0.5397029411610171
#
# Training model for store 8 and family 28...
# Root Mean Squared Error (RMSE): 221.56586536019609
# Root Mean Squared Logarithmic Error (RMSLE): 0.48394140293200427
#
# Training model for store 8 and family 29...
# Root Mean Squared Error (RMSE): 64.10659065413859
# Root Mean Squared Logarithmic Error (RMSLE): 0.4416400780765555
#
# Training model for store 8 and family 30...
# Root Mean Squared Error (RMSE): 1639.2531966742265
# Root Mean Squared Logarithmic Error (RMSLE): 0.5547810621019441
#
# Training model for store 8 and family 31...
# Root Mean Squared Error (RMSE): 1.4311542191273796
# Root Mean Squared Logarithmic Error (RMSLE): 0.5541707706768099
#
# Training model for store 8 and family 32...
# Root Mean Squared Error (RMSE): 21.57974998333623
# Root Mean Squared Logarithmic Error (RMSLE): 0.4944855632346692
#
# Training model for store 9 and family 0...
# Root Mean Squared Error (RMSE): 6.5972440108870485
# Root Mean Squared Logarithmic Error (RMSLE): 0.5923795553327895
#
# Training model for store 9 and family 1...
# Root Mean Squared Error (RMSE): 0.7819572118748224
# Root Mean Squared Logarithmic Error (RMSLE): 0.4198079518291146
#
# Training model for store 9 and family 2...
# Root Mean Squared Error (RMSE): 5.9907374009080545
# Root Mean Squared Logarithmic Error (RMSLE): 0.6286991655130261
#
# Training model for store 9 and family 3...
# Root Mean Squared Error (RMSE): 1643.6522965131626
# Root Mean Squared Logarithmic Error (RMSLE): 0.5831625915612085
#
# Training model for store 9 and family 4...
# Root Mean Squared Error (RMSE): 1.669548658199223e-16
# Root Mean Squared Logarithmic Error (RMSLE): 1.6695486581992227e-16
#
# Training model for store 9 and family 5...
# Root Mean Squared Error (RMSE): 181.60959516230898
# Root Mean Squared Logarithmic Error (RMSLE): 0.44459455462790753
#
# Training model for store 9 and family 6...
# Root Mean Squared Error (RMSE): 13.279780556414412
# Root Mean Squared Logarithmic Error (RMSLE): 0.7925441805605209
#
# Training model for store 9 and family 7...
# Root Mean Squared Error (RMSE): 725.3444383600377
# Root Mean Squared Logarithmic Error (RMSLE): 0.5416773744665384
#
# Training model for store 9 and family 8...
# Root Mean Squared Error (RMSE): 371.55603805531945
# Root Mean Squared Logarithmic Error (RMSLE): 0.50920842567674
#
# Training model for store 9 and family 9...
# Root Mean Squared Error (RMSE): 194.00893317239633
# Root Mean Squared Logarithmic Error (RMSLE): 0.46316621270479913
#
# Training model for store 9 and family 10...
# Root Mean Squared Error (RMSE): 107.47776918068854
# Root Mean Squared Logarithmic Error (RMSLE): 0.5662603176089778
#
# Training model for store 9 and family 11...
# Root Mean Squared Error (RMSE): 265.4601991019326
# Root Mean Squared Logarithmic Error (RMSLE): 0.7407002262337519
#
# Training model for store 9 and family 12...
# Root Mean Squared Error (RMSE): 3401.665646035544
# Root Mean Squared Logarithmic Error (RMSLE): 0.6105487642213998
#
# Training model for store 9 and family 13...
# Root Mean Squared Error (RMSE): 10.391739069095824
# Root Mean Squared Logarithmic Error (RMSLE): 0.8782850811302954
#
# Training model for store 9 and family 14...
# Root Mean Squared Error (RMSE): 1.5135758215954964
# Root Mean Squared Logarithmic Error (RMSLE): 0.6616859985298033
#
# Training model for store 9 and family 15...
# Root Mean Squared Error (RMSE): 85.3767250836751
# Root Mean Squared Logarithmic Error (RMSLE): 0.8781237637742368
#
# Training model for store 9 and family 16...
# Root Mean Squared Error (RMSE): 26.823682769963874
# Root Mean Squared Logarithmic Error (RMSLE): 0.8145920736181498
#
# Training model for store 9 and family 17...
# Root Mean Squared Error (RMSE): 0.4037620695530676
# Root Mean Squared Logarithmic Error (RMSLE): 0.2895402139049762
#
# Training model for store 9 and family 18...
# Root Mean Squared Error (RMSE): 436.3889521108825
# Root Mean Squared Logarithmic Error (RMSLE): 3.745136329754628
#
# Training model for store 9 and family 19...
# Root Mean Squared Error (RMSE): 10.855841120597473
# Root Mean Squared Logarithmic Error (RMSLE): 0.6506308670115185
#
# Training model for store 9 and family 20...
# Root Mean Squared Error (RMSE): 10.908332239799744
# Root Mean Squared Logarithmic Error (RMSLE): 0.7148283921886052
#
# Training model for store 9 and family 21...
# Root Mean Squared Error (RMSE): 5.159207422055424
# Root Mean Squared Logarithmic Error (RMSLE): 0.7456809497450914
#
# Training model for store 9 and family 22...
# Root Mean Squared Error (RMSE): 60.95311167719699
# Root Mean Squared Logarithmic Error (RMSLE): 1.0939826444271559
#
# Training model for store 9 and family 23...
# Root Mean Squared Error (RMSE): 3.206771582038049
# Root Mean Squared Logarithmic Error (RMSLE): 0.6335407162570897
#
# Training model for store 9 and family 24...
# Root Mean Squared Error (RMSE): 117.49181021088773
# Root Mean Squared Logarithmic Error (RMSLE): 0.43366120670702335
#
# Training model for store 9 and family 25...
# Root Mean Squared Error (RMSE): 235.64314751271598
# Root Mean Squared Logarithmic Error (RMSLE): 0.5663905228179685
#
# Training model for store 9 and family 26...
# Root Mean Squared Error (RMSE): 3.986206602305707
# Root Mean Squared Logarithmic Error (RMSLE): 0.4901164052106733
#
# Training model for store 9 and family 27...
# Root Mean Squared Error (RMSE): 7.4224523503452176
# Root Mean Squared Logarithmic Error (RMSLE): 0.5355938524833057
#
# Training model for store 9 and family 28...
# Root Mean Squared Error (RMSE): 205.73797089479515
# Root Mean Squared Logarithmic Error (RMSLE): 0.5185265614884672
#
# Training model for store 9 and family 29...
# Root Mean Squared Error (RMSE): 55.60111731350917
# Root Mean Squared Logarithmic Error (RMSLE): 0.550388436320355
#
# Training model for store 9 and family 30...
# Root Mean Squared Error (RMSE): 643.2245915152112
# Root Mean Squared Logarithmic Error (RMSLE): 0.5434391512493995
#
# Training model for store 9 and family 31...
# Root Mean Squared Error (RMSE): 32.82803710735294
# Root Mean Squared Logarithmic Error (RMSLE): 1.1980033179181433
#
# Training model for store 9 and family 32...
# Root Mean Squared Error (RMSE): 10.56648967152894
# Root Mean Squared Logarithmic Error (RMSLE): 0.6477736248476206

# %%
avg_rmse = total_rmse / num_models
avg_rmsle = total_rmsle / num_models

# %%
print(f"Average Root Mean Squared Error (RMSE) across all models: {avg_rmse}")
print(f"Average Root Mean Squared Logarithmic Error (RMSLE) across all models: {avg_rmsle}")
# Out:
# Average Root Mean Squared Error (RMSE) across all models: 108.59499935747574
# Average Root Mean Squared Logarithmic Error (RMSLE) across all models: 0.3919412718284703
