# %%
import pandas as pd
import numpy as np
from darts import TimeSeries
from darts.models import XGBModel
from sklearn.metrics import mean_squared_error, mean_squared_log_error

# %%
df = pd.read_csv("../../Data/Kaggle/StoreSales/train_darts.csv", parse_dates=["date"])

# %%
df.head()
# Out:
#         date  store_nbr  family  sales  onpromotion  typeholiday  dcoilwtico  \
# 0 2013-01-01          1       0    0.0            0            3       93.14
# 1 2013-01-01          1       1    0.0            0            3       93.14
# 2 2013-01-01          1       2    0.0            0            3       93.14
# 3 2013-01-01          1       3    0.0            0            3       93.14
# 4 2013-01-01          1       4    0.0            0            3       93.14
#
#    city  state  typestores  cluster  day_of_week  day  month  year
# 0    18     12           3       13            2    1      1  2013
# 1    18     12           3       13            2    1      1  2013
# 2    18     12           3       13            2    1      1  2013
# 3    18     12           3       13            2    1      1  2013
# 4    18     12           3       13            2    1      1  2013

# %%
unique_combinations = df[['store_nbr', 'family']].drop_duplicates()

# %%
total_rmse = 0
total_rmsle = 0
num_models = 0

# %%
trained_models = {}

# %%
included_stores = {5, 8, 16, 19, 22, 25, 33, 37, 41, 47, 51}
excluded_families = {1, 4, 14, 17, 19, 20, 31}

# %%
for index, row in unique_combinations.iterrows():
    store_nbr = row['store_nbr']
    family = row['family']
    
    if store_nbr in included_stores and family not in excluded_families:

        print(f"\nTraining model for store {store_nbr} and family {family}...")

        df_subset = df[(df['store_nbr'] == store_nbr) & (df['family'] == family)]

        ts = TimeSeries.from_dataframe(df_subset, value_cols=["sales"])

        training_size = int(len(ts) - 30)

        train = ts[:training_size]
        val = ts[training_size:]

        model = XGBModel(lags=2)
        model.fit(train)

        trained_models[(store_nbr, family)] = model

        predictions = model.predict(n=len(val))

        val = val.pd_series().tolist()
        predictions = predictions.pd_series().tolist()

        predictions = np.maximum(predictions, 0)

        rmse = np.sqrt(mean_squared_error(val, predictions))
        rmsle = np.sqrt(mean_squared_error(np.log1p(val), np.log1p(predictions)))

        total_rmse += rmse
        total_rmsle += rmsle
        num_models += 1
        
        model.save(f"SavedModels/XGBoost/XGB_S{store_nbr}P{family}.pkl")

        print(f"Root Mean Squared Error (RMSE): {rmse}")
        print(f"Root Mean Squared Logarithmic Error (RMSLE): {rmsle}")
# Out:
# Training model for store 16 and family 0...
# Root Mean Squared Error (RMSE): 3.043767365201265
# Root Mean Squared Logarithmic Error (RMSLE): 0.6141556098924779
#
# Training model for store 16 and family 2...
# Root Mean Squared Error (RMSE): 1.9985477827396958
# Root Mean Squared Logarithmic Error (RMSLE): 0.7294992285096012
#
# Training model for store 16 and family 3...
# Root Mean Squared Error (RMSE): 415.9741894788598
# Root Mean Squared Logarithmic Error (RMSLE): 0.3041269544067559
#
# Training model for store 16 and family 5...
# Root Mean Squared Error (RMSE): 56.4582044841987
# Root Mean Squared Logarithmic Error (RMSLE): 0.3670454769742482
#
# Training model for store 16 and family 6...
# Root Mean Squared Error (RMSE): 4.219543669773333
# Root Mean Squared Logarithmic Error (RMSLE): 0.7777147908764733
#
# Training model for store 16 and family 7...
# Root Mean Squared Error (RMSE): 584.7808738622896
# Root Mean Squared Logarithmic Error (RMSLE): 0.5391219139495663
#
# Training model for store 16 and family 8...
# Root Mean Squared Error (RMSE): 78.42901199866799
# Root Mean Squared Logarithmic Error (RMSLE): 0.28071801625870685
#
# Training model for store 16 and family 9...
# Root Mean Squared Error (RMSE): 60.67104517164013
# Root Mean Squared Logarithmic Error (RMSLE): 0.32981320631981
#
# Training model for store 16 and family 10...
# Root Mean Squared Error (RMSE): 124.21174350175136
# Root Mean Squared Logarithmic Error (RMSLE): 0.6790369138081885
#
# Training model for store 16 and family 11...
# Root Mean Squared Error (RMSE): 23.458870498219817
# Root Mean Squared Logarithmic Error (RMSLE): 0.564653216584659
#
# Training model for store 16 and family 12...
# Root Mean Squared Error (RMSE): 989.3424926449553
# Root Mean Squared Logarithmic Error (RMSLE): 0.40510098424816704
#
# Training model for store 16 and family 13...
# Root Mean Squared Error (RMSE): 4.105560442613007
# Root Mean Squared Logarithmic Error (RMSLE): 0.7427845881496757
#
# Training model for store 16 and family 15...
# Root Mean Squared Error (RMSE): 10.337323930595664
# Root Mean Squared Logarithmic Error (RMSLE): 0.7994102711170954
#
# Training model for store 16 and family 16...
# Root Mean Squared Error (RMSE): 7.550322234952298
# Root Mean Squared Logarithmic Error (RMSLE): 0.5237422650668824
#
# Training model for store 16 and family 18...
# Root Mean Squared Error (RMSE): 58.020814486753295
# Root Mean Squared Logarithmic Error (RMSLE): 0.33492571111240677
#
# Training model for store 16 and family 21...
# Root Mean Squared Error (RMSE): 2.5193806293502843
# Root Mean Squared Logarithmic Error (RMSLE): 0.7590397085943559
#
# Training model for store 16 and family 22...
# Root Mean Squared Error (RMSE): 38.609215478725815
# Root Mean Squared Logarithmic Error (RMSLE): 1.1779860676176315
#
# Training model for store 16 and family 23...
# Root Mean Squared Error (RMSE): 1.4592047881821752
# Root Mean Squared Logarithmic Error (RMSLE): 0.5463986150321045
#
# Training model for store 16 and family 24...
# Root Mean Squared Error (RMSE): 32.448860365885736
# Root Mean Squared Logarithmic Error (RMSLE): 0.4891881659815843
#
# Training model for store 16 and family 25...
# Root Mean Squared Error (RMSE): 88.1606276956781
# Root Mean Squared Logarithmic Error (RMSLE): 0.5112212139187667
#
# Training model for store 16 and family 26...
# Root Mean Squared Error (RMSE): 1.102333838351895
# Root Mean Squared Logarithmic Error (RMSLE): 0.5671215854096204
#
# Training model for store 16 and family 27...
# Root Mean Squared Error (RMSE): 2.5246017546146144
# Root Mean Squared Logarithmic Error (RMSLE): 0.6821332395575185
#
# Training model for store 16 and family 28...
# Root Mean Squared Error (RMSE): 45.574241807181245
# Root Mean Squared Logarithmic Error (RMSLE): 0.5544935539827827
#
# Training model for store 16 and family 29...
# Root Mean Squared Error (RMSE): 12.73967203860795
# Root Mean Squared Logarithmic Error (RMSLE): 0.3626539975587803
#
# Training model for store 16 and family 30...
# Root Mean Squared Error (RMSE): 235.21703891080503
# Root Mean Squared Logarithmic Error (RMSLE): 0.3944463194099123
#
# Training model for store 16 and family 32...
# Root Mean Squared Error (RMSE): 2.581294857639768
# Root Mean Squared Logarithmic Error (RMSLE): 1.0361195580730993
#
# Training model for store 19 and family 0...
# Root Mean Squared Error (RMSE): 3.278955077570334
# Root Mean Squared Logarithmic Error (RMSLE): 0.5499832530279718
#
# Training model for store 19 and family 2...
# Root Mean Squared Error (RMSE): 3.0504819452975163
# Root Mean Squared Logarithmic Error (RMSLE): 0.6859264284368616
#
# Training model for store 19 and family 3...
# Root Mean Squared Error (RMSE): 680.2756142616709
# Root Mean Squared Logarithmic Error (RMSLE): 0.24470009599413325
#
# Training model for store 19 and family 5...
# Root Mean Squared Error (RMSE): 65.2085081697528
# Root Mean Squared Logarithmic Error (RMSLE): 0.34822982485445425
#
# Training model for store 19 and family 6...
# Root Mean Squared Error (RMSE): 5.531275695223658
# Root Mean Squared Logarithmic Error (RMSLE): 0.900048876613088
#
# Training model for store 19 and family 7...
# Root Mean Squared Error (RMSE): 414.1421172101653
# Root Mean Squared Logarithmic Error (RMSLE): 0.37942607667521966
#
# Training model for store 19 and family 8...
# Root Mean Squared Error (RMSE): 101.96215167812478
# Root Mean Squared Logarithmic Error (RMSLE): 0.2793965131227233
#
# Training model for store 19 and family 9...
# Root Mean Squared Error (RMSE): 91.39865248024448
# Root Mean Squared Logarithmic Error (RMSLE): 0.31595110586173436
#
# Training model for store 19 and family 10...
# Root Mean Squared Error (RMSE): 31.73746356109123
# Root Mean Squared Logarithmic Error (RMSLE): 0.5235041548413393
#
# Training model for store 19 and family 11...
# Root Mean Squared Error (RMSE): 19.368650288618326
# Root Mean Squared Logarithmic Error (RMSLE): 0.41977954723672595
#
# Training model for store 19 and family 12...
# Root Mean Squared Error (RMSE): 932.7910687279576
# Root Mean Squared Logarithmic Error (RMSLE): 0.25496682922113634
#
# Training model for store 19 and family 13...
# Root Mean Squared Error (RMSE): 52.72924710288362
# Root Mean Squared Logarithmic Error (RMSLE): 1.5279123040201588
#
# Training model for store 19 and family 15...
# Root Mean Squared Error (RMSE): 10.735055434974411
# Root Mean Squared Logarithmic Error (RMSLE): 0.6303632904046818
#
# Training model for store 19 and family 16...
# Root Mean Squared Error (RMSE): 22.443608889670124
# Root Mean Squared Logarithmic Error (RMSLE): 0.6859727240289827
#
# Training model for store 19 and family 18...
# Root Mean Squared Error (RMSE): 82.78635711320682
# Root Mean Squared Logarithmic Error (RMSLE): 0.41610678453804445
#
# Training model for store 19 and family 21...
# Root Mean Squared Error (RMSE): 3.1177970005228186
# Root Mean Squared Logarithmic Error (RMSLE): 0.7218741000594239
#
# Training model for store 19 and family 22...
# Root Mean Squared Error (RMSE): 53.49583945328994
# Root Mean Squared Logarithmic Error (RMSLE): 1.2861481712284626
#
# Training model for store 19 and family 23...
# Root Mean Squared Error (RMSE): 2.389084130615463
# Root Mean Squared Logarithmic Error (RMSLE): 0.6054480982971018
#
# Training model for store 19 and family 24...
# Root Mean Squared Error (RMSE): 49.15358213488648
# Root Mean Squared Logarithmic Error (RMSLE): 0.2843588465587354
#
# Training model for store 19 and family 25...
# Root Mean Squared Error (RMSE): 76.17912375802258
# Root Mean Squared Logarithmic Error (RMSLE): 0.38548411790562503
#
# Training model for store 19 and family 26...
# Root Mean Squared Error (RMSE): 1.3498379875525741
# Root Mean Squared Logarithmic Error (RMSLE): 0.5807459637520026
#
# Training model for store 19 and family 27...
# Root Mean Squared Error (RMSE): 2.9944603586564447
# Root Mean Squared Logarithmic Error (RMSLE): 0.5843075006105075
#
# Training model for store 19 and family 28...
# Root Mean Squared Error (RMSE): 97.60998579477935
# Root Mean Squared Logarithmic Error (RMSLE): 0.6059767430760568
#
# Training model for store 19 and family 29...
# Root Mean Squared Error (RMSE): 10.375303452419276
# Root Mean Squared Logarithmic Error (RMSLE): 0.36326904502307344
#
# Training model for store 19 and family 30...
# Root Mean Squared Error (RMSE): 127.0375431343535
# Root Mean Squared Logarithmic Error (RMSLE): 0.27937887410686313
#
# Training model for store 19 and family 32...
# Root Mean Squared Error (RMSE): 3.223047415847402
# Root Mean Squared Logarithmic Error (RMSLE): 0.6581164072557033
#
# Training model for store 22 and family 0...
# Root Mean Squared Error (RMSE): 2.814389076473508
# Root Mean Squared Logarithmic Error (RMSLE): 0.5817587614569306
#
# Training model for store 22 and family 2...
# Root Mean Squared Error (RMSE): 2.408043894138404
# Root Mean Squared Logarithmic Error (RMSLE): 0.6738625734415964
#
# Training model for store 22 and family 3...
# Root Mean Squared Error (RMSE): 624.736437631878
# Root Mean Squared Logarithmic Error (RMSLE): 0.41280239727836415
#
# Training model for store 22 and family 5...
# Root Mean Squared Error (RMSE): 65.3474530620624
# Root Mean Squared Logarithmic Error (RMSLE): 0.3747250581879677
#
# Training model for store 22 and family 6...
# Root Mean Squared Error (RMSE): 10.063357534158538
# Root Mean Squared Logarithmic Error (RMSLE): 0.7938381244393927
#
# Training model for store 22 and family 7...
# Root Mean Squared Error (RMSE): 371.31427830788493
# Root Mean Squared Logarithmic Error (RMSLE): 0.4409388734877543
#
# Training model for store 22 and family 8...
# Root Mean Squared Error (RMSE): 77.25717363541864
# Root Mean Squared Logarithmic Error (RMSLE): 0.2681380331174334
#
# Training model for store 22 and family 9...
# Root Mean Squared Error (RMSE): 38.14237060464998
# Root Mean Squared Logarithmic Error (RMSLE): 0.2437169512000763
#
# Training model for store 22 and family 10...
# Root Mean Squared Error (RMSE): 35.334140176172966
# Root Mean Squared Logarithmic Error (RMSLE): 0.6025480485609939
#
# Training model for store 22 and family 11...
# Root Mean Squared Error (RMSE): 317.4813183150277
# Root Mean Squared Logarithmic Error (RMSLE): 1.1622514372356205
#
# Training model for store 22 and family 12...
# Root Mean Squared Error (RMSE): 844.1793920701269
# Root Mean Squared Logarithmic Error (RMSLE): 0.3655263816435677
#
# Training model for store 22 and family 13...
# Root Mean Squared Error (RMSE): 13.240555662281013
# Root Mean Squared Logarithmic Error (RMSLE): 1.0597479966961132
#
# Training model for store 22 and family 15...
# Root Mean Squared Error (RMSE): 27.409516213345427
# Root Mean Squared Logarithmic Error (RMSLE): 0.843784337495759
#
# Training model for store 22 and family 16...
# Root Mean Squared Error (RMSE): 8.322103987557963
# Root Mean Squared Logarithmic Error (RMSLE): 0.48237472770731893
#
# Training model for store 22 and family 18...
# Root Mean Squared Error (RMSE): 52.450607127016866
# Root Mean Squared Logarithmic Error (RMSLE): 0.3154279809712541
#
# Training model for store 22 and family 21...
# Root Mean Squared Error (RMSE): 3.5376405359125527
# Root Mean Squared Logarithmic Error (RMSLE): 0.7262851901258855
#
# Training model for store 22 and family 22...
# Root Mean Squared Error (RMSE): 154.25566641207683
# Root Mean Squared Logarithmic Error (RMSLE): 1.4751105172868066
#
# Training model for store 22 and family 23...
# Root Mean Squared Error (RMSE): 1.7177758777421617
# Root Mean Squared Logarithmic Error (RMSLE): 0.5456261273546226
#
# Training model for store 22 and family 24...
# Root Mean Squared Error (RMSE): 40.1433369749977
# Root Mean Squared Logarithmic Error (RMSLE): 0.4138840488252407
#
# Training model for store 22 and family 25...
# Root Mean Squared Error (RMSE): 53.40698511600889
# Root Mean Squared Logarithmic Error (RMSLE): 0.34861396227916924
#
# Training model for store 22 and family 26...
# Root Mean Squared Error (RMSE): 1.2502538292134011
# Root Mean Squared Logarithmic Error (RMSLE): 0.5646458383737626
#
# Training model for store 22 and family 27...
# Root Mean Squared Error (RMSE): 3.298913148288585
# Root Mean Squared Logarithmic Error (RMSLE): 0.4771521549986604
#
# Training model for store 22 and family 28...
# Root Mean Squared Error (RMSE): 77.47391397833286
# Root Mean Squared Logarithmic Error (RMSLE): 0.4627251312627752
#
# Training model for store 22 and family 29...
# Root Mean Squared Error (RMSE): 23.384624757720832
# Root Mean Squared Logarithmic Error (RMSLE): 0.6268168398744258
#
# Training model for store 22 and family 30...
# Root Mean Squared Error (RMSE): 255.3513905059018
# Root Mean Squared Logarithmic Error (RMSLE): 0.43015078677644136
#
# Training model for store 22 and family 32...
# Root Mean Squared Error (RMSE): 4.102790521311829
# Root Mean Squared Logarithmic Error (RMSLE): 0.8588344910415172
#
# Training model for store 25 and family 0...
# Root Mean Squared Error (RMSE): 2.7448487743350714
# Root Mean Squared Logarithmic Error (RMSLE): 0.7454578608667907
#
# Training model for store 25 and family 2...
# Root Mean Squared Error (RMSE): 2.616385160499093
# Root Mean Squared Logarithmic Error (RMSLE): 0.5701069974781773
#
# Training model for store 25 and family 3...
# Root Mean Squared Error (RMSE): 1255.679999817716
# Root Mean Squared Logarithmic Error (RMSLE): 0.4557474691850536
#
# Training model for store 25 and family 5...
# Root Mean Squared Error (RMSE): 176.11178048311956
# Root Mean Squared Logarithmic Error (RMSLE): 0.4306934588060204
#
# Training model for store 25 and family 6...
# Root Mean Squared Error (RMSE): 6.212423054919557
# Root Mean Squared Logarithmic Error (RMSLE): 0.5796062213170501
#
# Training model for store 25 and family 7...
# Root Mean Squared Error (RMSE): 194.84767227495004
# Root Mean Squared Logarithmic Error (RMSLE): 0.35275367955313225
#
# Training model for store 25 and family 8...
# Root Mean Squared Error (RMSE): 274.3309329023739
# Root Mean Squared Logarithmic Error (RMSLE): 0.381595610504199
#
# Training model for store 25 and family 9...
# Root Mean Squared Error (RMSE): 65.30322447043943
# Root Mean Squared Logarithmic Error (RMSLE): 0.4145598778839878
#
# Training model for store 25 and family 10...
# Root Mean Squared Error (RMSE): 78.66956216792165
# Root Mean Squared Logarithmic Error (RMSLE): 0.5265704002771744
#
# Training model for store 25 and family 11...
# Root Mean Squared Error (RMSE): 852.8892839544659
# Root Mean Squared Logarithmic Error (RMSLE): 2.034900301921633
#
# Training model for store 25 and family 12...
# Root Mean Squared Error (RMSE): 654.3088949326874
# Root Mean Squared Logarithmic Error (RMSLE): 0.26889725878792065
#
# Training model for store 25 and family 13...
# Root Mean Squared Error (RMSE): 19.95695679878295
# Root Mean Squared Logarithmic Error (RMSLE): 0.8135867690182279
#
# Training model for store 25 and family 15...
# Root Mean Squared Error (RMSE): 42.02726069456995
# Root Mean Squared Logarithmic Error (RMSLE): 1.3978293447519619
#
# Training model for store 25 and family 16...
# Root Mean Squared Error (RMSE): 14.587042089848037
# Root Mean Squared Logarithmic Error (RMSLE): 0.7198983600601736
#
# Training model for store 25 and family 18...
# Root Mean Squared Error (RMSE): 133.89893051983768
# Root Mean Squared Logarithmic Error (RMSLE): 0.7628055793725436
#
# Training model for store 25 and family 21...
# Root Mean Squared Error (RMSE): 4.877197844671167
# Root Mean Squared Logarithmic Error (RMSLE): 0.8715307060922035
#
# Training model for store 25 and family 22...
# Root Mean Squared Error (RMSE): 253.916620619762
# Root Mean Squared Logarithmic Error (RMSLE): 1.3941141823052206
#
# Training model for store 25 and family 23...
# Root Mean Squared Error (RMSE): 11.800895619444097
# Root Mean Squared Logarithmic Error (RMSLE): 0.9187428658858569
#
# Training model for store 25 and family 24...
# Root Mean Squared Error (RMSE): 102.75523082193574
# Root Mean Squared Logarithmic Error (RMSLE): 0.37168713311261786
#
# Training model for store 25 and family 25...
# Root Mean Squared Error (RMSE): 46.59249132521147
# Root Mean Squared Logarithmic Error (RMSLE): 0.38800900306696545
#
# Training model for store 25 and family 26...
# Root Mean Squared Error (RMSE): 3.2651592748468032
# Root Mean Squared Logarithmic Error (RMSLE): 0.4721868178113374
#
# Training model for store 25 and family 27...
# Root Mean Squared Error (RMSE): 5.663983448305225
# Root Mean Squared Logarithmic Error (RMSLE): 0.6361656209034509
#
# Training model for store 25 and family 28...
# Root Mean Squared Error (RMSE): 91.37783139380687
# Root Mean Squared Logarithmic Error (RMSLE): 0.4774152178422317
#
# Training model for store 25 and family 29...
# Root Mean Squared Error (RMSE): 18.29703985244875
# Root Mean Squared Logarithmic Error (RMSLE): 0.42759669880857515
#
# Training model for store 25 and family 30...
# Root Mean Squared Error (RMSE): 897.4296193005666
# Root Mean Squared Logarithmic Error (RMSLE): 0.4614096714497668
#
# Training model for store 25 and family 32...
# Root Mean Squared Error (RMSE): 5.204608634434563
# Root Mean Squared Logarithmic Error (RMSLE): 0.8398906345369138
#
# Training model for store 33 and family 0...
# Root Mean Squared Error (RMSE): 3.823081226919869
# Root Mean Squared Logarithmic Error (RMSLE): 0.4808003252300588
#
# Training model for store 33 and family 2...
# Root Mean Squared Error (RMSE): 2.499023913661877
# Root Mean Squared Logarithmic Error (RMSLE): 0.760353124708893
#
# Training model for store 33 and family 3...
# Root Mean Squared Error (RMSE): 1235.5889335398929
# Root Mean Squared Logarithmic Error (RMSLE): 0.4928594518650536
#
# Training model for store 33 and family 5...
# Root Mean Squared Error (RMSE): 67.06461393871979
# Root Mean Squared Logarithmic Error (RMSLE): 0.2831468929367099
#
# Training model for store 33 and family 6...
# Root Mean Squared Error (RMSE): 9.510353383255287
# Root Mean Squared Logarithmic Error (RMSLE): 0.8623494639720684
#
# Training model for store 33 and family 7...
# Root Mean Squared Error (RMSE): 297.5429624491121
# Root Mean Squared Logarithmic Error (RMSLE): 0.28497798605721947
#
# Training model for store 33 and family 8...
# Root Mean Squared Error (RMSE): 117.46910896220908
# Root Mean Squared Logarithmic Error (RMSLE): 0.28553764848705354
#
# Training model for store 33 and family 9...
# Root Mean Squared Error (RMSE): 47.23092422733807
# Root Mean Squared Logarithmic Error (RMSLE): 0.25360158237661135
#
# Training model for store 33 and family 10...
# Root Mean Squared Error (RMSE): 225.90685459383204
# Root Mean Squared Logarithmic Error (RMSLE): 0.7761084881486348
#
# Training model for store 33 and family 11...
# Root Mean Squared Error (RMSE): 54.37375797337288
# Root Mean Squared Logarithmic Error (RMSLE): 0.6623032913137752
#
# Training model for store 33 and family 12...
# Root Mean Squared Error (RMSE): 695.9244040536136
# Root Mean Squared Logarithmic Error (RMSLE): 0.22448716460177723
#
# Training model for store 33 and family 13...
# Root Mean Squared Error (RMSE): 3.467755586966389
# Root Mean Squared Logarithmic Error (RMSLE): 0.7156256181856738
#
# Training model for store 33 and family 15...
# Root Mean Squared Error (RMSE): 25.97305680712964
# Root Mean Squared Logarithmic Error (RMSLE): 0.6956583753555091
#
# Training model for store 33 and family 16...
# Root Mean Squared Error (RMSE): 11.897653712187664
# Root Mean Squared Logarithmic Error (RMSLE): 0.626567894698465
#
# Training model for store 33 and family 18...
# Root Mean Squared Error (RMSE): 128.07849805731604
# Root Mean Squared Logarithmic Error (RMSLE): 0.49493680005522184
#
# Training model for store 33 and family 21...
# Root Mean Squared Error (RMSE): 4.940233778287395
# Root Mean Squared Logarithmic Error (RMSLE): 0.3428913814981057
#
# Training model for store 33 and family 22...
# Root Mean Squared Error (RMSE): 378.6343990859319
# Root Mean Squared Logarithmic Error (RMSLE): 2.526911179958033
#
# Training model for store 33 and family 23...
# Root Mean Squared Error (RMSE): 1.2143655580226569
# Root Mean Squared Logarithmic Error (RMSLE): 0.5352443982266588
#
# Training model for store 33 and family 24...
# Root Mean Squared Error (RMSE): 82.20405682173194
# Root Mean Squared Logarithmic Error (RMSLE): 0.33327131360845763
#
# Training model for store 33 and family 25...
# Root Mean Squared Error (RMSE): 108.13946220913705
# Root Mean Squared Logarithmic Error (RMSLE): 0.42116638238227555
#
# Training model for store 33 and family 26...
# Root Mean Squared Error (RMSE): 1.7686612887227677
# Root Mean Squared Logarithmic Error (RMSLE): 0.5890923093341969
#
# Training model for store 33 and family 27...
# Root Mean Squared Error (RMSE): 2.4828023583609347
# Root Mean Squared Logarithmic Error (RMSLE): 0.5324468083876056
#
# Training model for store 33 and family 28...
# Root Mean Squared Error (RMSE): 80.30648154670055
# Root Mean Squared Logarithmic Error (RMSLE): 0.3647981234828744
#
# Training model for store 33 and family 29...
# Root Mean Squared Error (RMSE): 19.059546091257282
# Root Mean Squared Logarithmic Error (RMSLE): 0.7566060303223867
#
# Training model for store 33 and family 30...
# Root Mean Squared Error (RMSE): 636.3915309998946
# Root Mean Squared Logarithmic Error (RMSLE): 0.3975801393028384
#
# Training model for store 33 and family 32...
# Root Mean Squared Error (RMSE): 1.7777060612401645
# Root Mean Squared Logarithmic Error (RMSLE): 0.84205419203634
#
# Training model for store 37 and family 0...
# Root Mean Squared Error (RMSE): 3.2943072108390954
# Root Mean Squared Logarithmic Error (RMSLE): 0.691324077748022
#
# Training model for store 37 and family 2...
# Root Mean Squared Error (RMSE): 4.730680058361236
# Root Mean Squared Logarithmic Error (RMSLE): 0.5917784327164526
#
# Training model for store 37 and family 3...
# Root Mean Squared Error (RMSE): 1433.9137936406908
# Root Mean Squared Logarithmic Error (RMSLE): 0.719278111386079
#
# Training model for store 37 and family 5...
# Root Mean Squared Error (RMSE): 96.08335896223242
# Root Mean Squared Logarithmic Error (RMSLE): 0.20113208691151988
#
# Training model for store 37 and family 6...
# Root Mean Squared Error (RMSE): 7.743104554517484
# Root Mean Squared Logarithmic Error (RMSLE): 0.8535100319994722
#
# Training model for store 37 and family 7...
# Root Mean Squared Error (RMSE): 267.2050413447312
# Root Mean Squared Logarithmic Error (RMSLE): 0.3038217709387674
#
# Training model for store 37 and family 8...
# Root Mean Squared Error (RMSE): 183.99670310122045
# Root Mean Squared Logarithmic Error (RMSLE): 0.22163175499356158
#
# Training model for store 37 and family 9...
# Root Mean Squared Error (RMSE): 30.646424938155903
# Root Mean Squared Logarithmic Error (RMSLE): 0.19937550139294086
#
# Training model for store 37 and family 10...
# Root Mean Squared Error (RMSE): 35.44041826518845
# Root Mean Squared Logarithmic Error (RMSLE): 0.27388374957281864
#
# Training model for store 37 and family 11...
# Root Mean Squared Error (RMSE): 74.40689868594849
# Root Mean Squared Logarithmic Error (RMSLE): 0.5372430081180415
#
# Training model for store 37 and family 12...
# Root Mean Squared Error (RMSE): 758.5443328565144
# Root Mean Squared Logarithmic Error (RMSLE): 0.23498924610583663
#
# Training model for store 37 and family 13...
# Root Mean Squared Error (RMSE): 26.164947979679738
# Root Mean Squared Logarithmic Error (RMSLE): 0.4337364789810368
#
# Training model for store 37 and family 15...
# Root Mean Squared Error (RMSE): 21.843339728991204
# Root Mean Squared Logarithmic Error (RMSLE): 0.6139483452217378
#
# Training model for store 37 and family 16...
# Root Mean Squared Error (RMSE): 25.300082593120337
# Root Mean Squared Logarithmic Error (RMSLE): 0.6881959158092994
#
# Training model for store 37 and family 18...
# Root Mean Squared Error (RMSE): 54.41867434985878
# Root Mean Squared Logarithmic Error (RMSLE): 0.23211365727442815
#
# Training model for store 37 and family 21...
# Root Mean Squared Error (RMSE): 3.817405860413499
# Root Mean Squared Logarithmic Error (RMSLE): 1.1213156923098588
#
# Training model for store 37 and family 22...
# Root Mean Squared Error (RMSE): 47.12873793365846
# Root Mean Squared Logarithmic Error (RMSLE): 0.42752718052436495
#
# Training model for store 37 and family 23...
# Root Mean Squared Error (RMSE): 5.065402248233831
# Root Mean Squared Logarithmic Error (RMSLE): 0.5035521406980937
#
# Training model for store 37 and family 24...
# Root Mean Squared Error (RMSE): 87.86362616858985
# Root Mean Squared Logarithmic Error (RMSLE): 0.35276093240484074
#
# Training model for store 37 and family 25...
# Root Mean Squared Error (RMSE): 94.30260596412784
# Root Mean Squared Logarithmic Error (RMSLE): 0.311754216853302
#
# Training model for store 37 and family 26...
# Root Mean Squared Error (RMSE): 6.289015306054353
# Root Mean Squared Logarithmic Error (RMSLE): 0.3909254207742376
#
# Training model for store 37 and family 27...
# Root Mean Squared Error (RMSE): 6.235344079631619
# Root Mean Squared Logarithmic Error (RMSLE): 0.4237547440554002
#
# Training model for store 37 and family 28...
# Root Mean Squared Error (RMSE): 48.495833694729605
# Root Mean Squared Logarithmic Error (RMSLE): 0.1830175687538696
#
# Training model for store 37 and family 29...
# Root Mean Squared Error (RMSE): 70.59894010413296
# Root Mean Squared Logarithmic Error (RMSLE): 0.7396968905516395
#
# Training model for store 37 and family 30...
# Root Mean Squared Error (RMSE): 1564.3561159026435
# Root Mean Squared Logarithmic Error (RMSLE): 3.1293747902192623
#
# Training model for store 37 and family 32...
# Root Mean Squared Error (RMSE): 8.657362563594324
# Root Mean Squared Logarithmic Error (RMSLE): 0.5712135496607055
#
# Training model for store 41 and family 0...
# Root Mean Squared Error (RMSE): 4.5994324444199295
# Root Mean Squared Logarithmic Error (RMSLE): 0.568563306613783
#
# Training model for store 41 and family 2...
# Root Mean Squared Error (RMSE): 5.297498936690416
# Root Mean Squared Logarithmic Error (RMSLE): 0.6574085072040239
#
# Training model for store 41 and family 3...
# Root Mean Squared Error (RMSE): 1518.0366639952122
# Root Mean Squared Logarithmic Error (RMSLE): 0.5304666469239735
#
# Training model for store 41 and family 5...
# Root Mean Squared Error (RMSE): 138.1023449073862
# Root Mean Squared Logarithmic Error (RMSLE): 0.2599625509224407
#
# Training model for store 41 and family 6...
# Root Mean Squared Error (RMSE): 6.069878491621115
# Root Mean Squared Logarithmic Error (RMSLE): 0.5955555777741742
#
# Training model for store 41 and family 7...
# Root Mean Squared Error (RMSE): 640.6923697104708
# Root Mean Squared Logarithmic Error (RMSLE): 0.44531333961336284
#
# Training model for store 41 and family 8...
# Root Mean Squared Error (RMSE): 425.0063599187202
# Root Mean Squared Logarithmic Error (RMSLE): 0.8345756998377658
#
# Training model for store 41 and family 9...
# Root Mean Squared Error (RMSE): 64.63361848885704
# Root Mean Squared Logarithmic Error (RMSLE): 0.26644000013976454
#
# Training model for store 41 and family 10...
# Root Mean Squared Error (RMSE): 53.97792556620358
# Root Mean Squared Logarithmic Error (RMSLE): 0.3923570927733235
#
# Training model for store 41 and family 11...
# Root Mean Squared Error (RMSE): 65.89585040621934
# Root Mean Squared Logarithmic Error (RMSLE): 0.45520125404212125
#
# Training model for store 41 and family 12...
# Root Mean Squared Error (RMSE): 1575.5365121513028
# Root Mean Squared Logarithmic Error (RMSLE): 0.4060223197614
#
# Training model for store 41 and family 13...
# Root Mean Squared Error (RMSE): 42.540273119272904
# Root Mean Squared Logarithmic Error (RMSLE): 0.973030751774226
#
# Training model for store 41 and family 15...
# Root Mean Squared Error (RMSE): 12.148282842559828
# Root Mean Squared Logarithmic Error (RMSLE): 0.4600183656972975
#
# Training model for store 41 and family 16...
# Root Mean Squared Error (RMSE): 28.84378479512778
# Root Mean Squared Logarithmic Error (RMSLE): 0.635521851201794
#
# Training model for store 41 and family 18...
# Root Mean Squared Error (RMSE): 126.47474488731837
# Root Mean Squared Logarithmic Error (RMSLE): 0.46102841579168413
#
# Training model for store 41 and family 21...
# Root Mean Squared Error (RMSE): 4.873084972010126
# Root Mean Squared Logarithmic Error (RMSLE): 0.5739740921663468
#
# Training model for store 41 and family 22...
# Root Mean Squared Error (RMSE): 169.39640393594019
# Root Mean Squared Logarithmic Error (RMSLE): 1.4122741906618683
#
# Training model for store 41 and family 23...
# Root Mean Squared Error (RMSE): 7.361201406486618
# Root Mean Squared Logarithmic Error (RMSLE): 0.5385393143281076
#
# Training model for store 41 and family 24...
# Root Mean Squared Error (RMSE): 107.70654188871687
# Root Mean Squared Logarithmic Error (RMSLE): 0.45170619935148415
#
# Training model for store 41 and family 25...
# Root Mean Squared Error (RMSE): 389.6127997812582
# Root Mean Squared Logarithmic Error (RMSLE): 0.695976344247546
#
# Training model for store 41 and family 26...
# Root Mean Squared Error (RMSE): 7.576011081939979
# Root Mean Squared Logarithmic Error (RMSLE): 0.6086240093485596
#
# Training model for store 41 and family 27...
# Root Mean Squared Error (RMSE): 4.929929834930553
# Root Mean Squared Logarithmic Error (RMSLE): 0.5572417965434141
#
# Training model for store 41 and family 28...
# Root Mean Squared Error (RMSE): 54.5789996942019
# Root Mean Squared Logarithmic Error (RMSLE): 0.28332683970781425
#
# Training model for store 41 and family 29...
# Root Mean Squared Error (RMSE): 20.165184890720145
# Root Mean Squared Logarithmic Error (RMSLE): 0.3089336624890294
#
# Training model for store 41 and family 30...
# Root Mean Squared Error (RMSE): 495.34615611041664
# Root Mean Squared Logarithmic Error (RMSLE): 0.22929002710689028
#
# Training model for store 41 and family 32...
# Root Mean Squared Error (RMSE): 5.551918766476994
# Root Mean Squared Logarithmic Error (RMSLE): 0.7357106035646312
#
# Training model for store 47 and family 0...
# Root Mean Squared Error (RMSE): 7.02591958269562
# Root Mean Squared Logarithmic Error (RMSLE): 0.47372785570589726
#
# Training model for store 47 and family 2...
# Root Mean Squared Error (RMSE): 10.963456172693508
# Root Mean Squared Logarithmic Error (RMSLE): 0.5718382431436667
#
# Training model for store 47 and family 3...
# Root Mean Squared Error (RMSE): 2279.428815981442
# Root Mean Squared Logarithmic Error (RMSLE): 0.2318325644053998
#
# Training model for store 47 and family 5...
# Root Mean Squared Error (RMSE): 237.73721809873643
# Root Mean Squared Logarithmic Error (RMSLE): 0.20277399806929683
#
# Training model for store 47 and family 6...
# Root Mean Squared Error (RMSE): 14.316039061660334
# Root Mean Squared Logarithmic Error (RMSLE): 0.5309360459134639
#
# Training model for store 47 and family 7...
# Root Mean Squared Error (RMSE): 750.9238981780919
# Root Mean Squared Logarithmic Error (RMSLE): 0.3067717454412135
#
# Training model for store 47 and family 8...
# Root Mean Squared Error (RMSE): 558.0788119876747
# Root Mean Squared Logarithmic Error (RMSLE): 0.2497202170398156
#
# Training model for store 47 and family 9...
# Root Mean Squared Error (RMSE): 220.20840990877267
# Root Mean Squared Logarithmic Error (RMSLE): 0.3148984531443284
#
# Training model for store 47 and family 10...
# Root Mean Squared Error (RMSE): 97.65844316454033
# Root Mean Squared Logarithmic Error (RMSLE): 0.2539894990068987
#
# Training model for store 47 and family 11...
# Root Mean Squared Error (RMSE): 109.90330571673576
# Root Mean Squared Logarithmic Error (RMSLE): 0.3862696559977891
#
# Training model for store 47 and family 12...
# Root Mean Squared Error (RMSE): 2811.848459297784
# Root Mean Squared Logarithmic Error (RMSLE): 0.2785985003573729
#
# Training model for store 47 and family 13...
# Root Mean Squared Error (RMSE): 21.752607546845436
# Root Mean Squared Logarithmic Error (RMSLE): 0.3621453286333911
#
# Training model for store 47 and family 15...
# Root Mean Squared Error (RMSE): 41.91658578198192
# Root Mean Squared Logarithmic Error (RMSLE): 0.6159977615573833
#
# Training model for store 47 and family 16...
# Root Mean Squared Error (RMSE): 40.310762486555575
# Root Mean Squared Logarithmic Error (RMSLE): 0.4374557310033511
#
# Training model for store 47 and family 18...
# Root Mean Squared Error (RMSE): 253.26856043191856
# Root Mean Squared Logarithmic Error (RMSLE): 0.3511942025575523
#
# Training model for store 47 and family 21...
# Root Mean Squared Error (RMSE): 13.297190619771452
# Root Mean Squared Logarithmic Error (RMSLE): 0.8124952790108959
#
# Training model for store 47 and family 22...
# Root Mean Squared Error (RMSE): 127.03098547377844
# Root Mean Squared Logarithmic Error (RMSLE): 1.1619471445660094
#
# Training model for store 47 and family 23...
# Root Mean Squared Error (RMSE): 7.747424225847224
# Root Mean Squared Logarithmic Error (RMSLE): 0.5274312199854437
#
# Training model for store 47 and family 24...
# Root Mean Squared Error (RMSE): 387.87808249151476
# Root Mean Squared Logarithmic Error (RMSLE): 0.35128281674114653
#
# Training model for store 47 and family 25...
# Root Mean Squared Error (RMSE): 331.323628897911
# Root Mean Squared Logarithmic Error (RMSLE): 0.44905332009663346
#
# Training model for store 47 and family 26...
# Root Mean Squared Error (RMSE): 14.449038982385554
# Root Mean Squared Logarithmic Error (RMSLE): 0.5682530415442005
#
# Training model for store 47 and family 27...
# Root Mean Squared Error (RMSE): 18.091724592871607
# Root Mean Squared Logarithmic Error (RMSLE): 0.5440748368401912
#
# Training model for store 47 and family 28...
# Root Mean Squared Error (RMSE): 420.12397836310834
# Root Mean Squared Logarithmic Error (RMSLE): 0.3493489803219457
#
# Training model for store 47 and family 29...
# Root Mean Squared Error (RMSE): 100.00263521054703
# Root Mean Squared Logarithmic Error (RMSLE): 0.3873011455312163
#
# Training model for store 47 and family 30...
# Root Mean Squared Error (RMSE): 1581.976098871872
# Root Mean Squared Logarithmic Error (RMSLE): 0.2670988110291807
#
# Training model for store 47 and family 32...
# Root Mean Squared Error (RMSE): 29.896740616385124
# Root Mean Squared Logarithmic Error (RMSLE): 0.33657732648974703
#
# Training model for store 5 and family 0...
# Root Mean Squared Error (RMSE): 3.504671378313665
# Root Mean Squared Logarithmic Error (RMSLE): 0.47209842920459233
#
# Training model for store 5 and family 2...
# Root Mean Squared Error (RMSE): 4.282679722422121
# Root Mean Squared Logarithmic Error (RMSLE): 0.5349949076010221
#
# Training model for store 5 and family 3...
# Root Mean Squared Error (RMSE): 475.1533801378047
# Root Mean Squared Logarithmic Error (RMSLE): 0.23573663204065248
#
# Training model for store 5 and family 5...
# Root Mean Squared Error (RMSE): 60.10116607943898
# Root Mean Squared Logarithmic Error (RMSLE): 0.17234764868821326
#
# Training model for store 5 and family 6...
# Root Mean Squared Error (RMSE): 10.637500181156271
# Root Mean Squared Logarithmic Error (RMSLE): 0.42815552856256084
#
# Training model for store 5 and family 7...
# Root Mean Squared Error (RMSE): 225.64362736806132
# Root Mean Squared Logarithmic Error (RMSLE): 0.2535318283433147
#
# Training model for store 5 and family 8...
# Root Mean Squared Error (RMSE): 101.78662314607143
# Root Mean Squared Logarithmic Error (RMSLE): 0.1748993850472259
#
# Training model for store 5 and family 9...
# Root Mean Squared Error (RMSE): 45.53146630353598
# Root Mean Squared Logarithmic Error (RMSLE): 0.20230100388050984
#
# Training model for store 5 and family 10...
# Root Mean Squared Error (RMSE): 51.73093992856019
# Root Mean Squared Logarithmic Error (RMSLE): 0.4814092264049309
#
# Training model for store 5 and family 11...
# Root Mean Squared Error (RMSE): 377.5636666164663
# Root Mean Squared Logarithmic Error (RMSLE): 0.7524199630713434
#
# Training model for store 5 and family 12...
# Root Mean Squared Error (RMSE): 510.59178380616214
# Root Mean Squared Logarithmic Error (RMSLE): 0.17100243814563632
#
# Training model for store 5 and family 13...
# Root Mean Squared Error (RMSE): 67.73515605518055
# Root Mean Squared Logarithmic Error (RMSLE): 1.529917637581919
#
# Training model for store 5 and family 15...
# Root Mean Squared Error (RMSE): 11.886873568965363
# Root Mean Squared Logarithmic Error (RMSLE): 0.408368975290627
#
# Training model for store 5 and family 16...
# Root Mean Squared Error (RMSE): 7.891101024697799
# Root Mean Squared Logarithmic Error (RMSLE): 0.3415397289718022
#
# Training model for store 5 and family 18...
# Root Mean Squared Error (RMSE): 67.18641124017314
# Root Mean Squared Logarithmic Error (RMSLE): 0.275924031651676
#
# Training model for store 5 and family 21...
# Root Mean Squared Error (RMSE): 5.990789618060683
# Root Mean Squared Logarithmic Error (RMSLE): 0.516965188718334
#
# Training model for store 5 and family 22...
# Root Mean Squared Error (RMSE): 66.24265429097132
# Root Mean Squared Logarithmic Error (RMSLE): 1.2028060556540296
#
# Training model for store 5 and family 23...
# Root Mean Squared Error (RMSE): 4.265040007307774
# Root Mean Squared Logarithmic Error (RMSLE): 0.564514049918301
#
# Training model for store 5 and family 24...
# Root Mean Squared Error (RMSE): 84.27813935037103
# Root Mean Squared Logarithmic Error (RMSLE): 0.2919882713414858
#
# Training model for store 5 and family 25...
# Root Mean Squared Error (RMSE): 57.980610385243814
# Root Mean Squared Logarithmic Error (RMSLE): 0.22316226106120735
#
# Training model for store 5 and family 26...
# Root Mean Squared Error (RMSE): 2.081692544386377
# Root Mean Squared Logarithmic Error (RMSLE): 0.6112845972066048
#
# Training model for store 5 and family 27...
# Root Mean Squared Error (RMSE): 3.2038582809811813
# Root Mean Squared Logarithmic Error (RMSLE): 0.39695200226683075
#
# Training model for store 5 and family 28...
# Root Mean Squared Error (RMSE): 59.98697010121264
# Root Mean Squared Logarithmic Error (RMSLE): 0.26693401346629897
#
# Training model for store 5 and family 29...
# Root Mean Squared Error (RMSE): 27.02159044496439
# Root Mean Squared Logarithmic Error (RMSLE): 0.38569864176038304
#
# Training model for store 5 and family 30...
# Root Mean Squared Error (RMSE): 401.4544146668311
# Root Mean Squared Logarithmic Error (RMSLE): 0.2354576916178299
#
# Training model for store 5 and family 32...
# Root Mean Squared Error (RMSE): 6.066825537997716
# Root Mean Squared Logarithmic Error (RMSLE): 0.5316552430378475
#
# Training model for store 51 and family 0...
# Root Mean Squared Error (RMSE): 3.530068758515763
# Root Mean Squared Logarithmic Error (RMSLE): 0.3805367728711144
#
# Training model for store 51 and family 2...
# Root Mean Squared Error (RMSE): 3.327091686009701
# Root Mean Squared Logarithmic Error (RMSLE): 0.5306339368646419
#
# Training model for store 51 and family 3...
# Root Mean Squared Error (RMSE): 1461.5685829749468
# Root Mean Squared Logarithmic Error (RMSLE): 0.29970055449904376
#
# Training model for store 51 and family 5...
# Root Mean Squared Error (RMSE): 199.92954031132385
# Root Mean Squared Logarithmic Error (RMSLE): 0.2262148942646539
#
# Training model for store 51 and family 6...
# Root Mean Squared Error (RMSE): 9.760786447096123
# Root Mean Squared Logarithmic Error (RMSLE): 0.8308385284388301
#
# Training model for store 51 and family 7...
# Root Mean Squared Error (RMSE): 306.26943906690997
# Root Mean Squared Logarithmic Error (RMSLE): 0.222085172700973
#
# Training model for store 51 and family 8...
# Root Mean Squared Error (RMSE): 291.4044714341385
# Root Mean Squared Logarithmic Error (RMSLE): 0.1808610147561388
#
# Training model for store 51 and family 9...
# Root Mean Squared Error (RMSE): 79.80830614947115
# Root Mean Squared Logarithmic Error (RMSLE): 0.2983940842226833
#
# Training model for store 51 and family 10...
# Root Mean Squared Error (RMSE): 80.69270970335985
# Root Mean Squared Logarithmic Error (RMSLE): 0.23991025968384627
#
# Training model for store 51 and family 11...
# Root Mean Squared Error (RMSE): 97.8862949714598
# Root Mean Squared Logarithmic Error (RMSLE): 0.3511434096380819
#
# Training model for store 51 and family 12...
# Root Mean Squared Error (RMSE): 1142.049154126906
# Root Mean Squared Logarithmic Error (RMSLE): 0.219010153615069
#
# Training model for store 51 and family 13...
# Root Mean Squared Error (RMSE): 29.37871047394935
# Root Mean Squared Logarithmic Error (RMSLE): 0.6988006688362463
#
# Training model for store 51 and family 15...
# Root Mean Squared Error (RMSE): 35.345162860449456
# Root Mean Squared Logarithmic Error (RMSLE): 0.816683547311715
#
# Training model for store 51 and family 16...
# Root Mean Squared Error (RMSE): 79.65365452635425
# Root Mean Squared Logarithmic Error (RMSLE): 0.998171802789891
#
# Training model for store 51 and family 18...
# Root Mean Squared Error (RMSE): 110.05625479390606
# Root Mean Squared Logarithmic Error (RMSLE): 0.3636532917006854
#
# Training model for store 51 and family 21...
# Root Mean Squared Error (RMSE): 4.1705677938371695
# Root Mean Squared Logarithmic Error (RMSLE): 0.5422431853011535
#
# Training model for store 51 and family 22...
# Root Mean Squared Error (RMSE): 155.1388511370145
# Root Mean Squared Logarithmic Error (RMSLE): 0.8073644447163301
#
# Training model for store 51 and family 23...
# Root Mean Squared Error (RMSE): 5.471650436597635
# Root Mean Squared Logarithmic Error (RMSLE): 0.44401812699712107
#
# Training model for store 51 and family 24...
# Root Mean Squared Error (RMSE): 276.7481074990377
# Root Mean Squared Logarithmic Error (RMSLE): 0.3612471137578254
#
# Training model for store 51 and family 25...
# Root Mean Squared Error (RMSE): 101.27352685216937
# Root Mean Squared Logarithmic Error (RMSLE): 0.3215897056957168
#
# Training model for store 51 and family 26...
# Root Mean Squared Error (RMSE): 7.821260457759784
# Root Mean Squared Logarithmic Error (RMSLE): 0.3438223544251724
#
# Training model for store 51 and family 27...
# Root Mean Squared Error (RMSE): 5.568261638079257
# Root Mean Squared Logarithmic Error (RMSLE): 0.43804226006137503
#
# Training model for store 51 and family 28...
# Root Mean Squared Error (RMSE): 994.2601662520939
# Root Mean Squared Logarithmic Error (RMSLE): 0.6553309893975908
#
# Training model for store 51 and family 29...
# Root Mean Squared Error (RMSE): 69.02948670037028
# Root Mean Squared Logarithmic Error (RMSLE): 0.4568785260079995
#
# Training model for store 51 and family 30...
# Root Mean Squared Error (RMSE): 1979.900216985527
# Root Mean Squared Logarithmic Error (RMSLE): 0.34529567153984947
#
# Training model for store 51 and family 32...
# Root Mean Squared Error (RMSE): 19.43580501642087
# Root Mean Squared Logarithmic Error (RMSLE): 0.3861846460670256
#
# Training model for store 8 and family 0...
# Root Mean Squared Error (RMSE): 4.070409796162657
# Root Mean Squared Logarithmic Error (RMSLE): 0.7138259315113942
#
# Training model for store 8 and family 2...
# Root Mean Squared Error (RMSE): 6.374289462520198
# Root Mean Squared Logarithmic Error (RMSLE): 0.56619899422313
#
# Training model for store 8 and family 3...
# Root Mean Squared Error (RMSE): 1185.172978480327
# Root Mean Squared Logarithmic Error (RMSLE): 0.24813890504734842
#
# Training model for store 8 and family 5...
# Root Mean Squared Error (RMSE): 163.9231147024811
# Root Mean Squared Logarithmic Error (RMSLE): 0.1874814777758237
#
# Training model for store 8 and family 6...
# Root Mean Squared Error (RMSE): 10.056885207904541
# Root Mean Squared Logarithmic Error (RMSLE): 0.4508121581552943
#
# Training model for store 8 and family 7...
# Root Mean Squared Error (RMSE): 275.0932526821815
# Root Mean Squared Logarithmic Error (RMSLE): 0.22471343259099893
#
# Training model for store 8 and family 8...
# Root Mean Squared Error (RMSE): 334.52827589247136
# Root Mean Squared Logarithmic Error (RMSLE): 0.2305092008529035
#
# Training model for store 8 and family 9...
# Root Mean Squared Error (RMSE): 58.372499532656214
# Root Mean Squared Logarithmic Error (RMSLE): 0.19790161671954554
#
# Training model for store 8 and family 10...
# Root Mean Squared Error (RMSE): 100.45509574790665
# Root Mean Squared Logarithmic Error (RMSLE): 0.29873204583057383
#
# Training model for store 8 and family 11...
# Root Mean Squared Error (RMSE): 52.99226327863759
# Root Mean Squared Logarithmic Error (RMSLE): 0.30825597302324326
#
# Training model for store 8 and family 12...
# Root Mean Squared Error (RMSE): 1174.144621273515
# Root Mean Squared Logarithmic Error (RMSLE): 0.24894621713933912
#
# Training model for store 8 and family 13...
# Root Mean Squared Error (RMSE): 14.01847667144476
# Root Mean Squared Logarithmic Error (RMSLE): 0.36712687127995913
#
# Training model for store 8 and family 15...
# Root Mean Squared Error (RMSE): 25.35559130398787
# Root Mean Squared Logarithmic Error (RMSLE): 0.5405691100108486
#
# Training model for store 8 and family 16...
# Root Mean Squared Error (RMSE): 50.760877833339514
# Root Mean Squared Logarithmic Error (RMSLE): 0.5087405548175886
#
# Training model for store 8 and family 18...
# Root Mean Squared Error (RMSE): 83.42099468673766
# Root Mean Squared Logarithmic Error (RMSLE): 0.23101442468655417
#
# Training model for store 8 and family 21...
# Root Mean Squared Error (RMSE): 11.18428738067642
# Root Mean Squared Logarithmic Error (RMSLE): 0.4982407312495091
#
# Training model for store 8 and family 22...
# Root Mean Squared Error (RMSE): 91.22991783919416
# Root Mean Squared Logarithmic Error (RMSLE): 0.6134380600254118
#
# Training model for store 8 and family 23...
# Root Mean Squared Error (RMSE): 10.470116609010086
# Root Mean Squared Logarithmic Error (RMSLE): 0.5416235442843802
#
# Training model for store 8 and family 24...
# Root Mean Squared Error (RMSE): 228.45005060179815
# Root Mean Squared Logarithmic Error (RMSLE): 0.3989768287565148
#
# Training model for store 8 and family 25...
# Root Mean Squared Error (RMSE): 89.02600133084803
# Root Mean Squared Logarithmic Error (RMSLE): 0.24891433774501948
#
# Training model for store 8 and family 26...
# Root Mean Squared Error (RMSE): 10.933483849020842
# Root Mean Squared Logarithmic Error (RMSLE): 0.5197992403001763
#
# Training model for store 8 and family 27...
# Root Mean Squared Error (RMSE): 7.53756883965311
# Root Mean Squared Logarithmic Error (RMSLE): 0.38363828967171515
#
# Training model for store 8 and family 28...
# Root Mean Squared Error (RMSE): 200.21438709196553
# Root Mean Squared Logarithmic Error (RMSLE): 0.31412716184023814
#
# Training model for store 8 and family 29...
# Root Mean Squared Error (RMSE): 83.68980679603752
# Root Mean Squared Logarithmic Error (RMSLE): 0.46177071460061736
#
# Training model for store 8 and family 30...
# Root Mean Squared Error (RMSE): 1530.521943964539
# Root Mean Squared Logarithmic Error (RMSLE): 0.3145212163049629
#
# Training model for store 8 and family 32...
# Root Mean Squared Error (RMSE): 22.538404774057987
# Root Mean Squared Logarithmic Error (RMSLE): 0.4956788164687685

# %%
avg_rmse = total_rmse / num_models
avg_rmsle = total_rmsle / num_models

# %%
print(f"Average Root Mean Squared Error (RMSE) across all models: {avg_rmse}")
print(f"Average Root Mean Squared Logarithmic Error (RMSLE) across all models: {avg_rmsle}")
# Out:
# Average Root Mean Squared Error (RMSE) across all models: 195.59242160391832
# Average Root Mean Squared Logarithmic Error (RMSLE) across all models: 0.5333629225864212
